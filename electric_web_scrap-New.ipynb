# %% [markdown]
# ## 기상 스크래핑!

# %%
# 화면 가로 확장 코드
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
# 데이터 저장을 위한 csv 
import csv
# Selenium : 
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys

path = "C:/Users/82108/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)

# 기상포털 주소 1차 접속. 데이터가 충분히 표시된 2021년 1월 1일을 시작 화면으로 설정
driver.get('https://www.wunderground.com/history/daily/gb/london/EGLC/date/2021-1-1')

# YYYY
y = 2012
while(y<2016):
    y=y+1
    print('<<',y,'년','>>')
    
    # MM
    m = 0
    while(m<12):
        m=m+1
        print('<',m,'월','>')
        
        # DD
        # 01
        if(m==1):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                driver.get('https://www.wunderground.com/history/daily/gb/london/EGLC/date/'+str(y)+'-'+str(m)+'-'+str(d))
                h = 0
                while(h<48):
                    h=h+1
                    clk = driver.find_element(By.XPATH,'//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr['+str(h)+']/td[1]/span')
                    clk_str =clk.text
                    clk_list = clk_str.split()
                    clk_list.append('temp here')
                    time.sleep(0.01)
                    print(clk_list) # 확인용 print
                print()
                time.sleep(1)
                break
                
        # 02
        if(m==2):
            d=0
            while(d<28):
                d=d+1
                print(d,'일')
                
        # 03
        if(m==3):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                
        # 04
        if(m==4):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
                
        # 05
        if(m==5):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                
        # 06
        if(m==6):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
                
        # 07
        if(m==7):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                
        # 08
        if(m==8):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                
        # 09
        if(m==9):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
                
        # 10
        if(m==10):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                
        # 11
        if(m==11):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
                      
        # 12
        if(m==12):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
                      
        print()
    print('\n')
    break # 여기서 13년도까지 하고  멈추는걸 보니 1년 단위는 여기서 걸리는 걸 알 수 있음.
# Out:
# <ipython-input-19-eb0e3cc9b330>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# << 2013 년 >>
# < 1 월 >
# 1 일
# ['11:50', 'PM', 'temp here']
# ['12:20', 'AM', 'temp here']
# ['12:50', 'AM', 'temp here']
# ['1:20', 'AM', 'temp here']
# ['1:50', 'AM', 'temp here']
# ['2:20', 'AM', 'temp here']
# ['2:50', 'AM', 'temp here']
# ['3:20', 'AM', 'temp here']
# ['3:50', 'AM', 'temp here']
# ['4:20', 'AM', 'temp here']
# ['4:50', 'AM', 'temp here']
# ['5:20', 'AM', 'temp here']
# ['5:50', 'AM', 'temp here']
# ['6:20', 'AM', 'temp here']
# ['6:50', 'AM', 'temp here']
# ['7:20', 'AM', 'temp here']
# ['7:50', 'AM', 'temp here']
# ['8:20', 'AM', 'temp here']
# ['8:50', 'AM', 'temp here']
# ['9:20', 'AM', 'temp here']
# ['9:50', 'AM', 'temp here']
# ['10:20', 'AM', 'temp here']
# ['10:50', 'AM', 'temp here']
# ['11:20', 'AM', 'temp here']
# ['11:50', 'AM', 'temp here']
# ['12:20', 'PM', 'temp here']
# ['12:50', 'PM', 'temp here']
# ['1:20', 'PM', 'temp here']
# ['1:50', 'PM', 'temp here']
# ['2:20', 'PM', 'temp here']
# ['2:50', 'PM', 'temp here']
# ['3:20', 'PM', 'temp here']
# ['3:50', 'PM', 'temp here']
# ['4:20', 'PM', 'temp here']
# ['4:50', 'PM', 'temp here']
# ['5:20', 'PM', 'temp here']
# ['5:50', 'PM', 'temp here']
# ['6:20', 'PM', 'temp here']
# ['6:50', 'PM', 'temp here']
# ['7:20', 'PM', 'temp here']
# ['7:50', 'PM', 'temp here']
# ['8:20', 'PM', 'temp here']
# ['8:50', 'PM', 'temp here']
# ['9:20', 'PM', 'temp here']
# ['9:50', 'PM', 'temp here']
# ['10:20', 'PM', 'temp here']
# ['10:50', 'PM', 'temp here']
# ['11:20', 'PM', 'temp here']
#
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 6 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 7 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 8 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 9 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 10 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 11 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 12 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일

# %%
    # 해당 월 클릭 (2013년 1월부터 2016년12월에 해당되는 110~63 선택)
    m = 111
    while(m > 61):
        m = m-1
        # 연도와 월 선택창 클릭
        driver.find_element(By.XPATH, '//*[@id="month"]/option[' + str(m) + ']').click()
        
        # 달마다 구성일수가 다르기 때문에 반복일자 구별을 위해 월 출력
        month = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
        month_str = month.text
        month_list = month_str.split()
        month_5 = month_list[5]
        time.sleep(5)
        
        """
        각 달마다 날짜, 온도 표기는 동일한 과정이라 함수로 처리할려 했으나, 연도의 마지막에 모아서 
        저장하려면 각 달마다 리스트 저장 이름을 다르게 해서 마지막에 통합 저장해야 함.
        """
        
        # -----------------------------------------< 01 >-----------------------------------------------
        if (month_5 == 'January'):
            print('1월')
            # 1일~31일 크롤링
            d=0
            while(d<31):
                d=d+1
                driver.find_element(By.XPATH, '//*[@id="wt-his-select"]/option[' + str(d) + ']').click()
                time.sleep(3)
                
                # 1시~24시 온도 스크래핑
                for h in range(1, 25):
                    temp_str = driver.find_element(By.XPATH,
                                                   '//*[@id="wt-his"]/tbody/tr[' + str(h) + ']/td[2]').text
                    date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                    date_str = date.text
                    date_list = date_str.split()
                    Jan_list = date_list[4:7]
                    Jan_list.reverse()
                    Jan_list.append((str(h)+'h'))
                    Jan_list.append(temp_str) # 계속 추가됨
                    print(Jan_list) # 확인용 print

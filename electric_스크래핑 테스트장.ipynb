# %% [markdown]
# ## TEST

# %%
# 데이터 저장을 위한 csv 
import csv
# Selenium : 
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys

path = "C:/Users/Hwi/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get('https://www.timeanddate.com/weather/uk/london/historic?month=11&year=2022')

y = 2012
while(y < 2017):
    y = y+1

    # 해당 월 클릭 (2013년 1월부터 2016년12월에 해당되는 110~63 선택)
    m = 111
    while(m > 61):
        m = m-1
        # 연도와 월 선택창 클릭
        driver.find_element(By.XPATH, '//*[@id="month"]/option[' + str(m) + ']').click()
        
        # 달마다 구성일수가 다르기 때문에 반복일자 구별을 위해 월 출력
        month = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
        month_str = month.text
        month_list = month_str.split()
        month_5 = month_list[5]
        time.sleep(5)

        
        
        
        
        
        # -----------------------------------------< 01 >-----------------------------------------------
        if (month_5 == 'January'):
            print('1월')
            # 1일~5일 테스트 크롤링
            i=0
            while(i<30):
                i=i+1
                driver.find_element(By.XPATH, '//*[@id="wt-his-select"]/option[' + str(i) + ']').click()
                time.sleep(2.5)
                
                # 1시~5시 온도 테스트 스크래핑
                for j in range(1, 25):
                    temp_str = driver.find_element(By.XPATH,
                                                   '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                    date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                    date_str = date.text
                    date_list = date_str.split()
                    Jan_list = date_list[4:7]
                    Jan_list.reverse()
                    Jan_list.append((str(j)+'h'))
                    Jan_list.append(temp_str) # 계속 추가됨
                    print(Jan_list) # 확인용 print
                    
                    # csv 추가 및 저장
                print()
                time.sleep(5) 
                
            
            
            
            
            # 마지막날은 조건문 탈출을 위해 별도로 한번 시행.
                if(i==31):
                    for j in range(1, 25):
                        temp_str = driver.find_element(By.XPATH,
                                                   '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                        date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                        date_str = date.text
                        date_list = date_str.split()
                        Jan_list = date_list[4:7]
                        Jan_list.reverse()
                        Jan_list.append((str(j)+'h'))
                        Jan_list.append(temp_str) # 계속 추가됨
                        print(Jan_list) # 확인용 print
                        # csv에 추가
                    print()
                    time.sleep(5) 
                    break

            
        
        # -----------------------------------------< 02 >-----------------------------------------------
        if (month_5 == 'February'):
            print('2월')
            # 1일~5일 테스트 크롤링
            i=0
            while(i<28):
                i=i+1
                print(i,'일')
                driver.find_element(By.XPATH, '//*[@id="wt-his-select"]/option[' + str(i) + ']').click()
                time.sleep(2.5)
                
                # 1시~5시 온도 테스트 스크래핑
                for j in range(1, 25):
                    temp_str = driver.find_element(By.XPATH,
                                                   '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                    date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                    date_str = date.text
                    date_list = date_str.split()
                    Feb_list = date_list[4:7]
                    Feb_list.reverse()
                    Feb_list.append((str(j)+'h'))
                    Feb_list.append(temp_str) # 계속 추가됨
                    print(Feb_list) # 확인용 print
                    # csv 추가 및 저장
                print()
                time.sleep(5) 
                
            # 마지막날은 조건문 탈출을 위해 별도로 한번 시행.
                if(i==29):
                    for j in range(1, 25):
                        temp_str = driver.find_element(By.XPATH,
                                                       '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                        date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                        date_str = date.text
                        date_list = date_str.split()
                        Feb_list = date_list[4:7]
                        Feb_list.reverse()
                        Feb_list.append((str(j)+'h'))
                        Feb_list.append(temp_str) # 계속 추가됨
                        print(Feb_list) # 확인용 print
                        # csv에 추가
                    print()
                    time.sleep(5) 
                    break
# Out:
# C:\Users\Hwi\AppData\Local\Temp/ipykernel_6096/2266237129.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 1월
# ['2013', 'January', '1', '1h', '9 °C']
# ['2013', 'January', '1', '2h', '8 °C']
# ['2013', 'January', '1', '3h', '7 °C']
# ['2013', 'January', '1', '4h', '7 °C']
# ['2013', 'January', '1', '5h', '6 °C']
# ['2013', 'January', '1', '6h', '5 °C']
# ['2013', 'January', '1', '7h', '4 °C']
# ['2013', 'January', '1', '8h', '4 °C']
# ['2013', 'January', '1', '9h', '3 °C']
# ['2013', 'January', '1', '10h', '5 °C']
# ['2013', 'January', '1', '11h', '6 °C']
# ['2013', 'January', '1', '12h', '7 °C']
# ['2013', 'January', '1', '13h', '7 °C']
# ['2013', 'January', '1', '14h', '7 °C']
# ['2013', 'January', '1', '15h', '7 °C']
# ['2013', 'January', '1', '16h', '6 °C']
# ['2013', 'January', '1', '17h', '6 °C']
# ['2013', 'January', '1', '18h', '5 °C']
# ['2013', 'January', '1', '19h', '6 °C']
# ['2013', 'January', '1', '20h', '5 °C']
# ['2013', 'January', '1', '21h', '4 °C']
# ['2013', 'January', '1', '22h', '4 °C']
# ['2013', 'January', '1', '23h', '4 °C']
# ['2013', 'January', '1', '24h', '3 °C']
#
# ['2013', 'January', '2', '1h', '3 °C']
# ['2013', 'January', '2', '2h', '3 °C']
# ['2013', 'January', '2', '3h', '2 °C']
# ['2013', 'January', '2', '4h', '3 °C']
# ['2013', 'January', '2', '5h', '4 °C']
# ['2013', 'January', '2', '6h', '4 °C']
# ['2013', 'January', '2', '7h', '5 °C']
# ['2013', 'January', '2', '8h', '5 °C']
# ['2013', 'January', '2', '9h', '6 °C']
# ['2013', 'January', '2', '10h', '6 °C']
# ['2013', 'January', '2', '11h', '7 °C']
# ['2013', 'January', '2', '12h', '7 °C']
# ['2013', 'January', '2', '13h', '8 °C']
# ['2013', 'January', '2', '14h', '8 °C']
# ['2013', 'January', '2', '15h', '8 °C']
# ['2013', 'January', '2', '16h', '8 °C']
# ['2013', 'January', '2', '17h', '9 °C']
# ['2013', 'January', '2', '18h', '9 °C']
# ['2013', 'January', '2', '19h', '10 °C']
# ['2013', 'January', '2', '20h', '10 °C']
# ['2013', 'January', '2', '21h', '11 °C']
# ['2013', 'January', '2', '22h', '11 °C']
# ['2013', 'January', '2', '23h', '11 °C']
# ['2013', 'January', '2', '24h', '11 °C']
#
# ['2013', 'January', '3', '1h', '10 °C']
# ['2013', 'January', '3', '2h', '10 °C']
# ['2013', 'January', '3', '3h', '10 °C']
# ['2013', 'January', '3', '4h', '10 °C']
# ['2013', 'January', '3', '5h', '9 °C']
# ['2013', 'January', '3', '6h', '10 °C']
# ['2013', 'January', '3', '7h', '10 °C']
# ['2013', 'January', '3', '8h', '10 °C']
# ['2013', 'January', '3', '9h', '10 °C']
# ['2013', 'January', '3', '10h', '10 °C']
# ['2013', 'January', '3', '11h', '10 °C']
# ['2013', 'January', '3', '12h', '11 °C']
# ['2013', 'January', '3', '13h', '11 °C']
# ['2013', 'January', '3', '14h', '11 °C']
# ['2013', 'January', '3', '15h', '11 °C']
# ['2013', 'January', '3', '16h', '11 °C']
# ['2013', 'January', '3', '17h', '11 °C']
# ['2013', 'January', '3', '18h', '11 °C']
# ['2013', 'January', '3', '19h', '11 °C']
# ['2013', 'January', '3', '20h', '11 °C']
# ['2013', 'January', '3', '21h', '11 °C']
# ['2013', 'January', '3', '22h', '11 °C']
# ['2013', 'January', '3', '23h', '11 °C']
# ['2013', 'January', '3', '24h', '11 °C']
#
# ['2013', 'January', '4', '1h', '10 °C']
# ['2013', 'January', '4', '2h', '10 °C']
# ['2013', 'January', '4', '3h', '10 °C']
# ['2013', 'January', '4', '4h', '10 °C']
# ['2013', 'January', '4', '5h', '10 °C']
# ['2013', 'January', '4', '6h', '10 °C']
# ['2013', 'January', '4', '7h', '10 °C']
# ['2013', 'January', '4', '8h', '10 °C']
# ['2013', 'January', '4', '9h', '9 °C']
# ['2013', 'January', '4', '10h', '10 °C']
# ['2013', 'January', '4', '11h', '10 °C']
# ['2013', 'January', '4', '12h', '10 °C']
# ['2013', 'January', '4', '13h', '10 °C']
# ['2013', 'January', '4', '14h', '10 °C']
# ['2013', 'January', '4', '15h', '10 °C']
# ['2013', 'January', '4', '16h', '10 °C']
# ['2013', 'January', '4', '17h', '10 °C']
# ['2013', 'January', '4', '18h', '10 °C']
# ['2013', 'January', '4', '19h', '9 °C']
# ['2013', 'January', '4', '20h', '9 °C']
# ['2013', 'January', '4', '21h', '9 °C']
# ['2013', 'January', '4', '22h', '9 °C']
# ['2013', 'January', '4', '23h', '8 °C']
# ['2013', 'January', '4', '24h', '8 °C']
#
# ['2013', 'January', '5', '1h', '8 °C']
# ['2013', 'January', '5', '2h', '8 °C']
# ['2013', 'January', '5', '3h', '8 °C']
# ['2013', 'January', '5', '4h', '8 °C']
# ['2013', 'January', '5', '5h', '8 °C']
# ['2013', 'January', '5', '6h', '8 °C']
# ['2013', 'January', '5', '7h', '8 °C']
# ['2013', 'January', '5', '8h', '9 °C']
# ['2013', 'January', '5', '9h', '9 °C']
# ['2013', 'January', '5', '10h', '10 °C']
# ['2013', 'January', '5', '11h', '10 °C']
# ['2013', 'January', '5', '12h', '11 °C']
# ['2013', 'January', '5', '13h', '11 °C']
# ['2013', 'January', '5', '14h', '11 °C']
# ['2013', 'January', '5', '15h', '11 °C']
# ['2013', 'January', '5', '16h', '10 °C']
# ['2013', 'January', '5', '17h', '10 °C']
# ['2013', 'January', '5', '18h', '10 °C']
# ['2013', 'January', '5', '19h', '10 °C']
# ['2013', 'January', '5', '20h', '9 °C']
# ['2013', 'January', '5', '21h', '9 °C']
# ['2013', 'January', '5', '22h', '7 °C']
# ['2013', 'January', '5', '23h', '7 °C']
# ['2013', 'January', '5', '24h', '6 °C']
#
# ['2013', 'January', '6', '1h', '6 °C']
# ['2013', 'January', '6', '2h', '5 °C']
# ['2013', 'January', '6', '3h', '4 °C']
# ['2013', 'January', '6', '4h', '6 °C']
# ['2013', 'January', '6', '5h', '7 °C']
# ['2013', 'January', '6', '6h', '7 °C']
# ['2013', 'January', '6', '7h', '7 °C']
# ['2013', 'January', '6', '8h', '7 °C']
# ['2013', 'January', '6', '9h', '7 °C']
# ['2013', 'January', '6', '10h', '8 °C']
# ['2013', 'January', '6', '11h', '8 °C']
# ['2013', 'January', '6', '12h', '8 °C']
# ['2013', 'January', '6', '13h', '8 °C']
# ['2013', 'January', '6', '14h', '8 °C']
# ['2013', 'January', '6', '15h', '8 °C']
# ['2013', 'January', '6', '16h', '8 °C']
# ['2013', 'January', '6', '17h', '8 °C']
# ['2013', 'January', '6', '18h', '8 °C']
# ['2013', 'January', '6', '19h', '8 °C']
# ['2013', 'January', '6', '20h', '9 °C']
# ['2013', 'January', '6', '21h', '9 °C']
# ['2013', 'January', '6', '22h', '9 °C']
# ['2013', 'January', '6', '23h', '9 °C']
# ['2013', 'January', '6', '24h', '8 °C']
#
# ['2013', 'January', '7', '1h', '8 °C']
# ['2013', 'January', '7', '2h', '7 °C']
# ['2013', 'January', '7', '3h', '7 °C']
# ['2013', 'January', '7', '4h', '7 °C']
# ['2013', 'January', '7', '5h', '7 °C']
# ['2013', 'January', '7', '6h', '7 °C']
# ['2013', 'January', '7', '7h', '7 °C']
# ['2013', 'January', '7', '8h', '7 °C']
# ['2013', 'January', '7', '9h', '7 °C']
# ['2013', 'January', '7', '10h', '8 °C']
# ['2013', 'January', '7', '11h', '8 °C']
# ['2013', 'January', '7', '12h', '8 °C']
# ['2013', 'January', '7', '13h', '9 °C']
# ['2013', 'January', '7', '14h', '9 °C']
# ['2013', 'January', '7', '15h', '9 °C']
# ['2013', 'January', '7', '16h', '9 °C']
# ['2013', 'January', '7', '17h', '9 °C']
# ['2013', 'January', '7', '18h', '9 °C']
# ['2013', 'January', '7', '19h', '8 °C']
# ['2013', 'January', '7', '20h', '9 °C']
# ['2013', 'January', '7', '21h', '9 °C']
# ['2013', 'January', '7', '22h', '9 °C']
# ['2013', 'January', '7', '23h', '9 °C']
# ['2013', 'January', '7', '24h', '9 °C']
#
# ['2013', 'January', '8', '1h', '9 °C']
# ['2013', 'January', '8', '2h', '9 °C']
# ['2013', 'January', '8', '3h', '9 °C']
# ['2013', 'January', '8', '4h', '9 °C']
# ['2013', 'January', '8', '5h', '10 °C']
# ['2013', 'January', '8', '6h', '10 °C']
# ['2013', 'January', '8', '7h', '10 °C']
# ['2013', 'January', '8', '8h', '8 °C']
# ['2013', 'January', '8', '9h', '9 °C']
# ['2013', 'January', '8', '10h', '10 °C']
# ['2013', 'January', '8', '11h', '10 °C']
# ['2013', 'January', '8', '12h', '11 °C']
# ['2013', 'January', '8', '13h', '11 °C']
# ['2013', 'January', '8', '14h', '11 °C']
# ['2013', 'January', '8', '15h', '11 °C']
# ['2013', 'January', '8', '16h', '11 °C']
# ['2013', 'January', '8', '17h', '11 °C']
# ['2013', 'January', '8', '18h', '11 °C']
# ['2013', 'January', '8', '19h', '11 °C']
# ['2013', 'January', '8', '20h', '10 °C']
# ['2013', 'January', '8', '21h', '10 °C']
# ['2013', 'January', '8', '22h', '10 °C']
# ['2013', 'January', '8', '23h', '9 °C']
# ['2013', 'January', '8', '24h', '9 °C']
#
# ['2013', 'January', '9', '1h', '9 °C']
# ['2013', 'January', '9', '2h', '9 °C']
# ['2013', 'January', '9', '3h', '9 °C']
# ['2013', 'January', '9', '4h', '9 °C']
# ['2013', 'January', '9', '5h', '9 °C']
# ['2013', 'January', '9', '6h', '9 °C']
# ['2013', 'January', '9', '7h', '8 °C']
# ['2013', 'January', '9', '8h', '8 °C']
# ['2013', 'January', '9', '9h', '8 °C']
# ['2013', 'January', '9', '10h', '8 °C']
# ['2013', 'January', '9', '11h', '8 °C']
# ['2013', 'January', '9', '12h', '8 °C']
# ['2013', 'January', '9', '13h', '9 °C']
# ['2013', 'January', '9', '14h', '9 °C']
# ['2013', 'January', '9', '15h', '8 °C']
# ['2013', 'January', '9', '16h', '7 °C']
# ['2013', 'January', '9', '17h', '5 °C']
# ['2013', 'January', '9', '18h', '4 °C']
# ['2013', 'January', '9', '19h', '2 °C']
# ['2013', 'January', '9', '20h', '1 °C']
# ['2013', 'January', '9', '21h', '1 °C']
# ['2013', 'January', '9', '22h', '0 °C']
# ['2013', 'January', '9', '23h', '0 °C']
# ['2013', 'January', '9', '24h', '-1 °C']
#
# ['2013', 'January', '10', '1h', '-1 °C']
# ['2013', 'January', '10', '2h', '-2 °C']
# ['2013', 'January', '10', '3h', '-1 °C']
# ['2013', 'January', '10', '4h', '-1 °C']
# ['2013', 'January', '10', '5h', '-1 °C']
# ['2013', 'January', '10', '6h', '0 °C']
# ['2013', 'January', '10', '7h', '0 °C']
# ['2013', 'January', '10', '8h', '1 °C']
# ['2013', 'January', '10', '9h', '1 °C']
# ['2013', 'January', '10', '10h', '2 °C']
# ['2013', 'January', '10', '11h', '2 °C']
# ['2013', 'January', '10', '12h', '2 °C']
# ['2013', 'January', '10', '13h', '3 °C']
# ['2013', 'January', '10', '14h', '3 °C']
# ['2013', 'January', '10', '15h', '3 °C']
# ['2013', 'January', '10', '16h', '3 °C']
# ['2013', 'January', '10', '17h', '3 °C']
# ['2013', 'January', '10', '18h', '3 °C']
# ['2013', 'January', '10', '19h', '3 °C']
# ['2013', 'January', '10', '20h', '2 °C']
# ['2013', 'January', '10', '21h', '2 °C']
# ['2013', 'January', '10', '22h', '2 °C']
# ['2013', 'January', '10', '23h', '1 °C']
# ['2013', 'January', '10', '24h', '1 °C']
#
# ['2013', 'January', '11', '1h', '1 °C']
# ['2013', 'January', '11', '2h', '1 °C']
# ['2013', 'January', '11', '3h', '1 °C']
# ['2013', 'January', '11', '4h', '0 °C']
# ['2013', 'January', '11', '5h', '0 °C']
# ['2013', 'January', '11', '6h', '-1 °C']
# ['2013', 'January', '11', '7h', '-1 °C']
# ['2013', 'January', '11', '8h', '0 °C']
# ['2013', 'January', '11', '9h', '1 °C']
# ['2013', 'January', '11', '10h', '2 °C']
# ['2013', 'January', '11', '11h', '3 °C']
# ['2013', 'January', '11', '12h', '4 °C']
# ['2013', 'January', '11', '13h', '5 °C']
# ['2013', 'January', '11', '14h', '7 °C']
# ['2013', 'January', '11', '15h', '6 °C']
# ['2013', 'January', '11', '16h', '6 °C']
# ['2013', 'January', '11', '17h', '4 °C']
# ['2013', 'January', '11', '18h', '3 °C']
# ['2013', 'January', '11', '19h', '2 °C']
# ['2013', 'January', '11', '20h', '1 °C']
# ['2013', 'January', '11', '21h', '0 °C']
# ['2013', 'January', '11', '22h', '0 °C']
# ['2013', 'January', '11', '23h', '0 °C']
# ['2013', 'January', '11', '24h', '0 °C']
#
# ['2013', 'January', '12', '1h', '1 °C']
# ['2013', 'January', '12', '2h', '2 °C']
# ['2013', 'January', '12', '3h', '3 °C']
# ['2013', 'January', '12', '4h', '3 °C']
# ['2013', 'January', '12', '5h', '3 °C']
# ['2013', 'January', '12', '6h', '3 °C']
# ['2013', 'January', '12', '7h', '3 °C']
# ['2013', 'January', '12', '8h', '3 °C']
# ['2013', 'January', '12', '9h', '3 °C']
# ['2013', 'January', '12', '10h', '4 °C']
# ['2013', 'January', '12', '11h', '4 °C']
# ['2013', 'January', '12', '12h', '5 °C']
# ['2013', 'January', '12', '13h', '5 °C']
# ['2013', 'January', '12', '14h', '5 °C']
# ['2013', 'January', '12', '15h', '4 °C']
# ['2013', 'January', '12', '16h', '4 °C']
# ['2013', 'January', '12', '17h', '4 °C']
# ['2013', 'January', '12', '18h', '4 °C']
# ['2013', 'January', '12', '19h', '4 °C']
# ['2013', 'January', '12', '20h', '4 °C']
# ['2013', 'January', '12', '21h', '4 °C']
# ['2013', 'January', '12', '22h', '4 °C']
# ['2013', 'January', '12', '23h', '4 °C']
# ['2013', 'January', '12', '24h', '3 °C']
#
# ['2013', 'January', '13', '1h', '3 °C']
# ['2013', 'January', '13', '2h', '3 °C']
# ['2013', 'January', '13', '3h', '3 °C']
# ['2013', 'January', '13', '4h', '3 °C']
# ['2013', 'January', '13', '5h', '2 °C']
# ['2013', 'January', '13', '6h', '2 °C']
# ['2013', 'January', '13', '7h', '1 °C']
# ['2013', 'January', '13', '8h', '0 °C']
# ['2013', 'January', '13', '9h', '-1 °C']
# ['2013', 'January', '13', '10h', '2 °C']
# ['2013', 'January', '13', '11h', '3 °C']
# ['2013', 'January', '13', '12h', '2 °C']
# ['2013', 'January', '13', '13h', '2 °C']
# ['2013', 'January', '13', '14h', '2 °C']
# ['2013', 'January', '13', '15h', '2 °C']
# ['2013', 'January', '13', '16h', '2 °C']
# ['2013', 'January', '13', '17h', '1 °C']
# ['2013', 'January', '13', '18h', '0 °C']
# ['2013', 'January', '13', '19h', '0 °C']
# ['2013', 'January', '13', '20h', '0 °C']
# ['2013', 'January', '13', '21h', '0 °C']
# ['2013', 'January', '13', '22h', '0 °C']
# ['2013', 'January', '13', '23h', '0 °C']
# ['2013', 'January', '13', '24h', '0 °C']
#
# ['2013', 'January', '14', '1h', '0 °C']
# ['2013', 'January', '14', '2h', '0 °C']
# ['2013', 'January', '14', '3h', '0 °C']
# ['2013', 'January', '14', '4h', '0 °C']
# ['2013', 'January', '14', '5h', '0 °C']
# ['2013', 'January', '14', '6h', '0 °C']
# ['2013', 'January', '14', '7h', '0 °C']
# ['2013', 'January', '14', '8h', '0 °C']
# ['2013', 'January', '14', '9h', '0 °C']
# ['2013', 'January', '14', '10h', '0 °C']
# ['2013', 'January', '14', '11h', '0 °C']
# ['2013', 'January', '14', '12h', '1 °C']
# ['2013', 'January', '14', '13h', '1 °C']
# ['2013', 'January', '14', '14h', '1 °C']
# ['2013', 'January', '14', '15h', '1 °C']
# ['2013', 'January', '14', '16h', '1 °C']
# ['2013', 'January', '14', '17h', '1 °C']
# ['2013', 'January', '14', '18h', '1 °C']
# ['2013', 'January', '14', '19h', '2 °C']
# ['2013', 'January', '14', '20h', '3 °C']
# ['2013', 'January', '14', '21h', '3 °C']
# ['2013', 'January', '14', '22h', '2 °C']
# ['2013', 'January', '14', '23h', '2 °C']
# ['2013', 'January', '14', '24h', '2 °C']
#
# ['2013', 'January', '15', '1h', '2 °C']
# ['2013', 'January', '15', '2h', '2 °C']
# ['2013', 'January', '15', '3h', '2 °C']
# ['2013', 'January', '15', '4h', '1 °C']
# ['2013', 'January', '15', '5h', '2 °C']
# ['2013', 'January', '15', '6h', '2 °C']
# ['2013', 'January', '15', '7h', '1 °C']
# ['2013', 'January', '15', '8h', '1 °C']
# ['2013', 'January', '15', '9h', '1 °C']
# ['2013', 'January', '15', '10h', '1 °C']
# ['2013', 'January', '15', '11h', '1 °C']
# ['2013', 'January', '15', '12h', '1 °C']
# ['2013', 'January', '15', '13h', '1 °C']
# ['2013', 'January', '15', '14h', '2 °C']
# ['2013', 'January', '15', '15h', '2 °C']
# ['2013', 'January', '15', '16h', '3 °C']
# ['2013', 'January', '15', '17h', '1 °C']
# ['2013', 'January', '15', '18h', '-1 °C']
# ['2013', 'January', '15', '19h', '-1 °C']
# ['2013', 'January', '15', '20h', '-1 °C']
# ['2013', 'January', '15', '21h', '-1 °C']
# ['2013', 'January', '15', '22h', '-1 °C']
# ['2013', 'January', '15', '23h', '-3 °C']
# ['2013', 'January', '15', '24h', '-3 °C']
#
# ['2013', 'January', '16', '1h', '-4 °C']
# ['2013', 'January', '16', '2h', '-2 °C']
# ['2013', 'January', '16', '3h', '-2 °C']
# ['2013', 'January', '16', '4h', '-2 °C']
# ['2013', 'January', '16', '5h', '-2 °C']
# ['2013', 'January', '16', '6h', '-2 °C']
# ['2013', 'January', '16', '7h', '-3 °C']
# ['2013', 'January', '16', '8h', '-2 °C']
# ['2013', 'January', '16', '9h', '-2 °C']
# ['2013', 'January', '16', '10h', '-2 °C']
# ['2013', 'January', '16', '11h', '-2 °C']
# ['2013', 'January', '16', '12h', '-1 °C']
# ['2013', 'January', '16', '13h', '-1 °C']
# ['2013', 'January', '16', '14h', '-1 °C']
# ['2013', 'January', '16', '15h', '-1 °C']
# ['2013', 'January', '16', '16h', '-2 °C']
# ['2013', 'January', '16', '17h', '-2 °C']
# ['2013', 'January', '16', '18h', '-2 °C']
# ['2013', 'January', '16', '19h', '-2 °C']
# ['2013', 'January', '16', '20h', '-3 °C']
# ['2013', 'January', '16', '21h', '-4 °C']
# ['2013', 'January', '16', '22h', '-4 °C']
# ['2013', 'January', '16', '23h', '-4 °C']
# ['2013', 'January', '16', '24h', '-4 °C']
#
# ['2013', 'January', '17', '1h', '-3 °C']
# ['2013', 'January', '17', '2h', '-3 °C']
# ['2013', 'January', '17', '3h', '-4 °C']
# ['2013', 'January', '17', '4h', '-4 °C']
# ['2013', 'January', '17', '5h', '-5 °C']
# ['2013', 'January', '17', '6h', '-6 °C']
# ['2013', 'January', '17', '7h', '-5 °C']
# ['2013', 'January', '17', '8h', '-4 °C']
# ['2013', 'January', '17', '9h', '-3 °C']
# ['2013', 'January', '17', '10h', '-1 °C']
# ['2013', 'January', '17', '11h', '1 °C']
# ['2013', 'January', '17', '12h', '2 °C']
# ['2013', 'January', '17', '13h', '2 °C']
# ['2013', 'January', '17', '14h', '2 °C']
# ['2013', 'January', '17', '15h', '2 °C']
# ['2013', 'January', '17', '16h', '2 °C']
# ['2013', 'January', '17', '17h', '2 °C']
# ['2013', 'January', '17', '18h', '2 °C']
# ['2013', 'January', '17', '19h', '2 °C']
# ['2013', 'January', '17', '20h', '2 °C']
# ['2013', 'January', '17', '21h', '2 °C']
# ['2013', 'January', '17', '22h', '2 °C']
# ['2013', 'January', '17', '23h', '2 °C']
# ['2013', 'January', '17', '24h', '2 °C']
# ['2013', 'January', '18', '1h', '2 °C']
# ['2013', 'January', '18', '2h', '2 °C']
# ['2013', 'January', '18', '3h', '1 °C']
# ['2013', 'January', '18', '4h', '1 °C']
# ['2013', 'January', '18', '5h', '1 °C']
# ['2013', 'January', '18', '6h', '0 °C']
# ['2013', 'January', '18', '7h', '0 °C']
# ['2013', 'January', '18', '8h', '-1 °C']
# ['2013', 'January', '18', '9h', '-2 °C']
# ['2013', 'January', '18', '10h', '-1 °C']
# ['2013', 'January', '18', '11h', '-2 °C']
# ['2013', 'January', '18', '12h', '-2 °C']
# ['2013', 'January', '18', '13h', '-2 °C']
# ['2013', 'January', '18', '14h', '-2 °C']
# ['2013', 'January', '18', '15h', '-2 °C']
# ['2013', 'January', '18', '16h', '-1 °C']
# ['2013', 'January', '18', '17h', '-1 °C']
# ['2013', 'January', '18', '18h', '-1 °C']
# ['2013', 'January', '18', '19h', '-1 °C']
# ['2013', 'January', '18', '20h', '-1 °C']
# ['2013', 'January', '18', '21h', '-1 °C']
# ['2013', 'January', '18', '22h', '-1 °C']
# ['2013', 'January', '18', '23h', '0 °C']
# ['2013', 'January', '18', '24h', '0 °C']
#
# ['2013', 'January', '19', '1h', '0 °C']
# ['2013', 'January', '19', '2h', '0 °C']
# ['2013', 'January', '19', '3h', '0 °C']
# ['2013', 'January', '19', '4h', '0 °C']
# ['2013', 'January', '19', '5h', '0 °C']
# ['2013', 'January', '19', '6h', '0 °C']
# ['2013', 'January', '19', '7h', '0 °C']
# ['2013', 'January', '19', '8h', '0 °C']
# ['2013', 'January', '19', '9h', '1 °C']
# ['2013', 'January', '19', '10h', '1 °C']
# ['2013', 'January', '19', '11h', '1 °C']
# ['2013', 'January', '19', '12h', '1 °C']
# ['2013', 'January', '19', '13h', '1 °C']
# ['2013', 'January', '19', '14h', '1 °C']
# ['2013', 'January', '19', '15h', '1 °C']
# ['2013', 'January', '19', '16h', '0 °C']
# ['2013', 'January', '19', '17h', '0 °C']
# ['2013', 'January', '19', '18h', '0 °C']
# ['2013', 'January', '19', '19h', '0 °C']
# ['2013', 'January', '19', '20h', '0 °C']
# ['2013', 'January', '19', '21h', '-1 °C']
# ['2013', 'January', '19', '22h', '0 °C']
# ['2013', 'January', '19', '23h', '0 °C']
# ['2013', 'January', '19', '24h', '0 °C']
#
# ['2013', 'January', '20', '1h', '-1 °C']
# ['2013', 'January', '20', '2h', '-1 °C']
# ['2013', 'January', '20', '3h', '-1 °C']
# ['2013', 'January', '20', '4h', '-1 °C']
# ['2013', 'January', '20', '5h', '-1 °C']
# ['2013', 'January', '20', '6h', '-1 °C']
# ['2013', 'January', '20', '7h', '-1 °C']
# ['2013', 'January', '20', '8h', '-1 °C']
# ['2013', 'January', '20', '9h', '-1 °C']
# ['2013', 'January', '20', '10h', '-2 °C']
# ['2013', 'January', '20', '11h', '-1 °C']
# ['2013', 'January', '20', '12h', '-1 °C']
# ['2013', 'January', '20', '13h', '-1 °C']
# ['2013', 'January', '20', '14h', '-1 °C']
# ['2013', 'January', '20', '15h', '0 °C']
# ['2013', 'January', '20', '16h', '0 °C']
# ['2013', 'January', '20', '17h', '0 °C']
# ['2013', 'January', '20', '18h', '0 °C']
# ['2013', 'January', '20', '19h', '0 °C']
# ['2013', 'January', '20', '20h', '-1 °C']
# ['2013', 'January', '20', '21h', '-1 °C']
# ['2013', 'January', '20', '22h', '-1 °C']
# ['2013', 'January', '20', '23h', '-1 °C']
# ['2013', 'January', '20', '24h', '-1 °C']
#
# ['2013', 'January', '21', '1h', '-1 °C']
# ['2013', 'January', '21', '2h', '-1 °C']
# ['2013', 'January', '21', '3h', '-1 °C']
# ['2013', 'January', '21', '4h', '-1 °C']
# ['2013', 'January', '21', '5h', '-1 °C']
# ['2013', 'January', '21', '6h', '-1 °C']
# ['2013', 'January', '21', '7h', '-1 °C']
# ['2013', 'January', '21', '8h', '-1 °C']
# ['2013', 'January', '21', '9h', '0 °C']
# ['2013', 'January', '21', '10h', '0 °C']
# ['2013', 'January', '21', '11h', '0 °C']
# ['2013', 'January', '21', '12h', '0 °C']
# ['2013', 'January', '21', '13h', '1 °C']
# ['2013', 'January', '21', '14h', '1 °C']
# ['2013', 'January', '21', '15h', '1 °C']
# ['2013', 'January', '21', '16h', '1 °C']
# ['2013', 'January', '21', '17h', '1 °C']
# ['2013', 'January', '21', '18h', '1 °C']
# ['2013', 'January', '21', '19h', '0 °C']
# ['2013', 'January', '21', '20h', '0 °C']
# ['2013', 'January', '21', '21h', '0 °C']
# ['2013', 'January', '21', '22h', '-1 °C']
# ['2013', 'January', '21', '23h', '-2 °C']
# ['2013', 'January', '21', '24h', '-5 °C']
#
# ['2013', 'January', '22', '1h', '-6 °C']
# ['2013', 'January', '22', '2h', '-7 °C']
# ['2013', 'January', '22', '3h', '-7 °C']
# ['2013', 'January', '22', '4h', '-7 °C']
# ['2013', 'January', '22', '5h', '-7 °C']
# ['2013', 'January', '22', '6h', '-7 °C']
# ['2013', 'January', '22', '7h', '-2 °C']
# ['2013', 'January', '22', '8h', '-1 °C']
# ['2013', 'January', '22', '9h', '-1 °C']
# ['2013', 'January', '22', '10h', '-1 °C']
# ['2013', 'January', '22', '11h', '0 °C']
# ['2013', 'January', '22', '12h', '1 °C']
# ['2013', 'January', '22', '13h', '2 °C']
# ['2013', 'January', '22', '14h', '2 °C']
# ['2013', 'January', '22', '15h', '2 °C']
# ['2013', 'January', '22', '16h', '2 °C']
# ['2013', 'January', '22', '17h', '2 °C']
# ['2013', 'January', '22', '18h', '3 °C']
# ['2013', 'January', '22', '19h', '3 °C']
# ['2013', 'January', '22', '20h', '3 °C']
# ['2013', 'January', '22', '21h', '3 °C']
# ['2013', 'January', '22', '22h', '3 °C']
# ['2013', 'January', '22', '23h', '2 °C']
# ['2013', 'January', '22', '24h', '2 °C']
#
# ['2013', 'January', '23', '1h', '2 °C']
# ['2013', 'January', '23', '2h', '2 °C']
# ['2013', 'January', '23', '3h', '2 °C']
# ['2013', 'January', '23', '4h', '2 °C']
# ['2013', 'January', '23', '5h', '2 °C']
# ['2013', 'January', '23', '6h', '1 °C']
# ['2013', 'January', '23', '7h', '1 °C']
# ['2013', 'January', '23', '8h', '1 °C']
# ['2013', 'January', '23', '9h', '1 °C']
# ['2013', 'January', '23', '10h', '1 °C']
# ['2013', 'January', '23', '11h', '2 °C']
# ['2013', 'January', '23', '12h', '2 °C']
# ['2013', 'January', '23', '13h', '2 °C']
# ['2013', 'January', '23', '14h', '2 °C']
# ['2013', 'January', '23', '15h', '2 °C']
# ['2013', 'January', '23', '16h', '2 °C']
# ['2013', 'January', '23', '17h', '2 °C']
# ['2013', 'January', '23', '18h', '1 °C']
# ['2013', 'January', '23', '19h', '1 °C']
# ['2013', 'January', '23', '20h', '1 °C']
# ['2013', 'January', '23', '21h', '2 °C']
# ['2013', 'January', '23', '22h', '2 °C']
# ['2013', 'January', '23', '23h', '2 °C']
# ['2013', 'January', '23', '24h', '2 °C']
#
# ['2013', 'January', '24', '1h', '1 °C']
# ['2013', 'January', '24', '2h', '1 °C']
# ['2013', 'January', '24', '3h', '1 °C']
# ['2013', 'January', '24', '4h', '1 °C']
# ['2013', 'January', '24', '5h', '1 °C']
# ['2013', 'January', '24', '6h', '1 °C']
# ['2013', 'January', '24', '7h', '1 °C']
# ['2013', 'January', '24', '8h', '1 °C']
# ['2013', 'January', '24', '9h', '1 °C']
# ['2013', 'January', '24', '10h', '1 °C']
# ['2013', 'January', '24', '11h', '2 °C']
# ['2013', 'January', '24', '12h', '2 °C']
# ['2013', 'January', '24', '13h', '2 °C']
# ['2013', 'January', '24', '14h', '2 °C']
# ['2013', 'January', '24', '15h', '2 °C']
# ['2013', 'January', '24', '16h', '2 °C']
# ['2013', 'January', '24', '17h', '1 °C']
# ['2013', 'January', '24', '18h', '2 °C']
# ['2013', 'January', '24', '19h', '1 °C']
# ['2013', 'January', '24', '20h', '2 °C']
# ['2013', 'January', '24', '21h', '1 °C']
# ['2013', 'January', '24', '22h', '1 °C']
# ['2013', 'January', '24', '23h', '1 °C']
# ['2013', 'January', '24', '24h', '1 °C']
#
# ['2013', 'January', '25', '1h', '-1 °C']
# ['2013', 'January', '25', '2h', '-2 °C']
# ['2013', 'January', '25', '3h', '-1 °C']
# ['2013', 'January', '25', '4h', '-1 °C']
# ['2013', 'January', '25', '5h', '0 °C']
# ['2013', 'January', '25', '6h', '1 °C']
# ['2013', 'January', '25', '7h', '1 °C']
# ['2013', 'January', '25', '8h', '1 °C']
# ['2013', 'January', '25', '9h', '1 °C']
# ['2013', 'January', '25', '10h', '2 °C']
# ['2013', 'January', '25', '11h', '2 °C']
# ['2013', 'January', '25', '12h', '2 °C']
# ['2013', 'January', '25', '13h', '2 °C']
# ['2013', 'January', '25', '14h', '2 °C']
# ['2013', 'January', '25', '15h', '2 °C']
# ['2013', 'January', '25', '16h', '2 °C']
# ['2013', 'January', '25', '17h', '1 °C']
# ['2013', 'January', '25', '18h', '1 °C']
# ['2013', 'January', '25', '19h', '1 °C']
# ['2013', 'January', '25', '20h', '2 °C']
# ['2013', 'January', '25', '21h', '3 °C']
# ['2013', 'January', '25', '22h', '3 °C']
# ['2013', 'January', '25', '23h', '3 °C']
# ['2013', 'January', '25', '24h', '3 °C']
#
# ['2013', 'January', '26', '1h', '3 °C']
# ['2013', 'January', '26', '2h', '2 °C']
# ['2013', 'January', '26', '3h', '2 °C']
# ['2013', 'January', '26', '4h', '2 °C']
# ['2013', 'January', '26', '5h', '2 °C']
# ['2013', 'January', '26', '6h', '3 °C']
# ['2013', 'January', '26', '7h', '2 °C']
# ['2013', 'January', '26', '8h', '3 °C']
# ['2013', 'January', '26', '9h', '3 °C']
# ['2013', 'January', '26', '10h', '4 °C']
# ['2013', 'January', '26', '11h', '5 °C']
# ['2013', 'January', '26', '12h', '6 °C']
# ['2013', 'January', '26', '13h', '7 °C']
# ['2013', 'January', '26', '14h', '8 °C']
# ['2013', 'January', '26', '15h', '8 °C']
# ['2013', 'January', '26', '16h', '8 °C']
# ['2013', 'January', '26', '17h', '7 °C']
# ['2013', 'January', '26', '18h', '6 °C']
# ['2013', 'January', '26', '19h', '7 °C']
# ['2013', 'January', '26', '20h', '7 °C']
# ['2013', 'January', '26', '21h', '7 °C']
# ['2013', 'January', '26', '22h', '7 °C']
# ['2013', 'January', '26', '23h', '7 °C']
# ['2013', 'January', '26', '24h', '8 °C']
#
# ['2013', 'January', '27', '1h', '7 °C']
# ['2013', 'January', '27', '2h', '8 °C']
# ['2013', 'January', '27', '3h', '8 °C']
# ['2013', 'January', '27', '4h', '9 °C']
# ['2013', 'January', '27', '5h', '9 °C']
# ['2013', 'January', '27', '6h', '10 °C']
# ['2013', 'January', '27', '7h', '10 °C']
# ['2013', 'January', '27', '8h', '10 °C']
# ['2013', 'January', '27', '9h', '9 °C']
# ['2013', 'January', '27', '10h', '9 °C']
# ['2013', 'January', '27', '11h', '9 °C']
# ['2013', 'January', '27', '12h', '9 °C']
# ['2013', 'January', '27', '13h', '10 °C']
# ['2013', 'January', '27', '14h', '9 °C']
# ['2013', 'January', '27', '15h', '9 °C']
# ['2013', 'January', '27', '16h', '9 °C']
# ['2013', 'January', '27', '17h', '7 °C']
# ['2013', 'January', '27', '18h', '7 °C']
# ['2013', 'January', '27', '19h', '6 °C']
# ['2013', 'January', '27', '20h', '5 °C']
# ['2013', 'January', '27', '21h', '6 °C']
# ['2013', 'January', '27', '22h', '6 °C']
# ['2013', 'January', '27', '23h', '4 °C']
# ['2013', 'January', '27', '24h', '4 °C']
#
# ['2013', 'January', '28', '1h', '4 °C']
# ['2013', 'January', '28', '2h', '4 °C']
# ['2013', 'January', '28', '3h', '4 °C']
# ['2013', 'January', '28', '4h', '3 °C']
# ['2013', 'January', '28', '5h', '3 °C']
# ['2013', 'January', '28', '6h', '2 °C']
# ['2013', 'January', '28', '7h', '2 °C']
# ['2013', 'January', '28', '8h', '2 °C']
# ['2013', 'January', '28', '9h', '3 °C']
# ['2013', 'January', '28', '10h', '5 °C']
# ['2013', 'January', '28', '11h', '6 °C']
# ['2013', 'January', '28', '12h', '7 °C']
# ['2013', 'January', '28', '13h', '8 °C']
# ['2013', 'January', '28', '14h', '8 °C']
# ['2013', 'January', '28', '15h', '8 °C']
# ['2013', 'January', '28', '16h', '9 °C']
# ['2013', 'January', '28', '17h', '8 °C']
# ['2013', 'January', '28', '18h', '9 °C']
# ['2013', 'January', '28', '19h', '9 °C']
# ['2013', 'January', '28', '20h', '11 °C']
# ['2013', 'January', '28', '21h', '11 °C']
# ['2013', 'January', '28', '22h', '11 °C']
# ['2013', 'January', '28', '23h', '11 °C']
# ['2013', 'January', '28', '24h', '11 °C']
#
# ['2013', 'January', '29', '1h', '11 °C']
# ['2013', 'January', '29', '2h', '11 °C']
# ['2013', 'January', '29', '3h', '10 °C']
# ['2013', 'January', '29', '4h', '10 °C']
# ['2013', 'January', '29', '5h', '9 °C']
# ['2013', 'January', '29', '6h', '9 °C']
# ['2013', 'January', '29', '7h', '10 °C']
# ['2013', 'January', '29', '8h', '10 °C']
# ['2013', 'January', '29', '9h', '10 °C']
# ['2013', 'January', '29', '10h', '12 °C']
# ['2013', 'January', '29', '11h', '13 °C']
# ['2013', 'January', '29', '12h', '13 °C']
# ['2013', 'January', '29', '13h', '13 °C']
# ['2013', 'January', '29', '14h', '14 °C']
# ['2013', 'January', '29', '15h', '14 °C']
# ['2013', 'January', '29', '16h', '14 °C']
# ['2013', 'January', '29', '17h', '14 °C']
# ['2013', 'January', '29', '18h', '13 °C']
# ['2013', 'January', '29', '19h', '13 °C']
# ['2013', 'January', '29', '20h', '12 °C']
# ['2013', 'January', '29', '21h', '12 °C']
# ['2013', 'January', '29', '22h', '12 °C']
# ['2013', 'January', '29', '23h', '12 °C']
# ['2013', 'January', '29', '24h', '13 °C']
#
# ['2013', 'January', '30', '1h', '12 °C']
# ['2013', 'January', '30', '2h', '12 °C']
# ['2013', 'January', '30', '3h', '12 °C']
# ['2013', 'January', '30', '4h', '10 °C']
# ['2013', 'January', '30', '5h', '9 °C']
# ['2013', 'January', '30', '6h', '9 °C']
# ['2013', 'January', '30', '7h', '8 °C']
# ['2013', 'January', '30', '8h', '9 °C']
# ['2013', 'January', '30', '9h', '9 °C']
# ['2013', 'January', '30', '10h', '10 °C']
# ['2013', 'January', '30', '11h', '10 °C']
# ['2013', 'January', '30', '12h', '11 °C']
# ['2013', 'January', '30', '13h', '11 °C']
# ['2013', 'January', '30', '14h', '11 °C']
# ['2013', 'January', '30', '15h', '11 °C']
# ['2013', 'January', '30', '16h', '11 °C']
# ['2013', 'January', '30', '17h', '10 °C']
# ['2013', 'January', '30', '18h', '10 °C']
# ['2013', 'January', '30', '19h', '9 °C']
# ['2013', 'January', '30', '20h', '9 °C']
# ['2013', 'January', '30', '21h', '8 °C']
# ['2013', 'January', '30', '22h', '8 °C']
# ['2013', 'January', '30', '23h', '7 °C']
# ['2013', 'January', '30', '24h', '7 °C']
#
# 2월
# 1 일
# ['2013', 'February', '1', '1h', '6 °C']
# ['2013', 'February', '1', '2h', '5 °C']
# ['2013', 'February', '1', '3h', '5 °C']
# ['2013', 'February', '1', '4h', '5 °C']
# ['2013', 'February', '1', '5h', '5 °C']
# ['2013', 'February', '1', '6h', '5 °C']
# ['2013', 'February', '1', '7h', '6 °C']
# ['2013', 'February', '1', '8h', '7 °C']
# ['2013', 'February', '1', '9h', '7 °C']
# ['2013', 'February', '1', '10h', '7 °C']
# ['2013', 'February', '1', '11h', '7 °C']
# ['2013', 'February', '1', '12h', '5 °C']
# ['2013', 'February', '1', '13h', '5 °C']
# ['2013', 'February', '1', '14h', '5 °C']
# ['2013', 'February', '1', '15h', '4 °C']
# ['2013', 'February', '1', '16h', '3 °C']
# ['2013', 'February', '1', '17h', '2 °C']
# ['2013', 'February', '1', '18h', '2 °C']
# ['2013', 'February', '1', '19h', '4 °C']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6096/2266237129.py in <module>
#      98                 # 1시~5시 온도 테스트 스크래핑
#      99                 for j in range(1, 25):
# --> 100                     temp_str = driver.find_element(By.XPATH,
#     101                                                    '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
#     102                     date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="wt-his"]/tbody/tr[20]/td[2]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x004B6903+2517251]
# 	Ordinal0 [0x0044F8E1+2095329]
# 	Ordinal0 [0x00352848+1058888]
# 	Ordinal0 [0x0037D448+1233992]
# 	Ordinal0 [0x0037D63B+1234491]
# 	Ordinal0 [0x003A7812+1406994]
# 	Ordinal0 [0x0039650A+1336586]
# 	Ordinal0 [0x003A5BBF+1399743]
# 	Ordinal0 [0x0039639B+1336219]
# 	Ordinal0 [0x003727A7+1189799]
# 	Ordinal0 [0x00373609+1193481]
# 	GetHandleVerifier [0x00645904+1577972]
# 	GetHandleVerifier [0x006F0B97+2279047]
# 	GetHandleVerifier [0x00546D09+534521]
# 	GetHandleVerifier [0x00545DB9+530601]
# 	Ordinal0 [0x00454FF9+2117625]
# 	Ordinal0 [0x004598A8+2136232]
# 	Ordinal0 [0x004599E2+2136546]
# 	Ordinal0 [0x00463541+2176321]
# 	BaseThreadInitThunk [0x7753FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E07A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E07A6E+238]

# %%
# 데이터 저장을 위한 csv 
import csv
# Selenium : 
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys

path = "C:/Users/Hwi/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get('https://www.timeanddate.com/weather/uk/london/historic?month=11&year=2022')

y = 2012
while(y < 2017):
    y = y+1

    # 해당 월 클릭 (2013년 1월부터 2016년12월에 해당되는 110~63 선택)
    m = 110
    while(m > 61):
        m = m-1
        # 연도와 월 선택창 클릭
        driver.find_element(By.XPATH, '//*[@id="month"]/option[' + str(m) + ']').click()
        
        # 달마다 구성일수가 다르기 때문에 반복일자 구별을 위해 월 출력
        month = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
        month_str = month.text
        month_list = month_str.split()
        month_5 = month_list[5]
        time.sleep(5)

        
        # -----------------------------------------< 02 >-----------------------------------------------
        if (month_5 == 'February'):
            print('2월')
            # 1일~5일 테스트 크롤링
            i=0
            while(i<28):
                i=i+1
                print(i,'일')
                driver.find_element(By.XPATH, '//*[@id="wt-his-select"]/option[' + str(i) + ']').click()
                time.sleep(2.5)
                
                # 1시~5시 온도 테스트 스크래핑
                for j in range(int(j)):
                    temp_str = driver.find_element(By.XPATH,
                                                   '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                    
                    date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                    date_str = date.text
                    date_list = date_str.split()
                    Feb_list = date_list[4:7]
                    Feb_list.reverse()
                    Feb_list.append((str(j)+'h'))
                    Feb_list.append(temp_str) # 계속 추가됨
                    print(Feb_list) # 확인용 print
                    # csv 추가 및 저장
                print()
                time.sleep(5) 
                
            # 마지막날은 조건문 탈출을 위해 별도로 한번 시행.
                if(i==29):
                    for j in range(1, 25):
                        temp_str = driver.find_element(By.XPATH,
                                                       '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
                        date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
                        date_str = date.text
                        date_list = date_str.split()
                        Feb_list = date_list[4:7]
                        Feb_list.reverse()
                        Feb_list.append((str(j)+'h'))
                        Feb_list.append(temp_str) # 계속 추가됨
                        print(Feb_list) # 확인용 print
                        # csv에 추가
                    print()
                    time.sleep(5) 
                    break
# Out:
# C:\Users\Hwi\AppData\Local\Temp/ipykernel_6096/3870094505.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# 2월
# 1 일
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6096/3870094505.py in <module>
#      43                 # 1시~5시 온도 테스트 스크래핑
#      44                 for j in range(int(j)):
# ---> 45                     temp_str = driver.find_element(By.XPATH,
#      46                                                    '//*[@id="wt-his"]/tbody/tr[' + str(j) + ']/td[2]').text
#      47                     date = driver.find_element(By.XPATH, '//*[@id="wt-his-title"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="wt-his"]/tbody/tr[0]/td[2]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x004B6903+2517251]
# 	Ordinal0 [0x0044F8E1+2095329]
# 	Ordinal0 [0x00352848+1058888]
# 	Ordinal0 [0x0037D448+1233992]
# 	Ordinal0 [0x0037D63B+1234491]
# 	Ordinal0 [0x003A7812+1406994]
# 	Ordinal0 [0x0039650A+1336586]
# 	Ordinal0 [0x003A5BBF+1399743]
# 	Ordinal0 [0x0039639B+1336219]
# 	Ordinal0 [0x003727A7+1189799]
# 	Ordinal0 [0x00373609+1193481]
# 	GetHandleVerifier [0x00645904+1577972]
# 	GetHandleVerifier [0x006F0B97+2279047]
# 	GetHandleVerifier [0x00546D09+534521]
# 	GetHandleVerifier [0x00545DB9+530601]
# 	Ordinal0 [0x00454FF9+2117625]
# 	Ordinal0 [0x004598A8+2136232]
# 	Ordinal0 [0x004599E2+2136546]
# 	Ordinal0 [0x00463541+2176321]
# 	BaseThreadInitThunk [0x7753FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E07A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E07A6E+238]

# %%
y = 2012
while(y<2016):
    y=y+1
    print('<<',y,'년','>>')
    m = 0
    while(m<12):
        m=m+1
        print('<',m,'월','>')
        d=0
        # 01
        if(m==1):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 02
        if(m==2):
            d=0
            while(d<28):
                d=d+1
                print(d,'일')
        # 03
        if(m==3):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 04
        if(m==4):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 05
        if(m==5):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 06
        if(m==6):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 07
        if(m==7):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 08
        if(m==8):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 09
        if(m==9):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 10
        if(m==10):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 11
        if(m==11):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 12
        if(m==12):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        print()
    print()
# Out:
# << 2013 년 >>
# < 1 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 6 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 7 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 8 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 9 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 10 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 11 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 12 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
#
# << 2014 년 >>
# < 1 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 6 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 7 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 8 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 9 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 10 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 11 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 12 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
#
# << 2015 년 >>
# < 1 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 6 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 7 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 8 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 9 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 10 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 11 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 12 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
#
# << 2016 년 >>
# < 1 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 6 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 7 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 8 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 9 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 10 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 11 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 12 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일

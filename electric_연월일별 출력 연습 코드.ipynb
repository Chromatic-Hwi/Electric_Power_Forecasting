# %%
y = 2012
while(y<2016):
    y=y+1
    print('<<',y,'년','>>')
    
    m = 0
    while(m<12):
        m=m+1
        print('<',m,'월','>')
        
        # 01
        if(m==1):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 02
        if(m==2):
            d=0
            while(d<28):
                d=d+1
                print(d,'일')
        # 03
        if(m==3):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 04
        if(m==4):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 05
        if(m==5):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 06
        if(m==6):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 07
        if(m==7):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 08
        if(m==8):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 09
        if(m==9):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 10
        if(m==10):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        # 11
        if(m==11):
            d=0
            while(d<30):
                d=d+1
                print(d,'일')
        # 12
        if(m==12):
            d=0
            while(d<31):
                d=d+1
                print(d,'일')
        print()
    print()
# Out:
# << 2013 년 >>
# < 1 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 2 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
#
# < 3 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
# 31 일
#
# < 4 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# 19 일
# 20 일
# 21 일
# 22 일
# 23 일
# 24 일
# 25 일
# 26 일
# 27 일
# 28 일
# 29 일
# 30 일
#
# < 5 월 >
# 1 일
# 2 일
# 3 일
# 4 일
# 5 일
# 6 일
# 7 일
# 8 일
# 9 일
# 10 일
# 11 일
# 12 일
# 13 일
# 14 일
# 15 일
# 16 일
# 17 일
# 18 일
# ...

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
import time
print("Start")
time.sleep(1)
print("End")
# Out:
# Start
# End

# %%
git config user.name "Chromatic-Hwi"
# Out:
#   File "<ipython-input-1-513e14d87d17>", line 1
#     git config user.name "Chromatic-Hwi"
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 시간 출력 테스트

# %%
# 데이터 저장을 위한 csv 
import csv
# Selenium : 
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys

path = "C:/Users/82108/Downloads/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(path)

# 기상포털 주소 1차 접속. 데이터가 충분히 표시된 2013년 1월 1일을 시작 화면으로 설정
driver.get('https://www.wunderground.com/history/daily/gb/london/EGLC/date/2013-1-1')

"""
# 20130101
# PM 11:50 xpath
//*[@id="inner-content"]
/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr[1]/td[1]/span

# PM 11:20 xpath
//*[@id="inner-content"]/
div[2]/div[1]/div[5]
/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr[48]/td[1]/span

# 20130102
# pM 11:50 xpath
//*[@id="inner-content"]
/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr[1]/td[1]/span
"""
h = 0
while(h<48):
    h=h+1
    time = driver.find_element(By.XPATH, '//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr['+str(h)+']/td[1]/span')
    time_str = time.text
    time_list = time_str.split()
    time_list.append('temp here')
    print(time_list) # 확인용 print
# Out:
# <ipython-input-1-8ba7af807760>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ['11:50', 'PM', 'temp here']
# ['12:20', 'AM', 'temp here']
# ['12:50', 'AM', 'temp here']
# ['1:20', 'AM', 'temp here']
# ['1:50', 'AM', 'temp here']
# ['2:20', 'AM', 'temp here']
# ['2:50', 'AM', 'temp here']
# ['3:20', 'AM', 'temp here']
# ['3:50', 'AM', 'temp here']
# ['4:20', 'AM', 'temp here']
# ['4:50', 'AM', 'temp here']
# ['5:20', 'AM', 'temp here']
# ['5:50', 'AM', 'temp here']
# ['6:20', 'AM', 'temp here']
# ['6:50', 'AM', 'temp here']
# ['7:20', 'AM', 'temp here']
# ['7:50', 'AM', 'temp here']
# ['8:20', 'AM', 'temp here']
# ['8:50', 'AM', 'temp here']
# ['9:20', 'AM', 'temp here']
# ['9:50', 'AM', 'temp here']
# ['10:20', 'AM', 'temp here']
# ['10:50', 'AM', 'temp here']
# ['11:20', 'AM', 'temp here']
# ['11:50', 'AM', 'temp here']
# ['12:20', 'PM', 'temp here']
# ['12:50', 'PM', 'temp here']
# ...

# %%
import csv
import time
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
Data_13_4 = pd.read_csv('./Combined_Data_New/2013/2013_4_House1_Ch1_Combined_Data_New.csv', encoding='cp949')
Data_13_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43200 entries, 0 to 43199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       43200 non-null  int64
#  1   Year-Month-Date  43200 non-null  object
#  2   Time             43200 non-null  object
#  3   Holiday          43200 non-null  int64
#  4   Watt             43200 non-null  int64
#  5   Temp('C)         43200 non-null  float64
#  6   Humidity(%)      43200 non-null  float64
#  7   CPI              43200 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.6+ MB

# %%
plt.figure(figsize=(200,50))
plt.grid()
plt.title("2013_April_Watt")
plt.plot(range(len(Data_13_4)), Data_13_4["Watt"])
plt.savefig('./Data_13_4_Watt.png')
plt.show()

# %%
plt.figure(figsize=(200,50))
plt.grid()
plt.title("2013_April_Holiday")
plt.plot(range(len(Data_13_4)), Data_13_4["Holiday"])
plt.savefig('./Data_13_4_Holiday.png')
plt.show()

# %%
plt.figure(figsize=(200,50))
plt.grid()
plt.title("2013_April_Temp")
plt.plot(range(len(Data_13_4)), Data_13_4["Temp('C)"])
plt.savefig('./Data_13_4_Temp.png')
plt.show()

# %%
plt.figure(figsize=(200,50))
plt.grid()
plt.title("2013_April_Humidity")
plt.plot(range(len(Data_13_4)), Data_13_4["Humidity(%)"])
plt.savefig('./Data_13_4_Humidity.png')
plt.show()

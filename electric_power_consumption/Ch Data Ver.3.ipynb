# %%
import pandas as pd
ch1 = pd.read_csv('./channel_1.dat', names=['Unix', 'Watt'],header=None, delimiter=" ")
print('Done!')
# Out:
# Done!

# %%
ch1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Watt    int64
# dtypes: int64(2)
# memory usage: 333.2 MB

# %%
print(ch1[0:11])
print('1번째')
print(ch1[0:1])
print()
print('21837636번째')
print(ch1[21837635:21837636])
# Out:
#           Unix  Watt
# 0   1352500095   599
# 1   1352500101   582
# 2   1352500107   600
# 3   1352500113   586
# 4   1352500120   596
# 5   1352500132   581
# 6   1352500138   597
# 7   1352500144   592
# 8   1352500150   587
# 9   1352500156   574
# 10  1352500168   577
# 1번째
#          Unix  Watt
# 0  1352500095   599
#
# 21837636번째
#                 Unix  Watt
# 21837635  1493227960   672

# %%
from datetime import datetime
ch1_date = pd.DataFrame(ch1,columns = ['Unix', 'Date', 'Watt'])

ch1_date['Date'] = pd.to_datetime(ch1['Unix'], unit='s')
ch1_date.info()
ch1_date.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Date    datetime64[ns]
#  2   Watt    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 499.8 MB
#          Unix                Date  Watt
# 0  1352500095 2012-11-09 22:28:15   599
# 1  1352500101 2012-11-09 22:28:21   582
# 2  1352500107 2012-11-09 22:28:27   600
# 3  1352500113 2012-11-09 22:28:33   586
# 4  1352500120 2012-11-09 22:28:40   596
# 5  1352500132 2012-11-09 22:28:52   581
# 6  1352500138 2012-11-09 22:28:58   597
# 7  1352500144 2012-11-09 22:29:04   592
# 8  1352500150 2012-11-09 22:29:10   587
# 9  1352500156 2012-11-09 22:29:16   574

# %% [markdown]
# ### 정상 구동 버전 반복을 위한 코드

# %%
"""
jump 를 하는 경우가 있기 때문에 이 경우를 구분 짓는 변수를 j로 선택

watt_list 에는 해당 시단위동안 모든 watt값들이 저장됨. 그중에서 max값을 추출하면 max_watt로 저장됨.

"""

# %%
import csv


# 1. - 시작 지점 지정
#i = 431368, 517000, 684157
i = 684157
print('Running!', '\n'*9)



# 2. - 전체 반복 While문 진입
while(i < 20284836):
    list1 = ch1_date.loc[i].values.tolist()
            
    date = list1[1]
    y1 = date.year
    M1 = date.month
    d1 = date.day
    H1 = date.hour # 이 H가 있어야 밑에 있는 하루 단위 반복이 돌 변수가 됨.
    n = 0 # 데이터 개수를 세기 위한 변수
    
        
        
    # 3. - 하루 단위 반복
    while(H1 < 24):
        
        H0 = 0 # H1은 데이터 원본에 존재하는 시각만 불러오지만, H0는 결손 여부와 무관하게 하루 전체를 표시. (0~23)
        
        # 3'. - 결손 데이터를 처리하고 하루를 넘기기 위한 반복문
        while(H0 < 24):
            
            watt_list=[]
            h = date.hour
            
            # 3.1. - 하루 시작이 0시부터 잘 이뤄지는 경우
            if(H1 == H0):
                
                # 3.1'. - h시와 h+1 시 사이 반복
                while(h < h+1):
                    n=n+1
                    list2 = ch1_date.loc[i].values.tolist()

                    date = list2[1]
                    watt = list2[2]

                    y = date.year
                    M = date.month
                    d = date.day
                    h = date.hour
                    m = date.minute
                    s = date.second

                    print()

                    j=h-H1

                    # 3.1.1. - 시간정보가 제때에 맞는 경우, 계속 반복하게 되는 동작
                    if(j==0):
                        watt_list.append(watt)

                        # 확인용 각 변수 출력
                        total_date = '{0}년 {1}월 {2}일 - {3}시 {4}분 {5}초'.format(y, M, d, h, m, s)
                        print(total_date)
                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('칼럼 출력 >>', list2)

                        i = i+1


                    # 3.1.2. - 시단위가 바로 다음으로 넘어가는 경우
                    elif (j==1):
                        print()
                        
                        print('시 단위 변경! 루프 종료 및 맥스값 추출!')
                        print('========================================< 3.1.2. - 1시간치 끝!! >==================================================')
                        print()
                        
                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'H0 >>', H0, 'h >>', h, '  //  ','i >>', i)
                        print('1시간 동안 데이터 수 >>', n)
                        print()

                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)

                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date2 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                        hourly_date5 = '{0} {1} {2}'.format(y, M, d) # 밑의 경우를 위한 별도 저장
                        hourly_list = []
                        hourly_list.append(hourly_date2)
                        hourly_list.append(max_watt)

                        # 데이터 저장 
                        with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        H0 = H0+1
                        print('\n'*4)

                        break

                    # 3.1.3. - 1 시간치 정리가 끝났는데 일 단위가 다음 날로 넘어가는 경우
                    elif(d1+1==d and h ==0 and H1 ==23):
                        print('========================================< 3.1.3. - 1시간치 끝!! >==================================================')
                        print()
                        
                        print('d1 >>', d1, 'd >>', d, 'H0 >>', H0, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('1시간 동안 데이터 수 >>', n)
                        print()
                        
                        d=d-1
                        h=h+24

                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        
                        hourly_date3 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                        hourly_list = []
                        hourly_list.append(hourly_date3)
                        hourly_list.append(max_watt)

                        # 데이터 저장 
                        with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        H0 = H0+1
                        print('\n'*4)
                        
                        print('========================================< 하루 끝!! >==================================================')
                        print('d1 >>', d1, 'd >>', d, 'H0 >>', H0, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('\n'*4)
                        
                        break

                    
                    # 3.1.4. - 한시간의 데이터가 600개를 넘지 않기 때문에 별도의 경우로 설정. 결손된 데이터를 처라하기 위한 케이스
                    elif (n>600):
                        list(hourly_date5)
                        listed = hourly_date5.split()
                        y5 = listed[0]
                        m5 = listed[1]
                        d5 = listed[2]


                        # 일단 해당 시각 존재하는 만큼은 정리해서 맥스값을 추출
                        print()
                        
                        print('점프! 시 단위 변경! 루프 종료 및 맥스값 추출!')
                        print('========================================< 3.1.5. - 1시간치 끝!! >==================================================')
                        print()

                        print('d1 >>', d1, 'd >>', d, 'H0 >>', H0, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)

                        print('1시간 동안 데이터 수 >>', n)
                        print()

                        # 이 지점이 1시간 간격내에서 구해진 watt 값들 중 max를 뽑는 지점.
                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        time.sleep(1)

                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y5, m5, d5, H1)
                        hourly_list = []
                        hourly_list.append(hourly_date)
                        hourly_list.append(max_watt)

                        # 데이터 저장 
                        with open("./"+str(y5)+'_'+str(m5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!') 
                        print('\n'*4)
                        
                        # 3.1.4.1. - 같은 날짜 안인 경우
                        if(d1==d):
                            jc=j
                            
                            while(jc>0):
                                h=h+1
                                # 점프한 시각 이전까지 Null로 입력 
                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y5, m5, d5, h-j)
                                hourly_list = []
                                hourly_list.append(hourly_date)
                                hourly_list.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y)+'_'+str(m5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list)  

                                print(hourly_list)
                                print('*csv 저장 완료!')
                                print()
                                jc=jc-1
                                H1 = H1+1
                                H0 = H0+1
                                
                        # 3.1.4.2. - 결손 데이터 지속 중 일자가 달라지는 경우
                        if(d1!=d):
                            
                            # 건너뛴 횟수만큼 빈 시간대를 Null로 저장
                            while(H1<24):
                                # 점프한 시각 이전까지 Null로 입력 
                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y5, m5, d5, H1)
                                hourly_list = []
                                hourly_list.append(hourly_date)
                                hourly_list.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y)+'_'+str(m5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list)  

                                print(hourly_list)
                                print('*csv 저장 완료!')
                                print()
                                H1 = H1+1
                                H0 = H0+1
                                
                            H1 = H1+1
                            H0 = H0+1
                            
                        break
                    
            
            # 3.2. - 하루의 시작이 0시부터 순차적으로 진행되는 것이 아닌 결손되어 있는 경우
            if(H1 != H0):

                list3 = ch1_date.loc[i].values.tolist()

                date = list3[1]
                watt = list3[2]

                y = date.year
                M = date.month
                d = date.day
                h = date.hour
                m = date.minute
                s = date.second

                print()

                # jump 를 하는 경우가 있기 때문에 이 경우를 구분 짓는 변수를 j로 선택
                j=h-H1
                    
                print('시작 시각 불일치!!')
                print('H0 >>', H0, 'H1 >>', H1, 'h >>', h, 'j >>', j)
                

                hourly_date3121 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H0)
                hourly_list3121 = []
                hourly_list3121.append(hourly_date3121)
                print(hourly_list3121)
                hourly_list3121.append('Null')

                # 데이터 저장 
                with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow(hourly_list3121)       
                print('*csv 저장 완료!')
                print()
                print('========================================< 3.1.2.1. - 1시간치 끝!! >==================================================')
                
                
                h = h+1
                H0 = H0+1
                print()
                
                # 만약 하루의 시작부터 계속해서 데이터가 없다면 23 즉, 다음날로 넘기기 위함.
                if (H0 ==23):
                    break
                    
        # 3. 의 끝 지점
        print('종료 지점 확인용','\n'*9)
        break

        
    
        
# 전체 While문 종료 지점
# Out:
# Running!
#
#
#
#
#
#
#
#
#
#
# 시작 시가 안 맞아요!!
# H0 >> 0 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 0시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 1 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 1시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 2 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 2시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 3 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 3시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 4 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 4시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 5 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 5시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 시작 시가 안 맞아요!!
# H0 >> 6 H1 >> 7 h >> 7 j >> 0
# ['2013년 1월 28일 - 6시']
# *csv 저장 완료!
#
# ========================================< 3.1.2.1. - 1시간치 끝!! >==================================================
#
#
# 2013년 1월 28일 - 7시 0분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684157
# 칼럼 출력 >> [1359356401, Timestamp('2013-01-28 07:00:01'), 911]
#
# 2013년 1월 28일 - 7시 0분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684158
# 칼럼 출력 >> [1359356407, Timestamp('2013-01-28 07:00:07'), 928]
#
# 2013년 1월 28일 - 7시 0분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684159
# 칼럼 출력 >> [1359356413, Timestamp('2013-01-28 07:00:13'), 920]
#
# 2013년 1월 28일 - 7시 0분 20초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684160
# 칼럼 출력 >> [1359356420, Timestamp('2013-01-28 07:00:20'), 914]
#
# 2013년 1월 28일 - 7시 0분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684161
# 칼럼 출력 >> [1359356426, Timestamp('2013-01-28 07:00:26'), 924]
#
# 2013년 1월 28일 - 7시 0분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684162
# 칼럼 출력 >> [1359356432, Timestamp('2013-01-28 07:00:32'), 915]
#
# 2013년 1월 28일 - 7시 0분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684163
# 칼럼 출력 >> [1359356438, Timestamp('2013-01-28 07:00:38'), 933]
#
# 2013년 1월 28일 - 7시 0분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684164
# 칼럼 출력 >> [1359356444, Timestamp('2013-01-28 07:00:44'), 924]
#
# 2013년 1월 28일 - 7시 0분 51초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684165
# 칼럼 출력 >> [1359356451, Timestamp('2013-01-28 07:00:51'), 921]
#
# 2013년 1월 28일 - 7시 0분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684166
# 칼럼 출력 >> [1359356457, Timestamp('2013-01-28 07:00:57'), 395]
#
# 2013년 1월 28일 - 7시 1분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684167
# 칼럼 출력 >> [1359356463, Timestamp('2013-01-28 07:01:03'), 785]
#
# 2013년 1월 28일 - 7시 1분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684168
# 칼럼 출력 >> [1359356469, Timestamp('2013-01-28 07:01:09'), 392]
#
# 2013년 1월 28일 - 7시 1분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684169
# 칼럼 출력 >> [1359356475, Timestamp('2013-01-28 07:01:15'), 382]
#
# 2013년 1월 28일 - 7시 1분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684170
# 칼럼 출력 >> [1359356482, Timestamp('2013-01-28 07:01:22'), 383]
#
# 2013년 1월 28일 - 7시 1분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684171
# 칼럼 출력 >> [1359356488, Timestamp('2013-01-28 07:01:28'), 390]
#
# 2013년 1월 28일 - 7시 1분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684172
# 칼럼 출력 >> [1359356494, Timestamp('2013-01-28 07:01:34'), 913]
#
# 2013년 1월 28일 - 7시 1분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684173
# 칼럼 출력 >> [1359356500, Timestamp('2013-01-28 07:01:40'), 420]
#
# 2013년 1월 28일 - 7시 1분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684174
# 칼럼 출력 >> [1359356506, Timestamp('2013-01-28 07:01:46'), 400]
#
# 2013년 1월 28일 - 7시 1분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684175
# 칼럼 출력 >> [1359356513, Timestamp('2013-01-28 07:01:53'), 414]
#
# 2013년 1월 28일 - 7시 1분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684176
# 칼럼 출력 >> [1359356519, Timestamp('2013-01-28 07:01:59'), 412]
#
# 2013년 1월 28일 - 7시 2분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684177
# 칼럼 출력 >> [1359356525, Timestamp('2013-01-28 07:02:05'), 907]
#
# 2013년 1월 28일 - 7시 2분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684178
# 칼럼 출력 >> [1359356531, Timestamp('2013-01-28 07:02:11'), 392]
#
# 2013년 1월 28일 - 7시 2분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684179
# 칼럼 출력 >> [1359356537, Timestamp('2013-01-28 07:02:17'), 383]
#
# 2013년 1월 28일 - 7시 2분 24초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684180
# 칼럼 출력 >> [1359356544, Timestamp('2013-01-28 07:02:24'), 393]
#
# 2013년 1월 28일 - 7시 2분 30초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684181
# 칼럼 출력 >> [1359356550, Timestamp('2013-01-28 07:02:30'), 401]
#
# 2013년 1월 28일 - 7시 2분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684182
# 칼럼 출력 >> [1359356556, Timestamp('2013-01-28 07:02:36'), 406]
#
# 2013년 1월 28일 - 7시 2분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684183
# 칼럼 출력 >> [1359356562, Timestamp('2013-01-28 07:02:42'), 412]
#
# 2013년 1월 28일 - 7시 2분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684184
# 칼럼 출력 >> [1359356568, Timestamp('2013-01-28 07:02:48'), 405]
#
# 2013년 1월 28일 - 7시 2분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684185
# 칼럼 출력 >> [1359356574, Timestamp('2013-01-28 07:02:54'), 407]
#
# 2013년 1월 28일 - 7시 3분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684186
# 칼럼 출력 >> [1359356581, Timestamp('2013-01-28 07:03:01'), 418]
#
# 2013년 1월 28일 - 7시 3분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684187
# 칼럼 출력 >> [1359356587, Timestamp('2013-01-28 07:03:07'), 393]
#
# 2013년 1월 28일 - 7시 3분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684188
# 칼럼 출력 >> [1359356593, Timestamp('2013-01-28 07:03:13'), 412]
#
# 2013년 1월 28일 - 7시 3분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684189
# 칼럼 출력 >> [1359356599, Timestamp('2013-01-28 07:03:19'), 406]
#
# 2013년 1월 28일 - 7시 3분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684190
# 칼럼 출력 >> [1359356606, Timestamp('2013-01-28 07:03:26'), 416]
#
# 2013년 1월 28일 - 7시 3분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684191
# 칼럼 출력 >> [1359356612, Timestamp('2013-01-28 07:03:32'), 412]
#
# 2013년 1월 28일 - 7시 3분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684192
# 칼럼 출력 >> [1359356618, Timestamp('2013-01-28 07:03:38'), 412]
#
# 2013년 1월 28일 - 7시 3분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684193
# 칼럼 출력 >> [1359356624, Timestamp('2013-01-28 07:03:44'), 413]
#
# 2013년 1월 28일 - 7시 3분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684194
# 칼럼 출력 >> [1359356630, Timestamp('2013-01-28 07:03:50'), 412]
#
# 2013년 1월 28일 - 7시 3분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684195
# 칼럼 출력 >> [1359356637, Timestamp('2013-01-28 07:03:57'), 406]
#
# 2013년 1월 28일 - 7시 4분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684196
# 칼럼 출력 >> [1359356643, Timestamp('2013-01-28 07:04:03'), 424]
#
# 2013년 1월 28일 - 7시 4분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684197
# 칼럼 출력 >> [1359356649, Timestamp('2013-01-28 07:04:09'), 419]
#
# 2013년 1월 28일 - 7시 4분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684198
# 칼럼 출력 >> [1359356655, Timestamp('2013-01-28 07:04:15'), 418]
#
# 2013년 1월 28일 - 7시 4분 21초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684199
# 칼럼 출력 >> [1359356661, Timestamp('2013-01-28 07:04:21'), 407]
#
# 2013년 1월 28일 - 7시 4분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684200
# 칼럼 출력 >> [1359356668, Timestamp('2013-01-28 07:04:28'), 398]
#
# 2013년 1월 28일 - 7시 4분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684201
# 칼럼 출력 >> [1359356674, Timestamp('2013-01-28 07:04:34'), 398]
#
# 2013년 1월 28일 - 7시 4분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684202
# 칼럼 출력 >> [1359356680, Timestamp('2013-01-28 07:04:40'), 384]
#
# 2013년 1월 28일 - 7시 4분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684203
# 칼럼 출력 >> [1359356686, Timestamp('2013-01-28 07:04:46'), 393]
#
# 2013년 1월 28일 - 7시 4분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684204
# 칼럼 출력 >> [1359356692, Timestamp('2013-01-28 07:04:52'), 395]
#
# 2013년 1월 28일 - 7시 4분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684205
# 칼럼 출력 >> [1359356699, Timestamp('2013-01-28 07:04:59'), 405]
#
# 2013년 1월 28일 - 7시 5분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684206
# 칼럼 출력 >> [1359356705, Timestamp('2013-01-28 07:05:05'), 390]
#
# 2013년 1월 28일 - 7시 5분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684207
# 칼럼 출력 >> [1359356711, Timestamp('2013-01-28 07:05:11'), 396]
#
# 2013년 1월 28일 - 7시 5분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684208
# 칼럼 출력 >> [1359356717, Timestamp('2013-01-28 07:05:17'), 416]
#
# 2013년 1월 28일 - 7시 5분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684209
# 칼럼 출력 >> [1359356723, Timestamp('2013-01-28 07:05:23'), 398]
#
# 2013년 1월 28일 - 7시 5분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684210
# 칼럼 출력 >> [1359356736, Timestamp('2013-01-28 07:05:36'), 389]
#
# 2013년 1월 28일 - 7시 5분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684211
# 칼럼 출력 >> [1359356742, Timestamp('2013-01-28 07:05:42'), 388]
#
# 2013년 1월 28일 - 7시 5분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684212
# 칼럼 출력 >> [1359356748, Timestamp('2013-01-28 07:05:48'), 392]
#
# 2013년 1월 28일 - 7시 5분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684213
# 칼럼 출력 >> [1359356754, Timestamp('2013-01-28 07:05:54'), 404]
#
# 2013년 1월 28일 - 7시 6분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684214
# 칼럼 출력 >> [1359356761, Timestamp('2013-01-28 07:06:01'), 410]
#
# 2013년 1월 28일 - 7시 6분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684215
# 칼럼 출력 >> [1359356767, Timestamp('2013-01-28 07:06:07'), 388]
#
# 2013년 1월 28일 - 7시 6분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684216
# 칼럼 출력 >> [1359356773, Timestamp('2013-01-28 07:06:13'), 419]
#
# 2013년 1월 28일 - 7시 6분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684217
# 칼럼 출력 >> [1359356779, Timestamp('2013-01-28 07:06:19'), 406]
#
# 2013년 1월 28일 - 7시 6분 25초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684218
# 칼럼 출력 >> [1359356785, Timestamp('2013-01-28 07:06:25'), 406]
#
# 2013년 1월 28일 - 7시 6분 31초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684219
# 칼럼 출력 >> [1359356791, Timestamp('2013-01-28 07:06:31'), 399]
#
# 2013년 1월 28일 - 7시 6분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684220
# 칼럼 출력 >> [1359356798, Timestamp('2013-01-28 07:06:38'), 429]
#
# 2013년 1월 28일 - 7시 6분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684221
# 칼럼 출력 >> [1359356804, Timestamp('2013-01-28 07:06:44'), 422]
#
# 2013년 1월 28일 - 7시 6분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684222
# 칼럼 출력 >> [1359356810, Timestamp('2013-01-28 07:06:50'), 438]
#
# 2013년 1월 28일 - 7시 6분 56초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684223
# 칼럼 출력 >> [1359356816, Timestamp('2013-01-28 07:06:56'), 417]
#
# 2013년 1월 28일 - 7시 7분 2초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684224
# 칼럼 출력 >> [1359356822, Timestamp('2013-01-28 07:07:02'), 403]
#
# 2013년 1월 28일 - 7시 7분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684225
# 칼럼 출력 >> [1359356829, Timestamp('2013-01-28 07:07:09'), 415]
#
# 2013년 1월 28일 - 7시 7분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684226
# 칼럼 출력 >> [1359356835, Timestamp('2013-01-28 07:07:15'), 433]
#
# 2013년 1월 28일 - 7시 7분 21초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684227
# 칼럼 출력 >> [1359356841, Timestamp('2013-01-28 07:07:21'), 427]
#
# 2013년 1월 28일 - 7시 7분 27초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684228
# 칼럼 출력 >> [1359356847, Timestamp('2013-01-28 07:07:27'), 431]
#
# 2013년 1월 28일 - 7시 7분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684229
# 칼럼 출력 >> [1359356854, Timestamp('2013-01-28 07:07:34'), 426]
#
# 2013년 1월 28일 - 7시 7분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684230
# 칼럼 출력 >> [1359356860, Timestamp('2013-01-28 07:07:40'), 426]
#
# 2013년 1월 28일 - 7시 7분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684231
# 칼럼 출력 >> [1359356866, Timestamp('2013-01-28 07:07:46'), 399]
#
# 2013년 1월 28일 - 7시 7분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684232
# 칼럼 출력 >> [1359356872, Timestamp('2013-01-28 07:07:52'), 411]
#
# 2013년 1월 28일 - 7시 7분 58초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684233
# 칼럼 출력 >> [1359356878, Timestamp('2013-01-28 07:07:58'), 434]
#
# 2013년 1월 28일 - 7시 8분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684234
# 칼럼 출력 >> [1359356885, Timestamp('2013-01-28 07:08:05'), 414]
#
# 2013년 1월 28일 - 7시 8분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684235
# 칼럼 출력 >> [1359356891, Timestamp('2013-01-28 07:08:11'), 412]
#
# 2013년 1월 28일 - 7시 8분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684236
# 칼럼 출력 >> [1359356897, Timestamp('2013-01-28 07:08:17'), 423]
#
# 2013년 1월 28일 - 7시 8분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684237
# 칼럼 출력 >> [1359356903, Timestamp('2013-01-28 07:08:23'), 423]
#
# 2013년 1월 28일 - 7시 8분 29초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684238
# 칼럼 출력 >> [1359356909, Timestamp('2013-01-28 07:08:29'), 414]
#
# 2013년 1월 28일 - 7시 8분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684239
# 칼럼 출력 >> [1359356916, Timestamp('2013-01-28 07:08:36'), 428]
#
# 2013년 1월 28일 - 7시 8분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684240
# 칼럼 출력 >> [1359356922, Timestamp('2013-01-28 07:08:42'), 418]
#
# 2013년 1월 28일 - 7시 8분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684241
# 칼럼 출력 >> [1359356928, Timestamp('2013-01-28 07:08:48'), 430]
#
# 2013년 1월 28일 - 7시 8분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684242
# 칼럼 출력 >> [1359356934, Timestamp('2013-01-28 07:08:54'), 429]
#
# 2013년 1월 28일 - 7시 9분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684243
# 칼럼 출력 >> [1359356947, Timestamp('2013-01-28 07:09:07'), 405]
#
# 2013년 1월 28일 - 7시 9분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684244
# 칼럼 출력 >> [1359356953, Timestamp('2013-01-28 07:09:13'), 403]
#
# 2013년 1월 28일 - 7시 9분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684245
# 칼럼 출력 >> [1359356959, Timestamp('2013-01-28 07:09:19'), 411]
#
# 2013년 1월 28일 - 7시 9분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684246
# 칼럼 출력 >> [1359356966, Timestamp('2013-01-28 07:09:26'), 403]
#
# 2013년 1월 28일 - 7시 9분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684247
# 칼럼 출력 >> [1359356972, Timestamp('2013-01-28 07:09:32'), 408]
#
# 2013년 1월 28일 - 7시 9분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684248
# 칼럼 출력 >> [1359356978, Timestamp('2013-01-28 07:09:38'), 397]
#
# 2013년 1월 28일 - 7시 9분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684249
# 칼럼 출력 >> [1359356984, Timestamp('2013-01-28 07:09:44'), 406]
#
# 2013년 1월 28일 - 7시 9분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684250
# 칼럼 출력 >> [1359356990, Timestamp('2013-01-28 07:09:50'), 415]
#
# 2013년 1월 28일 - 7시 9분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684251
# 칼럼 출력 >> [1359356997, Timestamp('2013-01-28 07:09:57'), 400]
#
# 2013년 1월 28일 - 7시 10분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684252
# 칼럼 출력 >> [1359357003, Timestamp('2013-01-28 07:10:03'), 402]
#
# 2013년 1월 28일 - 7시 10분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684253
# 칼럼 출력 >> [1359357009, Timestamp('2013-01-28 07:10:09'), 420]
#
# 2013년 1월 28일 - 7시 10분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684254
# 칼럼 출력 >> [1359357015, Timestamp('2013-01-28 07:10:15'), 411]
#
# 2013년 1월 28일 - 7시 10분 21초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684255
# 칼럼 출력 >> [1359357021, Timestamp('2013-01-28 07:10:21'), 404]
#
# 2013년 1월 28일 - 7시 10분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684256
# 칼럼 출력 >> [1359357028, Timestamp('2013-01-28 07:10:28'), 404]
#
# 2013년 1월 28일 - 7시 10분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684257
# 칼럼 출력 >> [1359357034, Timestamp('2013-01-28 07:10:34'), 409]
#
# 2013년 1월 28일 - 7시 10분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684258
# 칼럼 출력 >> [1359357040, Timestamp('2013-01-28 07:10:40'), 411]
#
# 2013년 1월 28일 - 7시 10분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684259
# 칼럼 출력 >> [1359357046, Timestamp('2013-01-28 07:10:46'), 408]
#
# 2013년 1월 28일 - 7시 10분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684260
# 칼럼 출력 >> [1359357052, Timestamp('2013-01-28 07:10:52'), 392]
#
# 2013년 1월 28일 - 7시 10분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684261
# 칼럼 출력 >> [1359357059, Timestamp('2013-01-28 07:10:59'), 408]
#
# 2013년 1월 28일 - 7시 11분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684262
# 칼럼 출력 >> [1359357065, Timestamp('2013-01-28 07:11:05'), 404]
#
# 2013년 1월 28일 - 7시 11분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684263
# 칼럼 출력 >> [1359357071, Timestamp('2013-01-28 07:11:11'), 419]
#
# 2013년 1월 28일 - 7시 11분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684264
# 칼럼 출력 >> [1359357077, Timestamp('2013-01-28 07:11:17'), 383]
#
# 2013년 1월 28일 - 7시 11분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684265
# 칼럼 출력 >> [1359357083, Timestamp('2013-01-28 07:11:23'), 406]
#
# 2013년 1월 28일 - 7시 11분 30초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684266
# 칼럼 출력 >> [1359357090, Timestamp('2013-01-28 07:11:30'), 403]
#
# 2013년 1월 28일 - 7시 11분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684267
# 칼럼 출력 >> [1359357096, Timestamp('2013-01-28 07:11:36'), 386]
#
# 2013년 1월 28일 - 7시 11분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684268
# 칼럼 출력 >> [1359357102, Timestamp('2013-01-28 07:11:42'), 384]
#
# 2013년 1월 28일 - 7시 11분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684269
# 칼럼 출력 >> [1359357108, Timestamp('2013-01-28 07:11:48'), 394]
#
# 2013년 1월 28일 - 7시 11분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684270
# 칼럼 출력 >> [1359357114, Timestamp('2013-01-28 07:11:54'), 380]
#
# 2013년 1월 28일 - 7시 12분 0초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684271
# 칼럼 출력 >> [1359357120, Timestamp('2013-01-28 07:12:00'), 397]
#
# 2013년 1월 28일 - 7시 12분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684272
# 칼럼 출력 >> [1359357127, Timestamp('2013-01-28 07:12:07'), 388]
#
# 2013년 1월 28일 - 7시 12분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684273
# 칼럼 출력 >> [1359357133, Timestamp('2013-01-28 07:12:13'), 381]
#
# 2013년 1월 28일 - 7시 12분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684274
# 칼럼 출력 >> [1359357139, Timestamp('2013-01-28 07:12:19'), 387]
#
# 2013년 1월 28일 - 7시 12분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684275
# 칼럼 출력 >> [1359357152, Timestamp('2013-01-28 07:12:32'), 387]
#
# 2013년 1월 28일 - 7시 12분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684276
# 칼럼 출력 >> [1359357158, Timestamp('2013-01-28 07:12:38'), 398]
#
# 2013년 1월 28일 - 7시 12분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684277
# 칼럼 출력 >> [1359357164, Timestamp('2013-01-28 07:12:44'), 368]
#
# 2013년 1월 28일 - 7시 12분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684278
# 칼럼 출력 >> [1359357170, Timestamp('2013-01-28 07:12:50'), 376]
#
# 2013년 1월 28일 - 7시 12분 56초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684279
# 칼럼 출력 >> [1359357176, Timestamp('2013-01-28 07:12:56'), 377]
#
# 2013년 1월 28일 - 7시 13분 2초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684280
# 칼럼 출력 >> [1359357182, Timestamp('2013-01-28 07:13:02'), 362]
#
# 2013년 1월 28일 - 7시 13분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684281
# 칼럼 출력 >> [1359357189, Timestamp('2013-01-28 07:13:09'), 388]
#
# 2013년 1월 28일 - 7시 13분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684282
# 칼럼 출력 >> [1359357195, Timestamp('2013-01-28 07:13:15'), 367]
#
# 2013년 1월 28일 - 7시 13분 21초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684283
# 칼럼 출력 >> [1359357201, Timestamp('2013-01-28 07:13:21'), 366]
#
# 2013년 1월 28일 - 7시 13분 27초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684284
# 칼럼 출력 >> [1359357207, Timestamp('2013-01-28 07:13:27'), 373]
#
# 2013년 1월 28일 - 7시 13분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684285
# 칼럼 출력 >> [1359357214, Timestamp('2013-01-28 07:13:34'), 372]
#
# 2013년 1월 28일 - 7시 13분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684286
# 칼럼 출력 >> [1359357220, Timestamp('2013-01-28 07:13:40'), 389]
#
# 2013년 1월 28일 - 7시 13분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684287
# 칼럼 출력 >> [1359357226, Timestamp('2013-01-28 07:13:46'), 374]
#
# 2013년 1월 28일 - 7시 13분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684288
# 칼럼 출력 >> [1359357232, Timestamp('2013-01-28 07:13:52'), 373]
#
# 2013년 1월 28일 - 7시 13분 58초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684289
# 칼럼 출력 >> [1359357238, Timestamp('2013-01-28 07:13:58'), 381]
#
# 2013년 1월 28일 - 7시 14분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684290
# 칼럼 출력 >> [1359357245, Timestamp('2013-01-28 07:14:05'), 388]
#
# 2013년 1월 28일 - 7시 14분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684291
# 칼럼 출력 >> [1359357251, Timestamp('2013-01-28 07:14:11'), 364]
#
# 2013년 1월 28일 - 7시 14분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684292
# 칼럼 출력 >> [1359357257, Timestamp('2013-01-28 07:14:17'), 367]
#
# 2013년 1월 28일 - 7시 14분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684293
# 칼럼 출력 >> [1359357263, Timestamp('2013-01-28 07:14:23'), 375]
#
# 2013년 1월 28일 - 7시 14분 29초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684294
# 칼럼 출력 >> [1359357269, Timestamp('2013-01-28 07:14:29'), 379]
#
# 2013년 1월 28일 - 7시 14분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684295
# 칼럼 출력 >> [1359357276, Timestamp('2013-01-28 07:14:36'), 371]
#
# 2013년 1월 28일 - 7시 14분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684296
# 칼럼 출력 >> [1359357282, Timestamp('2013-01-28 07:14:42'), 377]
#
# 2013년 1월 28일 - 7시 14분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684297
# 칼럼 출력 >> [1359357288, Timestamp('2013-01-28 07:14:48'), 369]
#
# 2013년 1월 28일 - 7시 14분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684298
# 칼럼 출력 >> [1359357294, Timestamp('2013-01-28 07:14:54'), 367]
#
# 2013년 1월 28일 - 7시 15분 0초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684299
# 칼럼 출력 >> [1359357300, Timestamp('2013-01-28 07:15:00'), 367]
#
# 2013년 1월 28일 - 7시 15분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684300
# 칼럼 출력 >> [1359357307, Timestamp('2013-01-28 07:15:07'), 367]
#
# 2013년 1월 28일 - 7시 15분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684301
# 칼럼 출력 >> [1359357313, Timestamp('2013-01-28 07:15:13'), 358]
#
# 2013년 1월 28일 - 7시 15분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684302
# 칼럼 출력 >> [1359357319, Timestamp('2013-01-28 07:15:19'), 399]
#
# 2013년 1월 28일 - 7시 15분 25초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684303
# 칼럼 출력 >> [1359357325, Timestamp('2013-01-28 07:15:25'), 382]
#
# 2013년 1월 28일 - 7시 15분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684304
# 칼럼 출력 >> [1359357332, Timestamp('2013-01-28 07:15:32'), 391]
#
# 2013년 1월 28일 - 7시 15분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684305
# 칼럼 출력 >> [1359357338, Timestamp('2013-01-28 07:15:38'), 360]
#
# 2013년 1월 28일 - 7시 15분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684306
# 칼럼 출력 >> [1359357344, Timestamp('2013-01-28 07:15:44'), 398]
#
# 2013년 1월 28일 - 7시 15분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684307
# 칼럼 출력 >> [1359357350, Timestamp('2013-01-28 07:15:50'), 380]
#
# 2013년 1월 28일 - 7시 15분 56초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684308
# 칼럼 출력 >> [1359357356, Timestamp('2013-01-28 07:15:56'), 373]
#
# 2013년 1월 28일 - 7시 16분 2초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684309
# 칼럼 출력 >> [1359357362, Timestamp('2013-01-28 07:16:02'), 405]
#
# 2013년 1월 28일 - 7시 16분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684310
# 칼럼 출력 >> [1359357369, Timestamp('2013-01-28 07:16:09'), 383]
#
# 2013년 1월 28일 - 7시 16분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684311
# 칼럼 출력 >> [1359357375, Timestamp('2013-01-28 07:16:15'), 380]
#
# 2013년 1월 28일 - 7시 16분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684312
# 칼럼 출력 >> [1359357394, Timestamp('2013-01-28 07:16:34'), 364]
#
# 2013년 1월 28일 - 7시 16분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684313
# 칼럼 출력 >> [1359357400, Timestamp('2013-01-28 07:16:40'), 356]
#
# 2013년 1월 28일 - 7시 16분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684314
# 칼럼 출력 >> [1359357406, Timestamp('2013-01-28 07:16:46'), 406]
#
# 2013년 1월 28일 - 7시 16분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684315
# 칼럼 출력 >> [1359357412, Timestamp('2013-01-28 07:16:52'), 383]
#
# 2013년 1월 28일 - 7시 16분 58초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684316
# 칼럼 출력 >> [1359357418, Timestamp('2013-01-28 07:16:58'), 390]
#
# 2013년 1월 28일 - 7시 17분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684317
# 칼럼 출력 >> [1359357425, Timestamp('2013-01-28 07:17:05'), 364]
#
# 2013년 1월 28일 - 7시 17분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684318
# 칼럼 출력 >> [1359357431, Timestamp('2013-01-28 07:17:11'), 392]
#
# 2013년 1월 28일 - 7시 17분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684319
# 칼럼 출력 >> [1359357437, Timestamp('2013-01-28 07:17:17'), 386]
#
# 2013년 1월 28일 - 7시 17분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684320
# 칼럼 출력 >> [1359357443, Timestamp('2013-01-28 07:17:23'), 375]
#
# 2013년 1월 28일 - 7시 17분 29초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684321
# 칼럼 출력 >> [1359357449, Timestamp('2013-01-28 07:17:29'), 382]
#
# 2013년 1월 28일 - 7시 17분 35초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684322
# 칼럼 출력 >> [1359357455, Timestamp('2013-01-28 07:17:35'), 377]
#
# 2013년 1월 28일 - 7시 17분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684323
# 칼럼 출력 >> [1359357462, Timestamp('2013-01-28 07:17:42'), 239]
#
# 2013년 1월 28일 - 7시 17분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684324
# 칼럼 출력 >> [1359357468, Timestamp('2013-01-28 07:17:48'), 239]
#
# 2013년 1월 28일 - 7시 17분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684325
# 칼럼 출력 >> [1359357474, Timestamp('2013-01-28 07:17:54'), 241]
#
# 2013년 1월 28일 - 7시 18분 0초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684326
# 칼럼 출력 >> [1359357480, Timestamp('2013-01-28 07:18:00'), 242]
#
# 2013년 1월 28일 - 7시 18분 6초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684327
# 칼럼 출력 >> [1359357486, Timestamp('2013-01-28 07:18:06'), 243]
#
# 2013년 1월 28일 - 7시 18분 12초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684328
# 칼럼 출력 >> [1359357492, Timestamp('2013-01-28 07:18:12'), 332]
#
# 2013년 1월 28일 - 7시 18분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684329
# 칼럼 출력 >> [1359357499, Timestamp('2013-01-28 07:18:19'), 338]
#
# 2013년 1월 28일 - 7시 18분 25초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684330
# 칼럼 출력 >> [1359357505, Timestamp('2013-01-28 07:18:25'), 348]
#
# 2013년 1월 28일 - 7시 18분 31초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684331
# 칼럼 출력 >> [1359357511, Timestamp('2013-01-28 07:18:31'), 356]
#
# 2013년 1월 28일 - 7시 18분 37초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684332
# 칼럼 출력 >> [1359357517, Timestamp('2013-01-28 07:18:37'), 352]
#
# 2013년 1월 28일 - 7시 18분 43초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684333
# 칼럼 출력 >> [1359357523, Timestamp('2013-01-28 07:18:43'), 349]
#
# 2013년 1월 28일 - 7시 18분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684334
# 칼럼 출력 >> [1359357530, Timestamp('2013-01-28 07:18:50'), 350]
#
# 2013년 1월 28일 - 7시 18분 56초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684335
# 칼럼 출력 >> [1359357536, Timestamp('2013-01-28 07:18:56'), 345]
#
# 2013년 1월 28일 - 7시 19분 2초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684336
# 칼럼 출력 >> [1359357542, Timestamp('2013-01-28 07:19:02'), 349]
#
# 2013년 1월 28일 - 7시 19분 8초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684337
# 칼럼 출력 >> [1359357548, Timestamp('2013-01-28 07:19:08'), 345]
#
# 2013년 1월 28일 - 7시 19분 14초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684338
# 칼럼 출력 >> [1359357554, Timestamp('2013-01-28 07:19:14'), 349]
#
# 2013년 1월 28일 - 7시 19분 21초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684339
# 칼럼 출력 >> [1359357561, Timestamp('2013-01-28 07:19:21'), 345]
#
# 2013년 1월 28일 - 7시 19분 27초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684340
# 칼럼 출력 >> [1359357567, Timestamp('2013-01-28 07:19:27'), 344]
#
# 2013년 1월 28일 - 7시 19분 33초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684341
# 칼럼 출력 >> [1359357573, Timestamp('2013-01-28 07:19:33'), 350]
#
# 2013년 1월 28일 - 7시 19분 39초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684342
# 칼럼 출력 >> [1359357579, Timestamp('2013-01-28 07:19:39'), 346]
#
# 2013년 1월 28일 - 7시 19분 45초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684343
# 칼럼 출력 >> [1359357585, Timestamp('2013-01-28 07:19:45'), 345]
#
# 2013년 1월 28일 - 7시 19분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684344
# 칼럼 출력 >> [1359357592, Timestamp('2013-01-28 07:19:52'), 344]
#
# 2013년 1월 28일 - 7시 19분 58초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684345
# 칼럼 출력 >> [1359357598, Timestamp('2013-01-28 07:19:58'), 350]
#
# 2013년 1월 28일 - 7시 20분 4초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684346
# 칼럼 출력 >> [1359357604, Timestamp('2013-01-28 07:20:04'), 344]
#
# 2013년 1월 28일 - 7시 20분 10초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684347
# 칼럼 출력 >> [1359357610, Timestamp('2013-01-28 07:20:10'), 330]
#
# 2013년 1월 28일 - 7시 20분 16초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684348
# 칼럼 출력 >> [1359357616, Timestamp('2013-01-28 07:20:16'), 326]
#
# 2013년 1월 28일 - 7시 20분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684349
# 칼럼 출력 >> [1359357622, Timestamp('2013-01-28 07:20:22'), 325]
#
# 2013년 1월 28일 - 7시 20분 29초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684350
# 칼럼 출력 >> [1359357629, Timestamp('2013-01-28 07:20:29'), 359]
#
# 2013년 1월 28일 - 7시 20분 35초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684351
# 칼럼 출력 >> [1359357635, Timestamp('2013-01-28 07:20:35'), 345]
#
# 2013년 1월 28일 - 7시 20분 47초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684352
# 칼럼 출력 >> [1359357647, Timestamp('2013-01-28 07:20:47'), 332]
#
# 2013년 1월 28일 - 7시 20분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684353
# 칼럼 출력 >> [1359357653, Timestamp('2013-01-28 07:20:53'), 339]
#
# 2013년 1월 28일 - 7시 21분 0초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684354
# 칼럼 출력 >> [1359357660, Timestamp('2013-01-28 07:21:00'), 351]
#
# 2013년 1월 28일 - 7시 21분 6초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684355
# 칼럼 출력 >> [1359357666, Timestamp('2013-01-28 07:21:06'), 341]
#
# 2013년 1월 28일 - 7시 21분 12초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684356
# 칼럼 출력 >> [1359357672, Timestamp('2013-01-28 07:21:12'), 335]
#
# 2013년 1월 28일 - 7시 21분 18초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684357
# 칼럼 출력 >> [1359357678, Timestamp('2013-01-28 07:21:18'), 326]
#
# 2013년 1월 28일 - 7시 21분 24초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684358
# 칼럼 출력 >> [1359357684, Timestamp('2013-01-28 07:21:24'), 331]
#
# 2013년 1월 28일 - 7시 21분 31초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684359
# 칼럼 출력 >> [1359357691, Timestamp('2013-01-28 07:21:31'), 346]
#
# 2013년 1월 28일 - 7시 21분 37초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684360
# 칼럼 출력 >> [1359357697, Timestamp('2013-01-28 07:21:37'), 332]
#
# 2013년 1월 28일 - 7시 21분 43초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684361
# 칼럼 출력 >> [1359357703, Timestamp('2013-01-28 07:21:43'), 330]
#
# 2013년 1월 28일 - 7시 21분 49초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684362
# 칼럼 출력 >> [1359357709, Timestamp('2013-01-28 07:21:49'), 332]
#
# 2013년 1월 28일 - 7시 21분 55초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684363
# 칼럼 출력 >> [1359357715, Timestamp('2013-01-28 07:21:55'), 332]
#
# 2013년 1월 28일 - 7시 22분 2초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684364
# 칼럼 출력 >> [1359357722, Timestamp('2013-01-28 07:22:02'), 352]
#
# 2013년 1월 28일 - 7시 22분 8초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684365
# 칼럼 출력 >> [1359357728, Timestamp('2013-01-28 07:22:08'), 351]
#
# 2013년 1월 28일 - 7시 22분 14초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684366
# 칼럼 출력 >> [1359357734, Timestamp('2013-01-28 07:22:14'), 345]
#
# 2013년 1월 28일 - 7시 22분 20초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684367
# 칼럼 출력 >> [1359357740, Timestamp('2013-01-28 07:22:20'), 344]
#
# 2013년 1월 28일 - 7시 22분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684368
# 칼럼 출력 >> [1359357746, Timestamp('2013-01-28 07:22:26'), 346]
#
# 2013년 1월 28일 - 7시 22분 33초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684369
# 칼럼 출력 >> [1359357753, Timestamp('2013-01-28 07:22:33'), 340]
#
# 2013년 1월 28일 - 7시 22분 39초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684370
# 칼럼 출력 >> [1359357759, Timestamp('2013-01-28 07:22:39'), 338]
#
# 2013년 1월 28일 - 7시 22분 45초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684371
# 칼럼 출력 >> [1359357765, Timestamp('2013-01-28 07:22:45'), 357]
#
# 2013년 1월 28일 - 7시 22분 51초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684372
# 칼럼 출력 >> [1359357771, Timestamp('2013-01-28 07:22:51'), 342]
#
# 2013년 1월 28일 - 7시 22분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684373
# 칼럼 출력 >> [1359357777, Timestamp('2013-01-28 07:22:57'), 343]
#
# 2013년 1월 28일 - 7시 23분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684374
# 칼럼 출력 >> [1359357783, Timestamp('2013-01-28 07:23:03'), 341]
#
# 2013년 1월 28일 - 7시 23분 10초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684375
# 칼럼 출력 >> [1359357790, Timestamp('2013-01-28 07:23:10'), 348]
#
# 2013년 1월 28일 - 7시 23분 16초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684376
# 칼럼 출력 >> [1359357796, Timestamp('2013-01-28 07:23:16'), 343]
#
# 2013년 1월 28일 - 7시 23분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684377
# 칼럼 출력 >> [1359357802, Timestamp('2013-01-28 07:23:22'), 343]
#
# 2013년 1월 28일 - 7시 23분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684378
# 칼럼 출력 >> [1359357808, Timestamp('2013-01-28 07:23:28'), 340]
#
# 2013년 1월 28일 - 7시 23분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684379
# 칼럼 출력 >> [1359357814, Timestamp('2013-01-28 07:23:34'), 342]
#
# 2013년 1월 28일 - 7시 23분 41초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684380
# 칼럼 출력 >> [1359357821, Timestamp('2013-01-28 07:23:41'), 338]
#
# 2013년 1월 28일 - 7시 23분 47초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684381
# 칼럼 출력 >> [1359357827, Timestamp('2013-01-28 07:23:47'), 336]
#
# 2013년 1월 28일 - 7시 23분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684382
# 칼럼 출력 >> [1359357833, Timestamp('2013-01-28 07:23:53'), 356]
#
# 2013년 1월 28일 - 7시 23분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684383
# 칼럼 출력 >> [1359357839, Timestamp('2013-01-28 07:23:59'), 361]
#
# 2013년 1월 28일 - 7시 24분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684384
# 칼럼 출력 >> [1359357845, Timestamp('2013-01-28 07:24:05'), 360]
#
# 2013년 1월 28일 - 7시 24분 12초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684385
# 칼럼 출력 >> [1359357852, Timestamp('2013-01-28 07:24:12'), 355]
#
# 2013년 1월 28일 - 7시 24분 18초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684386
# 칼럼 출력 >> [1359357858, Timestamp('2013-01-28 07:24:18'), 360]
#
# 2013년 1월 28일 - 7시 24분 24초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684387
# 칼럼 출력 >> [1359357864, Timestamp('2013-01-28 07:24:24'), 359]
#
# 2013년 1월 28일 - 7시 24분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684388
# 칼럼 출력 >> [1359357876, Timestamp('2013-01-28 07:24:36'), 359]
#
# 2013년 1월 28일 - 7시 24분 43초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684389
# 칼럼 출력 >> [1359357883, Timestamp('2013-01-28 07:24:43'), 356]
#
# 2013년 1월 28일 - 7시 24분 49초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684390
# 칼럼 출력 >> [1359357889, Timestamp('2013-01-28 07:24:49'), 358]
#
# 2013년 1월 28일 - 7시 24분 55초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684391
# 칼럼 출력 >> [1359357895, Timestamp('2013-01-28 07:24:55'), 356]
#
# 2013년 1월 28일 - 7시 25분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684392
# 칼럼 출력 >> [1359357901, Timestamp('2013-01-28 07:25:01'), 354]
#
# 2013년 1월 28일 - 7시 25분 8초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684393
# 칼럼 출력 >> [1359357908, Timestamp('2013-01-28 07:25:08'), 354]
#
# 2013년 1월 28일 - 7시 25분 14초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684394
# 칼럼 출력 >> [1359357914, Timestamp('2013-01-28 07:25:14'), 354]
#
# 2013년 1월 28일 - 7시 25분 20초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684395
# 칼럼 출력 >> [1359357920, Timestamp('2013-01-28 07:25:20'), 351]
#
# 2013년 1월 28일 - 7시 25분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684396
# 칼럼 출력 >> [1359357926, Timestamp('2013-01-28 07:25:26'), 349]
#
# 2013년 1월 28일 - 7시 25분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684397
# 칼럼 출력 >> [1359357932, Timestamp('2013-01-28 07:25:32'), 339]
#
# 2013년 1월 28일 - 7시 25분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684398
# 칼럼 출력 >> [1359357938, Timestamp('2013-01-28 07:25:38'), 346]
#
# 2013년 1월 28일 - 7시 25분 45초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684399
# 칼럼 출력 >> [1359357945, Timestamp('2013-01-28 07:25:45'), 343]
#
# 2013년 1월 28일 - 7시 25분 51초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684400
# 칼럼 출력 >> [1359357951, Timestamp('2013-01-28 07:25:51'), 340]
#
# 2013년 1월 28일 - 7시 25분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684401
# 칼럼 출력 >> [1359357957, Timestamp('2013-01-28 07:25:57'), 346]
#
# 2013년 1월 28일 - 7시 26분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684402
# 칼럼 출력 >> [1359357963, Timestamp('2013-01-28 07:26:03'), 341]
#
# 2013년 1월 28일 - 7시 26분 10초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684403
# 칼럼 출력 >> [1359357970, Timestamp('2013-01-28 07:26:10'), 344]
#
# 2013년 1월 28일 - 7시 26분 16초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684404
# 칼럼 출력 >> [1359357976, Timestamp('2013-01-28 07:26:16'), 346]
#
# 2013년 1월 28일 - 7시 26분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684405
# 칼럼 출력 >> [1359357982, Timestamp('2013-01-28 07:26:22'), 340]
#
# 2013년 1월 28일 - 7시 26분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684406
# 칼럼 출력 >> [1359357988, Timestamp('2013-01-28 07:26:28'), 341]
#
# 2013년 1월 28일 - 7시 26분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684407
# 칼럼 출력 >> [1359357994, Timestamp('2013-01-28 07:26:34'), 342]
#
# 2013년 1월 28일 - 7시 26분 41초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684408
# 칼럼 출력 >> [1359358001, Timestamp('2013-01-28 07:26:41'), 354]
#
# 2013년 1월 28일 - 7시 26분 47초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684409
# 칼럼 출력 >> [1359358007, Timestamp('2013-01-28 07:26:47'), 366]
#
# 2013년 1월 28일 - 7시 26분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684410
# 칼럼 출력 >> [1359358013, Timestamp('2013-01-28 07:26:53'), 369]
#
# 2013년 1월 28일 - 7시 26분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684411
# 칼럼 출력 >> [1359358019, Timestamp('2013-01-28 07:26:59'), 365]
#
# 2013년 1월 28일 - 7시 27분 6초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684412
# 칼럼 출력 >> [1359358026, Timestamp('2013-01-28 07:27:06'), 354]
#
# 2013년 1월 28일 - 7시 27분 12초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684413
# 칼럼 출력 >> [1359358032, Timestamp('2013-01-28 07:27:12'), 355]
#
# 2013년 1월 28일 - 7시 27분 18초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684414
# 칼럼 출력 >> [1359358038, Timestamp('2013-01-28 07:27:18'), 358]
#
# 2013년 1월 28일 - 7시 27분 24초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684415
# 칼럼 출력 >> [1359358044, Timestamp('2013-01-28 07:27:24'), 356]
#
# 2013년 1월 28일 - 7시 27분 30초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684416
# 칼럼 출력 >> [1359358050, Timestamp('2013-01-28 07:27:30'), 356]
#
# 2013년 1월 28일 - 7시 27분 37초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684417
# 칼럼 출력 >> [1359358057, Timestamp('2013-01-28 07:27:37'), 359]
#
# 2013년 1월 28일 - 7시 27분 43초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684418
# 칼럼 출력 >> [1359358063, Timestamp('2013-01-28 07:27:43'), 360]
#
# 2013년 1월 28일 - 7시 27분 49초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684419
# 칼럼 출력 >> [1359358069, Timestamp('2013-01-28 07:27:49'), 360]
#
# 2013년 1월 28일 - 7시 27분 55초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684420
# 칼럼 출력 >> [1359358075, Timestamp('2013-01-28 07:27:55'), 361]
#
# 2013년 1월 28일 - 7시 28분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684421
# 칼럼 출력 >> [1359358081, Timestamp('2013-01-28 07:28:01'), 361]
#
# 2013년 1월 28일 - 7시 28분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684422
# 칼럼 출력 >> [1359358118, Timestamp('2013-01-28 07:28:38'), 360]
#
# 2013년 1월 28일 - 7시 28분 45초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684423
# 칼럼 출력 >> [1359358125, Timestamp('2013-01-28 07:28:45'), 357]
#
# 2013년 1월 28일 - 7시 28분 51초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684424
# 칼럼 출력 >> [1359358131, Timestamp('2013-01-28 07:28:51'), 359]
#
# 2013년 1월 28일 - 7시 28분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684425
# 칼럼 출력 >> [1359358137, Timestamp('2013-01-28 07:28:57'), 354]
#
# 2013년 1월 28일 - 7시 29분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684426
# 칼럼 출력 >> [1359358143, Timestamp('2013-01-28 07:29:03'), 362]
#
# 2013년 1월 28일 - 7시 29분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684427
# 칼럼 출력 >> [1359358149, Timestamp('2013-01-28 07:29:09'), 342]
#
# 2013년 1월 28일 - 7시 29분 16초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684428
# 칼럼 출력 >> [1359358156, Timestamp('2013-01-28 07:29:16'), 302]
#
# 2013년 1월 28일 - 7시 29분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684429
# 칼럼 출력 >> [1359358162, Timestamp('2013-01-28 07:29:22'), 304]
#
# 2013년 1월 28일 - 7시 29분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684430
# 칼럼 출력 >> [1359358168, Timestamp('2013-01-28 07:29:28'), 307]
#
# 2013년 1월 28일 - 7시 29분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684431
# 칼럼 출력 >> [1359358174, Timestamp('2013-01-28 07:29:34'), 308]
#
# 2013년 1월 28일 - 7시 29분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684432
# 칼럼 출력 >> [1359358180, Timestamp('2013-01-28 07:29:40'), 303]
#
# 2013년 1월 28일 - 7시 29분 47초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684433
# 칼럼 출력 >> [1359358187, Timestamp('2013-01-28 07:29:47'), 304]
#
# 2013년 1월 28일 - 7시 29분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684434
# 칼럼 출력 >> [1359358193, Timestamp('2013-01-28 07:29:53'), 308]
#
# 2013년 1월 28일 - 7시 29분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684435
# 칼럼 출력 >> [1359358199, Timestamp('2013-01-28 07:29:59'), 302]
#
# 2013년 1월 28일 - 7시 30분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684436
# 칼럼 출력 >> [1359358205, Timestamp('2013-01-28 07:30:05'), 308]
#
# 2013년 1월 28일 - 7시 30분 12초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684437
# 칼럼 출력 >> [1359358212, Timestamp('2013-01-28 07:30:12'), 480]
#
# 2013년 1월 28일 - 7시 30분 18초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684438
# 칼럼 출력 >> [1359358218, Timestamp('2013-01-28 07:30:18'), 379]
#
# 2013년 1월 28일 - 7시 30분 24초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684439
# 칼럼 출력 >> [1359358224, Timestamp('2013-01-28 07:30:24'), 364]
#
# 2013년 1월 28일 - 7시 30분 30초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684440
# 칼럼 출력 >> [1359358230, Timestamp('2013-01-28 07:30:30'), 410]
#
# 2013년 1월 28일 - 7시 30분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684441
# 칼럼 출력 >> [1359358236, Timestamp('2013-01-28 07:30:36'), 409]
#
# 2013년 1월 28일 - 7시 30분 43초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684442
# 칼럼 출력 >> [1359358243, Timestamp('2013-01-28 07:30:43'), 415]
#
# 2013년 1월 28일 - 7시 30분 49초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684443
# 칼럼 출력 >> [1359358249, Timestamp('2013-01-28 07:30:49'), 408]
#
# 2013년 1월 28일 - 7시 30분 55초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684444
# 칼럼 출력 >> [1359358255, Timestamp('2013-01-28 07:30:55'), 414]
#
# 2013년 1월 28일 - 7시 31분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684445
# 칼럼 출력 >> [1359358261, Timestamp('2013-01-28 07:31:01'), 417]
#
# 2013년 1월 28일 - 7시 31분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684446
# 칼럼 출력 >> [1359358267, Timestamp('2013-01-28 07:31:07'), 409]
#
# 2013년 1월 28일 - 7시 31분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684447
# 칼럼 출력 >> [1359358273, Timestamp('2013-01-28 07:31:13'), 414]
#
# 2013년 1월 28일 - 7시 31분 20초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684448
# 칼럼 출력 >> [1359358280, Timestamp('2013-01-28 07:31:20'), 413]
#
# 2013년 1월 28일 - 7시 31분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684449
# 칼럼 출력 >> [1359358286, Timestamp('2013-01-28 07:31:26'), 411]
#
# 2013년 1월 28일 - 7시 31분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684450
# 칼럼 출력 >> [1359358292, Timestamp('2013-01-28 07:31:32'), 411]
#
# 2013년 1월 28일 - 7시 31분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684451
# 칼럼 출력 >> [1359358298, Timestamp('2013-01-28 07:31:38'), 405]
#
# 2013년 1월 28일 - 7시 31분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684452
# 칼럼 출력 >> [1359358304, Timestamp('2013-01-28 07:31:44'), 401]
#
# 2013년 1월 28일 - 7시 31분 51초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684453
# 칼럼 출력 >> [1359358311, Timestamp('2013-01-28 07:31:51'), 423]
#
# 2013년 1월 28일 - 7시 31분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684454
# 칼럼 출력 >> [1359358317, Timestamp('2013-01-28 07:31:57'), 412]
#
# 2013년 1월 28일 - 7시 32분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684455
# 칼럼 출력 >> [1359358323, Timestamp('2013-01-28 07:32:03'), 415]
#
# 2013년 1월 28일 - 7시 32분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684456
# 칼럼 출력 >> [1359358335, Timestamp('2013-01-28 07:32:15'), 405]
#
# 2013년 1월 28일 - 7시 32분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684457
# 칼럼 출력 >> [1359358342, Timestamp('2013-01-28 07:32:22'), 403]
#
# 2013년 1월 28일 - 7시 32분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684458
# 칼럼 출력 >> [1359358348, Timestamp('2013-01-28 07:32:28'), 405]
#
# 2013년 1월 28일 - 7시 32분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684459
# 칼럼 출력 >> [1359358354, Timestamp('2013-01-28 07:32:34'), 401]
#
# 2013년 1월 28일 - 7시 32분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684460
# 칼럼 출력 >> [1359358360, Timestamp('2013-01-28 07:32:40'), 399]
#
# 2013년 1월 28일 - 7시 32분 46초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684461
# 칼럼 출력 >> [1359358366, Timestamp('2013-01-28 07:32:46'), 400]
#
# 2013년 1월 28일 - 7시 32분 52초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684462
# 칼럼 출력 >> [1359358372, Timestamp('2013-01-28 07:32:52'), 396]
#
# 2013년 1월 28일 - 7시 32분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684463
# 칼럼 출력 >> [1359358379, Timestamp('2013-01-28 07:32:59'), 401]
#
# 2013년 1월 28일 - 7시 33분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684464
# 칼럼 출력 >> [1359358385, Timestamp('2013-01-28 07:33:05'), 394]
#
# 2013년 1월 28일 - 7시 33분 11초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684465
# 칼럼 출력 >> [1359358391, Timestamp('2013-01-28 07:33:11'), 396]
#
# 2013년 1월 28일 - 7시 33분 17초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684466
# 칼럼 출력 >> [1359358397, Timestamp('2013-01-28 07:33:17'), 396]
#
# 2013년 1월 28일 - 7시 33분 23초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684467
# 칼럼 출력 >> [1359358403, Timestamp('2013-01-28 07:33:23'), 399]
#
# 2013년 1월 28일 - 7시 33분 30초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684468
# 칼럼 출력 >> [1359358410, Timestamp('2013-01-28 07:33:30'), 399]
#
# 2013년 1월 28일 - 7시 33분 36초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684469
# 칼럼 출력 >> [1359358416, Timestamp('2013-01-28 07:33:36'), 401]
#
# 2013년 1월 28일 - 7시 33분 42초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684470
# 칼럼 출력 >> [1359358422, Timestamp('2013-01-28 07:33:42'), 401]
#
# 2013년 1월 28일 - 7시 33분 48초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684471
# 칼럼 출력 >> [1359358428, Timestamp('2013-01-28 07:33:48'), 391]
#
# 2013년 1월 28일 - 7시 33분 54초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684472
# 칼럼 출력 >> [1359358434, Timestamp('2013-01-28 07:33:54'), 396]
#
# 2013년 1월 28일 - 7시 34분 1초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684473
# 칼럼 출력 >> [1359358441, Timestamp('2013-01-28 07:34:01'), 397]
#
# 2013년 1월 28일 - 7시 34분 7초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684474
# 칼럼 출력 >> [1359358447, Timestamp('2013-01-28 07:34:07'), 432]
#
# 2013년 1월 28일 - 7시 34분 13초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684475
# 칼럼 출력 >> [1359358453, Timestamp('2013-01-28 07:34:13'), 413]
#
# 2013년 1월 28일 - 7시 34분 19초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684476
# 칼럼 출력 >> [1359358459, Timestamp('2013-01-28 07:34:19'), 420]
#
# 2013년 1월 28일 - 7시 34분 26초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684477
# 칼럼 출력 >> [1359358466, Timestamp('2013-01-28 07:34:26'), 412]
#
# 2013년 1월 28일 - 7시 34분 32초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684478
# 칼럼 출력 >> [1359358472, Timestamp('2013-01-28 07:34:32'), 412]
#
# 2013년 1월 28일 - 7시 34분 38초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684479
# 칼럼 출력 >> [1359358478, Timestamp('2013-01-28 07:34:38'), 404]
#
# 2013년 1월 28일 - 7시 34분 44초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684480
# 칼럼 출력 >> [1359358484, Timestamp('2013-01-28 07:34:44'), 411]
#
# 2013년 1월 28일 - 7시 34분 50초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684481
# 칼럼 출력 >> [1359358490, Timestamp('2013-01-28 07:34:50'), 409]
#
# 2013년 1월 28일 - 7시 34분 57초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684482
# 칼럼 출력 >> [1359358497, Timestamp('2013-01-28 07:34:57'), 406]
#
# 2013년 1월 28일 - 7시 35분 3초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684483
# 칼럼 출력 >> [1359358503, Timestamp('2013-01-28 07:35:03'), 417]
#
# 2013년 1월 28일 - 7시 35분 9초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684484
# 칼럼 출력 >> [1359358509, Timestamp('2013-01-28 07:35:09'), 415]
#
# 2013년 1월 28일 - 7시 35분 15초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684485
# 칼럼 출력 >> [1359358515, Timestamp('2013-01-28 07:35:15'), 411]
#
# 2013년 1월 28일 - 7시 35분 22초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684486
# 칼럼 출력 >> [1359358522, Timestamp('2013-01-28 07:35:22'), 407]
#
# 2013년 1월 28일 - 7시 35분 28초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684487
# 칼럼 출력 >> [1359358528, Timestamp('2013-01-28 07:35:28'), 403]
#
# 2013년 1월 28일 - 7시 35분 34초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684488
# 칼럼 출력 >> [1359358534, Timestamp('2013-01-28 07:35:34'), 414]
#
# 2013년 1월 28일 - 7시 35분 40초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684489
# 칼럼 출력 >> [1359358540, Timestamp('2013-01-28 07:35:40'), 412]
#
# 2013년 1월 28일 - 7시 35분 53초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684490
# 칼럼 출력 >> [1359358553, Timestamp('2013-01-28 07:35:53'), 412]
#
# 2013년 1월 28일 - 7시 35분 59초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684491
# 칼럼 출력 >> [1359358559, Timestamp('2013-01-28 07:35:59'), 404]
#
# 2013년 1월 28일 - 7시 36분 5초
# d1 >> 28 d >> 28 H1 >> 7 h >> 7   //   i >> 684492
# 칼럼 출력 >> [1359358565, Timestamp('2013-01-28 07:36:05'), 410]
#
# 2013년 1월 28일 - 7시 36분 11초
# ...
# 칼럼 출력 >> [1360395018, Timestamp('2013-02-09 07:30:18'), 205]
#
# 2013년 2월 9일 - 7시 30분 24초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692242
# 칼럼 출력 >> [1360395024, Timestamp('2013-02-09 07:30:24'), 206]
#
# 2013년 2월 9일 - 7시 30분 30초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692243
# 칼럼 출력 >> [1360395030, Timestamp('2013-02-09 07:30:30'), 204]
#
# 2013년 2월 9일 - 7시 30분 37초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692244
# 칼럼 출력 >> [1360395037, Timestamp('2013-02-09 07:30:37'), 203]
#
# 2013년 2월 9일 - 7시 30분 43초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692245
# 칼럼 출력 >> [1360395043, Timestamp('2013-02-09 07:30:43'), 205]
#
# 2013년 2월 9일 - 7시 30분 49초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692246
# 칼럼 출력 >> [1360395049, Timestamp('2013-02-09 07:30:49'), 208]
#
# 2013년 2월 9일 - 7시 30분 55초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692247
# 칼럼 출력 >> [1360395055, Timestamp('2013-02-09 07:30:55'), 204]
#
# 2013년 2월 9일 - 7시 31분 2초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692248
# 칼럼 출력 >> [1360395062, Timestamp('2013-02-09 07:31:02'), 204]
#
# 2013년 2월 9일 - 7시 31분 8초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692249
# 칼럼 출력 >> [1360395068, Timestamp('2013-02-09 07:31:08'), 205]
#
# 2013년 2월 9일 - 7시 31분 14초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692250
# 칼럼 출력 >> [1360395074, Timestamp('2013-02-09 07:31:14'), 206]
#
# 2013년 2월 9일 - 7시 31분 20초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692251
# 칼럼 출력 >> [1360395080, Timestamp('2013-02-09 07:31:20'), 205]
#
# 2013년 2월 9일 - 7시 31분 27초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692252
# 칼럼 출력 >> [1360395087, Timestamp('2013-02-09 07:31:27'), 208]
#
# 2013년 2월 9일 - 7시 31분 39초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692253
# 칼럼 출력 >> [1360395099, Timestamp('2013-02-09 07:31:39'), 205]
#
# 2013년 2월 9일 - 7시 31분 45초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692254
# 칼럼 출력 >> [1360395105, Timestamp('2013-02-09 07:31:45'), 204]
#
# 2013년 2월 9일 - 7시 31분 52초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692255
# 칼럼 출력 >> [1360395112, Timestamp('2013-02-09 07:31:52'), 208]
#
# 2013년 2월 9일 - 7시 31분 58초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692256
# 칼럼 출력 >> [1360395118, Timestamp('2013-02-09 07:31:58'), 206]
#
# 2013년 2월 9일 - 7시 32분 4초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692257
# 칼럼 출력 >> [1360395124, Timestamp('2013-02-09 07:32:04'), 208]
#
# 2013년 2월 9일 - 7시 32분 10초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692258
# 칼럼 출력 >> [1360395130, Timestamp('2013-02-09 07:32:10'), 206]
#
# 2013년 2월 9일 - 7시 32분 16초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692259
# 칼럼 출력 >> [1360395136, Timestamp('2013-02-09 07:32:16'), 208]
#
# 2013년 2월 9일 - 7시 32분 22초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692260
# 칼럼 출력 >> [1360395142, Timestamp('2013-02-09 07:32:22'), 206]
#
# 2013년 2월 9일 - 7시 32분 35초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692261
# 칼럼 출력 >> [1360395155, Timestamp('2013-02-09 07:32:35'), 204]
#
# 2013년 2월 9일 - 7시 32분 41초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692262
# 칼럼 출력 >> [1360395161, Timestamp('2013-02-09 07:32:41'), 205]
#
# 2013년 2월 9일 - 7시 32분 48초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692263
# 칼럼 출력 >> [1360395168, Timestamp('2013-02-09 07:32:48'), 204]
#
# 2013년 2월 9일 - 7시 32분 54초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692264
# 칼럼 출력 >> [1360395174, Timestamp('2013-02-09 07:32:54'), 205]
#
# 2013년 2월 9일 - 7시 33분 0초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692265
# 칼럼 출력 >> [1360395180, Timestamp('2013-02-09 07:33:00'), 206]
#
# 2013년 2월 9일 - 7시 33분 6초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692266
# 칼럼 출력 >> [1360395186, Timestamp('2013-02-09 07:33:06'), 203]
#
# 2013년 2월 9일 - 7시 33분 12초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692267
# 칼럼 출력 >> [1360395192, Timestamp('2013-02-09 07:33:12'), 203]
#
# 2013년 2월 9일 - 7시 33분 19초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692268
# 칼럼 출력 >> [1360395199, Timestamp('2013-02-09 07:33:19'), 203]
#
# 2013년 2월 9일 - 7시 33분 25초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692269
# 칼럼 출력 >> [1360395205, Timestamp('2013-02-09 07:33:25'), 204]
#
# 2013년 2월 9일 - 7시 33분 31초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692270
# 칼럼 출력 >> [1360395211, Timestamp('2013-02-09 07:33:31'), 204]
#
# 2013년 2월 9일 - 7시 33분 37초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692271
# 칼럼 출력 >> [1360395217, Timestamp('2013-02-09 07:33:37'), 207]
#
# 2013년 2월 9일 - 7시 33분 43초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692272
# 칼럼 출력 >> [1360395223, Timestamp('2013-02-09 07:33:43'), 205]
#
# 2013년 2월 9일 - 7시 33분 50초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692273
# 칼럼 출력 >> [1360395230, Timestamp('2013-02-09 07:33:50'), 202]
#
# 2013년 2월 9일 - 7시 33분 56초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692274
# 칼럼 출력 >> [1360395236, Timestamp('2013-02-09 07:33:56'), 203]
#
# 2013년 2월 9일 - 7시 34분 2초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692275
# 칼럼 출력 >> [1360395242, Timestamp('2013-02-09 07:34:02'), 204]
#
# 2013년 2월 9일 - 7시 34분 8초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692276
# 칼럼 출력 >> [1360395248, Timestamp('2013-02-09 07:34:08'), 205]
#
# 2013년 2월 9일 - 7시 34분 14초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692277
# 칼럼 출력 >> [1360395254, Timestamp('2013-02-09 07:34:14'), 204]
#
# 2013년 2월 9일 - 7시 34분 20초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692278
# 칼럼 출력 >> [1360395260, Timestamp('2013-02-09 07:34:20'), 204]
#
# 2013년 2월 9일 - 7시 34분 27초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692279
# 칼럼 출력 >> [1360395267, Timestamp('2013-02-09 07:34:27'), 203]
#
# 2013년 2월 9일 - 7시 34분 33초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692280
# 칼럼 출력 >> [1360395273, Timestamp('2013-02-09 07:34:33'), 208]
#
# 2013년 2월 9일 - 7시 34분 39초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692281
# 칼럼 출력 >> [1360395279, Timestamp('2013-02-09 07:34:39'), 204]
#
# 2013년 2월 9일 - 7시 34분 45초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692282
# 칼럼 출력 >> [1360395285, Timestamp('2013-02-09 07:34:45'), 211]
#
# 2013년 2월 9일 - 7시 34분 52초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692283
# 칼럼 출력 >> [1360395292, Timestamp('2013-02-09 07:34:52'), 210]
#
# 2013년 2월 9일 - 7시 34분 58초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692284
# 칼럼 출력 >> [1360395298, Timestamp('2013-02-09 07:34:58'), 270]
#
# 2013년 2월 9일 - 7시 35분 4초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692285
# 칼럼 출력 >> [1360395304, Timestamp('2013-02-09 07:35:04'), 269]
#
# 2013년 2월 9일 - 7시 35분 10초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692286
# 칼럼 출력 >> [1360395310, Timestamp('2013-02-09 07:35:10'), 269]
#
# 2013년 2월 9일 - 7시 35분 16초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692287
# 칼럼 출력 >> [1360395316, Timestamp('2013-02-09 07:35:16'), 263]
#
# 2013년 2월 9일 - 7시 35분 23초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692288
# 칼럼 출력 >> [1360395323, Timestamp('2013-02-09 07:35:23'), 261]
#
# 2013년 2월 9일 - 7시 35분 29초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692289
# 칼럼 출력 >> [1360395329, Timestamp('2013-02-09 07:35:29'), 258]
#
# 2013년 2월 9일 - 7시 35분 35초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692290
# 칼럼 출력 >> [1360395335, Timestamp('2013-02-09 07:35:35'), 258]
#
# 2013년 2월 9일 - 7시 35분 41초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692291
# 칼럼 출력 >> [1360395341, Timestamp('2013-02-09 07:35:41'), 258]
#
# 2013년 2월 9일 - 7시 35분 47초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692292
# 칼럼 출력 >> [1360395347, Timestamp('2013-02-09 07:35:47'), 258]
#
# 2013년 2월 9일 - 7시 35분 54초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692293
# 칼럼 출력 >> [1360395354, Timestamp('2013-02-09 07:35:54'), 263]
#
# 2013년 2월 9일 - 7시 36분 0초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692294
# 칼럼 출력 >> [1360395360, Timestamp('2013-02-09 07:36:00'), 260]
#
# 2013년 2월 9일 - 7시 36분 6초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692295
# 칼럼 출력 >> [1360395366, Timestamp('2013-02-09 07:36:06'), 261]
#
# 2013년 2월 9일 - 7시 36분 12초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692296
# 칼럼 출력 >> [1360395372, Timestamp('2013-02-09 07:36:12'), 263]
#
# 2013년 2월 9일 - 7시 36분 18초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692297
# 칼럼 출력 >> [1360395378, Timestamp('2013-02-09 07:36:18'), 260]
#
# 2013년 2월 9일 - 7시 36분 25초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692298
# 칼럼 출력 >> [1360395385, Timestamp('2013-02-09 07:36:25'), 257]
#
# 2013년 2월 9일 - 7시 36분 31초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692299
# 칼럼 출력 >> [1360395391, Timestamp('2013-02-09 07:36:31'), 259]
#
# 2013년 2월 9일 - 7시 36분 37초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692300
# 칼럼 출력 >> [1360395397, Timestamp('2013-02-09 07:36:37'), 263]
#
# 2013년 2월 9일 - 7시 36분 43초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692301
# 칼럼 출력 >> [1360395403, Timestamp('2013-02-09 07:36:43'), 256]
#
# 2013년 2월 9일 - 7시 36분 49초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692302
# 칼럼 출력 >> [1360395409, Timestamp('2013-02-09 07:36:49'), 261]
#
# 2013년 2월 9일 - 7시 36분 56초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692303
# 칼럼 출력 >> [1360395416, Timestamp('2013-02-09 07:36:56'), 263]
#
# 2013년 2월 9일 - 7시 37분 2초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692304
# 칼럼 출력 >> [1360395422, Timestamp('2013-02-09 07:37:02'), 259]
#
# 2013년 2월 9일 - 7시 37분 8초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692305
# 칼럼 출력 >> [1360395428, Timestamp('2013-02-09 07:37:08'), 265]
#
# 2013년 2월 9일 - 7시 37분 14초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692306
# 칼럼 출력 >> [1360395434, Timestamp('2013-02-09 07:37:14'), 268]
#
# 2013년 2월 9일 - 7시 37분 20초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692307
# 칼럼 출력 >> [1360395440, Timestamp('2013-02-09 07:37:20'), 264]
#
# 2013년 2월 9일 - 7시 37분 27초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692308
# 칼럼 출력 >> [1360395447, Timestamp('2013-02-09 07:37:27'), 267]
#
# 2013년 2월 9일 - 7시 37분 33초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692309
# 칼럼 출력 >> [1360395453, Timestamp('2013-02-09 07:37:33'), 270]
#
# 2013년 2월 9일 - 7시 37분 45초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692310
# 칼럼 출력 >> [1360395465, Timestamp('2013-02-09 07:37:45'), 272]
#
# 2013년 2월 9일 - 7시 37분 52초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692311
# 칼럼 출력 >> [1360395472, Timestamp('2013-02-09 07:37:52'), 270]
#
# 2013년 2월 9일 - 7시 37분 58초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692312
# 칼럼 출력 >> [1360395478, Timestamp('2013-02-09 07:37:58'), 275]
#
# 2013년 2월 9일 - 7시 38분 4초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692313
# 칼럼 출력 >> [1360395484, Timestamp('2013-02-09 07:38:04'), 273]
#
# 2013년 2월 9일 - 7시 38분 10초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692314
# 칼럼 출력 >> [1360395490, Timestamp('2013-02-09 07:38:10'), 281]
#
# 2013년 2월 9일 - 7시 38분 17초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692315
# 칼럼 출력 >> [1360395497, Timestamp('2013-02-09 07:38:17'), 282]
#
# 2013년 2월 9일 - 7시 38분 23초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692316
# 칼럼 출력 >> [1360395503, Timestamp('2013-02-09 07:38:23'), 285]
#
# 2013년 2월 9일 - 7시 38분 29초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692317
# 칼럼 출력 >> [1360395509, Timestamp('2013-02-09 07:38:29'), 288]
#
# 2013년 2월 9일 - 7시 38분 35초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692318
# 칼럼 출력 >> [1360395515, Timestamp('2013-02-09 07:38:35'), 291]
#
# 2013년 2월 9일 - 7시 38분 41초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692319
# 칼럼 출력 >> [1360395521, Timestamp('2013-02-09 07:38:41'), 293]
#
# 2013년 2월 9일 - 7시 38분 48초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692320
# 칼럼 출력 >> [1360395528, Timestamp('2013-02-09 07:38:48'), 297]
#
# 2013년 2월 9일 - 7시 38분 54초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692321
# 칼럼 출력 >> [1360395534, Timestamp('2013-02-09 07:38:54'), 294]
#
# 2013년 2월 9일 - 7시 39분 0초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692322
# 칼럼 출력 >> [1360395540, Timestamp('2013-02-09 07:39:00'), 293]
#
# 2013년 2월 9일 - 7시 39분 6초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692323
# 칼럼 출력 >> [1360395546, Timestamp('2013-02-09 07:39:06'), 299]
#
# 2013년 2월 9일 - 7시 39분 12초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692324
# 칼럼 출력 >> [1360395552, Timestamp('2013-02-09 07:39:12'), 293]
#
# 2013년 2월 9일 - 7시 39분 19초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692325
# 칼럼 출력 >> [1360395559, Timestamp('2013-02-09 07:39:19'), 295]
#
# 2013년 2월 9일 - 7시 39분 25초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692326
# 칼럼 출력 >> [1360395565, Timestamp('2013-02-09 07:39:25'), 294]
#
# 2013년 2월 9일 - 7시 39분 31초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692327
# 칼럼 출력 >> [1360395571, Timestamp('2013-02-09 07:39:31'), 292]
#
# 2013년 2월 9일 - 7시 39분 37초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692328
# 칼럼 출력 >> [1360395577, Timestamp('2013-02-09 07:39:37'), 299]
#
# 2013년 2월 9일 - 7시 39분 44초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692329
# 칼럼 출력 >> [1360395584, Timestamp('2013-02-09 07:39:44'), 296]
#
# 2013년 2월 9일 - 7시 39분 50초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692330
# 칼럼 출력 >> [1360395590, Timestamp('2013-02-09 07:39:50'), 296]
#
# 2013년 2월 9일 - 7시 39분 56초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692331
# 칼럼 출력 >> [1360395596, Timestamp('2013-02-09 07:39:56'), 293]
#
# 2013년 2월 9일 - 7시 40분 2초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692332
# 칼럼 출력 >> [1360395602, Timestamp('2013-02-09 07:40:02'), 298]
#
# 2013년 2월 9일 - 7시 40분 8초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692333
# 칼럼 출력 >> [1360395608, Timestamp('2013-02-09 07:40:08'), 298]
#
# 2013년 2월 9일 - 7시 40분 15초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692334
# 칼럼 출력 >> [1360395615, Timestamp('2013-02-09 07:40:15'), 299]
#
# 2013년 2월 9일 - 7시 40분 27초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692335
# 칼럼 출력 >> [1360395627, Timestamp('2013-02-09 07:40:27'), 293]
#
# 2013년 2월 9일 - 7시 40분 33초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692336
# 칼럼 출력 >> [1360395633, Timestamp('2013-02-09 07:40:33'), 295]
#
# 2013년 2월 9일 - 7시 40분 40초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692337
# 칼럼 출력 >> [1360395640, Timestamp('2013-02-09 07:40:40'), 294]
#
# 2013년 2월 9일 - 7시 40분 46초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692338
# 칼럼 출력 >> [1360395646, Timestamp('2013-02-09 07:40:46'), 296]
#
# 2013년 2월 9일 - 7시 40분 52초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692339
# 칼럼 출력 >> [1360395652, Timestamp('2013-02-09 07:40:52'), 295]
#
# 2013년 2월 9일 - 7시 40분 58초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692340
# 칼럼 출력 >> [1360395658, Timestamp('2013-02-09 07:40:58'), 293]
#
# 2013년 2월 9일 - 7시 41분 4초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692341
# 칼럼 출력 >> [1360395664, Timestamp('2013-02-09 07:41:04'), 298]
#
# 2013년 2월 9일 - 7시 41분 11초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692342
# 칼럼 출력 >> [1360395671, Timestamp('2013-02-09 07:41:11'), 295]
#
# 2013년 2월 9일 - 7시 41분 17초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //   i >> 692343
# 칼럼 출력 >> [1360395677, Timestamp('2013-02-09 07:41:17'), 293]
#
# 2013년 2월 9일 - 7시 41분 23초
# d1 >> 9 d >> 9 H1 >> 7 h >> 7   //
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_16116/146455359.py in <module>
#      65                         total_date = '{0}년 {1}월 {2}일 - {3}시 {4}분 {5}초'.format(y, M, d, h, m, s)
#      66                         print(total_date)
# ---> 67                         print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
#      68                         print('칼럼 출력 >>', list2)
#      69
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
I = 0
for i in range(0, 24):
    print('i >> ',i, 'I >> ',I)
    if (i==20):
        I = I+10
        print('여기로 왔어요!')

# %%
                    
                    """
                    # 3.1.5.
                    # 시 단위가 순차적으로 넘어가는 것이 아닌 건너뛰고 점프해버린 경우 ---------------------------------------------------
                    else:
                        jc=j

                        y5 = hourly_date5[:4]
                        M5 = hourly_date5[6]
                        d5 = hourly_date5[9:10]

                        # 일단 해당 시각 존재하는 만큼은 정리해서 맥스값을 추출하고~
                        print()
                        print('점프! 시 단위 변경! 루프 종료 및 맥스값 추출!')

                        print('========================================< 3.1.5. - 1시간치 끝!! >==================================================')
                        print()

                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)

                        print('1시간 동안 데이터 수 >>', n)
                        print()

                        # 이 지점이 1시간 간격내에서 구해진 watt 값들 중 max를 뽑는 지점.
                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        time.sleep(1)

                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y5, M5, d5, H1)
                        hourly_list = []
                        hourly_list.append(hourly_date)
                        hourly_list.append(max_watt)
                        print(hourly_list)

                        # 데이터 저장 
                        with open("./"+str(y5)+'_'+str(M5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!') 

                        # 3.1.5.1.
                        # 같은 일자 안 중간에서 시간 단위로 데이터가 없는 경우
                        if(d1==d):

                            # 건너뛴 횟수만큼 빈 시간대를 Null로 저장
                            while(True):
                                h=h+1
                                # 점프한 시각 이전까지 Null로 입력 
                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, h-j)
                                hourly_list = []
                                hourly_list.append(hourly_date)
                                hourly_list.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list)       
                                print('*csv 저장 완료!')
                                print()

                                jc=jc-1

                                if jc==1:
                                    break

                        # 3.1.5.2. 
                        # 시간 단위로 빈 데이터가 지속되다가 날짜가 다음 날로 넘어가버리는 경우
                        else:
                            jc2 = H1

                            # *3.1.2.에서 저장해둔 날짜 정보를 쪼개서 연,월,일로 분해
                            y5 = hourly_date5[:4]
                            M5 = hourly_date5[6]
                            d5 = hourly_date5[9:11]
                            print(y5, M5, d5, '//', y, M, d)

                            while(jc2<23):
                                jc2 = jc2 + 1
                                combine = ' - {0}시'.format(jc2)
                                # 여기서 올바른 날짜가 담긴 리스트가 필요함. 이걸 전에 정보에서 불러오면 끝인데
                                hourly_date5_2 = hourly_date5 + combine
                                hourly_list5_2 = []
                                hourly_list5_2.append(hourly_date5_2)
                                hourly_list5_2.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y5)+'_'+str(M5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list5_2)       
                                print('*csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        print('\n'*4)

                        break
                    """

# %% [markdown]
# ##  자동 기상 스크래핑

# %% [markdown]
# #### ※ 웹 크롤링 및 스크래핑, csv 저장이 동시에 이뤄지기 때문에 작업 중지를 방지하기 위해 단독 실행을 추천합니다.

# %% [markdown]
# #### Chromedriver

# %%
"""
크롬 드라이버는 사용자의 크롬 버전에 맞게 드라이버를 다운로드 받아 스크래핑 코드와 같은 폴더에 넣어주시면 됩니다. 

크롬 브라우저의 버전은 우측 상단 더보기란 -> 도움말 -> Chrome 정보 를 선택하면 확인할 수 있습니다.

https://chromedriver.chromium.org/downloads 에 가시면 버전에 맞는 크롬 드라이버를 찾아서 다운로드할 수 있습니다.
"""

# %% [markdown]
# #### Selenium

# %%
# !pip3 install selenium

# %% [markdown]
# #### 화면 가로 확장

# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# #### 정상 시각 일치를 위한 시각과 48개의 순번 Dict

# %%
clk_48 = {'11:50 PM':1, '12:20 AM':2, '12:50 AM':3, '1:20 AM':4, '1:50 AM':5, '2:20 AM':6,
         '2:50 AM':7, '3:20 AM':8, '3:50 AM':9, '4:20 AM':10, '4:50 AM':11, '5:20 AM':12,
         '5:50 AM':13, '6:20 AM':14, '6:50 AM':15, '7:20 AM':16, '7:50 AM':17, '8:20 AM':18,
         '8:50 AM':19, '9:20 AM':20, '9:50 AM':21, '10:20 AM':22, '10:50 AM':23, '11:20 AM':24,
         '11:50 AM':25, '12:20 PM':26, '12:50 PM':27, '1:20 PM':28, '1:50 PM':29, '2:20 PM':30,
         '2:50 PM':31, '3:20 PM':32, '3:50 PM':33, '4:20 PM':34, '4:50 PM':35, '5:20 PM':36,
         '5:50 PM':37, '6:20 PM':38, '6:50 PM':39, '7:20 PM':40, '7:50 PM':41, '8:20 PM':42,
         '8:50 PM':43, '9:20 PM':44, '9:50 PM':45, '10:20 PM':46, '10:50 PM':47, '11:20 PM':48}

# reversed
re_clk_48 = dict(map(reversed, clk_48.items()))
print(re_clk_48)
# Out:
# {1: '11:50 PM', 2: '12:20 AM', 3: '12:50 AM', 4: '1:20 AM', 5: '1:50 AM', 6: '2:20 AM', 7: '2:50 AM', 8: '3:20 AM', 9: '3:50 AM', 10: '4:20 AM', 11: '4:50 AM', 12: '5:20 AM', 13: '5:50 AM', 14: '6:20 AM', 15: '6:50 AM', 16: '7:20 AM', 17: '7:50 AM', 18: '8:20 AM', 19: '8:50 AM', 20: '9:20 AM', 21: '9:50 AM', 22: '10:20 AM', 23: '10:50 AM', 24: '11:20 AM', 25: '11:50 AM', 26: '12:20 PM', 27: '12:50 PM', 28: '1:20 PM', 29: '1:50 PM', 30: '2:20 PM', 31: '2:50 PM', 32: '3:20 PM', 33: '3:50 PM', 34: '4:20 PM', 35: '4:50 PM', 36: '5:20 PM', 37: '5:50 PM', 38: '6:20 PM', 39: '6:50 PM', 40: '7:20 PM', 41: '7:50 PM', 42: '8:20 PM', 43: '8:50 PM', 44: '9:20 PM', 45: '9:50 PM', 46: '10:20 PM', 47: '10:50 PM', 48: '11:20 PM'}

# %% [markdown]
# #### 월 마다 다른 일수 반영, 48분할 하루의 온도를 스크래핑, 결측값 정상 입력 함수

# %%
def Monthly_Temp(YYYY, MM):
    driver.implicitly_wait(10)
    YYYY = y
    MM = m
            
    # 각 달마다 일수가 다르고 하루 단위로 동작되는 코드는 중복되는 내용이 많기 때문에 간소화를 위해 월 Dict 이용
    month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
    d=0
    while(d<month[m]):
        d=d+1
        print('====================< %d일 >=========================' %d)
        print()
        driver.get('https://www.wunderground.com/history/daily/gb/london/EGLC/date/'+str(y)+'-'+str(m)+'-'+str(d))
        time.sleep(3)
                
        h = 0 # 여기서는 하루를 30분 단위로 쪼갠 온도 개수, 중간 결측치 자리 포함 하루의 데이터를 48개로 맞춰주기 위한 변수.
        h2 = 1
        h3 = 1 # 11:20 PM 에서 데이터가 시작되지 않는 날들을 위한 변수
        
        while (h2 < 49 or h3 < 49):
            h = h+1
                    
            try:
                clk = driver.find_element(By.XPATH,'//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr['+str(h2)+']/td[1]/span')
                clk_str = clk.text
                clk_str.split()
                
                # 11:20 PM 에서 시작하는 날의 코드                              
                if(clk_48[clk_str]==h or clk_48[clk_str]==h3):
                    date_list = [int(y), int(m), int(d)] # 연,월,일 정보로 구성된 날짜 리스트 생성
                    date_list.append(clk_str) # 날짜 리스트에 해당 시각 원소 추가
                    date_list.append(int(h)) # 해당 시각이 그날 48개로 분할된 시간 중 몇번째인지 원소 추가
                    temp = driver.find_element(By.XPATH,'//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr['+str(h2)+']/td[2]')
                    temp_str = temp.text # 스크래핑한 xpath의 온도를 str로 변경
                    temp_list = date_list 
                    temp_list.append(temp_str) # 날짜+시각 리스트에 온도 원소 추가
                    time.sleep(0.05)
                    print(temp_list) # 확인용 print
                    # 시간 루프 종료 지점
                            
                    # csv 추가 및 저장
                    with open("./"+str(y)+'_'+str(m)+'_'+"London_Temperature.csv", 'a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow(temp_list)
                    print('h >>', str(h), 'h2 >>', str(h2), 'h3 >>', str(h3))
                    print()
                    h2 = h2+1
                    h3 = h3+1
                    
                # 11:20 PM 에서 시작하지 않는 날의 코드 
                elif((clk_48[clk_str]-46)==h):
                    date_list = [int(y), int(m), int(d)] # 연,월,일 정보로 구성된 날짜 리스트 생성
                    date_list.append(clk_str) # 날짜 리스트에 해당 시각 원소 추가
                    date_list.append(int(h)) # 해당 시각이 그날 48개로 분할된 시간 중 몇번째인지 원소 추가
                    temp = driver.find_element(By.XPATH,'//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table/tbody/tr['+str(h2)+']/td[2]')
                    temp_str = temp.text # 스크래핑한 xpath의 온도를 str로 변경
                    temp_list = date_list 
                    temp_list.append(temp_str) # 날짜+시각 리스트에 온도 원소 추가
                    time.sleep(0.05)
                    print(temp_list) # 확인용 print
                    # 시간 루프 종료 지점
                            
                    # csv 추가 및 저장
                    with open("./"+str(y)+'_'+str(m)+'_'+"London_Temperature.csv", 'a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow(temp_list)
                    print('h >>', str(h), 'h2 >>', str(h2), 'h3 >>', str(h3))
                    print()
                    h3 = h3+1
                    
                elif(h != h3):
                    date_list = [int(y), int(m), int(d)]
                    print('결손 데이터 칸의 정상 시각 >>',re_clk_48[h])
                    print('사이트에서 스크래핑한 시각 >>', clk_str)
                    date_list.append(re_clk_48[h])
                    date_list.append(int(h))
                    na_list = date_list
                    na_list.append('Null')
                    print(na_list)
                            
                    with open("./"+str(y)+'_'+str(m)+'_'+"London_Temperature.csv", 'a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow(na_list)
                            
                    print('h >>', str(h), 'h2 >>', str(h2), 'h3 >>', str(h3))
                    print() 
                    h3 = h3+1
                            
            except NoSuchElementException:
                break

        print('< Day End >')
        print('\n'*4)

# %% [markdown]
# #### 2013~2016년의 기상 데이터를 수집하는 전체 코드

# %%
# 데이터 저장을 위한 csv 
import csv

# Selenium : 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 에러 예외처리를 위해 해당 예외를 먼저 임포트해줌.
from selenium.common.exceptions import NoSuchElementException

# 정상작동을 위해서 중간 시간 정보 호출 사이에 강제 딜레이를 잠깐 넣어줌.
import time

path = "./chromedriver.exe"
driver = webdriver.Chrome(path)
driver.implicitly_wait(10)

# 기상포털 주소 1차 접속. 데이터가 충분히 표시된 2021년 1월 1일을 시작 화면으로 설정
driver.get('https://www.wunderground.com/history/daily/gb/london/EGLC/date/2021-1-1')
time.sleep(1)

# 온도 표기 선택창 클릭
driver.find_element(By.XPATH, '//*[@id="wuSettings"]/i').click()
time.sleep(1)

# 섭씨 선택
driver.find_element(By.XPATH, '//*[@id="wuSettings-quick"]/div/a[2]').click()
time.sleep(1)

# YYYY
# offset 2012
y = 2012
while(y<2016):
    y=y+1
    print('====================< %d년 >===================================' %y)
    
    # MM
    m = 3
    while(m<12):
        m=m+1
        print('====================< %d월 >==============================' %m)
        
        # DD
        Monthly_Temp(y, m)
                
                      
        print()
    print('\n')
    
    """
    여기서 당해의 1년 csv 데이터 합본 생성 (2013, 2014, 2015, 2016)
    2013_1_London_Temperature 파일 이름에서
    2013_m_London_Temperature 로 해서 m이 1~12 범위 내에서 반복 결합 되도록
    파일이름은 2013_Unit_London_Temperature
    """
    
    if (y == 2016):
        # 여기서는 4년치의 csv 데이터 합본 생성
        # 4years_London_Temperature_(20130101-20161231)
        print('끝!!')
        break 
    
    
    
driver.quit()
# Out:
# C:\Users\Hwi\AppData\Local\Temp/ipykernel_12576/3951317554.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ====================< 2013년 >===================================
# ====================< 4월 >==============================
# ====================< 1일 >=========================
#
# [2013, 4, 1, '10:50 PM', 1, '1 °C']
# h >> 1 h2 >> 1 h3 >> 1
#
# 결손 데이터 칸의 정상 시각 >> 12:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '12:50 AM', 3, 'Null']
# h >> 3 h2 >> 1 h3 >> 2
#
# 결손 데이터 칸의 정상 시각 >> 1:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '1:20 AM', 4, 'Null']
# h >> 4 h2 >> 1 h3 >> 3
#
# 결손 데이터 칸의 정상 시각 >> 1:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '1:50 AM', 5, 'Null']
# h >> 5 h2 >> 1 h3 >> 4
#
# 결손 데이터 칸의 정상 시각 >> 2:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '2:20 AM', 6, 'Null']
# h >> 6 h2 >> 1 h3 >> 5
#
# 결손 데이터 칸의 정상 시각 >> 2:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '2:50 AM', 7, 'Null']
# h >> 7 h2 >> 1 h3 >> 6
#
# 결손 데이터 칸의 정상 시각 >> 3:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '3:20 AM', 8, 'Null']
# h >> 8 h2 >> 1 h3 >> 7
#
# 결손 데이터 칸의 정상 시각 >> 3:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '3:50 AM', 9, 'Null']
# h >> 9 h2 >> 1 h3 >> 8
#
# 결손 데이터 칸의 정상 시각 >> 4:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '4:20 AM', 10, 'Null']
# h >> 10 h2 >> 1 h3 >> 9
#
# 결손 데이터 칸의 정상 시각 >> 4:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '4:50 AM', 11, 'Null']
# h >> 11 h2 >> 1 h3 >> 10
#
# 결손 데이터 칸의 정상 시각 >> 5:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '5:20 AM', 12, 'Null']
# h >> 12 h2 >> 1 h3 >> 11
#
# 결손 데이터 칸의 정상 시각 >> 5:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '5:50 AM', 13, 'Null']
# h >> 13 h2 >> 1 h3 >> 12
#
# 결손 데이터 칸의 정상 시각 >> 6:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '6:20 AM', 14, 'Null']
# h >> 14 h2 >> 1 h3 >> 13
#
# 결손 데이터 칸의 정상 시각 >> 6:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '6:50 AM', 15, 'Null']
# h >> 15 h2 >> 1 h3 >> 14
#
# 결손 데이터 칸의 정상 시각 >> 7:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '7:20 AM', 16, 'Null']
# h >> 16 h2 >> 1 h3 >> 15
#
# 결손 데이터 칸의 정상 시각 >> 7:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '7:50 AM', 17, 'Null']
# h >> 17 h2 >> 1 h3 >> 16
#
# 결손 데이터 칸의 정상 시각 >> 8:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '8:20 AM', 18, 'Null']
# h >> 18 h2 >> 1 h3 >> 17
#
# 결손 데이터 칸의 정상 시각 >> 8:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '8:50 AM', 19, 'Null']
# h >> 19 h2 >> 1 h3 >> 18
#
# 결손 데이터 칸의 정상 시각 >> 9:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '9:20 AM', 20, 'Null']
# h >> 20 h2 >> 1 h3 >> 19
#
# 결손 데이터 칸의 정상 시각 >> 9:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '9:50 AM', 21, 'Null']
# h >> 21 h2 >> 1 h3 >> 20
#
# 결손 데이터 칸의 정상 시각 >> 10:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '10:20 AM', 22, 'Null']
# h >> 22 h2 >> 1 h3 >> 21
#
# 결손 데이터 칸의 정상 시각 >> 10:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '10:50 AM', 23, 'Null']
# h >> 23 h2 >> 1 h3 >> 22
#
# 결손 데이터 칸의 정상 시각 >> 11:20 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '11:20 AM', 24, 'Null']
# h >> 24 h2 >> 1 h3 >> 23
#
# 결손 데이터 칸의 정상 시각 >> 11:50 AM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '11:50 AM', 25, 'Null']
# h >> 25 h2 >> 1 h3 >> 24
#
# 결손 데이터 칸의 정상 시각 >> 12:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '12:20 PM', 26, 'Null']
# h >> 26 h2 >> 1 h3 >> 25
#
# 결손 데이터 칸의 정상 시각 >> 12:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '12:50 PM', 27, 'Null']
# h >> 27 h2 >> 1 h3 >> 26
#
# 결손 데이터 칸의 정상 시각 >> 1:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '1:20 PM', 28, 'Null']
# h >> 28 h2 >> 1 h3 >> 27
#
# 결손 데이터 칸의 정상 시각 >> 1:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '1:50 PM', 29, 'Null']
# h >> 29 h2 >> 1 h3 >> 28
#
# 결손 데이터 칸의 정상 시각 >> 2:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '2:20 PM', 30, 'Null']
# h >> 30 h2 >> 1 h3 >> 29
#
# 결손 데이터 칸의 정상 시각 >> 2:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '2:50 PM', 31, 'Null']
# h >> 31 h2 >> 1 h3 >> 30
#
# 결손 데이터 칸의 정상 시각 >> 3:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '3:20 PM', 32, 'Null']
# h >> 32 h2 >> 1 h3 >> 31
#
# 결손 데이터 칸의 정상 시각 >> 3:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '3:50 PM', 33, 'Null']
# h >> 33 h2 >> 1 h3 >> 32
#
# 결손 데이터 칸의 정상 시각 >> 4:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '4:20 PM', 34, 'Null']
# h >> 34 h2 >> 1 h3 >> 33
#
# 결손 데이터 칸의 정상 시각 >> 4:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '4:50 PM', 35, 'Null']
# h >> 35 h2 >> 1 h3 >> 34
#
# 결손 데이터 칸의 정상 시각 >> 5:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '5:20 PM', 36, 'Null']
# h >> 36 h2 >> 1 h3 >> 35
#
# 결손 데이터 칸의 정상 시각 >> 5:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '5:50 PM', 37, 'Null']
# h >> 37 h2 >> 1 h3 >> 36
#
# 결손 데이터 칸의 정상 시각 >> 6:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '6:20 PM', 38, 'Null']
# h >> 38 h2 >> 1 h3 >> 37
#
# 결손 데이터 칸의 정상 시각 >> 6:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '6:50 PM', 39, 'Null']
# h >> 39 h2 >> 1 h3 >> 38
#
# 결손 데이터 칸의 정상 시각 >> 7:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '7:20 PM', 40, 'Null']
# h >> 40 h2 >> 1 h3 >> 39
#
# 결손 데이터 칸의 정상 시각 >> 7:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '7:50 PM', 41, 'Null']
# h >> 41 h2 >> 1 h3 >> 40
#
# 결손 데이터 칸의 정상 시각 >> 8:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '8:20 PM', 42, 'Null']
# h >> 42 h2 >> 1 h3 >> 41
#
# 결손 데이터 칸의 정상 시각 >> 8:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '8:50 PM', 43, 'Null']
# h >> 43 h2 >> 1 h3 >> 42
#
# 결손 데이터 칸의 정상 시각 >> 9:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '9:20 PM', 44, 'Null']
# h >> 44 h2 >> 1 h3 >> 43
#
# 결손 데이터 칸의 정상 시각 >> 9:50 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '9:50 PM', 45, 'Null']
# h >> 45 h2 >> 1 h3 >> 44
#
# 결손 데이터 칸의 정상 시각 >> 10:20 PM
# 사이트에서 스크래핑한 시각 >> 10:50 PM
# [2013, 4, 1, '10:20 PM', 46, 'Null']
# h >> 46 h2 >> 1 h3 >> 45
#
# [2013, 4, 1, '10:50 PM', 47, '1 °C']
# h >> 47 h2 >> 1 h3 >> 46
#
# [2013, 4, 1, '11:20 PM', 48, '1 °C']
# h >> 48 h2 >> 2 h3 >> 47
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12576/3951317554.py in <module>
#      43
#      44         # DD
# ---> 45         Monthly_Temp(y, m)
#      46
#      47
#
# ~\AppData\Local\Temp/ipykernel_12576/1146561749.py in Monthly_Temp(YYYY, MM)
#      71                 elif(h != h3):
#      72                     date_list = [int(y), int(m), int(d)]
# ---> 73                     print('결손 데이터 칸의 정상 시각 >>',re_clk_48[h])
#      74                     print('사이트에서 스크래핑한 시각 >>', clk_str)
#      75                     date_list.append(re_clk_48[h])
#
# KeyError: 49

# %% [markdown]
# #### 1년 기준 12달치 통합 저장 코드

# %%
# 보류

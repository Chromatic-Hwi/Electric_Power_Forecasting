# %%
import pandas as pd
ch1 = pd.read_csv('./channel_1.dat', names=['Unix', 'Watt'],header=None, delimiter=" ")
print('Done!')
# Out:
# Done!

# %%
ch1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Watt    int64
# dtypes: int64(2)
# memory usage: 333.2 MB

# %%
print(ch1[0:11])
print('1번째')
print(ch1[0:1])
print()
print('21837636번째')
print(ch1[21837635:21837636])
# Out:
#           Unix  Watt
# 0   1352500095   599
# 1   1352500101   582
# 2   1352500107   600
# 3   1352500113   586
# 4   1352500120   596
# 5   1352500132   581
# 6   1352500138   597
# 7   1352500144   592
# 8   1352500150   587
# 9   1352500156   574
# 10  1352500168   577
# 1번째
#          Unix  Watt
# 0  1352500095   599
#
# 21837636번째
#                 Unix  Watt
# 21837635  1493227960   672

# %%
from datetime import datetime
ch1_date = pd.DataFrame(ch1,columns = ['Unix', 'Date', 'Watt'])

ch1_date['Date'] = pd.to_datetime(ch1['Unix'], unit='s')
ch1_date.info()
ch1_date.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Date    datetime64[ns]
#  2   Watt    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 499.8 MB
#          Unix                Date  Watt
# 0  1352500095 2012-11-09 22:28:15   599
# 1  1352500101 2012-11-09 22:28:21   582
# 2  1352500107 2012-11-09 22:28:27   600
# 3  1352500113 2012-11-09 22:28:33   586
# 4  1352500120 2012-11-09 22:28:40   596
# 5  1352500132 2012-11-09 22:28:52   581
# 6  1352500138 2012-11-09 22:28:58   597
# 7  1352500144 2012-11-09 22:29:04   592
# 8  1352500150 2012-11-09 22:29:10   587
# 9  1352500156 2012-11-09 22:29:16   574

# %% [markdown]
# ### 정상 구동 버전 반복을 위한 코드

# %% [markdown]
# ### 이건 카피, 실험용

# %% [markdown]
# #### For문으로 시도중인 버전

# %%
import time
import csv

# 1.
#i = 431368, 517000, 684157
i = 517000
print('Running!', '\n'*9)

# 2.
while(i < 20284836):
    list1 = ch1_date.loc[i].values.tolist()
            
    # Nested List 사용해서 시간 정보만 따로 추출
    date = list1[1]
    y1 = date.year
    M1 = date.month
    d1 = date.day
    H1 = date.hour # 이 H가 있어야 밑에 있는 하루 단위 반복이 돌 변수가 됨.
    n = 0 # 데이터 개수를 세기 위한 변수
    
    # H1는 데이터에서 읽어오는 값이지만 H0는 절대적
    
        
    # 3. 
    # 하루 단위 반복
    while(H1 < 24):
        # watt_list=[] # 원래 3. 단계 시작 때 있던 애들
        # h = date.hour # 원래 3. 단계 시작 때 있던 애들
        H0 = -1
        
        while(True):
            H0 = H0+1
            watt_list=[]
            h = date.hour
            
            # 하루 시작이 0시부터 잘 이뤄지는 경우
            if(H1 == H0):
                
                # 3.1.
                # h시와 h+1 시 사이 반복
                while(h < h+1):
                    n=n+1
                    list2 = ch1_date.loc[i].values.tolist()

                    date = list2[1]
                    watt = list2[2]

                    y = date.year
                    M = date.month
                    d = date.day
                    h = date.hour
                    m = date.minute
                    s = date.second

                    print()

                    # jump 를 하는 경우가 있기 때문에 이 경우를 구분 짓는 변수를 j로 선택
                    j=h-H1

                    # 3.1.1.
                    # '시'단위가 바뀌기 전에 값들만 저장 (ex. 1시일 경우 2시가 되기전 데이터들만 저장)
                    if(j==0):
                        watt_list.append(watt) # 1시간 동안 6 or 7초 단위로 읽어오는 watt 값들 전부 추가

                        # 확인용 각 변수 출력
                        total_date = '{0}년 {1}월 {2}일 - {3}시 {4}분 {5}초'.format(y, M, d, h, m, s)
                        print(total_date)
                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('칼럼 출력 >>', list2)

                        i = i+1

                        if(j!=0):
                            break

                    # 3.1.2.    
                    # 시가 바뀌는 경우 -------------------------------------------------------------------------------------------------
                    elif (j==1):
                        print()
                        print('시 단위 변경! 루프 종료 및 맥스값 추출!')

                        print('========================================< 3.1.2. - 1시간치 끝!! >==================================================')
                        print()
                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('1시간 동안 데이터 수 >>', n)
                        print()

                        # 이 지점이 1시간 간격내에서 구해진 watt 값들 중 max를 뽑는 지점.
                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        time.sleep(1)

                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date2 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                        hourly_date5 = '{0}년 {1}월 {2}일'.format(y, M, d)
                        hourly_list = []
                        hourly_list.append(hourly_date2)
                        hourly_list.append(max_watt)

                        # 데이터 저장 
                        with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        print('\n'*4)

                        break

                    # 3.1.3.
                    # 1 시간치 정리가 끝나고 다음 날로 넘어가는 경우. 따로 설정함.---------------------------------------------------------
                    elif(d1+1==d):
                        print('========================================< 3.1.3. - 1시간치 끝!! >==================================================')
                        print()
                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
                        print('1시간 동안 데이터 수 >>', n)
                        print()
                        d=d-1
                        h=h+24

                        # 이 지점이 1시간 간격내에서 구해진 watt 값들 중 max를 뽑는 지점.
                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        time.sleep(1)


                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date3 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                        hourly_list = []
                        hourly_list.append(hourly_date3)
                        hourly_list.append(max_watt)

                        # 데이터 저장 
                        with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        print('\n'*4)
                        print('========================================< 하루 끝!! >==================================================')
                        print('\n'*4)
                        break

                    # 3.1.4.
                    # 1시간 단위 반복 중 에러 발생 경우-------------------------------------------------------------------------------------
                    elif (n>600):
                        print('\n'*9)
                        print('데이터 처리 필요!! 반복 루프 강제 종료')
                        print('X'*300)
                        print('\n'*9)
                        break


                    # 3.1.5.
                    # 시 단위가 순차적으로 넘어가는 것이 아닌 건너뛰고 점프해버린 경우 ---------------------------------------------------
                    else:
                        jc=j

                        y5 = hourly_date5[:4]
                        M5 = hourly_date5[6]
                        d5 = hourly_date5[9:10]

                        # 일단 해당 시각 존재하는 만큼은 정리해서 맥스값을 추출하고~
                        print()
                        print('점프! 시 단위 변경! 루프 종료 및 맥스값 추출!')

                        print('========================================< 3.1.5. - 1시간치 끝!! >==================================================')
                        print()

                        print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)

                        print('1시간 동안 데이터 수 >>', n)
                        print()

                        # 이 지점이 1시간 간격내에서 구해진 watt 값들 중 max를 뽑는 지점.
                        max_watt = max(watt_list)
                        print(H1, '시까지의 최대값 >>', max_watt)
                        time.sleep(1)

                        # 1시간 동안이니 해당 시각의 정보를 시 단위까지로 해서 새로 저장
                        hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y5, M5, d5, H1)
                        hourly_list = []
                        hourly_list.append(hourly_date)
                        hourly_list.append(max_watt)
                        print(hourly_list)

                        # 데이터 저장 
                        with open("./"+str(y5)+'_'+str(M5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list)       
                        print('*csv 저장 완료!') 

                        # 3.1.5.1.
                        # 같은 일자 안 중간에서 시간 단위로 데이터가 없는 경우
                        if(d1==d):

                            # 건너뛴 횟수만큼 빈 시간대를 Null로 저장
                            while(True):
                                h=h+1
                                # 점프한 시각 이전까지 Null로 입력 
                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, h-j)
                                hourly_list = []
                                hourly_list.append(hourly_date)
                                hourly_list.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list)       
                                print('*csv 저장 완료!')
                                print()

                                jc=jc-1

                                if jc==1:
                                    break

                        # 3.1.5.2. 
                        # 시간 단위로 빈 데이터가 지속되다가 날짜가 다음 날로 넘어가버리는 경우
                        else:
                            jc2 = H1

                            # *3.1.2.에서 저장해둔 날짜 정보를 쪼개서 연,월,일로 분해
                            y5 = hourly_date5[:4]
                            M5 = hourly_date5[6]
                            d5 = hourly_date5[9:11]
                            print(y5, M5, d5, '//', y, M, d)

                            while(jc2<23):
                                jc2 = jc2 + 1
                                combine = ' - {0}시'.format(jc2)
                                # 여기서 올바른 날짜가 담긴 리스트가 필요함. 이걸 전에 정보에서 불러오면 끝인데
                                hourly_date5_2 = hourly_date5 + combine
                                hourly_list5_2 = []
                                hourly_list5_2.append(hourly_date5_2)
                                hourly_list5_2.append('Null')

                                # 데이터 저장 
                                with open("./"+str(y5)+'_'+str(M5)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(hourly_list5_2)       
                                print('*csv 저장 완료!')

                        H1 = H1+1 # 저장했으니 다음 시각으로 넘어가기 위한 +1
                        print('\n'*4)

                        break
            
            if(H1 != H0):
                """
                3.1.5.2. 에서 연, 월, 일 정보를 저장해놔야 함.
                그걸 여기서 불러와서 조회를 해야 함. 2월 8일의 경우 불러왔을 때 2월 8일인건 알 수 있지만
                2월 1일부터 데이터가 비었는지 8일의 몇시부터 비는지를 모름. 그걸 구분해서 저장하도록 하는게
                관건.
                """
                
                print('시작 시가 안 맞아요!!', 'H0 >>', H0, 'H1 >>', H1)
                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y1, M1, d1, h)
                print(hourly_date)
                h = h+1
                print()
                
                if (H0 ==23):
                    break
                    
        # 3. 의 끝 지점
        print('종료 지점 확인용','\n'*9)
        break

        
    
        
# 전체 While문 종료 지점
# Out:
# Running!
#
#
#
#
#
#
#
#
#
# 시작 시가 안 맞아요!! H0 >> 0 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 1 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 2 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 3 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 4 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 5 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 6 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 7 H1 >> 9
# 2013년 1월 7일 - 9시
#
# 시작 시가 안 맞아요!! H0 >> 8 H1 >> 9
# 2013년 1월 7일 - 9시
#
#
# 2013년 1월 7일 - 9시 41분 1초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517000
# 칼럼 출력 >> [1357551661, Timestamp('2013-01-07 09:41:01'), 282]
#
# 2013년 1월 7일 - 9시 41분 7초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517001
# 칼럼 출력 >> [1357551667, Timestamp('2013-01-07 09:41:07'), 282]
#
# 2013년 1월 7일 - 9시 41분 13초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517002
# 칼럼 출력 >> [1357551673, Timestamp('2013-01-07 09:41:13'), 282]
#
# 2013년 1월 7일 - 9시 41분 20초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517003
# 칼럼 출력 >> [1357551680, Timestamp('2013-01-07 09:41:20'), 285]
#
# 2013년 1월 7일 - 9시 41분 26초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517004
# 칼럼 출력 >> [1357551686, Timestamp('2013-01-07 09:41:26'), 284]
#
# 2013년 1월 7일 - 9시 41분 32초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517005
# 칼럼 출력 >> [1357551692, Timestamp('2013-01-07 09:41:32'), 279]
#
# 2013년 1월 7일 - 9시 41분 38초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517006
# 칼럼 출력 >> [1357551698, Timestamp('2013-01-07 09:41:38'), 281]
#
# 2013년 1월 7일 - 9시 41분 44초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517007
# 칼럼 출력 >> [1357551704, Timestamp('2013-01-07 09:41:44'), 280]
#
# 2013년 1월 7일 - 9시 41분 50초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517008
# 칼럼 출력 >> [1357551710, Timestamp('2013-01-07 09:41:50'), 285]
#
# 2013년 1월 7일 - 9시 41분 56초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517009
# 칼럼 출력 >> [1357551716, Timestamp('2013-01-07 09:41:56'), 284]
#
# 2013년 1월 7일 - 9시 42분 3초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517010
# 칼럼 출력 >> [1357551723, Timestamp('2013-01-07 09:42:03'), 284]
#
# 2013년 1월 7일 - 9시 42분 9초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517011
# 칼럼 출력 >> [1357551729, Timestamp('2013-01-07 09:42:09'), 285]
#
# 2013년 1월 7일 - 9시 42분 15초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517012
# 칼럼 출력 >> [1357551735, Timestamp('2013-01-07 09:42:15'), 286]
#
# 2013년 1월 7일 - 9시 42분 21초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517013
# 칼럼 출력 >> [1357551741, Timestamp('2013-01-07 09:42:21'), 281]
#
# 2013년 1월 7일 - 9시 42분 27초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517014
# 칼럼 출력 >> [1357551747, Timestamp('2013-01-07 09:42:27'), 280]
#
# 2013년 1월 7일 - 9시 42분 33초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517015
# 칼럼 출력 >> [1357551753, Timestamp('2013-01-07 09:42:33'), 285]
#
# 2013년 1월 7일 - 9시 42분 40초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517016
# 칼럼 출력 >> [1357551760, Timestamp('2013-01-07 09:42:40'), 281]
#
# 2013년 1월 7일 - 9시 42분 46초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517017
# 칼럼 출력 >> [1357551766, Timestamp('2013-01-07 09:42:46'), 286]
#
# 2013년 1월 7일 - 9시 42분 52초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517018
# 칼럼 출력 >> [1357551772, Timestamp('2013-01-07 09:42:52'), 283]
#
# 2013년 1월 7일 - 9시 42분 58초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517019
# 칼럼 출력 >> [1357551778, Timestamp('2013-01-07 09:42:58'), 285]
#
# 2013년 1월 7일 - 9시 43분 4초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517020
# 칼럼 출력 >> [1357551784, Timestamp('2013-01-07 09:43:04'), 279]
#
# 2013년 1월 7일 - 9시 43분 10초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517021
# 칼럼 출력 >> [1357551790, Timestamp('2013-01-07 09:43:10'), 281]
#
# 2013년 1월 7일 - 9시 43분 17초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517022
# 칼럼 출력 >> [1357551797, Timestamp('2013-01-07 09:43:17'), 281]
#
# 2013년 1월 7일 - 9시 43분 23초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517023
# 칼럼 출력 >> [1357551803, Timestamp('2013-01-07 09:43:23'), 281]
#
# 2013년 1월 7일 - 9시 43분 29초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517024
# 칼럼 출력 >> [1357551809, Timestamp('2013-01-07 09:43:29'), 282]
#
# 2013년 1월 7일 - 9시 43분 35초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517025
# 칼럼 출력 >> [1357551815, Timestamp('2013-01-07 09:43:35'), 283]
#
# 2013년 1월 7일 - 9시 43분 41초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517026
# 칼럼 출력 >> [1357551821, Timestamp('2013-01-07 09:43:41'), 282]
#
# 2013년 1월 7일 - 9시 43분 47초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517027
# 칼럼 출력 >> [1357551827, Timestamp('2013-01-07 09:43:47'), 282]
#
# 2013년 1월 7일 - 9시 43분 53초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517028
# 칼럼 출력 >> [1357551833, Timestamp('2013-01-07 09:43:53'), 284]
#
# 2013년 1월 7일 - 9시 44분 0초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517029
# 칼럼 출력 >> [1357551840, Timestamp('2013-01-07 09:44:00'), 284]
#
# 2013년 1월 7일 - 9시 44분 6초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517030
# 칼럼 출력 >> [1357551846, Timestamp('2013-01-07 09:44:06'), 305]
#
# 2013년 1월 7일 - 9시 44분 12초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517031
# 칼럼 출력 >> [1357551852, Timestamp('2013-01-07 09:44:12'), 299]
#
# 2013년 1월 7일 - 9시 44분 18초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517032
# 칼럼 출력 >> [1357551858, Timestamp('2013-01-07 09:44:18'), 299]
#
# 2013년 1월 7일 - 9시 44분 24초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517033
# 칼럼 출력 >> [1357551864, Timestamp('2013-01-07 09:44:24'), 301]
#
# 2013년 1월 7일 - 9시 44분 30초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517034
# 칼럼 출력 >> [1357551870, Timestamp('2013-01-07 09:44:30'), 291]
#
# 2013년 1월 7일 - 9시 44분 36초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517035
# 칼럼 출력 >> [1357551876, Timestamp('2013-01-07 09:44:36'), 293]
#
# 2013년 1월 7일 - 9시 44분 43초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517036
# 칼럼 출력 >> [1357551883, Timestamp('2013-01-07 09:44:43'), 294]
#
# 2013년 1월 7일 - 9시 44분 49초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517037
# 칼럼 출력 >> [1357551889, Timestamp('2013-01-07 09:44:49'), 295]
#
# 2013년 1월 7일 - 9시 45분 1초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517038
# 칼럼 출력 >> [1357551901, Timestamp('2013-01-07 09:45:01'), 298]
#
# 2013년 1월 7일 - 9시 45분 7초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517039
# 칼럼 출력 >> [1357551907, Timestamp('2013-01-07 09:45:07'), 284]
#
# 2013년 1월 7일 - 9시 45분 13초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517040
# 칼럼 출력 >> [1357551913, Timestamp('2013-01-07 09:45:13'), 282]
#
# 2013년 1월 7일 - 9시 45분 20초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517041
# 칼럼 출력 >> [1357551920, Timestamp('2013-01-07 09:45:20'), 290]
#
# 2013년 1월 7일 - 9시 45분 26초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517042
# 칼럼 출력 >> [1357551926, Timestamp('2013-01-07 09:45:26'), 279]
#
# 2013년 1월 7일 - 9시 45분 32초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517043
# 칼럼 출력 >> [1357551932, Timestamp('2013-01-07 09:45:32'), 278]
#
# 2013년 1월 7일 - 9시 45분 38초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517044
# 칼럼 출력 >> [1357551938, Timestamp('2013-01-07 09:45:38'), 289]
#
# 2013년 1월 7일 - 9시 45분 44초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517045
# 칼럼 출력 >> [1357551944, Timestamp('2013-01-07 09:45:44'), 282]
#
# 2013년 1월 7일 - 9시 45분 50초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517046
# 칼럼 출력 >> [1357551950, Timestamp('2013-01-07 09:45:50'), 288]
#
# 2013년 1월 7일 - 9시 45분 57초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517047
# 칼럼 출력 >> [1357551957, Timestamp('2013-01-07 09:45:57'), 282]
#
# 2013년 1월 7일 - 9시 46분 3초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517048
# 칼럼 출력 >> [1357551963, Timestamp('2013-01-07 09:46:03'), 286]
#
# 2013년 1월 7일 - 9시 46분 9초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517049
# 칼럼 출력 >> [1357551969, Timestamp('2013-01-07 09:46:09'), 291]
#
# 2013년 1월 7일 - 9시 46분 15초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517050
# 칼럼 출력 >> [1357551975, Timestamp('2013-01-07 09:46:15'), 289]
#
# 2013년 1월 7일 - 9시 46분 21초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517051
# 칼럼 출력 >> [1357551981, Timestamp('2013-01-07 09:46:21'), 280]
#
# 2013년 1월 7일 - 9시 46분 27초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517052
# 칼럼 출력 >> [1357551987, Timestamp('2013-01-07 09:46:27'), 290]
#
# 2013년 1월 7일 - 9시 46분 33초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517053
# 칼럼 출력 >> [1357551993, Timestamp('2013-01-07 09:46:33'), 291]
#
# 2013년 1월 7일 - 9시 46분 40초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517054
# 칼럼 출력 >> [1357552000, Timestamp('2013-01-07 09:46:40'), 287]
#
# 2013년 1월 7일 - 9시 46분 46초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517055
# 칼럼 출력 >> [1357552006, Timestamp('2013-01-07 09:46:46'), 289]
#
# 2013년 1월 7일 - 9시 46분 52초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517056
# 칼럼 출력 >> [1357552012, Timestamp('2013-01-07 09:46:52'), 289]
#
# 2013년 1월 7일 - 9시 46분 58초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517057
# 칼럼 출력 >> [1357552018, Timestamp('2013-01-07 09:46:58'), 292]
#
# 2013년 1월 7일 - 9시 47분 4초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517058
# 칼럼 출력 >> [1357552024, Timestamp('2013-01-07 09:47:04'), 288]
#
# 2013년 1월 7일 - 9시 47분 10초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517059
# 칼럼 출력 >> [1357552030, Timestamp('2013-01-07 09:47:10'), 288]
#
# 2013년 1월 7일 - 9시 47분 17초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517060
# 칼럼 출력 >> [1357552037, Timestamp('2013-01-07 09:47:17'), 283]
#
# 2013년 1월 7일 - 9시 47분 23초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517061
# 칼럼 출력 >> [1357552043, Timestamp('2013-01-07 09:47:23'), 290]
#
# 2013년 1월 7일 - 9시 47분 35초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517062
# 칼럼 출력 >> [1357552055, Timestamp('2013-01-07 09:47:35'), 290]
#
# 2013년 1월 7일 - 9시 47분 41초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517063
# 칼럼 출력 >> [1357552061, Timestamp('2013-01-07 09:47:41'), 283]
#
# 2013년 1월 7일 - 9시 47분 48초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517064
# 칼럼 출력 >> [1357552068, Timestamp('2013-01-07 09:47:48'), 291]
#
# 2013년 1월 7일 - 9시 47분 54초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517065
# 칼럼 출력 >> [1357552074, Timestamp('2013-01-07 09:47:54'), 296]
#
# 2013년 1월 7일 - 9시 48분 0초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517066
# 칼럼 출력 >> [1357552080, Timestamp('2013-01-07 09:48:00'), 354]
#
# 2013년 1월 7일 - 9시 48분 6초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517067
# 칼럼 출력 >> [1357552086, Timestamp('2013-01-07 09:48:06'), 330]
#
# 2013년 1월 7일 - 9시 48분 12초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517068
# 칼럼 출력 >> [1357552092, Timestamp('2013-01-07 09:48:12'), 348]
#
# 2013년 1월 7일 - 9시 48분 18초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517069
# 칼럼 출력 >> [1357552098, Timestamp('2013-01-07 09:48:18'), 310]
#
# 2013년 1월 7일 - 9시 48분 25초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517070
# 칼럼 출력 >> [1357552105, Timestamp('2013-01-07 09:48:25'), 309]
#
# 2013년 1월 7일 - 9시 48분 31초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517071
# 칼럼 출력 >> [1357552111, Timestamp('2013-01-07 09:48:31'), 309]
#
# 2013년 1월 7일 - 9시 48분 37초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517072
# 칼럼 출력 >> [1357552117, Timestamp('2013-01-07 09:48:37'), 301]
#
# 2013년 1월 7일 - 9시 48분 43초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517073
# 칼럼 출력 >> [1357552123, Timestamp('2013-01-07 09:48:43'), 300]
#
# 2013년 1월 7일 - 9시 48분 49초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517074
# 칼럼 출력 >> [1357552129, Timestamp('2013-01-07 09:48:49'), 300]
#
# 2013년 1월 7일 - 9시 48분 55초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517075
# 칼럼 출력 >> [1357552135, Timestamp('2013-01-07 09:48:55'), 302]
#
# 2013년 1월 7일 - 9시 49분 1초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517076
# 칼럼 출력 >> [1357552141, Timestamp('2013-01-07 09:49:01'), 300]
#
# 2013년 1월 7일 - 9시 49분 8초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517077
# 칼럼 출력 >> [1357552148, Timestamp('2013-01-07 09:49:08'), 297]
#
# 2013년 1월 7일 - 9시 49분 14초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517078
# 칼럼 출력 >> [1357552154, Timestamp('2013-01-07 09:49:14'), 294]
#
# 2013년 1월 7일 - 9시 49분 20초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517079
# 칼럼 출력 >> [1357552160, Timestamp('2013-01-07 09:49:20'), 300]
#
# 2013년 1월 7일 - 9시 49분 26초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517080
# 칼럼 출력 >> [1357552166, Timestamp('2013-01-07 09:49:26'), 293]
#
# 2013년 1월 7일 - 9시 49분 32초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517081
# 칼럼 출력 >> [1357552172, Timestamp('2013-01-07 09:49:32'), 284]
#
# 2013년 1월 7일 - 9시 49분 45초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517082
# 칼럼 출력 >> [1357552185, Timestamp('2013-01-07 09:49:45'), 283]
#
# 2013년 1월 7일 - 9시 49분 51초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517083
# 칼럼 출력 >> [1357552191, Timestamp('2013-01-07 09:49:51'), 283]
#
# 2013년 1월 7일 - 9시 49분 57초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517084
# 칼럼 출력 >> [1357552197, Timestamp('2013-01-07 09:49:57'), 288]
#
# 2013년 1월 7일 - 9시 50분 3초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517085
# 칼럼 출력 >> [1357552203, Timestamp('2013-01-07 09:50:03'), 285]
#
# 2013년 1월 7일 - 9시 50분 10초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517086
# 칼럼 출력 >> [1357552210, Timestamp('2013-01-07 09:50:10'), 289]
#
# 2013년 1월 7일 - 9시 50분 16초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517087
# 칼럼 출력 >> [1357552216, Timestamp('2013-01-07 09:50:16'), 283]
#
# 2013년 1월 7일 - 9시 50분 22초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517088
# 칼럼 출력 >> [1357552222, Timestamp('2013-01-07 09:50:22'), 283]
#
# 2013년 1월 7일 - 9시 50분 28초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517089
# 칼럼 출력 >> [1357552228, Timestamp('2013-01-07 09:50:28'), 283]
#
# 2013년 1월 7일 - 9시 50분 34초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517090
# 칼럼 출력 >> [1357552234, Timestamp('2013-01-07 09:50:34'), 286]
#
# 2013년 1월 7일 - 9시 50분 40초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517091
# 칼럼 출력 >> [1357552240, Timestamp('2013-01-07 09:50:40'), 287]
#
# 2013년 1월 7일 - 9시 50분 53초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517092
# 칼럼 출력 >> [1357552253, Timestamp('2013-01-07 09:50:53'), 286]
#
# 2013년 1월 7일 - 9시 50분 59초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517093
# 칼럼 출력 >> [1357552259, Timestamp('2013-01-07 09:50:59'), 283]
#
# 2013년 1월 7일 - 9시 51분 5초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517094
# 칼럼 출력 >> [1357552265, Timestamp('2013-01-07 09:51:05'), 325]
#
# 2013년 1월 7일 - 9시 51분 11초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517095
# 칼럼 출력 >> [1357552271, Timestamp('2013-01-07 09:51:11'), 315]
#
# 2013년 1월 7일 - 9시 51분 17초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517096
# 칼럼 출력 >> [1357552277, Timestamp('2013-01-07 09:51:17'), 345]
#
# 2013년 1월 7일 - 9시 51분 24초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517097
# 칼럼 출력 >> [1357552284, Timestamp('2013-01-07 09:51:24'), 347]
#
# 2013년 1월 7일 - 9시 51분 30초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517098
# 칼럼 출력 >> [1357552290, Timestamp('2013-01-07 09:51:30'), 359]
#
# 2013년 1월 7일 - 9시 51분 36초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517099
# 칼럼 출력 >> [1357552296, Timestamp('2013-01-07 09:51:36'), 359]
#
# 2013년 1월 7일 - 9시 51분 42초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517100
# 칼럼 출력 >> [1357552302, Timestamp('2013-01-07 09:51:42'), 359]
#
# 2013년 1월 7일 - 9시 51분 48초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517101
# 칼럼 출력 >> [1357552308, Timestamp('2013-01-07 09:51:48'), 348]
#
# 2013년 1월 7일 - 9시 51분 54초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517102
# 칼럼 출력 >> [1357552314, Timestamp('2013-01-07 09:51:54'), 353]
#
# 2013년 1월 7일 - 9시 52분 0초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517103
# 칼럼 출력 >> [1357552320, Timestamp('2013-01-07 09:52:00'), 353]
#
# 2013년 1월 7일 - 9시 52분 7초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517104
# 칼럼 출력 >> [1357552327, Timestamp('2013-01-07 09:52:07'), 354]
#
# 2013년 1월 7일 - 9시 52분 13초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517105
# 칼럼 출력 >> [1357552333, Timestamp('2013-01-07 09:52:13'), 358]
#
# 2013년 1월 7일 - 9시 52분 19초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517106
# 칼럼 출력 >> [1357552339, Timestamp('2013-01-07 09:52:19'), 349]
#
# 2013년 1월 7일 - 9시 52분 25초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517107
# 칼럼 출력 >> [1357552345, Timestamp('2013-01-07 09:52:25'), 359]
#
# 2013년 1월 7일 - 9시 52분 31초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517108
# 칼럼 출력 >> [1357552351, Timestamp('2013-01-07 09:52:31'), 335]
#
# 2013년 1월 7일 - 9시 52분 38초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517109
# 칼럼 출력 >> [1357552358, Timestamp('2013-01-07 09:52:38'), 310]
#
# 2013년 1월 7일 - 9시 52분 44초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517110
# 칼럼 출력 >> [1357552364, Timestamp('2013-01-07 09:52:44'), 303]
#
# 2013년 1월 7일 - 9시 52분 50초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517111
# 칼럼 출력 >> [1357552370, Timestamp('2013-01-07 09:52:50'), 303]
#
# 2013년 1월 7일 - 9시 52분 56초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517112
# 칼럼 출력 >> [1357552376, Timestamp('2013-01-07 09:52:56'), 306]
#
# 2013년 1월 7일 - 9시 53분 2초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517113
# 칼럼 출력 >> [1357552382, Timestamp('2013-01-07 09:53:02'), 305]
#
# 2013년 1월 7일 - 9시 53분 8초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517114
# 칼럼 출력 >> [1357552388, Timestamp('2013-01-07 09:53:08'), 310]
#
# 2013년 1월 7일 - 9시 53분 15초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517115
# 칼럼 출력 >> [1357552395, Timestamp('2013-01-07 09:53:15'), 298]
#
# 2013년 1월 7일 - 9시 53분 21초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517116
# 칼럼 출력 >> [1357552401, Timestamp('2013-01-07 09:53:21'), 291]
#
# 2013년 1월 7일 - 9시 53분 27초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517117
# 칼럼 출력 >> [1357552407, Timestamp('2013-01-07 09:53:27'), 296]
#
# 2013년 1월 7일 - 9시 53분 33초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517118
# 칼럼 출력 >> [1357552413, Timestamp('2013-01-07 09:53:33'), 297]
#
# 2013년 1월 7일 - 9시 53분 39초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517119
# 칼럼 출력 >> [1357552419, Timestamp('2013-01-07 09:53:39'), 286]
#
# 2013년 1월 7일 - 9시 53분 45초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517120
# 칼럼 출력 >> [1357552425, Timestamp('2013-01-07 09:53:45'), 279]
#
# 2013년 1월 7일 - 9시 53분 52초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517121
# 칼럼 출력 >> [1357552432, Timestamp('2013-01-07 09:53:52'), 279]
#
# 2013년 1월 7일 - 9시 53분 58초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517122
# 칼럼 출력 >> [1357552438, Timestamp('2013-01-07 09:53:58'), 281]
#
# 2013년 1월 7일 - 9시 54분 4초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517123
# 칼럼 출력 >> [1357552444, Timestamp('2013-01-07 09:54:04'), 284]
#
# 2013년 1월 7일 - 9시 54분 10초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517124
# 칼럼 출력 >> [1357552450, Timestamp('2013-01-07 09:54:10'), 288]
#
# 2013년 1월 7일 - 9시 54분 16초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517125
# 칼럼 출력 >> [1357552456, Timestamp('2013-01-07 09:54:16'), 282]
#
# 2013년 1월 7일 - 9시 54분 22초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517126
# 칼럼 출력 >> [1357552462, Timestamp('2013-01-07 09:54:22'), 289]
#
# 2013년 1월 7일 - 9시 54분 29초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517127
# 칼럼 출력 >> [1357552469, Timestamp('2013-01-07 09:54:29'), 280]
#
# 2013년 1월 7일 - 9시 54분 35초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517128
# 칼럼 출력 >> [1357552475, Timestamp('2013-01-07 09:54:35'), 281]
#
# 2013년 1월 7일 - 9시 54분 41초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517129
# 칼럼 출력 >> [1357552481, Timestamp('2013-01-07 09:54:41'), 288]
#
# 2013년 1월 7일 - 9시 54분 47초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517130
# 칼럼 출력 >> [1357552487, Timestamp('2013-01-07 09:54:47'), 284]
#
# 2013년 1월 7일 - 9시 54분 53초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517131
# 칼럼 출력 >> [1357552493, Timestamp('2013-01-07 09:54:53'), 290]
#
# 2013년 1월 7일 - 9시 54분 59초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517132
# 칼럼 출력 >> [1357552499, Timestamp('2013-01-07 09:54:59'), 283]
#
# 2013년 1월 7일 - 9시 55분 6초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517133
# 칼럼 출력 >> [1357552506, Timestamp('2013-01-07 09:55:06'), 284]
#
# 2013년 1월 7일 - 9시 55분 12초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517134
# 칼럼 출력 >> [1357552512, Timestamp('2013-01-07 09:55:12'), 286]
#
# 2013년 1월 7일 - 9시 55분 18초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517135
# 칼럼 출력 >> [1357552518, Timestamp('2013-01-07 09:55:18'), 286]
#
# 2013년 1월 7일 - 9시 55분 30초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517136
# 칼럼 출력 >> [1357552530, Timestamp('2013-01-07 09:55:30'), 281]
#
# 2013년 1월 7일 - 9시 55분 36초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517137
# 칼럼 출력 >> [1357552536, Timestamp('2013-01-07 09:55:36'), 289]
#
# 2013년 1월 7일 - 9시 55분 42초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517138
# 칼럼 출력 >> [1357552542, Timestamp('2013-01-07 09:55:42'), 285]
#
# 2013년 1월 7일 - 9시 55분 49초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517139
# 칼럼 출력 >> [1357552549, Timestamp('2013-01-07 09:55:49'), 291]
#
# 2013년 1월 7일 - 9시 55분 55초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517140
# 칼럼 출력 >> [1357552555, Timestamp('2013-01-07 09:55:55'), 289]
#
# 2013년 1월 7일 - 9시 56분 1초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517141
# 칼럼 출력 >> [1357552561, Timestamp('2013-01-07 09:56:01'), 286]
#
# 2013년 1월 7일 - 9시 56분 7초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517142
# 칼럼 출력 >> [1357552567, Timestamp('2013-01-07 09:56:07'), 284]
#
# 2013년 1월 7일 - 9시 56분 13초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517143
# 칼럼 출력 >> [1357552573, Timestamp('2013-01-07 09:56:13'), 284]
#
# 2013년 1월 7일 - 9시 56분 19초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517144
# 칼럼 출력 >> [1357552579, Timestamp('2013-01-07 09:56:19'), 280]
#
# 2013년 1월 7일 - 9시 56분 26초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517145
# 칼럼 출력 >> [1357552586, Timestamp('2013-01-07 09:56:26'), 284]
#
# 2013년 1월 7일 - 9시 56분 38초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517146
# 칼럼 출력 >> [1357552598, Timestamp('2013-01-07 09:56:38'), 280]
#
# 2013년 1월 7일 - 9시 56분 44초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517147
# 칼럼 출력 >> [1357552604, Timestamp('2013-01-07 09:56:44'), 287]
#
# 2013년 1월 7일 - 9시 56분 50초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517148
# 칼럼 출력 >> [1357552610, Timestamp('2013-01-07 09:56:50'), 287]
#
# 2013년 1월 7일 - 9시 56분 56초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517149
# 칼럼 출력 >> [1357552616, Timestamp('2013-01-07 09:56:56'), 316]
#
# 2013년 1월 7일 - 9시 57분 2초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517150
# 칼럼 출력 >> [1357552622, Timestamp('2013-01-07 09:57:02'), 297]
#
# 2013년 1월 7일 - 9시 57분 9초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517151
# 칼럼 출력 >> [1357552629, Timestamp('2013-01-07 09:57:09'), 312]
#
# 2013년 1월 7일 - 9시 57분 15초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517152
# 칼럼 출력 >> [1357552635, Timestamp('2013-01-07 09:57:15'), 299]
#
# 2013년 1월 7일 - 9시 57분 21초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517153
# 칼럼 출력 >> [1357552641, Timestamp('2013-01-07 09:57:21'), 292]
#
# 2013년 1월 7일 - 9시 57분 27초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517154
# 칼럼 출력 >> [1357552647, Timestamp('2013-01-07 09:57:27'), 297]
#
# 2013년 1월 7일 - 9시 57분 33초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517155
# 칼럼 출력 >> [1357552653, Timestamp('2013-01-07 09:57:33'), 295]
#
# 2013년 1월 7일 - 9시 57분 40초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517156
# 칼럼 출력 >> [1357552660, Timestamp('2013-01-07 09:57:40'), 291]
#
# 2013년 1월 7일 - 9시 57분 46초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517157
# 칼럼 출력 >> [1357552666, Timestamp('2013-01-07 09:57:46'), 295]
#
# 2013년 1월 7일 - 9시 57분 52초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517158
# 칼럼 출력 >> [1357552672, Timestamp('2013-01-07 09:57:52'), 296]
#
# 2013년 1월 7일 - 9시 57분 58초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517159
# 칼럼 출력 >> [1357552678, Timestamp('2013-01-07 09:57:58'), 285]
#
# 2013년 1월 7일 - 9시 58분 4초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517160
# 칼럼 출력 >> [1357552684, Timestamp('2013-01-07 09:58:04'), 291]
#
# 2013년 1월 7일 - 9시 58분 10초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517161
# 칼럼 출력 >> [1357552690, Timestamp('2013-01-07 09:58:10'), 286]
#
# 2013년 1월 7일 - 9시 58분 17초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517162
# 칼럼 출력 >> [1357552697, Timestamp('2013-01-07 09:58:17'), 282]
#
# 2013년 1월 7일 - 9시 58분 23초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517163
# 칼럼 출력 >> [1357552703, Timestamp('2013-01-07 09:58:23'), 286]
#
# 2013년 1월 7일 - 9시 58분 29초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517164
# 칼럼 출력 >> [1357552709, Timestamp('2013-01-07 09:58:29'), 286]
#
# 2013년 1월 7일 - 9시 58분 35초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517165
# 칼럼 출력 >> [1357552715, Timestamp('2013-01-07 09:58:35'), 287]
#
# 2013년 1월 7일 - 9시 58분 41초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517166
# 칼럼 출력 >> [1357552721, Timestamp('2013-01-07 09:58:41'), 284]
#
# 2013년 1월 7일 - 9시 58분 48초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517167
# 칼럼 출력 >> [1357552728, Timestamp('2013-01-07 09:58:48'), 283]
#
# 2013년 1월 7일 - 9시 58분 54초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517168
# 칼럼 출력 >> [1357552734, Timestamp('2013-01-07 09:58:54'), 285]
#
# 2013년 1월 7일 - 9시 59분 0초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517169
# 칼럼 출력 >> [1357552740, Timestamp('2013-01-07 09:59:00'), 283]
#
# 2013년 1월 7일 - 9시 59분 6초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517170
# 칼럼 출력 >> [1357552746, Timestamp('2013-01-07 09:59:06'), 286]
#
# 2013년 1월 7일 - 9시 59분 12초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517171
# 칼럼 출력 >> [1357552752, Timestamp('2013-01-07 09:59:12'), 288]
#
# 2013년 1월 7일 - 9시 59분 19초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517172
# 칼럼 출력 >> [1357552759, Timestamp('2013-01-07 09:59:19'), 282]
#
# 2013년 1월 7일 - 9시 59분 25초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517173
# 칼럼 출력 >> [1357552765, Timestamp('2013-01-07 09:59:25'), 280]
#
# 2013년 1월 7일 - 9시 59분 31초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517174
# 칼럼 출력 >> [1357552771, Timestamp('2013-01-07 09:59:31'), 284]
#
# 2013년 1월 7일 - 9시 59분 37초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517175
# 칼럼 출력 >> [1357552777, Timestamp('2013-01-07 09:59:37'), 284]
#
# 2013년 1월 7일 - 9시 59분 43초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517176
# 칼럼 출력 >> [1357552783, Timestamp('2013-01-07 09:59:43'), 282]
#
# 2013년 1월 7일 - 9시 59분 49초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517177
# 칼럼 출력 >> [1357552789, Timestamp('2013-01-07 09:59:49'), 281]
#
# 2013년 1월 7일 - 9시 59분 56초
# d1 >> 7 d >> 7 H1 >> 9 h >> 9   //   i >> 517178
# 칼럼 출력 >> [1357552796, Timestamp('2013-01-07 09:59:56'), 283]
#
#
# 시 단위 변경! 루프 종료 및 맥스값 추출!
# ========================================< 3.1.2. - 1시간치 끝!! >==================================================
#
# d1 >> 7 d >> 7 H1 >> 9 h >> 10   //   i >> 517179
# 1시간 동안 데이터 수 >> 180
#
# 9 시까지의 최대값 >> 359
# csv 저장 완료!
#
#
#
#
#
# 시작 시가 안 맞아요!! H0 >> 9 H1 >> 10
# 2013년 1월 7일 - 10시
#
#
# 2013년 1월 7일 - 10시 0분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517179
# 칼럼 출력 >> [1357552802, Timestamp('2013-01-07 10:00:02'), 287]
#
# 2013년 1월 7일 - 10시 0분 8초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517180
# 칼럼 출력 >> [1357552808, Timestamp('2013-01-07 10:00:08'), 282]
#
# 2013년 1월 7일 - 10시 0분 14초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517181
# 칼럼 출력 >> [1357552814, Timestamp('2013-01-07 10:00:14'), 279]
#
# 2013년 1월 7일 - 10시 0분 20초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517182
# 칼럼 출력 >> [1357552820, Timestamp('2013-01-07 10:00:20'), 287]
#
# 2013년 1월 7일 - 10시 0분 26초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517183
# 칼럼 출력 >> [1357552826, Timestamp('2013-01-07 10:00:26'), 286]
#
# 2013년 1월 7일 - 10시 0분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517184
# 칼럼 출력 >> [1357552833, Timestamp('2013-01-07 10:00:33'), 282]
#
# 2013년 1월 7일 - 10시 0분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517185
# 칼럼 출력 >> [1357552839, Timestamp('2013-01-07 10:00:39'), 282]
#
# 2013년 1월 7일 - 10시 0분 45초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517186
# 칼럼 출력 >> [1357552845, Timestamp('2013-01-07 10:00:45'), 286]
#
# 2013년 1월 7일 - 10시 0분 51초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517187
# 칼럼 출력 >> [1357552851, Timestamp('2013-01-07 10:00:51'), 283]
#
# 2013년 1월 7일 - 10시 0분 57초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517188
# 칼럼 출력 >> [1357552857, Timestamp('2013-01-07 10:00:57'), 285]
#
# 2013년 1월 7일 - 10시 1분 3초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517189
# 칼럼 출력 >> [1357552863, Timestamp('2013-01-07 10:01:03'), 287]
#
# 2013년 1월 7일 - 10시 1분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517190
# 칼럼 출력 >> [1357552870, Timestamp('2013-01-07 10:01:10'), 305]
#
# 2013년 1월 7일 - 10시 1분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517191
# 칼럼 출력 >> [1357552876, Timestamp('2013-01-07 10:01:16'), 302]
#
# 2013년 1월 7일 - 10시 1분 22초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517192
# 칼럼 출력 >> [1357552882, Timestamp('2013-01-07 10:01:22'), 308]
#
# 2013년 1월 7일 - 10시 1분 28초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517193
# 칼럼 출력 >> [1357552888, Timestamp('2013-01-07 10:01:28'), 300]
#
# 2013년 1월 7일 - 10시 1분 34초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517194
# 칼럼 출력 >> [1357552894, Timestamp('2013-01-07 10:01:34'), 298]
#
# 2013년 1월 7일 - 10시 1분 40초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517195
# 칼럼 출력 >> [1357552900, Timestamp('2013-01-07 10:01:40'), 301]
#
# 2013년 1월 7일 - 10시 1분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517196
# 칼럼 출력 >> [1357552906, Timestamp('2013-01-07 10:01:46'), 301]
#
# 2013년 1월 7일 - 10시 1분 53초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517197
# 칼럼 출력 >> [1357552913, Timestamp('2013-01-07 10:01:53'), 298]
#
# 2013년 1월 7일 - 10시 1분 59초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517198
# 칼럼 출력 >> [1357552919, Timestamp('2013-01-07 10:01:59'), 808]
#
# 2013년 1월 7일 - 10시 2분 5초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517199
# 칼럼 출력 >> [1357552925, Timestamp('2013-01-07 10:02:05'), 292]
#
# 2013년 1월 7일 - 10시 2분 11초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517200
# 칼럼 출력 >> [1357552931, Timestamp('2013-01-07 10:02:11'), 290]
#
# 2013년 1월 7일 - 10시 2분 23초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517201
# 칼럼 출력 >> [1357552943, Timestamp('2013-01-07 10:02:23'), 289]
#
# 2013년 1월 7일 - 10시 2분 30초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517202
# 칼럼 출력 >> [1357552950, Timestamp('2013-01-07 10:02:30'), 552]
#
# 2013년 1월 7일 - 10시 2분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517203
# 칼럼 출력 >> [1357552956, Timestamp('2013-01-07 10:02:36'), 285]
#
# 2013년 1월 7일 - 10시 2분 48초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517204
# 칼럼 출력 >> [1357552968, Timestamp('2013-01-07 10:02:48'), 283]
#
# 2013년 1월 7일 - 10시 2분 54초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517205
# 칼럼 출력 >> [1357552974, Timestamp('2013-01-07 10:02:54'), 283]
#
# 2013년 1월 7일 - 10시 3분 1초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517206
# 칼럼 출력 >> [1357552981, Timestamp('2013-01-07 10:03:01'), 287]
#
# 2013년 1월 7일 - 10시 3분 13초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517207
# 칼럼 출력 >> [1357552993, Timestamp('2013-01-07 10:03:13'), 284]
#
# 2013년 1월 7일 - 10시 3분 19초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517208
# 칼럼 출력 >> [1357552999, Timestamp('2013-01-07 10:03:19'), 289]
#
# 2013년 1월 7일 - 10시 3분 25초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517209
# 칼럼 출력 >> [1357553005, Timestamp('2013-01-07 10:03:25'), 283]
#
# 2013년 1월 7일 - 10시 3분 31초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517210
# 칼럼 출력 >> [1357553011, Timestamp('2013-01-07 10:03:31'), 283]
#
# 2013년 1월 7일 - 10시 3분 38초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517211
# 칼럼 출력 >> [1357553018, Timestamp('2013-01-07 10:03:38'), 286]
#
# 2013년 1월 7일 - 10시 3분 44초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517212
# 칼럼 출력 >> [1357553024, Timestamp('2013-01-07 10:03:44'), 288]
#
# 2013년 1월 7일 - 10시 3분 50초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517213
# 칼럼 출력 >> [1357553030, Timestamp('2013-01-07 10:03:50'), 293]
#
# 2013년 1월 7일 - 10시 3분 56초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517214
# 칼럼 출력 >> [1357553036, Timestamp('2013-01-07 10:03:56'), 282]
#
# 2013년 1월 7일 - 10시 4분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517215
# 칼럼 출력 >> [1357553042, Timestamp('2013-01-07 10:04:02'), 290]
#
# 2013년 1월 7일 - 10시 4분 8초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517216
# 칼럼 출력 >> [1357553048, Timestamp('2013-01-07 10:04:08'), 285]
#
# 2013년 1월 7일 - 10시 4분 14초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517217
# 칼럼 출력 >> [1357553054, Timestamp('2013-01-07 10:04:14'), 280]
#
# 2013년 1월 7일 - 10시 4분 21초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517218
# 칼럼 출력 >> [1357553061, Timestamp('2013-01-07 10:04:21'), 288]
#
# 2013년 1월 7일 - 10시 4분 27초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517219
# 칼럼 출력 >> [1357553067, Timestamp('2013-01-07 10:04:27'), 284]
#
# 2013년 1월 7일 - 10시 4분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517220
# 칼럼 출력 >> [1357553073, Timestamp('2013-01-07 10:04:33'), 286]
#
# 2013년 1월 7일 - 10시 4분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517221
# 칼럼 출력 >> [1357553079, Timestamp('2013-01-07 10:04:39'), 287]
#
# 2013년 1월 7일 - 10시 4분 45초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517222
# 칼럼 출력 >> [1357553085, Timestamp('2013-01-07 10:04:45'), 289]
#
# 2013년 1월 7일 - 10시 4분 52초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517223
# 칼럼 출력 >> [1357553092, Timestamp('2013-01-07 10:04:52'), 287]
#
# 2013년 1월 7일 - 10시 4분 58초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517224
# 칼럼 출력 >> [1357553098, Timestamp('2013-01-07 10:04:58'), 285]
#
# 2013년 1월 7일 - 10시 5분 4초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517225
# 칼럼 출력 >> [1357553104, Timestamp('2013-01-07 10:05:04'), 283]
#
# 2013년 1월 7일 - 10시 5분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517226
# 칼럼 출력 >> [1357553110, Timestamp('2013-01-07 10:05:10'), 281]
#
# 2013년 1월 7일 - 10시 5분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517227
# 칼럼 출력 >> [1357553116, Timestamp('2013-01-07 10:05:16'), 283]
#
# 2013년 1월 7일 - 10시 5분 23초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517228
# 칼럼 출력 >> [1357553123, Timestamp('2013-01-07 10:05:23'), 284]
#
# 2013년 1월 7일 - 10시 5분 29초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517229
# 칼럼 출력 >> [1357553129, Timestamp('2013-01-07 10:05:29'), 320]
#
# 2013년 1월 7일 - 10시 5분 35초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517230
# 칼럼 출력 >> [1357553135, Timestamp('2013-01-07 10:05:35'), 306]
#
# 2013년 1월 7일 - 10시 5분 41초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517231
# 칼럼 출력 >> [1357553141, Timestamp('2013-01-07 10:05:41'), 303]
#
# 2013년 1월 7일 - 10시 5분 47초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517232
# 칼럼 출력 >> [1357553147, Timestamp('2013-01-07 10:05:47'), 300]
#
# 2013년 1월 7일 - 10시 5분 53초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517233
# 칼럼 출력 >> [1357553153, Timestamp('2013-01-07 10:05:53'), 299]
#
# 2013년 1월 7일 - 10시 5분 59초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517234
# 칼럼 출력 >> [1357553159, Timestamp('2013-01-07 10:05:59'), 299]
#
# 2013년 1월 7일 - 10시 6분 6초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517235
# 칼럼 출력 >> [1357553166, Timestamp('2013-01-07 10:06:06'), 297]
#
# 2013년 1월 7일 - 10시 6분 12초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517236
# 칼럼 출력 >> [1357553172, Timestamp('2013-01-07 10:06:12'), 289]
#
# 2013년 1월 7일 - 10시 6분 18초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517237
# 칼럼 출력 >> [1357553178, Timestamp('2013-01-07 10:06:18'), 289]
#
# 2013년 1월 7일 - 10시 6분 24초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517238
# 칼럼 출력 >> [1357553184, Timestamp('2013-01-07 10:06:24'), 294]
#
# 2013년 1월 7일 - 10시 6분 30초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517239
# 칼럼 출력 >> [1357553190, Timestamp('2013-01-07 10:06:30'), 292]
#
# 2013년 1월 7일 - 10시 6분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517240
# 칼럼 출력 >> [1357553196, Timestamp('2013-01-07 10:06:36'), 291]
#
# 2013년 1월 7일 - 10시 6분 43초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517241
# 칼럼 출력 >> [1357553203, Timestamp('2013-01-07 10:06:43'), 282]
#
# 2013년 1월 7일 - 10시 6분 49초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517242
# 칼럼 출력 >> [1357553209, Timestamp('2013-01-07 10:06:49'), 282]
#
# 2013년 1월 7일 - 10시 6분 55초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517243
# 칼럼 출력 >> [1357553215, Timestamp('2013-01-07 10:06:55'), 283]
#
# 2013년 1월 7일 - 10시 7분 1초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517244
# 칼럼 출력 >> [1357553221, Timestamp('2013-01-07 10:07:01'), 281]
#
# 2013년 1월 7일 - 10시 7분 7초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517245
# 칼럼 출력 >> [1357553227, Timestamp('2013-01-07 10:07:07'), 287]
#
# 2013년 1월 7일 - 10시 7분 13초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517246
# 칼럼 출력 >> [1357553233, Timestamp('2013-01-07 10:07:13'), 283]
#
# 2013년 1월 7일 - 10시 7분 20초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517247
# 칼럼 출력 >> [1357553240, Timestamp('2013-01-07 10:07:20'), 286]
#
# 2013년 1월 7일 - 10시 7분 26초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517248
# 칼럼 출력 >> [1357553246, Timestamp('2013-01-07 10:07:26'), 281]
#
# 2013년 1월 7일 - 10시 7분 32초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517249
# 칼럼 출력 >> [1357553252, Timestamp('2013-01-07 10:07:32'), 284]
#
# 2013년 1월 7일 - 10시 7분 38초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517250
# 칼럼 출력 >> [1357553258, Timestamp('2013-01-07 10:07:38'), 286]
#
# 2013년 1월 7일 - 10시 7분 44초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517251
# 칼럼 출력 >> [1357553264, Timestamp('2013-01-07 10:07:44'), 281]
#
# 2013년 1월 7일 - 10시 7분 56초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517252
# 칼럼 출력 >> [1357553276, Timestamp('2013-01-07 10:07:56'), 286]
#
# 2013년 1월 7일 - 10시 8분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517253
# 칼럼 출력 >> [1357553282, Timestamp('2013-01-07 10:08:02'), 282]
#
# 2013년 1월 7일 - 10시 8분 9초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517254
# 칼럼 출력 >> [1357553289, Timestamp('2013-01-07 10:08:09'), 290]
#
# 2013년 1월 7일 - 10시 8분 15초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517255
# 칼럼 출력 >> [1357553295, Timestamp('2013-01-07 10:08:15'), 323]
#
# 2013년 1월 7일 - 10시 8분 21초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517256
# 칼럼 출력 >> [1357553301, Timestamp('2013-01-07 10:08:21'), 346]
#
# 2013년 1월 7일 - 10시 8분 27초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517257
# 칼럼 출력 >> [1357553307, Timestamp('2013-01-07 10:08:27'), 348]
#
# 2013년 1월 7일 - 10시 8분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517258
# 칼럼 출력 >> [1357553313, Timestamp('2013-01-07 10:08:33'), 345]
#
# 2013년 1월 7일 - 10시 8분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517259
# 칼럼 출력 >> [1357553319, Timestamp('2013-01-07 10:08:39'), 351]
#
# 2013년 1월 7일 - 10시 8분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517260
# 칼럼 출력 >> [1357553326, Timestamp('2013-01-07 10:08:46'), 346]
#
# 2013년 1월 7일 - 10시 8분 52초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517261
# 칼럼 출력 >> [1357553332, Timestamp('2013-01-07 10:08:52'), 349]
#
# 2013년 1월 7일 - 10시 8분 58초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517262
# 칼럼 출력 >> [1357553338, Timestamp('2013-01-07 10:08:58'), 346]
#
# 2013년 1월 7일 - 10시 9분 4초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517263
# 칼럼 출력 >> [1357553344, Timestamp('2013-01-07 10:09:04'), 351]
#
# 2013년 1월 7일 - 10시 9분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517264
# 칼럼 출력 >> [1357553350, Timestamp('2013-01-07 10:09:10'), 348]
#
# 2013년 1월 7일 - 10시 9분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517265
# 칼럼 출력 >> [1357553356, Timestamp('2013-01-07 10:09:16'), 353]
#
# 2013년 1월 7일 - 10시 9분 22초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517266
# 칼럼 출력 >> [1357553362, Timestamp('2013-01-07 10:09:22'), 351]
#
# 2013년 1월 7일 - 10시 9분 29초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517267
# 칼럼 출력 >> [1357553369, Timestamp('2013-01-07 10:09:29'), 347]
#
# 2013년 1월 7일 - 10시 9분 35초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517268
# 칼럼 출력 >> [1357553375, Timestamp('2013-01-07 10:09:35'), 345]
#
# 2013년 1월 7일 - 10시 9분 41초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517269
# 칼럼 출력 >> [1357553381, Timestamp('2013-01-07 10:09:41'), 307]
#
# 2013년 1월 7일 - 10시 9분 47초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517270
# 칼럼 출력 >> [1357553387, Timestamp('2013-01-07 10:09:47'), 381]
#
# 2013년 1월 7일 - 10시 9분 53초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517271
# 칼럼 출력 >> [1357553393, Timestamp('2013-01-07 10:09:53'), 370]
#
# 2013년 1월 7일 - 10시 9분 59초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517272
# 칼럼 출력 >> [1357553399, Timestamp('2013-01-07 10:09:59'), 388]
#
# 2013년 1월 7일 - 10시 10분 6초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517273
# 칼럼 출력 >> [1357553406, Timestamp('2013-01-07 10:10:06'), 373]
#
# 2013년 1월 7일 - 10시 10분 12초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517274
# 칼럼 출력 >> [1357553412, Timestamp('2013-01-07 10:10:12'), 372]
#
# 2013년 1월 7일 - 10시 10분 18초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517275
# 칼럼 출력 >> [1357553418, Timestamp('2013-01-07 10:10:18'), 366]
#
# 2013년 1월 7일 - 10시 10분 24초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517276
# 칼럼 출력 >> [1357553424, Timestamp('2013-01-07 10:10:24'), 377]
#
# 2013년 1월 7일 - 10시 10분 30초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517277
# 칼럼 출력 >> [1357553430, Timestamp('2013-01-07 10:10:30'), 362]
#
# 2013년 1월 7일 - 10시 10분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517278
# 칼럼 출력 >> [1357553436, Timestamp('2013-01-07 10:10:36'), 362]
#
# 2013년 1월 7일 - 10시 10분 43초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517279
# 칼럼 출력 >> [1357553443, Timestamp('2013-01-07 10:10:43'), 373]
#
# 2013년 1월 7일 - 10시 10분 49초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517280
# 칼럼 출력 >> [1357553449, Timestamp('2013-01-07 10:10:49'), 362]
#
# 2013년 1월 7일 - 10시 10분 55초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517281
# 칼럼 출력 >> [1357553455, Timestamp('2013-01-07 10:10:55'), 370]
#
# 2013년 1월 7일 - 10시 11분 1초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517282
# 칼럼 출력 >> [1357553461, Timestamp('2013-01-07 10:11:01'), 360]
#
# 2013년 1월 7일 - 10시 11분 7초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517283
# 칼럼 출력 >> [1357553467, Timestamp('2013-01-07 10:11:07'), 357]
#
# 2013년 1월 7일 - 10시 11분 13초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517284
# 칼럼 출력 >> [1357553473, Timestamp('2013-01-07 10:11:13'), 358]
#
# 2013년 1월 7일 - 10시 11분 19초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517285
# 칼럼 출력 >> [1357553479, Timestamp('2013-01-07 10:11:19'), 358]
#
# 2013년 1월 7일 - 10시 11분 26초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517286
# 칼럼 출력 >> [1357553486, Timestamp('2013-01-07 10:11:26'), 354]
#
# 2013년 1월 7일 - 10시 11분 32초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517287
# 칼럼 출력 >> [1357553492, Timestamp('2013-01-07 10:11:32'), 365]
#
# 2013년 1월 7일 - 10시 11분 38초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517288
# 칼럼 출력 >> [1357553498, Timestamp('2013-01-07 10:11:38'), 360]
#
# 2013년 1월 7일 - 10시 11분 44초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517289
# 칼럼 출력 >> [1357553504, Timestamp('2013-01-07 10:11:44'), 357]
#
# 2013년 1월 7일 - 10시 11분 57초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517290
# 칼럼 출력 >> [1357553517, Timestamp('2013-01-07 10:11:57'), 357]
#
# 2013년 1월 7일 - 10시 12분 3초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517291
# 칼럼 출력 >> [1357553523, Timestamp('2013-01-07 10:12:03'), 358]
#
# 2013년 1월 7일 - 10시 12분 9초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517292
# 칼럼 출력 >> [1357553529, Timestamp('2013-01-07 10:12:09'), 355]
#
# 2013년 1월 7일 - 10시 12분 15초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517293
# 칼럼 출력 >> [1357553535, Timestamp('2013-01-07 10:12:15'), 357]
#
# 2013년 1월 7일 - 10시 12분 21초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517294
# 칼럼 출력 >> [1357553541, Timestamp('2013-01-07 10:12:21'), 353]
#
# 2013년 1월 7일 - 10시 12분 27초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517295
# 칼럼 출력 >> [1357553547, Timestamp('2013-01-07 10:12:27'), 361]
#
# 2013년 1월 7일 - 10시 12분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517296
# 칼럼 출력 >> [1357553553, Timestamp('2013-01-07 10:12:33'), 352]
#
# 2013년 1월 7일 - 10시 12분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517297
# 칼럼 출력 >> [1357553559, Timestamp('2013-01-07 10:12:39'), 651]
#
# 2013년 1월 7일 - 10시 12분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517298
# 칼럼 출력 >> [1357553566, Timestamp('2013-01-07 10:12:46'), 356]
#
# 2013년 1월 7일 - 10시 12분 52초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517299
# 칼럼 출력 >> [1357553572, Timestamp('2013-01-07 10:12:52'), 355]
#
# 2013년 1월 7일 - 10시 12분 58초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517300
# 칼럼 출력 >> [1357553578, Timestamp('2013-01-07 10:12:58'), 358]
#
# 2013년 1월 7일 - 10시 13분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517301
# 칼럼 출력 >> [1357553590, Timestamp('2013-01-07 10:13:10'), 473]
#
# 2013년 1월 7일 - 10시 13분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517302
# 칼럼 출력 >> [1357553596, Timestamp('2013-01-07 10:13:16'), 359]
#
# 2013년 1월 7일 - 10시 13분 23초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517303
# 칼럼 출력 >> [1357553603, Timestamp('2013-01-07 10:13:23'), 364]
#
# 2013년 1월 7일 - 10시 13분 29초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517304
# 칼럼 출력 >> [1357553609, Timestamp('2013-01-07 10:13:29'), 364]
#
# 2013년 1월 7일 - 10시 13분 35초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517305
# 칼럼 출력 >> [1357553615, Timestamp('2013-01-07 10:13:35'), 368]
#
# 2013년 1월 7일 - 10시 13분 41초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517306
# 칼럼 출력 >> [1357553621, Timestamp('2013-01-07 10:13:41'), 358]
#
# 2013년 1월 7일 - 10시 13분 47초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517307
# 칼럼 출력 >> [1357553627, Timestamp('2013-01-07 10:13:47'), 365]
#
# 2013년 1월 7일 - 10시 13분 54초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517308
# 칼럼 출력 >> [1357553634, Timestamp('2013-01-07 10:13:54'), 358]
#
# 2013년 1월 7일 - 10시 14분 0초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517309
# 칼럼 출력 >> [1357553640, Timestamp('2013-01-07 10:14:00'), 358]
#
# 2013년 1월 7일 - 10시 14분 6초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517310
# 칼럼 출력 >> [1357553646, Timestamp('2013-01-07 10:14:06'), 363]
#
# 2013년 1월 7일 - 10시 14분 12초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517311
# 칼럼 출력 >> [1357553652, Timestamp('2013-01-07 10:14:12'), 378]
#
# 2013년 1월 7일 - 10시 14분 18초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517312
# 칼럼 출력 >> [1357553658, Timestamp('2013-01-07 10:14:18'), 375]
#
# 2013년 1월 7일 - 10시 14분 24초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517313
# 칼럼 출력 >> [1357553664, Timestamp('2013-01-07 10:14:24'), 368]
#
# 2013년 1월 7일 - 10시 14분 31초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517314
# 칼럼 출력 >> [1357553671, Timestamp('2013-01-07 10:14:31'), 377]
#
# 2013년 1월 7일 - 10시 14분 37초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517315
# 칼럼 출력 >> [1357553677, Timestamp('2013-01-07 10:14:37'), 363]
#
# 2013년 1월 7일 - 10시 14분 43초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517316
# 칼럼 출력 >> [1357553683, Timestamp('2013-01-07 10:14:43'), 372]
#
# 2013년 1월 7일 - 10시 14분 49초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517317
# 칼럼 출력 >> [1357553689, Timestamp('2013-01-07 10:14:49'), 359]
#
# 2013년 1월 7일 - 10시 14분 55초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517318
# 칼럼 출력 >> [1357553695, Timestamp('2013-01-07 10:14:55'), 365]
#
# 2013년 1월 7일 - 10시 15분 1초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517319
# 칼럼 출력 >> [1357553701, Timestamp('2013-01-07 10:15:01'), 359]
#
# 2013년 1월 7일 - 10시 15분 7초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517320
# 칼럼 출력 >> [1357553707, Timestamp('2013-01-07 10:15:07'), 366]
#
# 2013년 1월 7일 - 10시 15분 14초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517321
# 칼럼 출력 >> [1357553714, Timestamp('2013-01-07 10:15:14'), 376]
#
# 2013년 1월 7일 - 10시 15분 20초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517322
# 칼럼 출력 >> [1357553720, Timestamp('2013-01-07 10:15:20'), 358]
#
# 2013년 1월 7일 - 10시 15분 26초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517323
# 칼럼 출력 >> [1357553726, Timestamp('2013-01-07 10:15:26'), 355]
#
# 2013년 1월 7일 - 10시 15분 32초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517324
# 칼럼 출력 >> [1357553732, Timestamp('2013-01-07 10:15:32'), 355]
#
# 2013년 1월 7일 - 10시 15분 38초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517325
# 칼럼 출력 >> [1357553738, Timestamp('2013-01-07 10:15:38'), 358]
#
# 2013년 1월 7일 - 10시 15분 45초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517326
# 칼럼 출력 >> [1357553745, Timestamp('2013-01-07 10:15:45'), 357]
#
# 2013년 1월 7일 - 10시 15분 51초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517327
# 칼럼 출력 >> [1357553751, Timestamp('2013-01-07 10:15:51'), 356]
#
# 2013년 1월 7일 - 10시 15분 57초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517328
# 칼럼 출력 >> [1357553757, Timestamp('2013-01-07 10:15:57'), 352]
#
# 2013년 1월 7일 - 10시 16분 3초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517329
# 칼럼 출력 >> [1357553763, Timestamp('2013-01-07 10:16:03'), 356]
#
# 2013년 1월 7일 - 10시 16분 9초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517330
# 칼럼 출력 >> [1357553769, Timestamp('2013-01-07 10:16:09'), 352]
#
# 2013년 1월 7일 - 10시 16분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517331
# 칼럼 출력 >> [1357553776, Timestamp('2013-01-07 10:16:16'), 360]
#
# 2013년 1월 7일 - 10시 16분 22초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517332
# 칼럼 출력 >> [1357553782, Timestamp('2013-01-07 10:16:22'), 356]
#
# 2013년 1월 7일 - 10시 16분 28초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517333
# 칼럼 출력 >> [1357553788, Timestamp('2013-01-07 10:16:28'), 360]
#
# 2013년 1월 7일 - 10시 16분 34초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517334
# 칼럼 출력 >> [1357553794, Timestamp('2013-01-07 10:16:34'), 356]
#
# 2013년 1월 7일 - 10시 16분 40초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517335
# 칼럼 출력 >> [1357553800, Timestamp('2013-01-07 10:16:40'), 357]
#
# 2013년 1월 7일 - 10시 16분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517336
# 칼럼 출력 >> [1357553806, Timestamp('2013-01-07 10:16:46'), 353]
#
# 2013년 1월 7일 - 10시 16분 53초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517337
# 칼럼 출력 >> [1357553813, Timestamp('2013-01-07 10:16:53'), 359]
#
# 2013년 1월 7일 - 10시 16분 59초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517338
# 칼럼 출력 >> [1357553819, Timestamp('2013-01-07 10:16:59'), 365]
#
# 2013년 1월 7일 - 10시 17분 5초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517339
# 칼럼 출력 >> [1357553825, Timestamp('2013-01-07 10:17:05'), 355]
#
# 2013년 1월 7일 - 10시 17분 11초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517340
# 칼럼 출력 >> [1357553831, Timestamp('2013-01-07 10:17:11'), 356]
#
# 2013년 1월 7일 - 10시 17분 17초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517341
# 칼럼 출력 >> [1357553837, Timestamp('2013-01-07 10:17:17'), 357]
#
# 2013년 1월 7일 - 10시 17분 24초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517342
# 칼럼 출력 >> [1357553844, Timestamp('2013-01-07 10:17:24'), 354]
#
# 2013년 1월 7일 - 10시 17분 30초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517343
# 칼럼 출력 >> [1357553850, Timestamp('2013-01-07 10:17:30'), 354]
#
# 2013년 1월 7일 - 10시 17분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517344
# ...
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517346
# 칼럼 출력 >> [1357553868, Timestamp('2013-01-07 10:17:48'), 353]
#
# 2013년 1월 7일 - 10시 17분 54초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517347
# 칼럼 출력 >> [1357553874, Timestamp('2013-01-07 10:17:54'), 362]
#
# 2013년 1월 7일 - 10시 18분 0초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517348
# 칼럼 출력 >> [1357553880, Timestamp('2013-01-07 10:18:00'), 359]
#
# 2013년 1월 7일 - 10시 18분 6초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517349
# 칼럼 출력 >> [1357553886, Timestamp('2013-01-07 10:18:06'), 379]
#
# 2013년 1월 7일 - 10시 18분 13초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517350
# 칼럼 출력 >> [1357553893, Timestamp('2013-01-07 10:18:13'), 380]
#
# 2013년 1월 7일 - 10시 18분 25초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517351
# 칼럼 출력 >> [1357553905, Timestamp('2013-01-07 10:18:25'), 374]
#
# 2013년 1월 7일 - 10시 18분 31초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517352
# 칼럼 출력 >> [1357553911, Timestamp('2013-01-07 10:18:31'), 377]
#
# 2013년 1월 7일 - 10시 18분 37초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517353
# 칼럼 출력 >> [1357553917, Timestamp('2013-01-07 10:18:37'), 372]
#
# 2013년 1월 7일 - 10시 18분 44초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517354
# 칼럼 출력 >> [1357553924, Timestamp('2013-01-07 10:18:44'), 354]
#
# 2013년 1월 7일 - 10시 18분 50초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517355
# 칼럼 출력 >> [1357553930, Timestamp('2013-01-07 10:18:50'), 366]
#
# 2013년 1월 7일 - 10시 18분 56초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517356
# 칼럼 출력 >> [1357553936, Timestamp('2013-01-07 10:18:56'), 348]
#
# 2013년 1월 7일 - 10시 19분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517357
# 칼럼 출력 >> [1357553942, Timestamp('2013-01-07 10:19:02'), 359]
#
# 2013년 1월 7일 - 10시 19분 8초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517358
# 칼럼 출력 >> [1357553948, Timestamp('2013-01-07 10:19:08'), 344]
#
# 2013년 1월 7일 - 10시 19분 14초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517359
# 칼럼 출력 >> [1357553954, Timestamp('2013-01-07 10:19:14'), 360]
#
# 2013년 1월 7일 - 10시 19분 21초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517360
# 칼럼 출력 >> [1357553961, Timestamp('2013-01-07 10:19:21'), 340]
#
# 2013년 1월 7일 - 10시 19분 27초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517361
# 칼럼 출력 >> [1357553967, Timestamp('2013-01-07 10:19:27'), 344]
#
# 2013년 1월 7일 - 10시 19분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517362
# 칼럼 출력 >> [1357553973, Timestamp('2013-01-07 10:19:33'), 324]
#
# 2013년 1월 7일 - 10시 19분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517363
# 칼럼 출력 >> [1357553979, Timestamp('2013-01-07 10:19:39'), 311]
#
# 2013년 1월 7일 - 10시 19분 51초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517364
# 칼럼 출력 >> [1357553991, Timestamp('2013-01-07 10:19:51'), 311]
#
# 2013년 1월 7일 - 10시 19분 58초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517365
# 칼럼 출력 >> [1357553998, Timestamp('2013-01-07 10:19:58'), 312]
#
# 2013년 1월 7일 - 10시 20분 4초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517366
# 칼럼 출력 >> [1357554004, Timestamp('2013-01-07 10:20:04'), 316]
#
# 2013년 1월 7일 - 10시 20분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517367
# 칼럼 출력 >> [1357554010, Timestamp('2013-01-07 10:20:10'), 290]
#
# 2013년 1월 7일 - 10시 20분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517368
# 칼럼 출력 >> [1357554016, Timestamp('2013-01-07 10:20:16'), 291]
#
# 2013년 1월 7일 - 10시 20분 22초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517369
# 칼럼 출력 >> [1357554022, Timestamp('2013-01-07 10:20:22'), 296]
#
# 2013년 1월 7일 - 10시 20분 28초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517370
# 칼럼 출력 >> [1357554028, Timestamp('2013-01-07 10:20:28'), 292]
#
# 2013년 1월 7일 - 10시 20분 35초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517371
# 칼럼 출력 >> [1357554035, Timestamp('2013-01-07 10:20:35'), 289]
#
# 2013년 1월 7일 - 10시 20분 41초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517372
# 칼럼 출력 >> [1357554041, Timestamp('2013-01-07 10:20:41'), 294]
#
# 2013년 1월 7일 - 10시 20분 47초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517373
# 칼럼 출력 >> [1357554047, Timestamp('2013-01-07 10:20:47'), 296]
#
# 2013년 1월 7일 - 10시 20분 53초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517374
# 칼럼 출력 >> [1357554053, Timestamp('2013-01-07 10:20:53'), 289]
#
# 2013년 1월 7일 - 10시 20분 59초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517375
# 칼럼 출력 >> [1357554059, Timestamp('2013-01-07 10:20:59'), 295]
#
# 2013년 1월 7일 - 10시 21분 5초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517376
# 칼럼 출력 >> [1357554065, Timestamp('2013-01-07 10:21:05'), 293]
#
# 2013년 1월 7일 - 10시 21분 12초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517377
# 칼럼 출력 >> [1357554072, Timestamp('2013-01-07 10:21:12'), 290]
#
# 2013년 1월 7일 - 10시 21분 18초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517378
# 칼럼 출력 >> [1357554078, Timestamp('2013-01-07 10:21:18'), 289]
#
# 2013년 1월 7일 - 10시 21분 24초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517379
# 칼럼 출력 >> [1357554084, Timestamp('2013-01-07 10:21:24'), 290]
#
# 2013년 1월 7일 - 10시 21분 30초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517380
# 칼럼 출력 >> [1357554090, Timestamp('2013-01-07 10:21:30'), 295]
#
# 2013년 1월 7일 - 10시 21분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517381
# 칼럼 출력 >> [1357554096, Timestamp('2013-01-07 10:21:36'), 295]
#
# 2013년 1월 7일 - 10시 21분 42초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517382
# 칼럼 출력 >> [1357554102, Timestamp('2013-01-07 10:21:42'), 295]
#
# 2013년 1월 7일 - 10시 21분 48초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517383
# 칼럼 출력 >> [1357554108, Timestamp('2013-01-07 10:21:48'), 294]
#
# 2013년 1월 7일 - 10시 21분 55초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517384
# 칼럼 출력 >> [1357554115, Timestamp('2013-01-07 10:21:55'), 289]
#
# 2013년 1월 7일 - 10시 22분 1초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517385
# 칼럼 출력 >> [1357554121, Timestamp('2013-01-07 10:22:01'), 293]
#
# 2013년 1월 7일 - 10시 22분 7초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517386
# 칼럼 출력 >> [1357554127, Timestamp('2013-01-07 10:22:07'), 289]
#
# 2013년 1월 7일 - 10시 22분 13초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517387
# 칼럼 출력 >> [1357554133, Timestamp('2013-01-07 10:22:13'), 289]
#
# 2013년 1월 7일 - 10시 22분 19초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517388
# 칼럼 출력 >> [1357554139, Timestamp('2013-01-07 10:22:19'), 291]
#
# 2013년 1월 7일 - 10시 22분 25초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517389
# 칼럼 출력 >> [1357554145, Timestamp('2013-01-07 10:22:25'), 328]
#
# 2013년 1월 7일 - 10시 22분 31초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517390
# 칼럼 출력 >> [1357554151, Timestamp('2013-01-07 10:22:31'), 315]
#
# 2013년 1월 7일 - 10시 22분 38초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517391
# 칼럼 출력 >> [1357554158, Timestamp('2013-01-07 10:22:38'), 289]
#
# 2013년 1월 7일 - 10시 22분 44초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517392
# 칼럼 출력 >> [1357554164, Timestamp('2013-01-07 10:22:44'), 316]
#
# 2013년 1월 7일 - 10시 22분 50초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517393
# 칼럼 출력 >> [1357554170, Timestamp('2013-01-07 10:22:50'), 311]
#
# 2013년 1월 7일 - 10시 22분 56초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517394
# 칼럼 출력 >> [1357554176, Timestamp('2013-01-07 10:22:56'), 349]
#
# 2013년 1월 7일 - 10시 23분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517395
# 칼럼 출력 >> [1357554182, Timestamp('2013-01-07 10:23:02'), 326]
#
# 2013년 1월 7일 - 10시 23분 8초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517396
# 칼럼 출력 >> [1357554188, Timestamp('2013-01-07 10:23:08'), 312]
#
# 2013년 1월 7일 - 10시 23분 15초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517397
# 칼럼 출력 >> [1357554195, Timestamp('2013-01-07 10:23:15'), 573]
#
# 2013년 1월 7일 - 10시 23분 21초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517398
# 칼럼 출력 >> [1357554201, Timestamp('2013-01-07 10:23:21'), 307]
#
# 2013년 1월 7일 - 10시 23분 27초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517399
# 칼럼 출력 >> [1357554207, Timestamp('2013-01-07 10:23:27'), 304]
#
# 2013년 1월 7일 - 10시 23분 33초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517400
# 칼럼 출력 >> [1357554213, Timestamp('2013-01-07 10:23:33'), 302]
#
# 2013년 1월 7일 - 10시 23분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517401
# 칼럼 출력 >> [1357554219, Timestamp('2013-01-07 10:23:39'), 298]
#
# 2013년 1월 7일 - 10시 23분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517402
# 칼럼 출력 >> [1357554226, Timestamp('2013-01-07 10:23:46'), 305]
#
# 2013년 1월 7일 - 10시 23분 52초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517403
# 칼럼 출력 >> [1357554232, Timestamp('2013-01-07 10:23:52'), 306]
#
# 2013년 1월 7일 - 10시 23분 58초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517404
# 칼럼 출력 >> [1357554238, Timestamp('2013-01-07 10:23:58'), 289]
#
# 2013년 1월 7일 - 10시 24분 4초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517405
# 칼럼 출력 >> [1357554244, Timestamp('2013-01-07 10:24:04'), 292]
#
# 2013년 1월 7일 - 10시 24분 10초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517406
# 칼럼 출력 >> [1357554250, Timestamp('2013-01-07 10:24:10'), 289]
#
# 2013년 1월 7일 - 10시 24분 16초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517407
# 칼럼 출력 >> [1357554256, Timestamp('2013-01-07 10:24:16'), 289]
#
# 2013년 1월 7일 - 10시 24분 23초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517408
# 칼럼 출력 >> [1357554263, Timestamp('2013-01-07 10:24:23'), 293]
#
# 2013년 1월 7일 - 10시 24분 29초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517409
# 칼럼 출력 >> [1357554269, Timestamp('2013-01-07 10:24:29'), 290]
#
# 2013년 1월 7일 - 10시 24분 35초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517410
# 칼럼 출력 >> [1357554275, Timestamp('2013-01-07 10:24:35'), 290]
#
# 2013년 1월 7일 - 10시 24분 41초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517411
# 칼럼 출력 >> [1357554281, Timestamp('2013-01-07 10:24:41'), 295]
#
# 2013년 1월 7일 - 10시 24분 47초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517412
# 칼럼 출력 >> [1357554287, Timestamp('2013-01-07 10:24:47'), 292]
#
# 2013년 1월 7일 - 10시 24분 54초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517413
# 칼럼 출력 >> [1357554294, Timestamp('2013-01-07 10:24:54'), 289]
#
# 2013년 1월 7일 - 10시 25분 0초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517414
# 칼럼 출력 >> [1357554300, Timestamp('2013-01-07 10:25:00'), 293]
#
# 2013년 1월 7일 - 10시 25분 12초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517415
# 칼럼 출력 >> [1357554312, Timestamp('2013-01-07 10:25:12'), 291]
#
# 2013년 1월 7일 - 10시 25분 18초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517416
# 칼럼 출력 >> [1357554318, Timestamp('2013-01-07 10:25:18'), 296]
#
# 2013년 1월 7일 - 10시 25분 25초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517417
# 칼럼 출력 >> [1357554325, Timestamp('2013-01-07 10:25:25'), 645]
#
# 2013년 1월 7일 - 10시 25분 31초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517418
# 칼럼 출력 >> [1357554331, Timestamp('2013-01-07 10:25:31'), 290]
#
# 2013년 1월 7일 - 10시 25분 37초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517419
# 칼럼 출력 >> [1357554337, Timestamp('2013-01-07 10:25:37'), 289]
#
# 2013년 1월 7일 - 10시 25분 43초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517420
# 칼럼 출력 >> [1357554343, Timestamp('2013-01-07 10:25:43'), 289]
#
# 2013년 1월 7일 - 10시 25분 49초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517421
# 칼럼 출력 >> [1357554349, Timestamp('2013-01-07 10:25:49'), 291]
#
# 2013년 1월 7일 - 10시 25분 55초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517422
# 칼럼 출력 >> [1357554355, Timestamp('2013-01-07 10:25:55'), 806]
#
# 2013년 1월 7일 - 10시 26분 2초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517423
# 칼럼 출력 >> [1357554362, Timestamp('2013-01-07 10:26:02'), 288]
#
# 2013년 1월 7일 - 10시 26분 8초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517424
# 칼럼 출력 >> [1357554368, Timestamp('2013-01-07 10:26:08'), 251]
#
# 2013년 1월 7일 - 10시 26분 14초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517425
# 칼럼 출력 >> [1357554374, Timestamp('2013-01-07 10:26:14'), 249]
#
# 2013년 1월 7일 - 10시 26분 20초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517426
# 칼럼 출력 >> [1357554380, Timestamp('2013-01-07 10:26:20'), 252]
#
# 2013년 1월 7일 - 10시 26분 26초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517427
# 칼럼 출력 >> [1357554386, Timestamp('2013-01-07 10:26:26'), 249]
#
# 2013년 1월 7일 - 10시 26분 32초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517428
# 칼럼 출력 >> [1357554392, Timestamp('2013-01-07 10:26:32'), 249]
#
# 2013년 1월 7일 - 10시 26분 39초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517429
# 칼럼 출력 >> [1357554399, Timestamp('2013-01-07 10:26:39'), 250]
#
# 2013년 1월 7일 - 10시 26분 45초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517430
# 칼럼 출력 >> [1357554405, Timestamp('2013-01-07 10:26:45'), 251]
#
# 2013년 1월 7일 - 10시 26분 51초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517431
# 칼럼 출력 >> [1357554411, Timestamp('2013-01-07 10:26:51'), 248]
#
# 2013년 1월 7일 - 10시 26분 57초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517432
# 칼럼 출력 >> [1357554417, Timestamp('2013-01-07 10:26:57'), 250]
#
# 2013년 1월 7일 - 10시 27분 3초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517433
# 칼럼 출력 >> [1357554423, Timestamp('2013-01-07 10:27:03'), 275]
#
# 2013년 1월 7일 - 10시 27분 9초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517434
# 칼럼 출력 >> [1357554429, Timestamp('2013-01-07 10:27:09'), 269]
#
# 2013년 1월 7일 - 10시 27분 15초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517435
# 칼럼 출력 >> [1357554435, Timestamp('2013-01-07 10:27:15'), 268]
#
# 2013년 1월 7일 - 10시 27분 22초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517436
# 칼럼 출력 >> [1357554442, Timestamp('2013-01-07 10:27:22'), 315]
#
# 2013년 1월 7일 - 10시 27분 46초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517437
# 칼럼 출력 >> [1357554466, Timestamp('2013-01-07 10:27:46'), 301]
#
# 2013년 1월 7일 - 10시 27분 52초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517438
# 칼럼 출력 >> [1357554472, Timestamp('2013-01-07 10:27:52'), 306]
#
# 2013년 1월 7일 - 10시 28분 5초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517439
# 칼럼 출력 >> [1357554485, Timestamp('2013-01-07 10:28:05'), 301]
#
# 2013년 1월 7일 - 10시 28분 11초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517440
# 칼럼 출력 >> [1357554491, Timestamp('2013-01-07 10:28:11'), 301]
#
# 2013년 1월 7일 - 10시 28분 17초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517441
# 칼럼 출력 >> [1357554497, Timestamp('2013-01-07 10:28:17'), 295]
#
# 2013년 1월 7일 - 10시 28분 23초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517442
# 칼럼 출력 >> [1357554503, Timestamp('2013-01-07 10:28:23'), 296]
#
# 2013년 1월 7일 - 10시 28분 29초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517443
# 칼럼 출력 >> [1357554509, Timestamp('2013-01-07 10:28:29'), 290]
#
# 2013년 1월 7일 - 10시 28분 36초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517444
# 칼럼 출력 >> [1357554516, Timestamp('2013-01-07 10:28:36'), 293]
#
# 2013년 1월 7일 - 10시 28분 42초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517445
# 칼럼 출력 >> [1357554522, Timestamp('2013-01-07 10:28:42'), 295]
#
# 2013년 1월 7일 - 10시 28분 48초
# d1 >> 7 d >> 7 H1 >> 10 h >> 10   //   i >> 517446
# 칼럼 출력 >> [1357554528, Timestamp('2013-01-07 10:28:48'), 293]
#
# 2013년 1월 7일 - 10시 28분 54초
# d1 >> 7 d >> 7 H1 >> 10 h >>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/3430891512.py in <module>
#      66                         total_date = '{0}년 {1}월 {2}일 - {3}시 {4}분 {5}초'.format(y, M, d, h, m, s)
#      67                         print(total_date)
# ---> 68                         print('d1 >>', d1, 'd >>', d, 'H1 >>', H1, 'h >>', h, '  //  ','i >>', i)
#      69                         print('칼럼 출력 >>', list2)
#      70
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
I = 0
for i in range(0, 24):
    print('i >> ',i, 'I >> ',I)
    if (i==20):
        I = I+10
        print('여기로 왔어요!')
# Out:
# i >>  0 I >>  0
# i >>  1 I >>  0
# i >>  2 I >>  0
# i >>  3 I >>  0
# i >>  4 I >>  0
# i >>  5 I >>  0
# i >>  6 I >>  0
# i >>  7 I >>  0
# i >>  8 I >>  0
# i >>  9 I >>  0
# i >>  10 I >>  0
# i >>  11 I >>  0
# i >>  12 I >>  0
# i >>  13 I >>  0
# i >>  14 I >>  0
# i >>  15 I >>  0
# i >>  16 I >>  0
# i >>  17 I >>  0
# i >>  18 I >>  0
# i >>  19 I >>  0
# i >>  20 I >>  0
# 여기로 왔어요!
# i >>  21 I >>  10
# i >>  22 I >>  10
# i >>  23 I >>  10

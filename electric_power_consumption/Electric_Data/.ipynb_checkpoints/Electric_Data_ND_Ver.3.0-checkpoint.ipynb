# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
import os
try:
    os.mkdir('./Electirc_Data_CSV_Null_Disposed')
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.\n폴더를 확인해주세요.')

# %%
import csv
import pandas as pd
import time

month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

for y in range(2013, 2017):
    
    for m in range(1,13):
        csv_origin = pd.read_csv("./Electirc_Data_CSV/"+str(y)+'_'+str(m)+'_'+"House1_Ch1_Electric_Data.csv", 
                  names = ['Time', 'Watt'], 
                  header = None, encoding='cp949')
        s = 0
        # 각 월의 일수만큼 
        for d in range(month[m]):
            d=d+1 # 밑에서 코드의 계산을 편리하게 하기 위한 1 더해주기. = 실제일과 맞추는 작업
            one_day_list_p1=[]
            one_day_list_d1=[]

            for n in range(s, s+24):
                date1 = csv_origin['Time'][n]
                power1 = csv_origin['Watt'][n]
                one_day_list_d1.append(date1)
                one_day_list_p1.append(power1)
                
            s=s+24
            
            if 'Null' in one_day_list_p1:
                N=0
                print(24*month[m])
                print('결손치 존재\n')
                for n in range(24):
                    try:
                        new_list=[]
                        new_list.append(one_day_list_d1[n])
                        new_list.append(int(n))

                        if one_day_list_p1[n] == 'Null':
                            N=n+24*d 
                            power2 = csv_origin['Watt'][N] 
                            print('power2 >>', power2)

                            if power2 == 'Null':
                                N=n+24*(d+1)
                                print(N)
                                power3 = csv_origin['Watt'][N] 
                                print('power3 >>', power3)

                                if power3 == 'Null':
                                    N=n+24*(d+2)
                                    print(N)
                                    power4 = csv_origin['Watt'][N]
                                    print('power4 >>', power4)

                                    if power4 == 'Null':
                                        N=n+24*(d+3)
                                        print(N)
                                        power5 = csv_origin['Watt'][N]
                                        print('power5 >>', power5)

                                        if power5 == 'Null':
                                            N=n+24*(d+4)
                                            print(N)
                                            power6 = csv_origin['Watt'][N]
                                            print('power6 >>', power6)

                                            if power6 == 'Null':
                                                N=n+24*(d+5)
                                                print(N)
                                                power7 = csv_origin['Watt'][N]
                                                print('power7 >>', power7)

                                                if power7 == 'Null':
                                                    N=n+24*(d+6)
                                                    print(N)
                                                    power8 = csv_origin['Watt'][N]
                                                    print('power8 >>', power8)

                                                    if power8 == 'Null':
                                                        N=n+24*(d+7)
                                                        print(N)
                                                        power9 = csv_origin['Watt'][N]
                                                        print('power9 >>', power9)
                                                        new_list.append(power9)

                                                    else:
                                                        new_list.append(power8)
                                                else:
                                                    new_list.append(power7)
                                            else:
                                                new_list.append(power6)
                                        else:
                                            new_list.append(power5)
                                    else:
                                        new_list.append(power4)
                                else:
                                    new_list.append(power3)
                            else: 
                                new_list.append(power2)
                        else:
                            new_list.append(one_day_list_p1[n])

                        print(new_list)
                        print()
                        with open("./Electirc_Data_CSV_Null_Disposed/"+str(y)+'_'+str(m)+'_'+"House1_Ch1_Electric_Data_ND.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(new_list)
                    # 월말의 경우 더이상 다음 일자의 데이터를 불러올 수 없기 때문에 역행해서 이전 일자를 불러옴.
                    except KeyError:
                        new_list=[]
                        new_list.append(one_day_list_d1[n])
                        new_list.append(int(n))

                        if one_day_list_p1[n] == 'Null':
                            N=n+24*(d-1) # N이 계속 커지다가 해당일의 한계일까지 더한 값이 되면 예외 조치를 해야함.(=월말)
                            power2b = csv_origin['Watt'][N] 
                            print('power2b >>', power2b)

                            if power2b == 'Null':
                                N=n+24*(d-2)
                                print(N)
                                power3b = csv_origin['Watt'][N] 
                                print('power3b >>', power3b)

                                if power3b == 'Null':
                                    N=n+24*(d-3)
                                    print(N)
                                    power4b = csv_origin['Watt'][N]
                                    print('power4b >>', power4b)

                                    if power4b == 'Null':
                                        N=n+24*(d-4)
                                        print(N)
                                        power5b = csv_origin['Watt'][N]
                                        print('power5b >>', power5b)

                                        if power5b == 'Null':
                                            N=n+24*(d-5)
                                            print(N)
                                            power6b = csv_origin['Watt'][N]
                                            print('power6b >>', power6b)

                                            if power6b == 'Null':
                                                N=n+24*(d-6)
                                                print(N)
                                                power7b = csv_origin['Watt'][N]
                                                print('power7b >>', power7b)

                                                if power7b == 'Null':
                                                    N=n+24*(d-7)
                                                    print(N)
                                                    power8b = csv_origin['Watt'][N]
                                                    print('power8b >>', power8b)

                                                    if power8b == 'Null':
                                                        N=n+24*(d-8)
                                                        print(N)
                                                        power9b = csv_origin['Watt'][N]
                                                        print('power9b >>', power9b)
                                                        new_list.append(power9b)

                                                    else:
                                                        new_list.append(power8b)
                                                else:
                                                    new_list.append(power7b)
                                            else:
                                                new_list.append(power6b)
                                        else:
                                            new_list.append(power5b)
                                    else:
                                        new_list.append(power4b)
                                else:
                                    new_list.append(power3b)
                            else: 
                                new_list.append(power2b)
                        else:
                            new_list.append(one_day_list_p1[n])

                        print(new_list)
                        print()
                        with open("./Electirc_Data_CSV_Null_Disposed/"+str(y)+'_'+str(m)+'_'+"House1_Ch1_Electric_Data_ND.csv", 'a', newline='') as file:
                                    writer = csv.writer(file)
                                    writer.writerow(new_list)
                
            else:
                print('정상일\n')
                
                for n in range(24):
                    new_list=[]
                    new_list.append(one_day_list_d1[n])
                    new_list.append(int(n))
                    new_list.append(one_day_list_p1[n])
                    print(new_list)
                    print()
                    with open("./Electirc_Data_CSV_Null_Disposed/"+str(y)+'_'+str(m)+'_'+"House1_Ch1_Electric_Data_ND.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(new_list)
                    
            print('\n'*4)
            
print('\n'*9, '------------------------------< Null값 처리 완료! >------------------------------')

# 잔여 널값 검사
for y in range(2013, 2017):
    
    for m in range(1,13):
        csv_origin = pd.read_csv("./Electirc_Data_CSV_Null_Disposed/"+str(y)+'_'+str(m)+'_'+"House1_Ch1_Electric_Data_ND.csv", names = ['DateTime', 'Seq', 'Watt'], header = None, encoding='cp949')
        
        s = 0
        for d in range(month[m]):
            d=d+1 
            one_day_list_p1=[]

            for n in range(s, s+24):
                power = csv_origin['Watt'][n]
                one_day_list_p1.append(power)

            s=s+24
            
            if 'Null' in one_day_list_p1:
                print('------------------------------< Null값 잔존! >------------------------------')
                

print('\n'*9,'------------------------------< Job Done!! >------------------------------')
# Out:
# 정상일
#
# ['2013년 1월 1일 - 0시', 0, '2495']
#
# ['2013년 1월 1일 - 1시', 1, '2482']
#
# ['2013년 1월 1일 - 2시', 2, '2441']
#
# ['2013년 1월 1일 - 3시', 3, '265']
#
# ['2013년 1월 1일 - 4시', 4, '260']
#
# ['2013년 1월 1일 - 5시', 5, '260']
#
# ['2013년 1월 1일 - 6시', 6, '326']
#
# ['2013년 1월 1일 - 7시', 7, '372']
#
# ['2013년 1월 1일 - 8시', 8, '4444']
#
# ['2013년 1월 1일 - 9시', 9, '2691']
#
# ['2013년 1월 1일 - 10시', 10, '2558']
#
# ['2013년 1월 1일 - 11시', 11, '779']
#
# ['2013년 1월 1일 - 12시', 12, '2961']
#
# ['2013년 1월 1일 - 13시', 13, '529']
#
# ['2013년 1월 1일 - 14시', 14, '3032']
#
# ['2013년 1월 1일 - 15시', 15, '2869']
#
# ['2013년 1월 1일 - 16시', 16, '354']
#
# ['2013년 1월 1일 - 17시', 17, '2297']
#
# ['2013년 1월 1일 - 18시', 18, '2184']
#
# ['2013년 1월 1일 - 19시', 19, '2981']
#
# ['2013년 1월 1일 - 20시', 20, '729']
#
# ['2013년 1월 1일 - 21시', 21, '2122']
#
# ['2013년 1월 1일 - 22시', 22, '543']
#
# ['2013년 1월 1일 - 23시', 23, '572']
#
#
#
#
#
#
# 정상일
#
# ['2013년 1월 2일 - 0시', 0, '1913']
#
# ['2013년 1월 2일 - 1시', 1, '240']
#
# ...

# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# ### 데이터 판다스로 입력, 컬럼 정리

# %%
import pandas as pd
ch1 = pd.read_csv('../../../channel_1.dat', names=['Unix', 'Watt'],header=None, delimiter=" ")
print('Data File Import Done.')
# Out:
# Data File Import Done.

# %%
ch1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Watt    int64
# dtypes: int64(2)
# memory usage: 333.2 MB

# %%
from datetime import datetime
ch1_dated = pd.DataFrame(ch1,columns = ['Unix', 'Date', 'Watt'])

ch1_dated['Date'] = pd.to_datetime(ch1['Unix'], unit='s')
ch1_dated.info()
ch1_dated.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Date    datetime64[ns]
#  2   Watt    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 499.8 MB
#          Unix                Date  Watt
# 0  1352500095 2012-11-09 22:28:15   599
# 1  1352500101 2012-11-09 22:28:21   582
# 2  1352500107 2012-11-09 22:28:27   600
# 3  1352500113 2012-11-09 22:28:33   586
# 4  1352500120 2012-11-09 22:28:40   596
# 5  1352500132 2012-11-09 22:28:52   581
# 6  1352500138 2012-11-09 22:28:58   597
# 7  1352500144 2012-11-09 22:29:04   592
# 8  1352500150 2012-11-09 22:29:10   587
# 9  1352500156 2012-11-09 22:29:16   574

# %% [markdown]
# ### 변수 및 구분 단계

# %% [markdown]
# ### csv 파일 저장을 위한 폴더 생성

# %%
import os
try:
    os.mkdir('./New_Electirc_Data_CSV')
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.\n폴더를 확인해주세요.')
# Out:
# 해당 폴더가 이미 존재합니다.
# 폴더를 확인해주세요.

# %% [markdown]
# ### 실험안

# %%
import csv
import time
import sys
month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

EMPTY_HOUR_LIST=[]
for _ in range(60):
    EMPTY_HOUR_LIST.append(0)
    
EMPTY_DAY_LIST=[]
for _ in range(1440):
    EMPTY_DAY_LIST.append(0)
#===============================================================================================================
def value (data, num):
    list0 = data.loc[num].values.tolist()
    date = list0[1]
    YYYY = date.year
    MM = date.month
    DD = date.day
    hh = date.hour
    mm = date.minute
    watt = list0[2]
    return YYYY, MM, DD, hh, mm, watt, date
#===============================================================================================================
print("해당 전력 데이터는 2012년 11월 10일부터 2017년 4월 25일까지 온전한 데이터가 존재합니다.\n")
time.sleep(0.5)
print("데이터는 사용자가 선택한 기간 중 1년 단위로 처리됩니다.\n")
time.sleep(0.5)
global TARGET_YEAR_START 
TARGET_YEAR_START = int(input("목표로 하는 처리 기간의 시작 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)
global TARGET_YEAR_END
TARGET_YEAR_END = int(input("목표로 하는 처리 기간의 종료 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)

if(TARGET_YEAR_START<2012 or TARGET_YEAR_START>2017 or TARGET_YEAR_END>2017 or  TARGET_YEAR_END<2012):
    print("\---기간을 잘못 설정했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

if(TARGET_YEAR_START==2012 or TARGET_YEAR_END==2017):
    print("\n---해당 기간은 현재 서비스하지 않습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

global HANDLE_MINUTE
HANDLE_MINUTE = int(input("데이터들은 기본적으로 1분 단위 최댓값으로 정리됩니다.\n추후 가공될 분 단위를 5분과 10분 중 골라 숫자만 입력해주세요. : \n"))
if(HANDLE_MINUTE!=5 and HANDLE_MINUTE!=10):
    print("\n---잘못된 시간 처리 단위를 선택했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

#TARGET_YEAR_START = 2013
#TARGET_YEAR_END=2013
#===============================================================================================================

i1=0
if TARGET_YEAR_START==2013:
    i1=431369
if TARGET_YEAR_START==2014:
    i1=5133240
if TARGET_YEAR_START==2015:
    i1=10179389
if TARGET_YEAR_START==2016:
    i1=15176099	

while(i1 < len(ch1_dated)):
    print("전체 과정 시작")
    YEAR0 = value(ch1_dated, i1)[0]

    if(YEAR0>=TARGET_YEAR_START and YEAR0<=TARGET_YEAR_END):
        print("<<<<<{0}년 데이터 시작 {1}>>>>>".format(YEAR0, value(ch1_dated, i1)[6]))
        MONTH0 = value(ch1_dated, i1)[1]
        
        REAL_DAY = 1
        ONE_MONTH_LIST=[]
        while(MONTH0<13):
            print("<<<<{0}월 데이터 시작 {1}>>>>".format(MONTH0, value(ch1_dated, i1)[6]), i1)
            MONTH1 = value(ch1_dated, i1)[1]
            DAY1= value(ch1_dated, i1)[2]
            
            if DAY1==REAL_DAY:
                while(REAL_DAY<=month[MONTH1]):
                    print("<<<{0}일 데이터 시작 {1}>>>".format(REAL_DAY, value(ch1_dated, i1)[6]), i1)
        
                    REAL_HOUR = 0
                    ONE_DAY_LIST=[]
                    while(REAL_HOUR<24):
                        print("<<{0}시 데이터 시작 {1}>>".format(REAL_HOUR, value(ch1_dated, i1)[6]), i1)
                        HOUR1 = value(ch1_dated, i1)[3]

                        REAL_MINUTE = 0
                        MIN_60_LIST=[]
                        if HOUR1==REAL_HOUR:
                            while(REAL_MINUTE<60):#특정 시간대 안에서 분단위 데이터를 60개 처리
                                MINUTE1 = value(ch1_dated, i1)[4]
                                HOUR2 = value(ch1_dated, i1)[3]

                                #print("<{0}분 데이터 시작 {1}>".format(REAL_MINUTE, value(ch1_dated, i1)[6]),i1)
                                SEC_60_LIST=[]

                                if MINUTE1==REAL_MINUTE and HOUR2==REAL_HOUR:
                                    while(True):#특정 분대 안에서 초단위 데이터를 처리
                                        MONTH2 = value(ch1_dated, i1)[1]
                                        DAY1 = value(ch1_dated, i1)[2] #여기 넣는게 맞나......??
                                        HOUR3 = value(ch1_dated, i1)[3]
                                        MINUTE2 = value(ch1_dated, i1)[4]
                                        SEC_60_LIST.append(value(ch1_dated, i1)[5])
                                        i1+=1

                                        if MINUTE1!=MINUTE2:
                                            if MINUTE2-MINUTE1==1 or MINUTE1-MINUTE2==59: #직후 분으로 넘어가거나 59분에서 다음 시로 넘어가는 경우
                                                #print("*{0}분의 값들 >> {1}\n".format(MINUTE1, SEC_60_LIST))
                                                i1-=1
                                                break

                                            else:#진행되다가 분대가 넘어가긴 했으나 다음 분으로 넘어가지 않고 점프해버린경우
                                                #print("*{0}분의 값들 >> {1} (결손 후 점프 시각 => {2})\n".format(MINUTE1, SEC_60_LIST, value(ch1_dated, i1)[6]))
                                                break

                                if MINUTE1!=REAL_MINUTE:#아예 해당분대가 결손된 경우
                                    if HOUR3==REAL_HOUR:
                                        #print("같은 시각대 내 분 결손")
                                        SEC_60_LIST.append(0)
                                        #print("*{0}시 {1}분의 결손치는 0으로 처리됨.\n".format(REAL_HOUR, REAL_MINUTE))
                                        
                                    if HOUR3!=REAL_HOUR:
                                        #print("결손 + 타 시각대 점프")
                                        for _ in range(60-len(MIN_60_LIST)):
                                            MIN_60_LIST.append(0)
                                            #print("*{0}시 {1}분의 결손치는 0으로 처리됨.\n".format(REAL_HOUR, REAL_MINUTE))
                                            REAL_MINUTE+=1
                                        break
                                
                                MIN_60_LIST.append(max(SEC_60_LIST))
                                REAL_MINUTE+=1

                        # 어떤 경우든 간에 시간이 바뀌는 경우, 정상이든 결손이든
                        if HOUR1!=REAL_HOUR:                
                            if DAY1==REAL_DAY:
                                #print("시각 불일치! 점프됨!")
                                for i in EMPTY_HOUR_LIST:
                                    ONE_DAY_LIST.append(i)
                                #print("*{0}시의 결손 데이터는 60개의 0으로 처리됨.{1}".format(REAL_HOUR, "\n"*3))
                                
                            if DAY1!=REAL_DAY:
                                #print("시각 불일치! 점프됨!")
                                if REAL_HOUR==0:
                                    break

                                FAKE_HOUR=REAL_HOUR
                                for _ in range(23-REAL_HOUR+1):
                                    for i in EMPTY_HOUR_LIST:
                                        ONE_DAY_LIST.append(i)
                                    #print("*{0}시의 결손 데이터는 60개의 0으로 처리됨.{1}".format(FAKE_HOUR, "\n"*3))
                                    FAKE_HOUR+=1
                                REAL_HOUR=23
                                

                        if REAL_MINUTE==60:
                            if len(MIN_60_LIST)==60:
                                for i in MIN_60_LIST:
                                    ONE_DAY_LIST.append(i)
                                
                            if len(MIN_60_LIST)<60:
                                for i in range(60-len(MIN_60_LIST)):
                                    MIN_60_LIST.append(0)
                                for i in MIN_60_LIST:
                                    ONE_DAY_LIST.append(i)
                                    
                            #print("*{0}시의 분별 최댓값 {1}개 >> {2}{3}".format(REAL_HOUR, len(MIN_60_LIST), MIN_60_LIST, "\n"*3))
                            
                        REAL_HOUR+=1

                    if REAL_HOUR==24:
                        if len(ONE_DAY_LIST)==1440:
                            for i in ONE_DAY_LIST:
                                    ONE_MONTH_LIST.append(i)
                        if len(ONE_DAY_LIST)<1440:
                            for _ in range(1440-len(ONE_DAY_LIST)):
                                ONE_DAY_LIST.append(0)
                            for i in ONE_DAY_LIST:
                                ONE_MONTH_LIST.append(i)
                        
                        print("*{0}일의 분별 최댓값 {1}개 추가됨.".format(REAL_DAY, len(ONE_DAY_LIST)))
                        print("{0}개의 데이터 누적, 계산된 일자 => {1}{2}".format(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440, "\n"*5))
                            
                    if DAY1!=REAL_DAY and REAL_HOUR!=24:
                        break
                    
                    REAL_DAY+=1
                    #print("Real Day 1 더해짐! 현재 정상일 => {0}{1}".format(REAL_DAY, "\n"*5))
                    
            if DAY1!=REAL_DAY:
                if MONTH2==MONTH1:
                    #for _ in range(DAY1-REAL_DAY-1):
                    for _ in range(1440-len(ONE_DAY_LIST)):
                        ONE_DAY_LIST.append(0)
                    for i in ONE_DAY_LIST:
                        ONE_MONTH_LIST.append(i)
                            
                    print("*{0}일의 분별 최댓값 {1}개 결손 처리됨(1)".format(REAL_DAY, len(ONE_DAY_LIST)))
                    print("{0}개의 데이터 누적, 계산된 일자 => {1}{2}".format(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440, "\n"*5))
                    REAL_DAY+=1
                    
                if MONTH2!=MONTH1:
                    while(REAL_DAY<=month[MONTH1]):
                        #print("일자 불일치! 점프됨!")
                        #print(REAL_DAY, month[MONTH1])
                        if REAL_HOUR==0:
                            ONE_DAY_LIST=EMPTY_DAY_LIST
                            for i in EMPTY_DAY_LIST:
                                ONE_MONTH_LIST.append(i)

                        if REAL_HOUR!=0:
                            for _ in range(1440-len(ONE_DAY_LIST)):
                                ONE_DAY_LIST.append(0)
                            for i in ONE_DAY_LIST:
                                ONE_MONTH_LIST.append(i)
                                
                        print("*{0}일의 분별 최댓값 {1}개 결손 처리됨(2)".format(REAL_DAY, len(ONE_DAY_LIST)))
                        print("{0}개의 데이터 누적, 계산된 일자 => {1}{2}".format(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440, "\n"*5))       
                        REAL_DAY+=1
                        
                    if REAL_DAY==month[MONTH1]+1:
                        break
            
            if MONTH1==2 and DAY1==29:
                print(i1)
                i1+=1
                pass
                
        num=0
        try:
            for D in range(1, month[1]+1):
                if int(D)<10:
                    D=str(0)+str(D)
                for H in range(24):
                    if int(H)<10:
                        H=str(0)+str(H)
                    for M in range(60):
                        if int(M)<10:
                            M=str(0)+str(M)
                        SAVE_LIST=[]
                        SAVE_LIST.append(str(D))
                        SAVE_LIST.append(str(H))
                        SAVE_LIST.append(str(M))
                        SAVE_LIST.append(ONE_MONTH_LIST[num])

                        with open("./New_Electirc_Data_CSV/"+str(YEAR0)+'_'+str(MONTH0)+'_'+"House1_Ch1_Electric_Data_NEW.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(SAVE_LIST)
                        int(M)
                        num+=1

        except:
            pass
                    
        print("{0}월의 {1}일분 전체 데이터 {2}개 CSV 파일 저장 완료{3}".format(MONTH1, len(ONE_MONTH_LIST)//1440, len(ONE_MONTH_LIST), "\n"*10))
        print(i1)
        
    else:
        if value(ch1_dated, i1)[0]<TARGET_YEAR_START:
            i1+=1
        if value(ch1_dated, i1)[0]>TARGET_YEAR_END:
            sys.exit()
# Out:
# 해당 전력 데이터는 2012년 11월 10일부터 2017년 4월 25일까지 온전한 데이터가 존재합니다.
#
# 데이터는 사용자가 선택한 기간 중 1년 단위로 처리됩니다.
#
# 목표로 하는 처리 기간의 시작 연도를 4자리 숫자로 입력해주세요. :
# 2016
# 목표로 하는 처리 기간의 종료 연도를 4자리 숫자로 입력해주세요. :
# 2016
# 데이터들은 기본적으로 1분 단위 최댓값으로 정리됩니다.
# 추후 가공될 분 단위를 5분과 10분 중 골라 숫자만 입력해주세요. :
# 5
# 전체 과정 시작
# <<<<<2016년 데이터 시작 2016-01-01 00:00:10>>>>>
# <<<<1월 데이터 시작 2016-01-01 00:00:10>>>> 15176099
# <<<1일 데이터 시작 2016-01-01 00:00:10>>> 15176099
# <<0시 데이터 시작 2016-01-01 00:00:10>> 15176099
# <<1시 데이터 시작 2016-01-01 01:00:02>> 15176677
# <<2시 데이터 시작 2016-01-01 02:00:01>> 15177261
# <<3시 데이터 시작 2016-01-01 03:00:06>> 15177851
# <<4시 데이터 시작 2016-01-01 04:00:03>> 15178437
# <<5시 데이터 시작 2016-01-01 05:00:04>> 15179027
# <<6시 데이터 시작 2016-01-01 06:00:04>> 15179618
# <<7시 데이터 시작 2016-01-01 07:00:01>> 15180205
# <<8시 데이터 시작 2016-01-01 08:00:00>> 15180796
# <<9시 데이터 시작 2016-01-01 09:00:03>> 15181359
# <<10시 데이터 시작 2016-01-01 10:00:01>> 15181935
# <<11시 데이터 시작 2016-01-01 11:00:00>> 15182512
# <<12시 데이터 시작 2016-01-01 12:00:11>> 15183097
# <<13시 데이터 시작 2016-01-01 13:00:05>> 15183687
# <<14시 데이터 시작 2016-01-01 14:00:00>> 15184272
# <<15시 데이터 시작 2016-01-01 15:00:03>> 15184862
# <<16시 데이터 시작 2016-01-01 16:00:01>> 15185444
# <<17시 데이터 시작 2016-01-01 17:00:05>> 15186034
# <<18시 데이터 시작 2016-01-01 18:00:04>> 15186622
# <<19시 데이터 시작 2016-01-01 19:00:03>> 15187209
# <<20시 데이터 시작 2016-01-01 20:00:01>> 15187794
# <<21시 데이터 시작 2016-01-01 21:00:00>> 15188384
# <<22시 데이터 시작 2016-01-01 22:00:05>> 15188974
# <<23시 데이터 시작 2016-01-01 23:00:01>> 15189557
# *1일의 분별 최댓값 1440개 추가됨.
# 1440개의 데이터 누적, 계산된 일자 => 1
#
#
#
#
#
# <<<2일 데이터 시작 2016-01-02 00:00:05>>> 15190148
# <<0시 데이터 시작 2016-01-02 00:00:05>> 15190148
# <<1시 데이터 시작 2016-01-02 01:00:00>> 15190731
# <<2시 데이터 시작 2016-01-02 02:00:03>> 15191319
# <<3시 데이터 시작 2016-01-02 03:00:01>> 15191901
# <<4시 데이터 시작 2016-01-02 04:00:01>> 15192491
# <<5시 데이터 시작 2016-01-02 05:00:06>> 15193078
# <<6시 데이터 시작 2016-01-02 06:00:04>> 15193668
# <<7시 데이터 시작 2016-01-02 07:00:03>> 15194259
# <<8시 데이터 시작 2016-01-02 08:00:02>> 15194847
# <<9시 데이터 시작 2016-01-02 09:00:05>> 15195414
# <<10시 데이터 시작 2016-01-02 10:00:03>> 15195979
# <<11시 데이터 시작 2016-01-02 11:00:04>> 15196566
# <<12시 데이터 시작 2016-01-02 12:00:02>> 15197146
# <<13시 데이터 시작 2016-01-02 13:00:00>> 15197723
# <<14시 데이터 시작 2016-01-02 14:00:01>> 15198311
# <<15시 데이터 시작 2016-01-02 15:00:10>> 15198898
# <<16시 데이터 시작 2016-01-02 16:00:00>> 15199482
# <<17시 데이터 시작 2016-01-02 17:00:00>> 15200069
# <<18시 데이터 시작 2016-01-02 18:00:01>> 15200659
# <<19시 데이터 시작 2016-01-02 19:00:01>> 15201245
# <<20시 데이터 시작 2016-01-02 20:00:02>> 15201832
# <<21시 데이터 시작 2016-01-02 21:00:02>> 15202416
# <<22시 데이터 시작 2016-01-02 22:00:02>> 15203002
# <<23시 데이터 시작 2016-01-02 23:00:03>> 15203589
# *2일의 분별 최댓값 1440개 추가됨.
# 2880개의 데이터 누적, 계산된 일자 => 2
#
#
#
#
#
# <<<3일 데이터 시작 2016-01-03 00:00:00>>> 15204176
# <<0시 데이터 시작 2016-01-03 00:00:00>> 15204176
# <<1시 데이터 시작 2016-01-03 01:00:01>> 15204766
# <<2시 데이터 시작 2016-01-03 02:00:03>> 15205351
# <<3시 데이터 시작 2016-01-03 03:00:00>> 15205941
# <<4시 데이터 시작 2016-01-03 04:00:01>> 15206522
# <<5시 데이터 시작 2016-01-03 05:00:01>> 15207104
# <<6시 데이터 시작 2016-01-03 06:00:04>> 15207696
# <<7시 데이터 시작 2016-01-03 07:00:05>> 15208282
# <<8시 데이터 시작 2016-01-03 08:00:03>> 15208870
# <<9시 데이터 시작 2016-01-03 09:00:00>> 15209444
# <<10시 데이터 시작 2016-01-03 10:00:02>> 15210019
# <<11시 데이터 시작 2016-01-03 11:00:04>> 15210603
# <<12시 데이터 시작 2016-01-03 12:00:03>> 15211195
# <<13시 데이터 시작 2016-01-03 13:00:02>> 15211762
# <<14시 데이터 시작 2016-01-03 14:00:03>> 15212342
# <<15시 데이터 시작 2016-01-03 15:00:05>> 15212931
# <<16시 데이터 시작 2016-01-03 16:00:01>> 15213489
# <<17시 데이터 시작 2016-01-03 17:00:04>> 15214045
# <<18시 데이터 시작 2016-01-03 18:00:01>> 15214623
# <<19시 데이터 시작 2016-01-03 19:00:03>> 15215205
# <<20시 데이터 시작 2016-01-03 20:00:01>> 15215792
# <<21시 데이터 시작 2016-01-03 21:00:03>> 15216381
# <<22시 데이터 시작 2016-01-03 22:00:05>> 15216969
# <<23시 데이터 시작 2016-01-03 23:00:04>> 15217560
# *3일의 분별 최댓값 1440개 추가됨.
# 4320개의 데이터 누적, 계산된 일자 => 3
#
#
#
#
#
# <<<4일 데이터 시작 2016-01-04 00:00:01>>> 15218148
# <<0시 데이터 시작 2016-01-04 00:00:01>> 15218148
# <<1시 데이터 시작 2016-01-04 01:00:05>> 15218734
# <<2시 데이터 시작 2016-01-04 02:00:01>> 15219322
# <<3시 데이터 시작 2016-01-04 03:00:02>> 15219901
# <<4시 데이터 시작 2016-01-04 04:00:02>> 15220485
# <<5시 데이터 시작 2016-01-04 05:00:05>> 15221069
# <<6시 데이터 시작 2016-01-04 06:00:03>> 15221661
# <<7시 데이터 시작 2016-01-04 07:00:04>> 15222247
# <<8시 데이터 시작 2016-01-04 08:00:03>> 15222837
# <<9시 데이터 시작 2016-01-04 09:00:01>> 15223405
# <<10시 데이터 시작 2016-01-04 10:00:03>> 15223996
# <<11시 데이터 시작 2016-01-04 11:00:03>> 15224575
# <<12시 데이터 시작 2016-01-04 12:00:03>> 15225166
# <<13시 데이터 시작 2016-01-04 13:00:07>> 15225729
# <<14시 데이터 시작 2016-01-04 14:00:05>> 15226301
# <<15시 데이터 시작 2016-01-04 15:00:00>> 15226890
# <<16시 데이터 시작 2016-01-04 16:00:04>> 15227483
# <<17시 데이터 시작 2016-01-04 17:00:02>> 15228048
# <<18시 데이터 시작 2016-01-04 18:00:02>> 15228638
# <<19시 데이터 시작 2016-01-04 19:00:05>> 15229207
# <<20시 데이터 시작 2016-01-04 20:00:04>> 15229780
# <<21시 데이터 시작 2016-01-04 21:00:03>> 15230361
# <<22시 데이터 시작 2016-01-04 22:00:05>> 15230948
# <<23시 데이터 시작 2016-01-04 23:00:01>> 15231531
# *4일의 분별 최댓값 1440개 추가됨.
# 5760개의 데이터 누적, 계산된 일자 => 4
#
#
#
#
#
# <<<5일 데이터 시작 2016-01-05 00:00:02>>> 15232121
# <<0시 데이터 시작 2016-01-05 00:00:02>> 15232121
# <<1시 데이터 시작 2016-01-05 01:00:00>> 15232713
# <<2시 데이터 시작 2016-01-05 02:00:04>> 15233305
# <<3시 데이터 시작 2016-01-05 03:00:04>> 15233888
# <<4시 데이터 시작 2016-01-05 04:00:02>> 15234474
# <<5시 데이터 시작 2016-01-05 05:00:04>> 15235064
# <<6시 데이터 시작 2016-01-05 06:00:03>> 15235654
# <<7시 데이터 시작 2016-01-05 07:00:04>> 15236242
# <<8시 데이터 시작 2016-01-05 08:00:00>> 15236814
# <<9시 데이터 시작 2016-01-05 09:00:03>> 15237402
# <<10시 데이터 시작 2016-01-05 10:00:01>> 15237987
# <<11시 데이터 시작 2016-01-05 11:00:00>> 15238580
# <<12시 데이터 시작 2016-01-05 12:00:02>> 15239174
# <<13시 데이터 시작 2016-01-05 13:00:02>> 15239736
# <<14시 데이터 시작 2016-01-05 14:00:00>> 15240323
# <<15시 데이터 시작 2016-01-05 15:00:05>> 15240914
# <<16시 데이터 시작 2016-01-05 16:00:02>> 15241505
# <<17시 데이터 시작 2016-01-05 17:00:03>> 15242096
# <<18시 데이터 시작 2016-01-05 18:00:02>> 15242682
# <<19시 데이터 시작 2016-01-05 19:00:03>> 15243271
# <<20시 데이터 시작 2016-01-05 20:00:02>> 15243860
# <<21시 데이터 시작 2016-01-05 21:00:02>> 15244444
# <<22시 데이터 시작 2016-01-05 22:00:02>> 15245032
# <<23시 데이터 시작 2016-01-05 23:00:04>> 15245620
# *5일의 분별 최댓값 1440개 추가됨.
# 7200개의 데이터 누적, 계산된 일자 => 5
#
#
#
#
#
# <<<6일 데이터 시작 2016-01-06 00:00:04>>> 15246205
# <<0시 데이터 시작 2016-01-06 00:00:04>> 15246205
# <<1시 데이터 시작 2016-01-06 01:00:01>> 15246795
# <<2시 데이터 시작 2016-01-06 02:00:01>> 15247386
# <<3시 데이터 시작 2016-01-06 03:00:01>> 15247973
# <<4시 데이터 시작 2016-01-06 04:00:04>> 15248557
# <<5시 데이터 시작 2016-01-06 05:00:03>> 15249146
# <<6시 데이터 시작 2016-01-06 06:00:03>> 15249723
# <<7시 데이터 시작 2016-01-06 07:00:02>> 15250302
# <<8시 데이터 시작 2016-01-06 08:00:03>> 15250871
# <<9시 데이터 시작 2016-01-06 09:00:03>> 15251437
# <<10시 데이터 시작 2016-01-06 10:00:00>> 15252024
# <<11시 데이터 시작 2016-01-06 11:00:02>> 15252610
# <<12시 데이터 시작 2016-01-06 12:00:04>> 15253194
# <<13시 데이터 시작 2016-01-06 13:00:03>> 15253757
# <<14시 데이터 시작 2016-01-06 14:00:02>> 15254333
# <<15시 데이터 시작 2016-01-06 15:00:00>> 15254922
# <<16시 데이터 시작 2016-01-06 16:00:05>> 15255510
# <<17시 데이터 시작 2016-01-06 17:00:01>> 15256089
# <<18시 데이터 시작 2016-01-06 18:00:02>> 15256674
# <<19시 데이터 시작 2016-01-06 19:00:05>> 15257249
# <<20시 데이터 시작 2016-01-06 20:00:02>> 15257826
# <<21시 데이터 시작 2016-01-06 21:00:06>> 15258416
# <<22시 데이터 시작 2016-01-06 22:00:02>> 15259001
# <<23시 데이터 시작 2016-01-06 23:00:04>> 15259594
# *6일의 분별 최댓값 1440개 추가됨.
# 8640개의 데이터 누적, 계산된 일자 => 6
#
#
#
#
#
# <<<7일 데이터 시작 2016-01-07 00:00:05>>> 15260185
# <<0시 데이터 시작 2016-01-07 00:00:05>> 15260185
# <<1시 데이터 시작 2016-01-07 01:00:03>> 15260774
# <<2시 데이터 시작 2016-01-07 02:00:04>> 15261362
# <<3시 데이터 시작 2016-01-07 03:00:05>> 15261949
# <<4시 데이터 시작 2016-01-07 04:00:03>> 15262538
# <<5시 데이터 시작 2016-01-07 05:00:04>> 15263120
# <<6시 데이터 시작 2016-01-07 06:00:02>> 15263702
# <<7시 데이터 시작 2016-01-07 07:00:00>> 15264283
# <<8시 데이터 시작 2016-01-07 08:00:02>> 15264817
# <<9시 데이터 시작 2016-01-07 09:00:01>> 15265402
# <<10시 데이터 시작 2016-01-07 10:00:05>> 15265990
# <<11시 데이터 시작 2016-01-07 11:00:04>> 15266578
# <<12시 데이터 시작 2016-01-07 12:00:02>> 15267169
# <<13시 데이터 시작 2016-01-07 13:00:02>> 15267758
# <<14시 데이터 시작 2016-01-07 14:00:02>> 15268338
# <<15시 데이터 시작 2016-01-07 15:00:04>> 15268913
# <<16시 데이터 시작 2016-01-07 16:00:02>> 15269505
# <<17시 데이터 시작 2016-01-07 17:00:00>> 15270083
# <<18시 데이터 시작 2016-01-07 18:00:04>> 15270659
# <<19시 데이터 시작 2016-01-07 19:00:04>> 15271249
# <<20시 데이터 시작 2016-01-07 20:00:00>> 15271836
# <<21시 데이터 시작 2016-01-07 21:00:03>> 15272423
# <<22시 데이터 시작 2016-01-07 22:00:05>> 15273010
# <<23시 데이터 시작 2016-01-07 23:00:02>> 15273601
# *7일의 분별 최댓값 1440개 추가됨.
# 10080개의 데이터 누적, 계산된 일자 => 7
#
#
#
#
#
# <<<8일 데이터 시작 2016-01-08 00:00:03>>> 15274172
# <<0시 데이터 시작 2016-01-08 00:00:03>> 15274172
# <<1시 데이터 시작 2016-01-08 01:00:01>> 15274745
# <<2시 데이터 시작 2016-01-08 02:00:05>> 15275337
# <<3시 데이터 시작 2016-01-08 03:00:03>> 15275924
# <<4시 데이터 시작 2016-01-08 04:00:03>> 15276513
# <<5시 데이터 시작 2016-01-08 05:00:03>> 15277097
# <<6시 데이터 시작 2016-01-08 06:00:01>> 15277682
# <<7시 데이터 시작 2016-01-08 07:00:04>> 15278257
# <<8시 데이터 시작 2016-01-08 08:00:04>> 15278819
# <<9시 데이터 시작 2016-01-08 09:00:04>> 15279387
# <<10시 데이터 시작 2016-01-08 10:00:04>> 15279959
# <<11시 데이터 시작 2016-01-08 11:00:02>> 15280539
# <<12시 데이터 시작 2016-01-08 12:00:03>> 15281105
# <<13시 데이터 시작 2016-01-08 13:00:05>> 15281683
# <<14시 데이터 시작 2016-01-08 14:00:04>> 15282260
# <<15시 데이터 시작 2016-01-08 15:00:01>> 15282841
# <<16시 데이터 시작 2016-01-08 16:00:01>> 15283421
# <<17시 데이터 시작 2016-01-08 17:00:01>> 15284004
# <<18시 데이터 시작 2016-01-08 18:00:05>> 15284584
# <<19시 데이터 시작 2016-01-08 19:00:05>> 15285162
# <<20시 데이터 시작 2016-01-08 20:00:05>> 15285746
# <<21시 데이터 시작 2016-01-08 21:00:04>> 15286337
# <<22시 데이터 시작 2016-01-08 22:00:00>> 15286924
# <<23시 데이터 시작 2016-01-08 23:00:01>> 15287514
# *8일의 분별 최댓값 1440개 추가됨.
# 11520개의 데이터 누적, 계산된 일자 => 8
#
#
#
#
#
# <<<9일 데이터 시작 2016-01-09 00:00:03>>> 15288102
# <<0시 데이터 시작 2016-01-09 00:00:03>> 15288102
# <<1시 데이터 시작 2016-01-09 01:00:03>> 15288688
# <<2시 데이터 시작 2016-01-09 02:00:03>> 15289276
# <<3시 데이터 시작 2016-01-09 03:00:01>> 15289867
# <<4시 데이터 시작 2016-01-09 04:00:02>> 15290458
# <<5시 데이터 시작 2016-01-09 05:00:03>> 15291041
# <<6시 데이터 시작 2016-01-09 06:00:04>> 15291627
# <<7시 데이터 시작 2016-01-09 07:00:00>> 15292213
# <<8시 데이터 시작 2016-01-09 08:00:02>> 15292795
# <<9시 데이터 시작 2016-01-09 09:00:04>> 15293350
# <<10시 데이터 시작 2016-01-09 10:00:03>> 15293923
# <<11시 데이터 시작 2016-01-09 11:00:01>> 15294500
# <<12시 데이터 시작 2016-01-09 12:00:04>> 15295072
# <<13시 데이터 시작 2016-01-09 13:00:04>> 15295657
# <<14시 데이터 시작 2016-01-09 14:00:03>> 15296237
# <<15시 데이터 시작 2016-01-09 15:00:00>> 15296806
# <<16시 데이터 시작 2016-01-09 16:00:00>> 15297388
# <<17시 데이터 시작 2016-01-09 17:00:03>> 15297970
# <<18시 데이터 시작 2016-01-09 18:00:05>> 15298550
# <<19시 데이터 시작 2016-01-09 19:00:03>> 15299121
# <<20시 데이터 시작 2016-01-09 20:00:05>> 15299709
# <<21시 데이터 시작 2016-01-09 21:00:02>> 15300298
# <<22시 데이터 시작 2016-01-09 22:00:01>> 15300886
# <<23시 데이터 시작 2016-01-09 23:00:04>> 15301475
# *9일의 분별 최댓값 1440개 추가됨.
# 12960개의 데이터 누적, 계산된 일자 => 9
#
#
#
#
#
# <<<10일 데이터 시작 2016-01-10 00:00:05>>> 15302038
# <<0시 데이터 시작 2016-01-10 00:00:05>> 15302038
# <<1시 데이터 시작 2016-01-10 01:00:03>> 15302623
# <<2시 데이터 시작 2016-01-10 02:00:02>> 15303210
# <<3시 데이터 시작 2016-01-10 03:00:02>> 15303798
# <<4시 데이터 시작 2016-01-10 04:00:02>> 15304382
# <<5시 데이터 시작 2016-01-10 05:00:04>> 15304970
# <<6시 데이터 시작 2016-01-10 06:00:05>> 15305561
# <<7시 데이터 시작 2016-01-10 07:00:05>> 15306153
# <<8시 데이터 시작 2016-01-10 08:00:01>> 15306737
# <<9시 데이터 시작 2016-01-10 09:00:06>> 15307322
# <<10시 데이터 시작 2016-01-10 10:00:03>> 15307912
# <<11시 데이터 시작 2016-01-10 11:00:05>> 15308499
# <<12시 데이터 시작 2016-01-10 12:00:02>> 15309087
# <<13시 데이터 시작 2016-01-10 13:00:04>> 15309665
# <<14시 데이터 시작 2016-01-10 14:00:05>> 15310239
# <<15시 데이터 시작 2016-01-10 15:00:05>> 15310826
# <<16시 데이터 시작 2016-01-10 16:00:00>> 15311414
# <<17시 데이터 시작 2016-01-10 17:00:01>> 15311999
# <<18시 데이터 시작 2016-01-10 18:00:00>> 15312583
# <<19시 데이터 시작 2016-01-10 19:00:04>> 15313172
# <<20시 데이터 시작 2016-01-10 20:00:01>> 15313754
# <<21시 데이터 시작 2016-01-10 21:00:04>> 15314338
# <<22시 데이터 시작 2016-01-10 22:00:01>> 15314923
# <<23시 데이터 시작 2016-01-10 23:00:00>> 15315508
# *10일의 분별 최댓값 1440개 추가됨.
# 14400개의 데이터 누적, 계산된 일자 => 10
#
#
#
#
#
# <<<11일 데이터 시작 2016-01-11 00:00:02>>> 15316097
# <<0시 데이터 시작 2016-01-11 00:00:02>> 15316097
# <<1시 데이터 시작 2016-01-11 01:00:03>> 15316673
# <<2시 데이터 시작 2016-01-11 02:00:05>> 15317257
# <<3시 데이터 시작 2016-01-11 03:00:01>> 15317839
# <<4시 데이터 시작 2016-01-11 04:00:05>> 15318417
# <<5시 데이터 시작 2016-01-11 05:00:05>> 15318995
# <<6시 데이터 시작 2016-01-11 06:00:05>> 15319576
# <<7시 데이터 시작 2016-01-11 07:00:01>> 15320153
# <<8시 데이터 시작 2016-01-11 08:00:04>> 15320703
# <<9시 데이터 시작 2016-01-11 09:00:04>> 15321276
# <<10시 데이터 시작 2016-01-11 10:00:01>> 15321855
# <<11시 데이터 시작 2016-01-11 11:00:04>> 15322438
# <<12시 데이터 시작 2016-01-11 12:00:02>> 15322999
# <<13시 데이터 시작 2016-01-11 13:00:02>> 15323576
# <<14시 데이터 시작 2016-01-11 14:00:02>> 15324155
# <<15시 데이터 시작 2016-01-11 15:00:06>> 15324727
# <<16시 데이터 시작 2016-01-11 16:00:04>> 15325312
# <<17시 데이터 시작 2016-01-11 17:00:00>> 15325874
# <<18시 데이터 시작 2016-01-11 18:00:05>> 15326454
# <<19시 데이터 시작 2016-01-11 19:00:05>> 15327042
# <<20시 데이터 시작 2016-01-11 20:00:00>> 15327613
# <<21시 데이터 시작 2016-01-11 21:00:01>> 15328197
# <<22시 데이터 시작 2016-01-11 22:00:04>> 15328782
# <<23시 데이터 시작 2016-01-11 23:00:00>> 15329365
# *11일의 분별 최댓값 1440개 추가됨.
# 15840개의 데이터 누적, 계산된 일자 => 11
#
#
#
#
#
# <<<12일 데이터 시작 2016-01-12 00:00:01>>> 15329949
# <<0시 데이터 시작 2016-01-12 00:00:01>> 15329949
# <<1시 데이터 시작 2016-01-12 01:00:05>> 15330536
# <<2시 데이터 시작 2016-01-12 02:00:05>> 15331114
# <<3시 데이터 시작 2016-01-12 03:00:05>> 15331695
# <<4시 데이터 시작 2016-01-12 04:00:02>> 15332275
# <<5시 데이터 시작 2016-01-12 05:00:01>> 15332856
# <<6시 데이터 시작 2016-01-12 06:00:04>> 15333435
# <<7시 데이터 시작 2016-01-12 07:00:03>> 15334013
# <<8시 데이터 시작 2016-01-12 08:00:01>> 15334570
# <<9시 데이터 시작 2016-01-12 09:00:00>> 15335135
# <<10시 데이터 시작 2016-01-12 10:00:05>> 15335689
# <<11시 데이터 시작 2016-01-12 11:00:01>> 15336262
# <<12시 데이터 시작 2016-01-12 12:00:02>> 15336823
# <<13시 데이터 시작 2016-01-12 13:00:05>> 15337389
# <<14시 데이터 시작 2016-01-12 14:00:03>> 15337977
# <<15시 데이터 시작 2016-01-12 15:00:05>> 15338564
# <<16시 데이터 시작 2016-01-12 16:00:05>> 15339149
# <<17시 데이터 시작 2016-01-12 17:00:03>> 15339737
# <<18시 데이터 시작 2016-01-12 18:00:04>> 15340315
# <<19시 데이터 시작 2016-01-12 19:00:05>> 15340900
# <<20시 데이터 시작 2016-01-12 20:00:02>> 15341486
# <<21시 데이터 시작 2016-01-12 21:00:03>> 15342068
# <<22시 데이터 시작 2016-01-12 22:00:01>> 15342657
# <<23시 데이터 시작 2016-01-12 23:00:05>> 15343241
# *12일의 분별 최댓값 1440개 추가됨.
# 17280개의 데이터 누적, 계산된 일자 => 12
#
#
#
#
#
# <<<13일 데이터 시작 2016-01-13 00:00:01>>> 15343830
# <<0시 데이터 시작 2016-01-13 00:00:01>> 15343830
# <<1시 데이터 시작 2016-01-13 01:00:04>> 15344422
# <<2시 데이터 시작 2016-01-13 02:00:01>> 15345014
# <<3시 데이터 시작 2016-01-13 03:00:01>> 15345601
# <<4시 데이터 시작 2016-01-13 04:00:05>> 15346188
# <<5시 데이터 시작 2016-01-13 05:00:00>> 15346764
# <<6시 데이터 시작 2016-01-13 06:00:05>> 15347345
# <<7시 데이터 시작 2016-01-13 07:00:02>> 15347906
# <<8시 데이터 시작 2016-01-13 08:00:06>> 15348447
# <<9시 데이터 시작 2016-01-13 09:00:00>> 15349013
# <<10시 데이터 시작 2016-01-13 10:00:04>> 15349559
# <<11시 데이터 시작 2016-01-13 11:00:00>> 15350135
# <<12시 데이터 시작 2016-01-13 12:00:06>> 15350711
# <<13시 데이터 시작 2016-01-13 13:00:01>> 15351283
# <<14시 데이터 시작 2016-01-13 14:00:04>> 15351856
# <<15시 데이터 시작 2016-01-13 15:00:06>> 15352436
# <<16시 데이터 시작 2016-01-13 16:00:06>> 15353014
# <<17시 데이터 시작 2016-01-13 17:00:00>> 15353587
# <<18시 데이터 시작 2016-01-13 18:00:02>> 15354155
# <<19시 데이터 시작 2016-01-13 19:00:01>> 15354735
# <<20시 데이터 시작 2016-01-13 20:00:03>> 15355295
# <<21시 데이터 시작 2016-01-13 21:00:01>> 15355877
# <<22시 데이터 시작 2016-01-13 22:00:04>> 15356456
# <<23시 데이터 시작 2016-01-13 23:00:04>> 15357015
# *13일의 분별 최댓값 1440개 추가됨.
# 18720개의 데이터 누적, 계산된 일자 => 13
#
#
#
#
#
# <<<14일 데이터 시작 2016-01-14 00:00:04>>> 15357563
# <<0시 데이터 시작 2016-01-14 00:00:04>> 15357563
# <<1시 데이터 시작 2016-01-14 01:00:05>> 15358145
# <<2시 데이터 시작 2016-01-14 02:00:00>> 15358720
# <<3시 데이터 시작 2016-01-14 03:00:03>> 15359290
# <<4시 데이터 시작 2016-01-14 04:00:06>> 15359866
# <<5시 데이터 시작 2016-01-14 05:00:05>> 15360441
# <<6시 데이터 시작 2016-01-14 06:00:05>> 15361018
# <<7시 데이터 시작 2016-01-14 07:00:04>> 15361591
# <<8시 데이터 시작 2016-01-14 08:00:11>> 15362141
# <<9시 데이터 시작 2016-01-14 09:00:00>> 15362711
# <<10시 데이터 시작 2016-01-14 10:00:05>> 15363292
# <<11시 데이터 시작 2016-01-14 11:00:05>> 15363858
# <<12시 데이터 시작 2016-01-14 12:00:01>> 15364425
# <<13시 데이터 시작 2016-01-14 13:00:06>> 15365009
# <<14시 데이터 시작 2016-01-14 14:00:01>> 15365585
# <<15시 데이터 시작 2016-01-14 15:00:02>> 15366161
# <<16시 데이터 시작 2016-01-14 16:00:03>> 15366744
# <<17시 데이터 시작 2016-01-14 17:00:02>> 15367310
# <<18시 데이터 시작 2016-01-14 18:00:00>> 15367889
# <<19시 데이터 시작 2016-01-14 19:00:02>> 15368472
# <<20시 데이터 시작 2016-01-14 20:00:01>> 15369045
# <<21시 데이터 시작 2016-01-14 21:00:08>> 15369623
# <<22시 데이터 시작 2016-01-14 22:00:01>> 15370197
# <<23시 데이터 시작 2016-01-14 23:00:03>> 15370776
# *14일의 분별 최댓값 1440개 추가됨.
# 20160개의 데이터 누적, 계산된 일자 => 14
#
#
#
#
#
# <<<15일 데이터 시작 2016-01-15 00:00:03>>> 15371357
# <<0시 데이터 시작 2016-01-15 00:00:03>> 15371357
# <<1시 데이터 시작 2016-01-15 01:00:04>> 15371938
# <<2시 데이터 시작 2016-01-15 02:00:01>> 15372513
# <<3시 데이터 시작 2016-01-15 03:00:04>> 15373087
# <<4시 데이터 시작 2016-01-15 04:00:03>> 15373664
# <<5시 데이터 시작 2016-01-15 05:00:01>> 15374243
# <<6시 데이터 시작 2016-01-15 06:00:05>> 15374817
# <<7시 데이터 시작 2016-01-15 07:00:02>> 15375381
# <<8시 데이터 시작 2016-01-15 08:00:00>> 15375936
# <<9시 데이터 시작 2016-01-15 09:00:01>> 15376498
# <<10시 데이터 시작 2016-01-15 10:00:05>> 15377047
# <<11시 데이터 시작 2016-01-15 11:00:01>> 15377620
# <<12시 데이터 시작 2016-01-15 12:00:01>> 15378182
# <<13시 데이터 시작 2016-01-15 13:00:00>> 15378760
# <<14시 데이터 시작 2016-01-15 14:00:03>> 15379337
# <<15시 데이터 시작 2016-01-15 15:00:04>> 15379913
# <<16시 데이터 시작 2016-01-15 16:00:00>> 15380491
# <<17시 데이터 시작 2016-01-15 17:00:05>> 15381065
# <<18시 데이터 시작 2016-01-15 18:00:12>> 15381640
# <<19시 데이터 시작 2016-01-15 19:00:03>> 15382215
# <<20시 데이터 시작 2016-01-15 20:00:02>> 15382793
# <<21시 데이터 시작 2016-01-15 21:00:03>> 15383364
# <<22시 데이터 시작 2016-01-15 22:00:00>> 15383941
# <<23시 데이터 시작 2016-01-15 23:00:05>> 15384523
# *15일의 분별 최댓값 1440개 추가됨.
# 21600개의 데이터 누적, 계산된 일자 => 15
#
#
#
#
#
# <<<16일 데이터 시작 2016-01-16 00:00:03>>> 15385100
# <<0시 데이터 시작 2016-01-16 00:00:03>> 15385100
# <<1시 데이터 시작 2016-01-16 01:00:04>> 15385677
# <<2시 데이터 시작 2016-01-16 02:00:03>> 15386255
# <<3시 데이터 시작 2016-01-16 03:00:01>> 15386829
# <<4시 데이터 시작 2016-01-16 04:00:02>> 15387399
# <<5시 데이터 시작 2016-01-16 05:00:10>> 15387968
# <<6시 데이터 시작 2016-01-16 06:00:01>> 15388545
# <<7시 데이터 시작 2016-01-16 07:00:03>> 15389126
# <<8시 데이터 시작 2016-01-16 08:00:03>> 15389705
# <<9시 데이터 시작 2016-01-16 09:00:02>> 15390270
# <<10시 데이터 시작 2016-01-16 10:00:05>> 15390855
# <<11시 데이터 시작 2016-01-16 11:00:00>> 15391406
# <<12시 데이터 시작 2016-01-16 12:00:03>> 15391951
# <<13시 데이터 시작 2016-01-16 13:00:02>> 15392527
# <<14시 데이터 시작 2016-01-16 14:00:00>> 15393069
# <<15시 데이터 시작 2016-01-16 15:00:05>> 15393634
# <<16시 데이터 시작 2016-01-16 16:00:04>> 15394208
# <<17시 데이터 시작 2016-01-16 17:00:03>> 15394773
# <<18시 데이터 시작 2016-01-16 18:00:00>> 15395345
# <<19시 데이터 시작 2016-01-16 19:00:03>> 15395929
# <<20시 데이터 시작 2016-01-16 20:00:07>> 15396507
# <<21시 데이터 시작 2016-01-16 21:00:01>> 15397083
# <<22시 데이터 시작 2016-01-16 22:00:00>> 15397661
# <<23시 데이터 시작 2016-01-16 23:00:03>> 15398240
# *16일의 분별 최댓값 1440개 추가됨.
# 23040개의 데이터 누적, 계산된 일자 => 16
#
#
#
#
#
# <<<17일 데이터 시작 2016-01-17 00:00:03>>> 15398817
# <<0시 데이터 시작 2016-01-17 00:00:03>> 15398817
# <<1시 데이터 시작 2016-01-17 01:00:05>> 15399393
# <<2시 데이터 시작 2016-01-17 02:00:00>> 15399966
# <<3시 데이터 시작 2016-01-17 03:00:03>> 15400545
# <<4시 데이터 시작 2016-01-17 04:00:01>> 15401123
# <<5시 데이터 시작 2016-01-17 05:00:03>> 15401699
# <<6시 데이터 시작 2016-01-17 06:00:02>> 15402275
# <<7시 데이터 시작 2016-01-17 07:00:06>> 15402846
# <<8시 데이터 시작 2016-01-17 08:00:01>> 15403424
# <<9시 데이터 시작 2016-01-17 09:00:02>> 15403999
# <<10시 데이터 시작 2016-01-17 10:00:00>> 15404570
# <<11시 데이터 시작 2016-01-17 11:00:02>> 15405128
# <<12시 데이터 시작 2016-01-17 12:00:02>> 15405665
# <<13시 데이터 시작 2016-01-17 13:00:01>> 15406223
# <<14시 데이터 시작 2016-01-17 14:00:03>> 15406795
# <<15시 데이터 시작 2016-01-17 15:00:04>> 15407376
# <<16시 데이터 시작 2016-01-17 16:00:04>> 15407940
# <<17시 데이터 시작 2016-01-17 17:00:00>> 15408516
# <<18시 데이터 시작 2016-01-17 18:00:03>> 15409088
# <<19시 데이터 시작 2016-01-17 19:00:04>> 15409652
# <<20시 데이터 시작 2016-01-17 20:00:01>> 15410232
# <<21시 데이터 시작 2016-01-17 21:00:05>> 15410802
# <<22시 데이터 시작 2016-01-17 22:00:04>> 15411376
# <<23시 데이터 시작 2016-01-17 23:00:01>> 15411952
# *17일의 분별 최댓값 1440개 추가됨.
# 24480개의 데이터 누적, 계산된 일자 => 17
#
#
#
#
#
# <<<18일 데이터 시작 2016-01-18 00:00:04>>> 15412528
# <<0시 데이터 시작 2016-01-18 00:00:04>> 15412528
# <<1시 데이터 시작 2016-01-18 01:00:01>> 15413096
# <<2시 데이터 시작 2016-01-18 02:00:04>> 15413673
# <<3시 데이터 시작 2016-01-18 03:00:05>> 15414252
# <<4시 데이터 시작 2016-01-18 04:00:05>> 15414830
# <<5시 데이터 시작 2016-01-18 05:00:00>> 15415404
# <<6시 데이터 시작 2016-01-18 06:00:05>> 15415978
# <<7시 데이터 시작 2016-01-18 07:00:03>> 15416545
# <<8시 데이터 시작 2016-01-18 08:00:04>> 15417106
# <<9시 데이터 시작 2016-01-18 09:00:00>> 15417667
# <<10시 데이터 시작 2016-01-18 10:00:05>> 15418239
# <<11시 데이터 시작 2016-01-18 11:00:04>> 15418814
# <<12시 데이터 시작 2016-01-18 12:00:03>> 15419371
# <<13시 데이터 시작 2016-01-18 13:00:04>> 15419930
# <<14시 데이터 시작 2016-01-18 14:00:02>> 15420494
# <<15시 데이터 시작 2016-01-18 15:00:00>> 15421037
# <<16시 데이터 시작 2016-01-18 16:00:00>> 15421615
# <<17시 데이터 시작 2016-01-18 17:00:03>> 15422176
# <<18시 데이터 시작 2016-01-18 18:00:04>> 15422751
# <<19시 데이터 시작 2016-01-18 19:00:02>> 15423321
# <<20시 데이터 시작 2016-01-18 20:00:02>> 15423882
# <<21시 데이터 시작 2016-01-18 21:00:00>> 15424444
# <<22시 데이터 시작 2016-01-18 22:00:02>> 15425021
# <<23시 데이터 시작 2016-01-18 23:00:00>> 15425598
# *18일의 분별 최댓값 1440개 추가됨.
# 25920개의 데이터 누적, 계산된 일자 => 18
#
#
#
#
#
# <<<19일 데이터 시작 2016-01-19 00:00:06>>> 15426174
# <<0시 데이터 시작 2016-01-19 00:00:06>> 15426174
# <<1시 데이터 시작 2016-01-19 01:00:03>> 15426747
# <<2시 데이터 시작 2016-01-19 02:00:03>> 15427323
# <<3시 데이터 시작 2016-01-19 03:00:00>> 15427901
# <<4시 데이터 시작 2016-01-19 04:00:05>> 15428478
# <<5시 데이터 시작 2016-01-19 05:00:05>> 15429056
# <<6시 데이터 시작 2016-01-19 06:00:01>> 15429636
# <<7시 데이터 시작 2016-01-19 07:00:03>> 15430221
# <<8시 데이터 시작 2016-01-19 08:00:03>> 15430804
# <<9시 데이터 시작 2016-01-19 09:00:02>> 15431365
# <<10시 데이터 시작 2016-01-19 10:00:03>> 15431938
# <<11시 데이터 시작 2016-01-19 11:00:00>> 15432509
# <<12시 데이터 시작 2016-01-19 12:00:04>> 15433086
# <<13시 데이터 시작 2016-01-19 13:00:00>> 15433663
# <<14시 데이터 시작 2016-01-19 14:00:02>> 15434224
# <<15시 데이터 시작 2016-01-19 15:00:03>> 15434797
# <<16시 데이터 시작 2016-01-19 16:00:00>> 15435376
# <<17시 데이터 시작 2016-01-19 17:00:04>> 15435957
# <<18시 데이터 시작 2016-01-19 18:00:01>> 15436526
# <<19시 데이터 시작 2016-01-19 19:00:03>> 15437090
# <<20시 데이터 시작 2016-01-19 20:00:04>> 15437668
# <<21시 데이터 시작 2016-01-19 21:00:05>> 15438239
# <<22시 데이터 시작 2016-01-19 22:00:00>> 15438816
# <<23시 데이터 시작 2016-01-19 23:00:06>> 15439389
# *19일의 분별 최댓값 1440개 추가됨.
# 27360개의 데이터 누적, 계산된 일자 => 19
#
#
#
#
#
# <<<20일 데이터 시작 2016-01-20 00:00:02>>> 15439965
# <<0시 데이터 시작 2016-01-20 00:00:02>> 15439965
# <<1시 데이터 시작 2016-01-20 01:00:00>> 15440538
# <<2시 데이터 시작 2016-01-20 02:00:01>> 15441119
# <<3시 데이터 시작 2016-01-20 03:00:02>> 15441697
# <<4시 데이터 시작 2016-01-20 04:00:04>> 15442282
# <<5시 데이터 시작 2016-01-20 05:00:01>> 15442869
# <<6시 데이터 시작 2016-01-20 06:00:03>> 15443460
# <<7시 데이터 시작 2016-01-20 07:00:03>> 15444052
# <<8시 데이터 시작 2016-01-20 08:00:01>> 15444641
# <<9시 데이터 시작 2016-01-20 09:00:04>> 15445226
# <<10시 데이터 시작 2016-01-20 10:00:02>> 15445808
# <<11시 데이터 시작 2016-01-20 11:00:05>> 15446401
# <<12시 데이터 시작 2016-01-20 12:00:02>> 15446994
# <<13시 데이터 시작 2016-01-20 13:00:00>> 15447586
# <<14시 데이터 시작 2016-01-20 14:00:01>> 15448170
# <<15시 데이터 시작 2016-01-20 15:00:00>> 15448750
# <<16시 데이터 시작 2016-01-20 16:00:00>> 15449323
# <<17시 데이터 시작 2016-01-20 17:00:03>> 15449894
# <<18시 데이터 시작 2016-01-20 18:00:04>> 15450462
# <<19시 데이터 시작 2016-01-20 19:00:00>> 15451040
# <<20시 데이터 시작 2016-01-20 20:00:02>> 15451605
# <<21시 데이터 시작 2016-01-20 21:00:01>> 15452179
# <<22시 데이터 시작 2016-01-20 22:00:02>> 15452755
# <<23시 데이터 시작 2016-01-20 23:00:02>> 15453271
# *20일의 분별 최댓값 1440개 추가됨.
# 28800개의 데이터 누적, 계산된 일자 => 20
#
#
#
#
#
# <<<21일 데이터 시작 2016-01-21 00:00:04>>> 15453746
# <<0시 데이터 시작 2016-01-21 00:00:04>> 15453746
# <<1시 데이터 시작 2016-01-21 01:00:04>> 15454321
# <<2시 데이터 시작 2016-01-21 02:00:01>> 15454891
# <<3시 데이터 시작 2016-01-21 03:00:04>> 15455467
# <<4시 데이터 시작 2016-01-21 04:00:01>> 15456043
# <<5시 데이터 시작 2016-01-21 05:00:05>> 15456628
# <<6시 데이터 시작 2016-01-21 06:00:02>> 15457214
# <<7시 데이터 시작 2016-01-21 07:00:05>> 15457796
# <<8시 데이터 시작 2016-01-21 08:00:03>> 15458364
# <<9시 데이터 시작 2016-01-21 09:00:04>> 15458941
# <<10시 데이터 시작 2016-01-21 10:00:04>> 15459518
# <<11시 데이터 시작 2016-01-21 11:00:04>> 15460092
# <<12시 데이터 시작 2016-01-21 12:00:01>> 15460649
# <<13시 데이터 시작 2016-01-21 13:00:05>> 15461217
# <<14시 데이터 시작 2016-01-21 14:00:03>> 15461766
# <<15시 데이터 시작 2016-01-21 15:00:03>> 15462299
# <<16시 데이터 시작 2016-01-21 16:00:01>> 15462877
# <<17시 데이터 시작 2016-01-21 17:00:03>> 15463438
# <<18시 데이터 시작 2016-01-21 18:00:03>> 15464011
# <<19시 데이터 시작 2016-01-21 19:00:02>> 15464585
# <<20시 데이터 시작 2016-01-21 20:00:04>> 15465152
# <<21시 데이터 시작 2016-01-21 21:00:05>> 15465730
# <<22시 데이터 시작 2016-01-21 22:00:01>> 15466306
# <<23시 데이터 시작 2016-01-21 23:00:00>> 15466881
# *21일의 분별 최댓값 1440개 추가됨.
# 30240개의 데이터 누적, 계산된 일자 => 21
#
#
#
#
#
# <<<22일 데이터 시작 2016-01-22 00:00:04>>> 15467452
# <<0시 데이터 시작 2016-01-22 00:00:04>> 15467452
# <<1시 데이터 시작 2016-01-22 01:00:02>> 15468029
# <<2시 데이터 시작 2016-01-22 02:00:00>> 15468610
# <<3시 데이터 시작 2016-01-22 03:00:05>> 15469190
# <<4시 데이터 시작 2016-01-22 04:00:05>> 15469767
# <<5시 데이터 시작 2016-01-22 05:00:01>> 15470336
# <<6시 데이터 시작 2016-01-22 06:00:05>> 15470914
# <<7시 데이터 시작 2016-01-22 07:00:03>> 15471490
# <<8시 데이터 시작 2016-01-22 08:00:05>> 15472051
# <<9시 데이터 시작 2016-01-22 09:00:02>> 15472612
# <<10시 데이터 시작 2016-01-22 10:00:00>> 15473187
# <<11시 데이터 시작 2016-01-22 11:00:09>> 15473765
# <<12시 데이터 시작 2016-01-22 12:00:01>> 15474331
# <<13시 데이터 시작 2016-01-22 13:00:05>> 15474828
# <<14시 데이터 시작 2016-01-22 14:00:00>> 15475379
# <<15시 데이터 시작 2016-01-22 15:00:02>> 15475946
# <<16시 데이터 시작 2016-01-22 16:00:03>> 15476530
# <<17시 데이터 시작 2016-01-22 17:00:06>> 15477118
# <<18시 데이터 시작 2016-01-22 18:00:02>> 15477703
# <<19시 데이터 시작 2016-01-22 19:00:01>> 15478276
# <<20시 데이터 시작 2016-01-22 20:00:03>> 15478854
# <<21시 데이터 시작 2016-01-22 21:00:05>> 15479444
# <<22시 데이터 시작 2016-01-22 22:00:01>> 15480029
# <<23시 데이터 시작 2016-01-22 23:00:03>> 15480613
# *22일의 분별 최댓값 1440개 추가됨.
# 31680개의 데이터 누적, 계산된 일자 => 22
#
#
#
#
#
# <<<23일 데이터 시작 2016-01-23 00:00:03>>> 15481190
# <<0시 데이터 시작 2016-01-23 00:00:03>> 15481190
# <<1시 데이터 시작 2016-01-23 01:00:06>> 15481775
# <<2시 데이터 시작 2016-01-23 02:00:03>> 15482354
# <<3시 데이터 시작 2016-01-23 03:00:01>> 15482936
# <<4시 데이터 시작 2016-01-23 04:00:02>> 15483517
# <<5시 데이터 시작 2016-01-23 05:00:04>> 15484093
# <<6시 데이터 시작 2016-01-23 06:00:03>> 15484670
# <<7시 데이터 시작 2016-01-23 07:00:02>> 15485248
# <<8시 데이터 시작 2016-01-23 08:00:04>> 15485826
# <<9시 데이터 시작 2016-01-23 09:00:04>> 15486374
# <<10시 데이터 시작 2016-01-23 10:00:00>> 15486931
# <<11시 데이터 시작 2016-01-23 11:00:03>> 15487508
# <<12시 데이터 시작 2016-01-23 12:00:00>> 15488079
# <<13시 데이터 시작 2016-01-23 13:00:05>> 15488645
# <<14시 데이터 시작 2016-01-23 14:00:00>> 15489218
# <<15시 데이터 시작 2016-01-23 15:00:00>> 15489806
# <<16시 데이터 시작 2016-01-23 16:00:05>> 15490389
# <<17시 데이터 시작 2016-01-23 17:00:02>> 15490964
# <<18시 데이터 시작 2016-01-23 18:00:00>> 15491532
# <<19시 데이터 시작 2016-01-23 19:00:04>> 15492111
# <<20시 데이터 시작 2016-01-23 20:00:04>> 15492698
# <<21시 데이터 시작 2016-01-23 21:00:04>> 15493285
# <<22시 데이터 시작 2016-01-23 22:00:03>> 15493874
# <<23시 데이터 시작 2016-01-23 23:00:04>> 15494465
# *23일의 분별 최댓값 1440개 추가됨.
# 33120개의 데이터 누적, 계산된 일자 => 23
#
#
#
#
#
# <<<24일 데이터 시작 2016-01-24 00:00:05>>> 15495052
# <<0시 데이터 시작 2016-01-24 00:00:05>> 15495052
# <<1시 데이터 시작 2016-01-24 01:00:01>> 15495640
# <<2시 데이터 시작 2016-01-24 02:00:02>> 15496229
# <<3시 데이터 시작 2016-01-24 03:00:02>> 15496816
# <<4시 데이터 시작 2016-01-24 04:00:02>> 15497406
# <<5시 데이터 시작 2016-01-24 05:00:03>> 15497994
# <<6시 데이터 시작 2016-01-24 06:00:05>> 15498587
# <<7시 데이터 시작 2016-01-24 07:00:05>> 15499168
# <<8시 데이터 시작 2016-01-24 08:00:04>> 15499757
# <<9시 데이터 시작 2016-01-24 09:00:05>> 15500347
# <<10시 데이터 시작 2016-01-24 10:00:03>> 15500907
# <<11시 데이터 시작 2016-01-24 11:00:04>> 15501461
# <<12시 데이터 시작 2016-01-24 12:00:00>> 15502038
# <<13시 데이터 시작 2016-01-24 13:00:01>> 15502618
# <<14시 데이터 시작 2016-01-24 14:00:01>> 15503186
# <<15시 데이터 시작 2016-01-24 15:00:04>> 15503777
# <<16시 데이터 시작 2016-01-24 16:00:03>> 15504366
# <<17시 데이터 시작 2016-01-24 17:00:04>> 15504933
# <<18시 데이터 시작 2016-01-24 18:00:04>> 15505504
# <<19시 데이터 시작 2016-01-24 19:00:05>> 15506089
# <<20시 데이터 시작 2016-01-24 20:00:04>> 15506638
# <<21시 데이터 시작 2016-01-24 21:00:00>> 15507225
# <<22시 데이터 시작 2016-01-24 22:00:02>> 15507815
# <<23시 데이터 시작 2016-01-24 23:00:04>> 15508404
# *24일의 분별 최댓값 1440개 추가됨.
# 34560개의 데이터 누적, 계산된 일자 => 24
#
#
#
#
#
# <<<25일 데이터 시작 2016-01-25 00:00:02>>> 15508994
# <<0시 데이터 시작 2016-01-25 00:00:02>> 15508994
# <<1시 데이터 시작 2016-01-25 01:00:03>> 15509581
# <<2시 데이터 시작 2016-01-25 02:00:04>> 15510172
# <<3시 데이터 시작 2016-01-25 03:00:00>> 15510762
# <<4시 데이터 시작 2016-01-25 04:00:00>> 15511349
# <<5시 데이터 시작 2016-01-25 05:00:01>> 15511937
# <<6시 데이터 시작 2016-01-25 06:00:04>> 15512528
# <<7시 데이터 시작 2016-01-25 07:00:05>> 15513116
# <<8시 데이터 시작 2016-01-25 08:00:02>> 15513682
# <<9시 데이터 시작 2016-01-25 09:00:03>> 15514270
# <<10시 데이터 시작 2016-01-25 10:00:00>> 15514856
# <<11시 데이터 시작 2016-01-25 11:00:03>> 15515439
# <<12시 데이터 시작 2016-01-25 12:00:04>> 15516029
# <<13시 데이터 시작 2016-01-25 13:00:03>> 15516600
# <<14시 데이터 시작 2016-01-25 14:00:04>> 15517188
# <<15시 데이터 시작 2016-01-25 15:00:01>> 15517765
# <<16시 데이터 시작 2016-01-25 16:00:03>> 15518344
# <<17시 데이터 시작 2016-01-25 17:00:01>> 15518929
# <<18시 데이터 시작 2016-01-25 18:00:05>> 15519509
# <<19시 데이터 시작 2016-01-25 19:00:01>> 15520077
# <<20시 데이터 시작 2016-01-25 20:00:03>> 15520648
# <<21시 데이터 시작 2016-01-25 21:00:04>> 15521232
# <<22시 데이터 시작 2016-01-25 22:00:01>> 15521815
# <<23시 데이터 시작 2016-01-25 23:00:03>> 15522392
# *25일의 분별 최댓값 1440개 추가됨.
# 36000개의 데이터 누적, 계산된 일자 => 25
#
#
#
#
#
# <<<26일 데이터 시작 2016-01-26 00:00:05>>> 15522947
# <<0시 데이터 시작 2016-01-26 00:00:05>> 15522947
# <<1시 데이터 시작 2016-01-26 01:00:03>> 15523531
# <<2시 데이터 시작 2016-01-26 02:00:03>> 15524119
# <<3시 데이터 시작 2016-01-26 03:00:04>> 15524711
# <<4시 데이터 시작 2016-01-26 04:00:02>> 15525298
# <<5시 데이터 시작 2016-01-26 05:00:02>> 15525884
# <<6시 데이터 시작 2016-01-26 06:00:02>> 15526465
# <<7시 데이터 시작 2016-01-26 07:00:04>> 15527050
# <<8시 데이터 시작 2016-01-26 08:00:05>> 15527610
# <<9시 데이터 시작 2016-01-26 09:00:02>> 15528193
# <<10시 데이터 시작 2016-01-26 10:00:02>> 15528784
# <<11시 데이터 시작 2016-01-26 11:00:01>> 15529368
# <<12시 데이터 시작 2016-01-26 12:00:00>> 15529953
# <<13시 데이터 시작 2016-01-26 13:00:00>> 15530543
# <<14시 데이터 시작 2016-01-26 14:00:02>> 15531134
# <<15시 데이터 시작 2016-01-26 15:00:02>> 15531726
# <<16시 데이터 시작 2016-01-26 16:00:02>> 15532318
# <<17시 데이터 시작 2016-01-26 17:00:05>> 15532899
# <<18시 데이터 시작 2016-01-26 18:00:05>> 15533491
# <<19시 데이터 시작 2016-01-26 19:00:00>> 15534077
# <<20시 데이터 시작 2016-01-26 20:00:00>> 15534669
# <<21시 데이터 시작 2016-01-26 21:00:04>> 15535261
# <<22시 데이터 시작 2016-01-26 22:00:05>> 15535840
# <<23시 데이터 시작 2016-01-26 23:00:01>> 15536425
# *26일의 분별 최댓값 1440개 추가됨.
# 37440개의 데이터 누적, 계산된 일자 => 26
#
#
#
#
#
# <<<27일 데이터 시작 2016-01-27 00:00:05>>> 15537010
# <<0시 데이터 시작 2016-01-27 00:00:05>> 15537010
# <<1시 데이터 시작 2016-01-27 01:00:02>> 15537596
# <<2시 데이터 시작 2016-01-27 02:00:00>> 15538185
# <<3시 데이터 시작 2016-01-27 03:00:03>> 15538774
# <<4시 데이터 시작 2016-01-27 04:00:00>> 15539363
# <<5시 데이터 시작 2016-01-27 05:00:05>> 15539950
# <<6시 데이터 시작 2016-01-27 06:00:02>> 15540534
# <<7시 데이터 시작 2016-01-27 07:00:04>> 15541124
# <<8시 데이터 시작 2016-01-27 08:00:00>> 15541702
# <<9시 데이터 시작 2016-01-27 09:00:05>> 15542278
# <<10시 데이터 시작 2016-01-27 10:00:03>> 15542863
# <<11시 데이터 시작 2016-01-27 11:00:01>> 15543426
# <<12시 데이터 시작 2016-01-27 12:00:01>> 15544001
# <<13시 데이터 시작 2016-01-27 13:00:01>> 15544572
# <<14시 데이터 시작 2016-01-27 14:00:05>> 15545161
# <<15시 데이터 시작 2016-01-27 15:00:00>> 15545750
# <<16시 데이터 시작 2016-01-27 16:00:04>> 15546342
# <<17시 데이터 시작 2016-01-27 17:00:00>> 15546913
# <<18시 데이터 시작 2016-01-27 18:00:00>> 15547496
# <<19시 데이터 시작 2016-01-27 19:00:05>> 15548075
# <<20시 데이터 시작 2016-01-27 20:00:01>> 15548665
# <<21시 데이터 시작 2016-01-27 21:00:04>> 15549246
# <<22시 데이터 시작 2016-01-27 22:00:02>> 15549830
# <<23시 데이터 시작 2016-01-27 23:00:03>> 15550397
# *27일의 분별 최댓값 1440개 추가됨.
# 38880개의 데이터 누적, 계산된 일자 => 27
#
#
#
#
#
# <<<28일 데이터 시작 2016-01-28 00:00:00>>> 15550967
# <<0시 데이터 시작 2016-01-28 00:00:00>> 15550967
# <<1시 데이터 시작 2016-01-28 01:00:04>> 15551552
# <<2시 데이터 시작 2016-01-28 02:00:05>> 15552131
# <<3시 데이터 시작 2016-01-28 03:00:02>> 15552719
# <<4시 데이터 시작 2016-01-28 04:00:05>> 15553308
# <<5시 데이터 시작 2016-01-28 05:00:04>> 15553895
# <<6시 데이터 시작 2016-01-28 06:00:03>> 15554484
# <<7시 데이터 시작 2016-01-28 07:00:04>> 15555075
# <<8시 데이터 시작 2016-01-28 08:00:02>> 15555647
# <<9시 데이터 시작 2016-01-28 09:00:01>> 15556227
# <<10시 데이터 시작 2016-01-28 10:00:04>> 15556818
# <<11시 데이터 시작 2016-01-28 11:00:06>> 15557399
# <<12시 데이터 시작 2016-01-28 12:00:04>> 15557977
# <<13시 데이터 시작 2016-01-28 13:00:01>> 15558566
# <<14시 데이터 시작 2016-01-28 14:00:03>> 15559156
# <<15시 데이터 시작 2016-01-28 15:00:03>> 15559733
# <<16시 데이터 시작 2016-01-28 16:00:05>> 15560322
# <<17시 데이터 시작 2016-01-28 17:00:01>> 15560910
# <<18시 데이터 시작 2016-01-28 18:00:05>> 15561491
# <<19시 데이터 시작 2016-01-28 19:00:05>> 15562078
# <<20시 데이터 시작 2016-01-28 20:00:00>> 15562659
# <<21시 데이터 시작 2016-01-28 21:00:00>> 15563245
# <<22시 데이터 시작 2016-01-28 22:00:02>> 15563836
# <<23시 데이터 시작 2016-01-28 23:00:03>> 15564425
# *28일의 분별 최댓값 1440개 추가됨.
# 40320개의 데이터 누적, 계산된 일자 => 28
#
#
#
#
#
# <<<29일 데이터 시작 2016-01-29 00:00:04>>> 15565015
# <<0시 데이터 시작 2016-01-29 00:00:04>> 15565015
# <<1시 데이터 시작 2016-01-29 01:00:03>> 15565602
# <<2시 데이터 시작 2016-01-29 02:00:05>> 15566194
# <<3시 데이터 시작 2016-01-29 03:00:04>> 15566779
# <<4시 데이터 시작 2016-01-29 04:00:01>> 15567367
# <<5시 데이터 시작 2016-01-29 05:00:01>> 15567951
# <<6시 데이터 시작 2016-01-29 06:00:03>> 15568539
# <<7시 데이터 시작 2016-01-29 07:00:05>> 15569127
# <<8시 데이터 시작 2016-01-29 08:00:03>> 15569700
# <<9시 데이터 시작 2016-01-29 09:00:02>> 15570285
# <<10시 데이터 시작 2016-01-29 10:00:01>> 15570854
# <<11시 데이터 시작 2016-01-29 11:00:02>> 15571445
# <<12시 데이터 시작 2016-01-29 12:00:05>> 15572022
# <<13시 데이터 시작 2016-01-29 13:00:04>> 15572588
# <<14시 데이터 시작 2016-01-29 14:00:05>> 15573178
# <<15시 데이터 시작 2016-01-29 15:00:02>> 15573766
# <<16시 데이터 시작 2016-01-29 16:00:04>> 15574356
# <<17시 데이터 시작 2016-01-29 17:00:02>> 15574944
# <<18시 데이터 시작 2016-01-29 18:00:00>> 15575532
# <<19시 데이터 시작 2016-01-29 19:00:04>> 15576113
# <<20시 데이터 시작 2016-01-29 20:00:01>> 15576694
# <<21시 데이터 시작 2016-01-29 21:00:06>> 15577284
# <<22시 데이터 시작 2016-01-29 22:00:00>> 15577870
# <<23시 데이터 시작 2016-01-29 23:00:04>> 15578456
# *29일의 분별 최댓값 1440개 추가됨.
# 41760개의 데이터 누적, 계산된 일자 => 29
#
#
#
#
#
# <<<30일 데이터 시작 2016-01-30 00:00:00>>> 15579042
# <<0시 데이터 시작 2016-01-30 00:00:00>> 15579042
# <<1시 데이터 시작 2016-01-30 01:00:05>> 15579629
# <<2시 데이터 시작 2016-01-30 02:00:00>> 15580216
# <<3시 데이터 시작 2016-01-30 03:00:01>> 15580805
# <<4시 데이터 시작 2016-01-30 04:00:03>> 15581394
# <<5시 데이터 시작 2016-01-30 05:00:04>> 15581981
# <<6시 데이터 시작 2016-01-30 06:00:03>> 15582567
# <<7시 데이터 시작 2016-01-30 07:00:00>> 15583154
# <<8시 데이터 시작 2016-01-30 08:00:04>> 15583743
# <<9시 데이터 시작 2016-01-30 09:00:03>> 15584325
# <<10시 데이터 시작 2016-01-30 10:00:00>> 15584886
# <<11시 데이터 시작 2016-01-30 11:00:05>> 15585457
# <<12시 데이터 시작 2016-01-30 12:00:00>> 15586042
# <<13시 데이터 시작 2016-01-30 13:00:00>> 15586632
# <<14시 데이터 시작 2016-01-30 14:00:01>> 15587223
# <<15시 데이터 시작 2016-01-30 15:00:00>> 15587807
# <<16시 데이터 시작 2016-01-30 16:00:04>> 15588392
# <<17시 데이터 시작 2016-01-30 17:00:01>> 15588983
# <<18시 데이터 시작 2016-01-30 18:00:01>> 15589567
# <<19시 데이터 시작 2016-01-30 19:00:01>> 15590152
# <<20시 데이터 시작 2016-01-30 20:00:01>> 15590736
# <<21시 데이터 시작 2016-01-30 21:00:00>> 15591328
# <<22시 데이터 시작 2016-01-30 22:00:00>> 15591914
# <<23시 데이터 시작 2016-01-30 23:00:01>> 15592497
# *30일의 분별 최댓값 1440개 추가됨.
# 43200개의 데이터 누적, 계산된 일자 => 30
#
#
#
#
#
# <<<31일 데이터 시작 2016-01-31 00:00:04>>> 15593087
# <<0시 데이터 시작 2016-01-31 00:00:04>> 15593087
# <<1시 데이터 시작 2016-01-31 01:00:01>> 15593676
# <<2시 데이터 시작 2016-01-31 02:00:04>> 15594264
# <<3시 데이터 시작 2016-01-31 03:00:05>> 15594848
# <<4시 데이터 시작 2016-01-31 04:00:05>> 15595437
# <<5시 데이터 시작 2016-01-31 05:00:03>> 15596020
# <<6시 데이터 시작 2016-01-31 06:00:02>> 15596604
# <<7시 데이터 시작 2016-01-31 07:00:02>> 15597184
# <<8시 데이터 시작 2016-01-31 08:00:00>> 15597766
# <<9시 데이터 시작 2016-01-31 09:00:01>> 15598332
# <<10시 데이터 시작 2016-01-31 10:00:05>> 15598901
# <<11시 데이터 시작 2016-01-31 11:00:00>> 15599483
# <<12시 데이터 시작 2016-01-31 12:00:01>> 15600063
# <<13시 데이터 시작 2016-01-31 13:00:03>> 15600635
# <<14시 데이터 시작 2016-01-31 14:00:05>> 15601210
# <<15시 데이터 시작 2016-01-31 15:00:02>> 15601792
# <<16시 데이터 시작 2016-01-31 16:00:06>> 15602379
# <<17시 데이터 시작 2016-01-31 17:00:00>> 15602958
# <<18시 데이터 시작 2016-01-31 18:00:00>> 15603542
# <<19시 데이터 시작 2016-01-31 19:00:05>> 15604134
# <<20시 데이터 시작 2016-01-31 20:00:01>> 15604721
# <<21시 데이터 시작 2016-01-31 21:00:01>> 15605311
# <<22시 데이터 시작 2016-01-31 22:00:03>> 15605898
# <<23시 데이터 시작 2016-01-31 23:00:00>> 15606474
# *31일의 분별 최댓값 1440개 추가됨.
# 44640개의 데이터 누적, 계산된 일자 => 31
#
#
#
#
#
# 1월의 31일분 전체 데이터 44640개 CSV 파일 저장 완료
#
#
#
#
#
#
#
#
#
#
# 15607043
# 전체 과정 시작
# <<<<<2016년 데이터 시작 2016-02-01 00:00:05>>>>>
# <<<<2월 데이터 시작 2016-02-01 00:00:05>>>> 15607043
# <<<1일 데이터 시작 2016-02-01 00:00:05>>> 15607043
# <<0시 데이터 시작 2016-02-01 00:00:05>> 15607043
# <<1시 데이터 시작 2016-02-01 01:00:02>> 15607632
# <<2시 데이터 시작 2016-02-01 02:00:00>> 15608211
# <<3시 데이터 시작 2016-02-01 03:00:04>> 15608795
# <<4시 데이터 시작 2016-02-01 04:00:02>> 15609381
# <<5시 데이터 시작 2016-02-01 05:00:05>> 15609964
# <<6시 데이터 시작 2016-02-01 06:00:01>> 15610551
# <<7시 데이터 시작 2016-02-01 07:00:03>> 15611137
# <<8시 데이터 시작 2016-02-01 08:00:00>> 15611706
# <<9시 데이터 시작 2016-02-01 09:00:00>> 15612288
# <<10시 데이터 시작 2016-02-01 10:00:00>> 15612874
# <<11시 데이터 시작 2016-02-01 11:00:00>> 15613462
# <<12시 데이터 시작 2016-02-01 12:00:03>> 15614046
# <<13시 데이터 시작 2016-02-01 13:00:05>> 15614612
# <<14시 데이터 시작 2016-02-01 14:00:02>> 15615194
# <<15시 데이터 시작 2016-02-01 15:00:01>> 15615785
# <<16시 데이터 시작 2016-02-01 16:00:01>> 15616373
# <<17시 데이터 시작 2016-02-01 17:00:01>> 15616953
# <<18시 데이터 시작 2016-02-01 18:00:05>> 15617537
# <<19시 데이터 시작 2016-02-01 19:00:01>> 15618123
# <<20시 데이터 시작 2016-02-01 20:00:01>> 15618701
# <<21시 데이터 시작 2016-02-01 21:00:00>> 15619287
# <<22시 데이터 시작 2016-02-01 22:00:02>> 15619873
# <<23시 데이터 시작 2016-02-01 23:00:00>> 15620452
# *1일의 분별 최댓값 1440개 추가됨.
# 1440개의 데이터 누적, 계산된 일자 => 1
#
#
#
#
#
# <<<2일 데이터 시작 2016-02-02 00:00:01>>> 15621037
# <<0시 데이터 시작 2016-02-02 00:00:01>> 15621037
# <<1시 데이터 시작 2016-02-02 01:00:01>> 15621623
# <<2시 데이터 시작 2016-02-02 02:00:01>> 15622213
# <<3시 데이터 시작 2016-02-02 03:00:05>> 15622804
# <<4시 데이터 시작 2016-02-02 04:00:03>> 15623388
# <<5시 데이터 시작 2016-02-02 05:00:01>> 15623974
# <<6시 데이터 시작 2016-02-02 06:00:01>> 15624560
# <<7시 데이터 시작 2016-02-02 07:00:00>> 15625146
# <<8시 데이터 시작 2016-02-02 08:00:05>> 15625728
# <<9시 데이터 시작 2016-02-02 09:00:03>> 15626308
# <<10시 데이터 시작 2016-02-02 10:00:01>> 15626892
# <<11시 데이터 시작 2016-02-02 11:00:05>> 15627474
# <<12시 데이터 시작 2016-02-02 12:00:04>> 15628049
# <<13시 데이터 시작 2016-02-02 13:00:03>> 15628641
# <<14시 데이터 시작 2016-02-02 14:00:00>> 15629227
# <<15시 데이터 시작 2016-02-02 15:00:02>> 15629810
# <<16시 데이터 시작 2016-02-02 16:00:00>> 15630392
# <<17시 데이터 시작 2016-02-02 17:00:02>> 15630979
# <<18시 데이터 시작 2016-02-02 18:00:04>> 15631561
# <<19시 데이터 시작 2016-02-02 19:00:00>> 15632140
# <<20시 데이터 시작 2016-02-02 20:00:03>> 15632719
# <<21시 데이터 시작 2016-02-02 21:00:05>> 15633309
# <<22시 데이터 시작 2016-02-02 22:00:02>> 15633896
# <<23시 데이터 시작 2016-02-02 23:00:02>> 15634479
# *2일의 분별 최댓값 1440개 추가됨.
# 2880개의 데이터 누적, 계산된 일자 => 2
#
#
#
#
#
# <<<3일 데이터 시작 2016-02-03 00:00:01>>> 15635039
# <<0시 데이터 시작 2016-02-03 00:00:01>> 15635039
# <<1시 데이터 시작 2016-02-03 01:00:02>> 15635627
# <<2시 데이터 시작 2016-02-03 02:00:05>> 15636212
# <<3시 데이터 시작 2016-02-03 03:00:01>> 15636796
# <<4시 데이터 시작 2016-02-03 04:00:01>> 15637385
# <<5시 데이터 시작 2016-02-03 05:00:05>> 15637970
# <<6시 데이터 시작 2016-02-03 06:00:03>> 15638559
# <<7시 데이터 시작 2016-02-03 07:00:11>> 15639145
# <<8시 데이터 시작 2016-02-03 08:00:04>> 15639711
# <<9시 데이터 시작 2016-02-03 09:00:02>> 15640277
# <<10시 데이터 시작 2016-02-03 10:00:04>> 15640857
# <<11시 데이터 시작 2016-02-03 11:00:04>> 15641445
# <<12시 데이터 시작 2016-02-03 12:00:02>> 15642027
# <<13시 데이터 시작 2016-02-03 13:00:02>> 15642607
# <<14시 데이터 시작 2016-02-03 14:00:05>> 15643187
# <<15시 데이터 시작 2016-02-03 15:00:03>> 15643777
# <<16시 데이터 시작 2016-02-03 16:00:00>> 15644364
# <<17시 데이터 시작 2016-02-03 17:00:05>> 15644949
# <<18시 데이터 시작 2016-02-03 18:00:01>> 15645532
# <<19시 데이터 시작 2016-02-03 19:00:00>> 15646115
# <<20시 데이터 시작 2016-02-03 20:00:05>> 15646699
# <<21시 데이터 시작 2016-02-03 21:00:00>> 15647288
# <<22시 데이터 시작 2016-02-03 22:00:02>> 15647874
# <<23시 데이터 시작 2016-02-03 23:00:03>> 15648465
# *3일의 분별 최댓값 1440개 추가됨.
# 4320개의 데이터 누적, 계산된 일자 => 3
#
#
#
#
#
# <<<4일 데이터 시작 2016-02-04 00:00:02>>> 15649051
# <<0시 데이터 시작 2016-02-04 00:00:02>> 15649051
# <<1시 데이터 시작 2016-02-04 01:00:01>> 15649636
# <<2시 데이터 시작 2016-02-04 02:00:04>> 15650223
# <<3시 데이터 시작 2016-02-04 03:00:00>> 15650805
# <<4시 데이터 시작 2016-02-04 04:00:04>> 15651381
# <<5시 데이터 시작 2016-02-04 05:00:03>> 15651962
# <<6시 데이터 시작 2016-02-04 06:00:01>> 15652543
# <<7시 데이터 시작 2016-02-04 07:00:03>> 15653120
# <<8시 데이터 시작 2016-02-04 08:00:02>> 15653695
# <<9시 데이터 시작 2016-02-04 09:00:03>> 15654264
# <<10시 데이터 시작 2016-02-04 10:00:01>> 15654843
# <<11시 데이터 시작 2016-02-04 11:00:04>> 15655430
# <<12시 데이터 시작 2016-02-04 12:00:01>> 15656001
# <<13시 데이터 시작 2016-02-04 13:00:03>> 15656579
# <<14시 데이터 시작 2016-02-04 14:00:01>> 15657164
# <<15시 데이터 시작 2016-02-04 15:00:04>> 15657754
# <<16시 데이터 시작 2016-02-04 16:00:05>> 15658344
# <<17시 데이터 시작 2016-02-04 17:00:07>> 15658918
# <<18시 데이터 시작 2016-02-04 18:00:01>> 15659501
# <<19시 데이터 시작 2016-02-04 19:00:05>> 15660087
# <<20시 데이터 시작 2016-02-04 20:00:08>> 15660669
# <<21시 데이터 시작 2016-02-04 21:00:00>> 15661256
# <<22시 데이터 시작 2016-02-04 22:00:03>> 15661841
# <<23시 데이터 시작 2016-02-04 23:00:05>> 15662430
# *4일의 분별 최댓값 1440개 추가됨.
# 5760개의 데이터 누적, 계산된 일자 => 4
#
#
#
#
#
# <<<5일 데이터 시작 2016-02-05 00:00:02>>> 15663006
# <<0시 데이터 시작 2016-02-05 00:00:02>> 15663006
# <<1시 데이터 시작 2016-02-05 01:00:03>> 15663580
# <<2시 데이터 시작 2016-02-05 02:00:05>> 15664170
# <<3시 데이터 시작 2016-02-05 03:00:01>> 15664757
# <<4시 데이터 시작 2016-02-05 04:00:01>> 15665347
# <<5시 데이터 시작 2016-02-05 05:00:02>> 15665934
# <<6시 데이터 시작 2016-02-05 06:00:01>> 15666520
# <<7시 데이터 시작 2016-02-05 07:00:05>> 15667111
# <<8시 데이터 시작 2016-02-05 08:00:03>> 15667681
# <<9시 데이터 시작 2016-02-05 09:00:01>> 15668255
# <<10시 데이터 시작 2016-02-05 10:00:01>> 15668838
# <<11시 데이터 시작 2016-02-05 11:00:02>> 15669425
# <<12시 데이터 시작 2016-02-05 12:00:04>> 15670016
# <<13시 데이터 시작 2016-02-05 13:00:00>> 15670601
# <<14시 데이터 시작 2016-02-05 14:00:05>> 15671187
# <<15시 데이터 시작 2016-02-05 15:00:05>> 15671776
# <<16시 데이터 시작 2016-02-05 16:00:01>> 15672358
# <<17시 데이터 시작 2016-02-05 17:00:00>> 15672941
# <<18시 데이터 시작 2016-02-05 18:00:04>> 15673520
# <<19시 데이터 시작 2016-02-05 19:00:01>> 15674093
# <<20시 데이터 시작 2016-02-05 20:00:00>> 15674686
# <<21시 데이터 시작 2016-02-05 21:00:02>> 15675276
# <<22시 데이터 시작 2016-02-05 22:00:03>> 15675864
# <<23시 데이터 시작 2016-02-05 23:00:05>> 15676450
# *5일의 분별 최댓값 1440개 추가됨.
# 7200개의 데이터 누적, 계산된 일자 => 5
#
#
#
#
#
# <<<6일 데이터 시작 2016-02-06 00:00:05>>> 15677042
# <<0시 데이터 시작 2016-02-06 00:00:05>> 15677042
# <<1시 데이터 시작 2016-02-06 01:00:03>> 15677632
# <<2시 데이터 시작 2016-02-06 02:00:04>> 15678224
# <<3시 데이터 시작 2016-02-06 03:00:00>> 15678810
# <<4시 데이터 시작 2016-02-06 04:00:01>> 15679396
# <<5시 데이터 시작 2016-02-06 05:00:03>> 15679985
# <<6시 데이터 시작 2016-02-06 06:00:01>> 15680575
# <<7시 데이터 시작 2016-02-06 07:00:03>> 15681156
# <<8시 데이터 시작 2016-02-06 08:00:03>> 15681744
# <<9시 데이터 시작 2016-02-06 09:00:05>> 15682318
# <<10시 데이터 시작 2016-02-06 10:00:01>> 15682897
# <<11시 데이터 시작 2016-02-06 11:00:01>> 15683488
# <<12시 데이터 시작 2016-02-06 12:00:00>> 15684062
# <<13시 데이터 시작 2016-02-06 13:00:02>> 15684630
# <<14시 데이터 시작 2016-02-06 14:00:01>> 15685215
# <<15시 데이터 시작 2016-02-06 15:00:05>> 15685799
# <<16시 데이터 시작 2016-02-06 16:00:05>> 15686375
# <<17시 데이터 시작 2016-02-06 17:00:03>> 15686960
# <<18시 데이터 시작 2016-02-06 18:00:05>> 15687546
# <<19시 데이터 시작 2016-02-06 19:00:04>> 15688133
# <<20시 데이터 시작 2016-02-06 20:00:02>> 15688712
# <<21시 데이터 시작 2016-02-06 21:00:01>> 15689298
# <<22시 데이터 시작 2016-02-06 22:00:05>> 15689886
# <<23시 데이터 시작 2016-02-06 23:00:00>> 15690473
# *6일의 분별 최댓값 1440개 추가됨.
# 8640개의 데이터 누적, 계산된 일자 => 6
#
#
#
#
#
# <<<7일 데이터 시작 2016-02-07 00:00:05>>> 15691065
# <<0시 데이터 시작 2016-02-07 00:00:05>> 15691065
# <<1시 데이터 시작 2016-02-07 01:00:02>> 15691651
# <<2시 데이터 시작 2016-02-07 02:00:05>> 15692240
# <<3시 데이터 시작 2016-02-07 03:00:03>> 15692830
# <<4시 데이터 시작 2016-02-07 04:00:05>> 15693421
# <<5시 데이터 시작 2016-02-07 05:00:05>> 15694009
# <<6시 데이터 시작 2016-02-07 06:00:00>> 15694599
# <<7시 데이터 시작 2016-02-07 07:00:04>> 15695188
# <<8시 데이터 시작 2016-02-07 08:00:04>> 15695777
# <<9시 데이터 시작 2016-02-07 09:00:05>> 15696342
# <<10시 데이터 시작 2016-02-07 10:00:04>> 15696924
# <<11시 데이터 시작 2016-02-07 11:00:02>> 15697516
# <<12시 데이터 시작 2016-02-07 12:00:02>> 15698083
# <<13시 데이터 시작 2016-02-07 13:00:05>> 15698652
# <<14시 데이터 시작 2016-02-07 14:00:04>> 15699236
# <<15시 데이터 시작 2016-02-07 15:00:00>> 15699823
# <<16시 데이터 시작 2016-02-07 16:00:00>> 15700404
# <<17시 데이터 시작 2016-02-07 17:00:01>> 15700994
# <<18시 데이터 시작 2016-02-07 18:00:05>> 15701584
# <<19시 데이터 시작 2016-02-07 19:00:03>> 15702161
# <<20시 데이터 시작 2016-02-07 20:00:05>> 15702742
# <<21시 데이터 시작 2016-02-07 21:00:00>> 15703328
# <<22시 데이터 시작 2016-02-07 22:00:05>> 15703918
# <<23시 데이터 시작 2016-02-07 23:00:02>> 15704508
# *7일의 분별 최댓값 1440개 추가됨.
# 10080개의 데이터 누적, 계산된 일자 => 7
#
#
#
#
#
# <<<8일 데이터 시작 2016-02-08 00:00:05>>> 15705095
# <<0시 데이터 시작 2016-02-08 00:00:05>> 15705095
# <<1시 데이터 시작 2016-02-08 01:00:04>> 15705680
# <<2시 데이터 시작 2016-02-08 02:00:02>> 15706268
# <<3시 데이터 시작 2016-02-08 03:00:03>> 15706858
# <<4시 데이터 시작 2016-02-08 04:00:05>> 15707439
# <<5시 데이터 시작 2016-02-08 05:00:04>> 15708028
# <<6시 데이터 시작 2016-02-08 06:00:03>> 15708614
# <<7시 데이터 시작 2016-02-08 07:00:01>> 15709199
# <<8시 데이터 시작 2016-02-08 08:00:04>> 15709788
# <<9시 데이터 시작 2016-02-08 09:00:03>> 15710370
# <<10시 데이터 시작 2016-02-08 10:00:01>> 15710962
# <<11시 데이터 시작 2016-02-08 11:00:03>> 15711536
# <<12시 데이터 시작 2016-02-08 12:00:03>> 15712089
# <<13시 데이터 시작 2016-02-08 13:00:00>> 15712679
# <<14시 데이터 시작 2016-02-08 14:00:00>> 15713253
# <<15시 데이터 시작 2016-02-08 15:00:00>> 15713821
# <<16시 데이터 시작 2016-02-08 16:00:03>> 15714391
# <<17시 데이터 시작 2016-02-08 17:00:00>> 15714973
# <<18시 데이터 시작 2016-02-08 18:00:01>> 15715553
# <<19시 데이터 시작 2016-02-08 19:00:04>> 15716134
# <<20시 데이터 시작 2016-02-08 20:00:02>> 15716720
# <<21시 데이터 시작 2016-02-08 21:00:01>> 15717300
# <<22시 데이터 시작 2016-02-08 22:00:01>> 15717888
# <<23시 데이터 시작 2016-02-08 23:00:04>> 15718477
# *8일의 분별 최댓값 1440개 추가됨.
# 11520개의 데이터 누적, 계산된 일자 => 8
#
#
#
#
#
# <<<9일 데이터 시작 2016-02-09 00:00:00>>> 15719063
# <<0시 데이터 시작 2016-02-09 00:00:00>> 15719063
# <<1시 데이터 시작 2016-02-09 01:00:03>> 15719651
# <<2시 데이터 시작 2016-02-09 02:00:00>> 15720240
# <<3시 데이터 시작 2016-02-09 03:00:02>> 15720831
# <<4시 데이터 시작 2016-02-09 04:00:05>> 15721419
# <<5시 데이터 시작 2016-02-09 05:00:04>> 15722010
# <<6시 데이터 시작 2016-02-09 06:00:03>> 15722594
# <<7시 데이터 시작 2016-02-09 07:00:00>> 15723179
# <<8시 데이터 시작 2016-02-09 08:00:02>> 15723732
# <<9시 데이터 시작 2016-02-09 09:00:04>> 15724315
# <<10시 데이터 시작 2016-02-09 10:00:05>> 15724902
# <<11시 데이터 시작 2016-02-09 11:00:05>> 15725481
# <<12시 데이터 시작 2016-02-09 12:00:12>> 15726057
# <<13시 데이터 시작 2016-02-09 13:00:01>> 15726639
# <<14시 데이터 시작 2016-02-09 14:00:00>> 15727208
# <<15시 데이터 시작 2016-02-09 15:00:00>> 15727796
# <<16시 데이터 시작 2016-02-09 16:00:02>> 15728378
# <<17시 데이터 시작 2016-02-09 17:00:03>> 15728958
# <<18시 데이터 시작 2016-02-09 18:00:04>> 15729531
# <<19시 데이터 시작 2016-02-09 19:00:03>> 15730110
# <<20시 데이터 시작 2016-02-09 20:00:03>> 15730702
# <<21시 데이터 시작 2016-02-09 21:00:01>> 15731284
# <<22시 데이터 시작 2016-02-09 22:00:00>> 15731872
# <<23시 데이터 시작 2016-02-09 23:00:05>> 15732462
# *9일의 분별 최댓값 1440개 추가됨.
# 12960개의 데이터 누적, 계산된 일자 => 9
#
#
#
#
#
# <<<10일 데이터 시작 2016-02-10 00:00:00>>> 15733031
# <<0시 데이터 시작 2016-02-10 00:00:00>> 15733031
# <<1시 데이터 시작 2016-02-10 01:00:02>> 15733604
# <<2시 데이터 시작 2016-02-10 02:00:00>> 15734192
# <<3시 데이터 시작 2016-02-10 03:00:04>> 15734783
# <<4시 데이터 시작 2016-02-10 04:00:03>> 15735371
# <<5시 데이터 시작 2016-02-10 05:00:03>> 15735950
# <<6시 데이터 시작 2016-02-10 06:00:05>> 15736533
# <<7시 데이터 시작 2016-02-10 07:00:05>> 15737112
# <<8시 데이터 시작 2016-02-10 08:00:03>> 15737677
# <<9시 데이터 시작 2016-02-10 09:00:02>> 15738254
# <<10시 데이터 시작 2016-02-10 10:00:01>> 15738831
# <<11시 데이터 시작 2016-02-10 11:00:00>> 15739413
# <<12시 데이터 시작 2016-02-10 12:00:04>> 15740003
# <<13시 데이터 시작 2016-02-10 13:00:02>> 15740575
# <<14시 데이터 시작 2016-02-10 14:00:05>> 15741164
# <<15시 데이터 시작 2016-02-10 15:00:04>> 15741753
# <<16시 데이터 시작 2016-02-10 16:00:03>> 15742335
# <<17시 데이터 시작 2016-02-10 17:00:01>> 15742924
# <<18시 데이터 시작 2016-02-10 18:00:05>> 15743507
# <<19시 데이터 시작 2016-02-10 19:00:01>> 15744076
# <<20시 데이터 시작 2016-02-10 20:00:04>> 15744663
# <<21시 데이터 시작 2016-02-10 21:00:11>> 15745244
# <<22시 데이터 시작 2016-02-10 22:00:02>> 15745825
# <<23시 데이터 시작 2016-02-10 23:00:05>> 15746415
# *10일의 분별 최댓값 1440개 추가됨.
# 14400개의 데이터 누적, 계산된 일자 => 10
#
#
#
#
#
# <<<11일 데이터 시작 2016-02-11 00:00:09>>> 15747002
# <<0시 데이터 시작 2016-02-11 00:00:09>> 15747002
# <<1시 데이터 시작 2016-02-11 01:00:05>> 15747591
# <<2시 데이터 시작 2016-02-11 02:00:01>> 15748174
# <<3시 데이터 시작 2016-02-11 03:00:01>> 15748756
# <<4시 데이터 시작 2016-02-11 04:00:03>> 15749332
# <<5시 데이터 시작 2016-02-11 05:00:03>> 15749907
# <<6시 데이터 시작 2016-02-11 06:00:05>> 15750486
# <<7시 데이터 시작 2016-02-11 07:00:11>> 15751065
# ...
# <<2시 데이터 시작 2016-06-17 02:00:03>> 17518126
# <<3시 데이터 시작 2016-06-17 03:00:01>> 17518714
# <<4시 데이터 시작 2016-06-17 04:00:00>> 17519298
# <<5시 데이터 시작 2016-06-17 05:00:04>> 17519879
# <<6시 데이터 시작 2016-06-17 06:00:03>> 17520457
# <<7시 데이터 시작 2016-06-17 07:00:01>> 17521026
# <<8시 데이터 시작 2016-06-17 08:00:01>> 17521604
# <<9시 데이터 시작 2016-06-17 09:00:03>> 17522180
# <<10시 데이터 시작 2016-06-17 10:00:05>> 17522755
# <<11시 데이터 시작 2016-06-17 11:00:05>> 17523333
# <<12시 데이터 시작 2016-06-17 12:00:02>> 17523913
# <<13시 데이터 시작 2016-06-17 13:00:00>> 17524494
# <<14시 데이터 시작 2016-06-17 14:00:04>> 17525068
# <<15시 데이터 시작 2016-06-17 15:00:01>> 17525649
# <<16시 데이터 시작 2016-06-17 16:00:02>> 17526233
# <<17시 데이터 시작 2016-06-17 17:00:03>> 17526813
# <<18시 데이터 시작 2016-06-17 18:00:04>> 17527376
# <<19시 데이터 시작 2016-06-17 19:00:02>> 17527956
# <<20시 데이터 시작 2016-06-17 20:00:00>> 17528521
# <<21시 데이터 시작 2016-06-17 21:00:02>> 17529099
# <<22시 데이터 시작 2016-06-17 22:00:04>> 17529677
# <<23시 데이터 시작 2016-06-17 23:00:00>> 17530258
# *17일의 분별 최댓값 1440개 추가됨.
# 24480개의 데이터 누적, 계산된 일자 => 17
#
#
#
#
#
# <<<18일 데이터 시작 2016-06-18 00:00:00>>> 17530844
# <<0시 데이터 시작 2016-06-18 00:00:00>> 17530844
# <<1시 데이터 시작 2016-06-18 01:00:04>> 17531424
# <<2시 데이터 시작 2016-06-18 02:00:01>> 17532007
# <<3시 데이터 시작 2016-06-18 03:00:02>> 17532594
# <<4시 데이터 시작 2016-06-18 04:00:03>> 17533181
# <<5시 데이터 시작 2016-06-18 05:00:00>> 17533767
# <<6시 데이터 시작 2016-06-18 06:00:05>> 17534358
# <<7시 데이터 시작 2016-06-18 07:00:03>> 17534939
# <<8시 데이터 시작 2016-06-18 08:00:01>> 17535499
# <<9시 데이터 시작 2016-06-18 09:00:03>> 17536077
# <<10시 데이터 시작 2016-06-18 10:00:01>> 17536654
# <<11시 데이터 시작 2016-06-18 11:00:03>> 17537233
# <<12시 데이터 시작 2016-06-18 12:00:00>> 17537813
# <<13시 데이터 시작 2016-06-18 13:00:04>> 17538404
# <<14시 데이터 시작 2016-06-18 14:00:03>> 17538989
# <<15시 데이터 시작 2016-06-18 15:00:01>> 17539577
# <<16시 데이터 시작 2016-06-18 16:00:01>> 17540164
# <<17시 데이터 시작 2016-06-18 17:00:02>> 17540743
# <<18시 데이터 시작 2016-06-18 18:00:05>> 17541325
# <<19시 데이터 시작 2016-06-18 19:00:04>> 17541908
# <<20시 데이터 시작 2016-06-18 20:00:01>> 17542488
# <<21시 데이터 시작 2016-06-18 21:00:04>> 17543075
# <<22시 데이터 시작 2016-06-18 22:00:04>> 17543652
# <<23시 데이터 시작 2016-06-18 23:00:05>> 17544219
# *18일의 분별 최댓값 1440개 추가됨.
# 25920개의 데이터 누적, 계산된 일자 => 18
#
#
#
#
#
# <<<19일 데이터 시작 2016-06-19 00:00:01>>> 17544806
# <<0시 데이터 시작 2016-06-19 00:00:01>> 17544806
# <<1시 데이터 시작 2016-06-19 01:00:03>> 17545391
# <<2시 데이터 시작 2016-06-19 02:00:03>> 17545980
# <<3시 데이터 시작 2016-06-19 03:00:05>> 17546572
# <<4시 데이터 시작 2016-06-19 04:00:01>> 17547161
# <<5시 데이터 시작 2016-06-19 05:00:01>> 17547745
# <<6시 데이터 시작 2016-06-19 06:00:03>> 17548329
# <<7시 데이터 시작 2016-06-19 07:00:04>> 17548897
# <<8시 데이터 시작 2016-06-19 08:00:04>> 17549480
# <<9시 데이터 시작 2016-06-19 09:00:04>> 17550055
# <<10시 데이터 시작 2016-06-19 10:00:05>> 17550635
# <<11시 데이터 시작 2016-06-19 11:00:01>> 17551216
# <<12시 데이터 시작 2016-06-19 12:00:10>> 17551789
# <<13시 데이터 시작 2016-06-19 13:00:02>> 17552363
# <<14시 데이터 시작 2016-06-19 14:00:04>> 17552941
# <<15시 데이터 시작 2016-06-19 15:00:05>> 17553526
# <<16시 데이터 시작 2016-06-19 16:00:05>> 17554109
# <<17시 데이터 시작 2016-06-19 17:00:03>> 17554674
# <<18시 데이터 시작 2016-06-19 18:00:00>> 17555248
# <<19시 데이터 시작 2016-06-19 19:00:02>> 17555831
# <<20시 데이터 시작 2016-06-19 20:00:00>> 17556417
# <<21시 데이터 시작 2016-06-19 21:00:03>> 17557002
# <<22시 데이터 시작 2016-06-19 22:00:02>> 17557584
# <<23시 데이터 시작 2016-06-19 23:00:05>> 17558166
# *19일의 분별 최댓값 1440개 추가됨.
# 27360개의 데이터 누적, 계산된 일자 => 19
#
#
#
#
#
# <<<20일 데이터 시작 2016-06-20 00:00:04>>> 17558744
# <<0시 데이터 시작 2016-06-20 00:00:04>> 17558744
# <<1시 데이터 시작 2016-06-20 01:00:00>> 17559325
# <<2시 데이터 시작 2016-06-20 02:00:02>> 17559910
# <<3시 데이터 시작 2016-06-20 03:00:01>> 17560483
# <<4시 데이터 시작 2016-06-20 04:00:06>> 17561064
# <<5시 데이터 시작 2016-06-20 05:00:00>> 17561642
# <<6시 데이터 시작 2016-06-20 06:00:01>> 17562226
# <<7시 데이터 시작 2016-06-20 07:00:03>> 17562800
# <<8시 데이터 시작 2016-06-20 08:00:03>> 17563365
# <<9시 데이터 시작 2016-06-20 09:00:02>> 17563948
# <<10시 데이터 시작 2016-06-20 10:00:05>> 17564535
# <<11시 데이터 시작 2016-06-20 11:00:01>> 17565086
# <<12시 데이터 시작 2016-06-20 12:00:05>> 17565651
# <<13시 데이터 시작 2016-06-20 13:00:00>> 17566231
# <<14시 데이터 시작 2016-06-20 14:00:03>> 17566807
# <<15시 데이터 시작 2016-06-20 15:00:02>> 17567387
# <<16시 데이터 시작 2016-06-20 16:00:04>> 17567969
# <<17시 데이터 시작 2016-06-20 17:00:04>> 17568539
# <<18시 데이터 시작 2016-06-20 18:00:00>> 17569117
# <<19시 데이터 시작 2016-06-20 19:00:01>> 17569689
# <<20시 데이터 시작 2016-06-20 20:00:04>> 17570273
# <<21시 데이터 시작 2016-06-20 21:00:03>> 17570858
# <<22시 데이터 시작 2016-06-20 22:00:03>> 17571441
# <<23시 데이터 시작 2016-06-20 23:00:03>> 17572012
# *20일의 분별 최댓값 1440개 추가됨.
# 28800개의 데이터 누적, 계산된 일자 => 20
#
#
#
#
#
# <<<21일 데이터 시작 2016-06-21 00:00:00>>> 17572597
# <<0시 데이터 시작 2016-06-21 00:00:00>> 17572597
# <<1시 데이터 시작 2016-06-21 01:00:00>> 17573183
# <<2시 데이터 시작 2016-06-21 02:00:01>> 17573769
# <<3시 데이터 시작 2016-06-21 03:00:02>> 17574346
# <<4시 데이터 시작 2016-06-21 04:00:00>> 17574933
# <<5시 데이터 시작 2016-06-21 05:00:05>> 17575519
# <<6시 데이터 시작 2016-06-21 06:00:04>> 17576100
# <<7시 데이터 시작 2016-06-21 07:00:04>> 17576657
# <<8시 데이터 시작 2016-06-21 08:00:03>> 17577237
# <<9시 데이터 시작 2016-06-21 09:00:03>> 17577821
# <<10시 데이터 시작 2016-06-21 10:00:00>> 17578411
# <<11시 데이터 시작 2016-06-21 11:00:03>> 17579001
# <<12시 데이터 시작 2016-06-21 12:00:04>> 17579592
# <<13시 데이터 시작 2016-06-21 13:00:03>> 17580183
# <<14시 데이터 시작 2016-06-21 14:00:01>> 17580768
# <<15시 데이터 시작 2016-06-21 15:00:02>> 17581311
# <<16시 데이터 시작 2016-06-21 16:00:00>> 17581895
# <<17시 데이터 시작 2016-06-21 17:00:01>> 17582485
# <<18시 데이터 시작 2016-06-21 18:00:01>> 17583074
# <<19시 데이터 시작 2016-06-21 19:00:02>> 17583652
# <<20시 데이터 시작 2016-06-21 20:00:02>> 17584240
# <<21시 데이터 시작 2016-06-21 21:00:00>> 17584828
# <<22시 데이터 시작 2016-06-21 22:00:03>> 17585418
# <<23시 데이터 시작 2016-06-21 23:00:01>> 17586006
# *21일의 분별 최댓값 1440개 추가됨.
# 30240개의 데이터 누적, 계산된 일자 => 21
#
#
#
#
#
# <<<22일 데이터 시작 2016-06-22 00:00:05>>> 17586594
# <<0시 데이터 시작 2016-06-22 00:00:05>> 17586594
# <<1시 데이터 시작 2016-06-22 01:00:03>> 17587183
# <<2시 데이터 시작 2016-06-22 02:00:02>> 17587773
# <<3시 데이터 시작 2016-06-22 03:00:00>> 17588355
# <<4시 데이터 시작 2016-06-22 04:00:04>> 17588944
# <<5시 데이터 시작 2016-06-22 05:00:02>> 17589532
# <<6시 데이터 시작 2016-06-22 06:00:04>> 17590116
# <<7시 데이터 시작 2016-06-22 07:00:02>> 17590686
# <<8시 데이터 시작 2016-06-22 08:00:02>> 17591264
# <<9시 데이터 시작 2016-06-22 09:00:02>> 17591852
# <<10시 데이터 시작 2016-06-22 10:00:02>> 17592438
# <<11시 데이터 시작 2016-06-22 11:00:05>> 17593010
# <<12시 데이터 시작 2016-06-22 12:00:00>> 17593589
# <<13시 데이터 시작 2016-06-22 13:00:00>> 17594154
# <<14시 데이터 시작 2016-06-22 14:00:03>> 17594744
# <<15시 데이터 시작 2016-06-22 15:00:00>> 17595333
# <<16시 데이터 시작 2016-06-22 16:00:06>> 17595914
# <<17시 데이터 시작 2016-06-22 17:00:04>> 17596496
# <<18시 데이터 시작 2016-06-22 18:00:01>> 17597085
# <<19시 데이터 시작 2016-06-22 19:00:01>> 17597658
# <<20시 데이터 시작 2016-06-22 20:00:01>> 17598244
# <<21시 데이터 시작 2016-06-22 21:00:05>> 17598835
# <<22시 데이터 시작 2016-06-22 22:00:04>> 17599422
# <<23시 데이터 시작 2016-06-22 23:00:02>> 17599982
# *22일의 분별 최댓값 1440개 추가됨.
# 31680개의 데이터 누적, 계산된 일자 => 22
#
#
#
#
#
# <<<23일 데이터 시작 2016-06-23 00:00:01>>> 17600566
# <<0시 데이터 시작 2016-06-23 00:00:01>> 17600566
# <<1시 데이터 시작 2016-06-23 01:00:01>> 17601157
# <<2시 데이터 시작 2016-06-23 02:00:02>> 17601745
# <<3시 데이터 시작 2016-06-23 03:00:02>> 17602335
# <<4시 데이터 시작 2016-06-23 04:00:03>> 17602926
# <<5시 데이터 시작 2016-06-23 05:00:04>> 17603517
# <<6시 데이터 시작 2016-06-23 06:00:00>> 17604107
# <<7시 데이터 시작 2016-06-23 07:00:01>> 17604687
# <<8시 데이터 시작 2016-06-23 08:00:05>> 17605268
# <<9시 데이터 시작 2016-06-23 09:00:05>> 17605857
# <<10시 데이터 시작 2016-06-23 10:00:05>> 17606448
# <<11시 데이터 시작 2016-06-23 11:00:04>> 17607039
# <<12시 데이터 시작 2016-06-23 12:00:02>> 17607630
# <<13시 데이터 시작 2016-06-23 13:00:00>> 17608221
# <<14시 데이터 시작 2016-06-23 14:00:04>> 17608813
# <<15시 데이터 시작 2016-06-23 15:00:01>> 17609403
# <<16시 데이터 시작 2016-06-23 16:00:05>> 17609995
# <<17시 데이터 시작 2016-06-23 17:00:03>> 17610581
# <<18시 데이터 시작 2016-06-23 18:00:00>> 17611171
# <<19시 데이터 시작 2016-06-23 19:00:03>> 17611763
# <<20시 데이터 시작 2016-06-23 20:00:00>> 17612354
# <<21시 데이터 시작 2016-06-23 21:00:03>> 17612945
# <<22시 데이터 시작 2016-06-23 22:00:00>> 17613536
# <<23시 데이터 시작 2016-06-23 23:00:03>> 17614127
# *23일의 분별 최댓값 1440개 추가됨.
# 33120개의 데이터 누적, 계산된 일자 => 23
#
#
#
#
#
# <<<24일 데이터 시작 2016-06-24 00:00:01>>> 17614715
# <<0시 데이터 시작 2016-06-24 00:00:01>> 17614715
# <<1시 데이터 시작 2016-06-24 01:00:01>> 17615306
# <<2시 데이터 시작 2016-06-24 02:00:04>> 17615897
# <<3시 데이터 시작 2016-06-24 03:00:01>> 17616483
# <<4시 데이터 시작 2016-06-24 04:00:01>> 17617067
# <<5시 데이터 시작 2016-06-24 05:00:04>> 17617649
# <<6시 데이터 시작 2016-06-24 06:00:11>> 17618230
# <<7시 데이터 시작 2016-06-24 07:00:01>> 17618802
# <<8시 데이터 시작 2016-06-24 08:00:05>> 17619382
# <<9시 데이터 시작 2016-06-24 09:00:04>> 17619968
# <<10시 데이터 시작 2016-06-24 10:00:03>> 17620553
# <<11시 데이터 시작 2016-06-24 11:00:02>> 17621119
# <<12시 데이터 시작 2016-06-24 12:00:03>> 17621707
# <<13시 데이터 시작 2016-06-24 13:00:03>> 17622293
# <<14시 데이터 시작 2016-06-24 14:00:04>> 17622884
# <<15시 데이터 시작 2016-06-24 15:00:04>> 17623469
# <<16시 데이터 시작 2016-06-24 16:00:04>> 17624060
# <<17시 데이터 시작 2016-06-24 17:00:00>> 17624642
# <<18시 데이터 시작 2016-06-24 18:00:00>> 17625232
# <<19시 데이터 시작 2016-06-24 19:00:05>> 17625824
# <<20시 데이터 시작 2016-06-24 20:00:04>> 17626404
# <<21시 데이터 시작 2016-06-24 21:00:03>> 17626954
# <<22시 데이터 시작 2016-06-24 22:00:06>> 17627543
# <<23시 데이터 시작 2016-06-24 23:00:04>> 17628133
# *24일의 분별 최댓값 1440개 추가됨.
# 34560개의 데이터 누적, 계산된 일자 => 24
#
#
#
#
#
# <<<25일 데이터 시작 2016-06-25 00:00:00>>> 17628721
# <<0시 데이터 시작 2016-06-25 00:00:00>> 17628721
# <<1시 데이터 시작 2016-06-25 01:00:05>> 17629308
# <<2시 데이터 시작 2016-06-25 02:00:05>> 17629893
# <<3시 데이터 시작 2016-06-25 03:00:05>> 17630472
# <<4시 데이터 시작 2016-06-25 04:00:00>> 17631053
# <<5시 데이터 시작 2016-06-25 05:00:00>> 17631629
# <<6시 데이터 시작 2016-06-25 06:00:01>> 17632213
# <<7시 데이터 시작 2016-06-25 07:00:01>> 17632792
# <<8시 데이터 시작 2016-06-25 08:00:03>> 17633370
# <<9시 데이터 시작 2016-06-25 09:00:00>> 17633940
# <<10시 데이터 시작 2016-06-25 10:00:03>> 17634520
# <<11시 데이터 시작 2016-06-25 11:00:03>> 17635098
# <<12시 데이터 시작 2016-06-25 12:00:02>> 17635677
# <<13시 데이터 시작 2016-06-25 13:00:05>> 17636243
# <<14시 데이터 시작 2016-06-25 14:00:02>> 17636817
# <<15시 데이터 시작 2016-06-25 15:00:00>> 17637378
# <<16시 데이터 시작 2016-06-25 16:00:03>> 17637956
# <<17시 데이터 시작 2016-06-25 17:00:02>> 17638543
# <<18시 데이터 시작 2016-06-25 18:00:03>> 17639128
# <<19시 데이터 시작 2016-06-25 19:00:04>> 17639713
# <<20시 데이터 시작 2016-06-25 20:00:05>> 17640295
# <<21시 데이터 시작 2016-06-25 21:00:01>> 17640875
# <<22시 데이터 시작 2016-06-25 22:00:03>> 17641457
# <<23시 데이터 시작 2016-06-25 23:00:04>> 17642038
# *25일의 분별 최댓값 1440개 추가됨.
# 36000개의 데이터 누적, 계산된 일자 => 25
#
#
#
#
#
# <<<26일 데이터 시작 2016-06-26 00:00:05>>> 17642618
# <<0시 데이터 시작 2016-06-26 00:00:05>> 17642618
# <<1시 데이터 시작 2016-06-26 01:00:00>> 17643203
# <<2시 데이터 시작 2016-06-26 02:00:04>> 17643787
# <<3시 데이터 시작 2016-06-26 03:00:03>> 17644369
# <<4시 데이터 시작 2016-06-26 04:00:05>> 17644949
# <<5시 데이터 시작 2016-06-26 05:00:06>> 17645526
# <<6시 데이터 시작 2016-06-26 06:00:04>> 17646111
# <<7시 데이터 시작 2016-06-26 07:00:06>> 17646696
# <<8시 데이터 시작 2016-06-26 08:00:04>> 17647276
# <<9시 데이터 시작 2016-06-26 09:00:01>> 17647854
# <<10시 데이터 시작 2016-06-26 10:00:04>> 17648429
# <<11시 데이터 시작 2016-06-26 11:00:03>> 17649008
# <<12시 데이터 시작 2016-06-26 12:00:14>> 17649579
# <<13시 데이터 시작 2016-06-26 13:00:00>> 17650155
# <<14시 데이터 시작 2016-06-26 14:00:01>> 17650738
# <<15시 데이터 시작 2016-06-26 15:00:04>> 17651324
# <<16시 데이터 시작 2016-06-26 16:00:01>> 17651906
# <<17시 데이터 시작 2016-06-26 17:00:03>> 17652487
# <<18시 데이터 시작 2016-06-26 18:00:05>> 17653062
# <<19시 데이터 시작 2016-06-26 19:00:03>> 17653634
# <<20시 데이터 시작 2016-06-26 20:00:04>> 17654215
# <<21시 데이터 시작 2016-06-26 21:00:02>> 17654799
# <<22시 데이터 시작 2016-06-26 22:00:03>> 17655381
# <<23시 데이터 시작 2016-06-26 23:00:00>> 17655964
# *26일의 분별 최댓값 1440개 추가됨.
# 37440개의 데이터 누적, 계산된 일자 => 26
#
#
#
#
#
# <<<27일 데이터 시작 2016-06-27 00:00:03>>> 17656544
# <<0시 데이터 시작 2016-06-27 00:00:03>> 17656544
# <<1시 데이터 시작 2016-06-27 01:00:02>> 17657129
# <<2시 데이터 시작 2016-06-27 02:00:13>> 17657716
# <<3시 데이터 시작 2016-06-27 03:00:00>> 17658289
# <<4시 데이터 시작 2016-06-27 04:00:01>> 17658869
# <<5시 데이터 시작 2016-06-27 05:00:03>> 17659450
# <<6시 데이터 시작 2016-06-27 06:00:05>> 17660028
# <<7시 데이터 시작 2016-06-27 07:00:00>> 17660598
# <<8시 데이터 시작 2016-06-27 08:00:03>> 17661172
# <<9시 데이터 시작 2016-06-27 09:00:05>> 17661755
# <<10시 데이터 시작 2016-06-27 10:00:05>> 17662335
# <<11시 데이터 시작 2016-06-27 11:00:03>> 17662914
# <<12시 데이터 시작 2016-06-27 12:00:05>> 17663497
# <<13시 데이터 시작 2016-06-27 13:00:04>> 17664069
# <<14시 데이터 시작 2016-06-27 14:00:01>> 17664652
# <<15시 데이터 시작 2016-06-27 15:00:04>> 17665241
# <<16시 데이터 시작 2016-06-27 16:00:03>> 17665825
# <<17시 데이터 시작 2016-06-27 17:00:01>> 17666410
# <<18시 데이터 시작 2016-06-27 18:00:02>> 17666994
# <<19시 데이터 시작 2016-06-27 19:00:06>> 17667585
# <<20시 데이터 시작 2016-06-27 20:00:05>> 17668174
# <<21시 데이터 시작 2016-06-27 21:00:05>> 17668757
# <<22시 데이터 시작 2016-06-27 22:00:01>> 17669339
# <<23시 데이터 시작 2016-06-27 23:00:04>> 17669890
# *27일의 분별 최댓값 1440개 추가됨.
# 38880개의 데이터 누적, 계산된 일자 => 27
#
#
#
#
#
# <<<28일 데이터 시작 2016-06-28 00:00:05>>> 17670469
# <<0시 데이터 시작 2016-06-28 00:00:05>> 17670469
# <<1시 데이터 시작 2016-06-28 01:00:00>> 17671046
# <<2시 데이터 시작 2016-06-28 02:00:02>> 17671628
# <<3시 데이터 시작 2016-06-28 03:00:00>> 17672211
# <<4시 데이터 시작 2016-06-28 04:00:00>> 17672795
# <<5시 데이터 시작 2016-06-28 05:00:04>> 17673378
# <<6시 데이터 시작 2016-06-28 06:00:00>> 17673950
# <<7시 데이터 시작 2016-06-28 07:00:01>> 17674521
# <<8시 데이터 시작 2016-06-28 08:00:00>> 17675102
# <<9시 데이터 시작 2016-06-28 09:00:03>> 17675681
# <<10시 데이터 시작 2016-06-28 10:00:00>> 17676259
# <<11시 데이터 시작 2016-06-28 11:00:03>> 17676822
# <<12시 데이터 시작 2016-06-28 12:00:04>> 17677411
# <<13시 데이터 시작 2016-06-28 13:00:01>> 17677999
# <<14시 데이터 시작 2016-06-28 14:00:03>> 17678580
# <<15시 데이터 시작 2016-06-28 15:00:01>> 17679165
# <<16시 데이터 시작 2016-06-28 16:00:03>> 17679750
# <<17시 데이터 시작 2016-06-28 17:00:05>> 17680331
# <<18시 데이터 시작 2016-06-28 18:00:03>> 17680914
# <<19시 데이터 시작 2016-06-28 19:00:04>> 17681504
# <<20시 데이터 시작 2016-06-28 20:00:01>> 17682094
# <<21시 데이터 시작 2016-06-28 21:00:06>> 17682684
# <<22시 데이터 시작 2016-06-28 22:00:03>> 17683274
# <<23시 데이터 시작 2016-06-28 23:00:03>> 17683848
# *28일의 분별 최댓값 1440개 추가됨.
# 40320개의 데이터 누적, 계산된 일자 => 28
#
#
#
#
#
# <<<29일 데이터 시작 2016-06-29 00:00:01>>> 17684409
# <<0시 데이터 시작 2016-06-29 00:00:01>> 17684409
# <<1시 데이터 시작 2016-06-29 01:00:04>> 17684997
# <<2시 데이터 시작 2016-06-29 02:00:02>> 17685585
# <<3시 데이터 시작 2016-06-29 03:00:04>> 17686172
# <<4시 데이터 시작 2016-06-29 04:00:04>> 17686754
# <<5시 데이터 시작 2016-06-29 05:00:03>> 17687336
# <<6시 데이터 시작 2016-06-29 06:00:02>> 17687916
# <<7시 데이터 시작 2016-06-29 07:00:05>> 17688499
# <<8시 데이터 시작 2016-06-29 08:00:03>> 17689051
# <<9시 데이터 시작 2016-06-29 09:00:05>> 17689620
# <<10시 데이터 시작 2016-06-29 10:00:02>> 17690196
# <<11시 데이터 시작 2016-06-29 11:00:03>> 17690779
# <<12시 데이터 시작 2016-06-29 12:00:03>> 17691346
# <<13시 데이터 시작 2016-06-29 13:00:04>> 17691923
# <<14시 데이터 시작 2016-06-29 14:00:02>> 17692504
# <<15시 데이터 시작 2016-06-29 15:00:03>> 17693081
# <<16시 데이터 시작 2016-06-29 16:00:04>> 17693653
# <<17시 데이터 시작 2016-06-29 17:00:03>> 17694239
# <<18시 데이터 시작 2016-06-29 18:00:01>> 17694824
# <<19시 데이터 시작 2016-06-29 19:00:04>> 17695414
# <<20시 데이터 시작 2016-06-29 20:00:01>> 17695995
# <<21시 데이터 시작 2016-06-29 21:00:05>> 17696584
# <<22시 데이터 시작 2016-06-29 22:00:04>> 17697170
# <<23시 데이터 시작 2016-06-29 23:00:21>> 17697734
# *29일의 분별 최댓값 1440개 추가됨.
# 41760개의 데이터 누적, 계산된 일자 => 29
#
#
#
#
#
# <<<30일 데이터 시작 2016-06-30 00:00:00>>> 17698294
# <<0시 데이터 시작 2016-06-30 00:00:00>> 17698294
# <<1시 데이터 시작 2016-06-30 01:00:03>> 17698880
# <<2시 데이터 시작 2016-06-30 02:00:03>> 17699469
# <<3시 데이터 시작 2016-06-30 03:00:02>> 17700050
# <<4시 데이터 시작 2016-06-30 04:00:05>> 17700633
# <<5시 데이터 시작 2016-06-30 05:00:05>> 17701216
# <<6시 데이터 시작 2016-06-30 06:00:00>> 17701794
# <<7시 데이터 시작 2016-06-30 07:00:01>> 17702375
# <<8시 데이터 시작 2016-06-30 08:00:05>> 17702955
# <<9시 데이터 시작 2016-06-30 09:00:05>> 17703540
# <<10시 데이터 시작 2016-06-30 10:00:01>> 17704112
# <<11시 데이터 시작 2016-06-30 11:00:03>> 17704689
# <<12시 데이터 시작 2016-06-30 12:00:00>> 17705266
# <<13시 데이터 시작 2016-06-30 13:00:05>> 17705852
# <<14시 데이터 시작 2016-06-30 14:00:05>> 17706436
# <<15시 데이터 시작 2016-06-30 15:00:00>> 17707018
# <<16시 데이터 시작 2016-06-30 16:00:00>> 17707607
# <<17시 데이터 시작 2016-06-30 17:00:05>> 17708196
# <<18시 데이터 시작 2016-06-30 18:00:01>> 17708782
# <<19시 데이터 시작 2016-06-30 19:00:05>> 17709368
# <<20시 데이터 시작 2016-06-30 20:00:03>> 17709956
# <<21시 데이터 시작 2016-06-30 21:00:00>> 17710546
# <<22시 데이터 시작 2016-06-30 22:00:05>> 17711132
# <<23시 데이터 시작 2016-06-30 23:00:05>> 17711714
# *30일의 분별 최댓값 1440개 추가됨.
# 43200개의 데이터 누적, 계산된 일자 => 30

# %% [markdown]
# #### 그래프 표시

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(400,40))
plt.grid()
plt.title("13_Jan_by_1Minute")
plt.plot(range(len(ONE_MONTH_LIST)), ONE_MONTH_LIST)
plt.savefig('./13_Jan_by_1Minute.png')
plt.show()

# %% [markdown]
# ### 보관안

# %%
import csv
import time
import sys
month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}


print("해당 전력 데이터는 2012년 11월 10일부터 2017년 4월 25일까지 온전한 데이터가 존재합니다.\n")
time.sleep(0.5)
print("데이터는 사용자가 선택한 기간 중 1년 단위로 처리됩니다.\n")
time.sleep(0.5)
global TARGET_YEAR_START 
TARGET_YEAR_START = int(input("목표로 하는 처리 기간의 시작 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)
global TARGET_YEAR_END
TARGET_YEAR_END = int(input("목표로 하는 처리 기간의 종료 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)

if(TARGET_YEAR_START<2012 or TARGET_YEAR_START>2017 or TARGET_YEAR_END>2017 or  TARGET_YEAR_END<2012):
    print("\---기간을 잘못 설정했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

if(TARGET_YEAR_START==2012 or TARGET_YEAR_END==2017):
    print("\n---해당 기간은 현재 서비스하지 않습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

global HANDLE_MINUTE
HANDLE_MINUTE = int(input("데이터들은 기본적으로 1분 단위 최댓값으로 정리됩니다.\n추후 가공될 분 단위를 5분과 10분 중 골라 숫자만 입력해주세요. : \n"))
if(HANDLE_MINUTE!=5 and HANDLE_MINUTE!=10):
    print("\n---잘못된 시간 처리 단위를 선택했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

EMPTY_HOUR_LIST=[]
for _ in range(60):
    EMPTY_HOUR_LIST.append(0)
    
EMPTY_DAY_LIST=[]
for _ in range(1440):
    EMPTY_DAY_LIST.append(0)
        
TARGET_YEAR_START = 2013
TARGET_YEAR_END=2013

def value (data, num):
    list0 = data.loc[num].values.tolist()
    date = list0[1]
    YYYY = date.year
    MM = date.month
    DD = date.day
    hh = date.hour
    mm = date.minute
    watt = list0[2]
    return YYYY, MM, DD, hh, mm, watt, date

print(value(ch1_dated,431369)[0])

#i1=0
i1=431369
while(i1 < len(ch1_dated)):
    print("전체 과정 시작")
    YEAR0 = value(ch1_dated, i1)[0]

    if(YEAR0>=TARGET_YEAR_START and YEAR0<=TARGET_YEAR_END):
        print("<<<<<{0}년 데이터 시작 {1}>>>>>".format(YEAR0, value(ch1_dated, i1)[6]))
        MONTH0 = value(ch1_dated, i1)[1]
        
        REAL_DAY = 1
        ONE_MONTH_LIST=[]
        while(MONTH0<13):
            print("<<<<{0}월 데이터 시작 {1}>>>>".format(MONTH0, value(ch1_dated, i1)[6]), i1)
            MONTH1 = value(ch1_dated, i1)[1]
            DAY1= value(ch1_dated, i1)[2]
            
            if DAY1==REAL_DAY:
                while(REAL_DAY<=month[MONTH1]):
                    print("<<<{0}일 데이터 시작 {1}>>>".format(REAL_DAY, value(ch1_dated, i1)[6]), i1)
        
                    REAL_HOUR = 0
                    ONE_DAY_LIST=[]
                    while(REAL_HOUR<24):
                        print("<<{0}시 데이터 시작 {1}>>".format(REAL_HOUR, value(ch1_dated, i1)[6]), i1)
                        HOUR1 = value(ch1_dated, i1)[3]

                        REAL_MINUTE = 0
                        MIN_60_LIST=[]
                        if HOUR1==REAL_HOUR:
                            while(REAL_MINUTE<60):#특정 시간대 안에서 분단위 데이터를 60개 처리
                                MINUTE1 = value(ch1_dated, i1)[4]
                                HOUR2 = value(ch1_dated, i1)[3]

                                print("<{0}분 데이터 시작 {1}>".format(REAL_MINUTE, value(ch1_dated, i1)[6]),i1)
                                SEC_60_LIST=[]

                                if MINUTE1==REAL_MINUTE and HOUR2==REAL_HOUR:
                                    while(True):#특정 분대 안에서 초단위 데이터를 처리
                                        MONTH2 = value(ch1_dated, i1)[1]
                                        DAY1 = value(ch1_dated, i1)[2] #여기 넣는게 맞나......??
                                        HOUR3 = value(ch1_dated, i1)[3]
                                        MINUTE2 = value(ch1_dated, i1)[4]
                                        SEC_60_LIST.append(value(ch1_dated, i1)[5])
                                        i1+=1

                                        if MINUTE1!=MINUTE2:
                                            if MINUTE2-MINUTE1==1 or MINUTE1-MINUTE2==59: #직후 분으로 넘어가거나 59분에서 다음 시로 넘어가는 경우
                                                print("*{0}분의 값들 >> {1}\n".format(MINUTE1, SEC_60_LIST))
                                                i1-=1
                                                break

                                            else:#진행되다가 분대가 넘어가긴 했으나 다음 분으로 넘어가지 않고 점프해버린경우
                                                print("*{0}분의 값들 >> {1} (결손 후 점프 시각 => {2})\n".format(MINUTE1, SEC_60_LIST, value(ch1_dated, i1)[6]))
                                                break

                                if MINUTE1!=REAL_MINUTE:#아예 해당분대가 결손된 경우
                                    if HOUR3==REAL_HOUR:
                                        print("같은 시각대 내 분 결손")
                                        SEC_60_LIST.append(0)
                                        print("*{0}시 {1}분의 결손치는 0으로 처리됨.\n".format(REAL_HOUR, REAL_MINUTE))
                                        
                                    if HOUR3!=REAL_HOUR:
                                        print("결손 + 타 시각대 점프")
                                        for _ in range(60-len(MIN_60_LIST)):
                                            MIN_60_LIST.append(0)
                                            print("*{0}시 {1}분의 결손치는 0으로 처리됨.\n".format(REAL_HOUR, REAL_MINUTE))
                                            REAL_MINUTE+=1
                                        break
                                
                                MIN_60_LIST.append(max(SEC_60_LIST))
                                REAL_MINUTE+=1

                        # 어떤 경우든 간에 시간이 바뀌는 경우, 정상이든 결손이든
                        if HOUR1!=REAL_HOUR:                
                            if DAY1==REAL_DAY:
                                print("시각 불일치! 점프됨!")
                                for i in EMPTY_HOUR_LIST:
                                    ONE_DAY_LIST.append(i)
                                print("*{0}시의 결손 데이터는 60개의 0으로 처리됨.{1}".format(REAL_HOUR, "\n"*3))
                                
                            if DAY1!=REAL_DAY:
                                print("시각 불일치! 점프됨!")
                                if REAL_HOUR==0:
                                    break

                                FAKE_HOUR=REAL_HOUR
                                for _ in range(23-REAL_HOUR+1):
                                    for i in EMPTY_HOUR_LIST:
                                        ONE_DAY_LIST.append(i)
                                    print("*{0}시의 결손 데이터는 60개의 0으로 처리됨.{1}".format(FAKE_HOUR, "\n"*3))
                                    FAKE_HOUR+=1
                                REAL_HOUR=23
                                

                        if REAL_MINUTE==60:
                            if len(MIN_60_LIST)==60:
                                for i in MIN_60_LIST:
                                    ONE_DAY_LIST.append(i)
                                
                            if len(MIN_60_LIST)<60:
                                for i in range(60-len(MIN_60_LIST)):
                                    MIN_60_LIST.append(0)
                                for i in MIN_60_LIST:
                                    ONE_DAY_LIST.append(i)
                                    
                            print("*{0}시의 분별 최댓값 {1}개 >> {2}{3}".format(REAL_HOUR, len(MIN_60_LIST), MIN_60_LIST, "\n"*3))
                            
                        REAL_HOUR+=1

                    if REAL_HOUR==24:
                        if len(ONE_DAY_LIST)==1440:
                            for i in ONE_DAY_LIST:
                                    ONE_MONTH_LIST.append(i)
                        if len(ONE_DAY_LIST)<1440:
                            for _ in range(1440-len(ONE_DAY_LIST)):
                                ONE_DAY_LIST.append(0)
                            for i in ONE_DAY_LIST:
                                ONE_MONTH_LIST.append(i)
                                
                        print(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440)
                        print("*{0}일의 분별 최댓값 {1}개 추가됨.{2}".format(REAL_DAY, len(ONE_DAY_LIST), "\n"*5))
                            
                    if DAY1!=REAL_DAY and REAL_HOUR!=24:
                        break
                    
                    REAL_DAY+=1
                    #print("Real Day 1 더해짐! 현재 정상일 => {0}{1}".format(REAL_DAY, "\n"*5))
                    
            if DAY1!=REAL_DAY:
                if MONTH2==MONTH1:
                    #for _ in range(DAY1-REAL_DAY-1):
                    for _ in range(1440-len(ONE_DAY_LIST)):
                        ONE_DAY_LIST.append(0)
                    for i in ONE_DAY_LIST:
                        ONE_MONTH_LIST.append(i)
                            
                    print(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440)
                    print("*{0}일의 분별 최댓값 {1}개 결손 처리됨(1).{2}".format(REAL_DAY, len(ONE_DAY_LIST), "\n"*5))
                    REAL_DAY+=1
                    
                if MONTH2!=MONTH1:
                    while(REAL_DAY<=month[MONTH1]):
                        print("일자 불일치! 점프됨!")
                        print(REAL_DAY, month[MONTH1])
                        if REAL_HOUR==0:
                            ONE_DAY_LIST=EMPTY_DAY_LIST
                            for i in EMPTY_DAY_LIST:
                                ONE_MONTH_LIST.append(i)

                        if REAL_HOUR!=0:
                            for _ in range(1440-len(ONE_DAY_LIST)):
                                ONE_DAY_LIST.append(0)
                            for i in ONE_DAY_LIST:
                                ONE_MONTH_LIST.append(i)
                                
                        print(len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440)
                        print("*{0}일의 분별 최댓값 {1}개 결손 처리됨(2).{2}".format(REAL_DAY, len(ONE_DAY_LIST), "\n"*5))
                        REAL_DAY+=1
                        
                    if REAL_DAY==month[MONTH1]+1:
                        break
                
                
        print("{0}월의 전체 데이터 {1}개 CSV 파일 저장 완료 {2}{3}".format(MONTH1, len(ONE_MONTH_LIST), len(ONE_MONTH_LIST)//1440, "\n"*10))
                
    else:
        i1+=1
        pass

# %% [markdown]
# ### 아래가 원본

# %%
import csv
import time

month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

# 1. 
i = 431369#431369가 맞음
print('Running!', '\n'*4)


# 2. 
while(i < 20284837):
    try:
        list1 = ch1_date.loc[i].values.tolist()
        date = list1[1]
        y1 = date.year
        M1 = date.month
        d1 = date.day
        H1 = date.hour 
        n = 0 

        # 3. 
        while(H1 < 24):
            H0 = 0 

            # 3'. 
            while(H0 < 24):
                watt_list=[]
                h = date.hour

                # 3.1. 
                if(H1 == H0):

                    # 3.1'. 
                    while(h < h+1):
                        n=n+1
                        list2 = ch1_date.loc[i].values.tolist()
                        date = list2[1]
                        watt = list2[2]
                        y = date.year
                        M = date.month
                        d = date.day
                        h = date.hour
                        m = date.minute
                        s = date.second

                        j=h-H1

                        # 3.1'.1. 
                        if(j==0):
                            watt_list.append(watt)
                            i = i+1

                        # 3.1'.2.
                        elif (j==1):
                            max_watt = max(watt_list)

                            hourly_date2 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                            hourly_date5 = '{0} {1} {2}'.format(y, M, d) 
                            hourly_list = []
                            hourly_list.append(hourly_date2)
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            H1 = H1+1 
                            H0 = H0+1
                            break

                        # 3.1'.3. 
                        elif(d1+1==d and h ==0 and H1 ==23):
                            d=d-1
                            h=h+24

                            max_watt = max(watt_list)

                            hourly_date3 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                            hourly_list = []
                            hourly_list.append(hourly_date3)
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            H1 = H1+1 
                            H0 = H0+1                   
                            break

                        # 3.1'.4.
                        elif (n>600):
                            list(hourly_date5)
                            listed = hourly_date5.split()
                            y4 = listed[0]
                            M4 = listed[1]
                            d4 = listed[2]

                            max_watt = max(watt_list)

                            hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, H1)
                            hourly_list = []
                            hourly_list.append(hourly_date)
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            # 3.1'.4.1. 
                            if(d1==d):
                                jc=j

                                while(jc>1):
                                    h=h+1
                                    hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, h-j)
                                    hourly_list = []
                                    hourly_list.append(hourly_date)
                                    hourly_list.append('Null')

                                    with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                        writer = csv.writer(file)
                                        writer.writerow(hourly_list)  

                                    jc=jc-1
                                    H1 = H1+1
                                    H0 = H0+1

                                H1 = H1+1
                                H0 = H0+1

                            # 3.1'.4.2.
                            if(d1!=d):

                                while(H1<23):
                                    hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, H1+1)
                                    hourly_list = []
                                    hourly_list.append(hourly_date)
                                    hourly_list.append('Null')

                                    with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                        writer = csv.writer(file)
                                        writer.writerow(hourly_list)  

                                    H1 = H1+1
                                    H0 = H0+1

                                H1 = H1+1
                                H0 = H0+1

                                # 3.1'.4.2.1. 
                                if(int(d4)+1 != d):
                                    D = int(d4)+1 

                                    # 3.1'.4.2.1.1. 
                                    if(int(M) == int(M4)):
                                        while(D<d):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, D, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D=D+1

                                    # 3.1'.4.2.1.2.
                                    if(int(M) != int(M4)):
                                        while(D<=month[int(M4)]):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, D, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D=D+1

                                        D2 = 1
                                        while(D2 < d):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M, D2, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D2 = D2+1

                            break


                # 3.2. 
                if(H1 != H0):
                    list3 = ch1_date.loc[i].values.tolist()
                    date = list3[1]
                    watt = list3[2]
                    y = date.year
                    M = date.month
                    d = date.day
                    h = date.hour
                    m = date.minute
                    s = date.second

                    j=h-H1           

                    hourly_date3121 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H0)
                    hourly_list3121 = []
                    hourly_list3121.append(hourly_date3121)
                    hourly_list3121.append('Null')

                    with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow(hourly_list3121)       

                    h = h+1
                    H0 = H0+1

                    if (H0 ==23 and h!=24 and H1!=23):
                                break

                    if(h==24 and H0==23 and H1==23):
                        hourly_date3121 = '{0}년 {1}월 {2}일 - 23시'.format(y, M, d)
                        hourly_list3121 = []
                        hourly_list3121.append(hourly_date3121)
                        hourly_list3121.append('Null')

                        with open("./Ch"+str(Total_num)+"_Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch"+str(Total_num)+"_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list3121)

            break
    except:
        pass
    
print('Job Done!!')
time.sleep(5)

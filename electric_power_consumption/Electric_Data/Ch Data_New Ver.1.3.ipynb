# %%
# 화면 가로 확장 코드 (기본 width 50%)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# ### 데이터 판다스로 입력, 컬럼 정리

# %%
import pandas as pd
ch1 = pd.read_csv('../../../channel_1.dat', names=['Unix', 'Watt'],header=None, delimiter=" ")
print('Module Import Done.')
# Out:
# Module Import Done.

# %%
ch1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Watt    int64
# dtypes: int64(2)
# memory usage: 333.2 MB

# %%
from datetime import datetime
ch1_dated = pd.DataFrame(ch1,columns = ['Unix', 'Date', 'Watt'])

ch1_dated['Date'] = pd.to_datetime(ch1['Unix'], unit='s')
ch1_dated.info()
ch1_dated.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21837636 entries, 0 to 21837635
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Unix    int64
#  1   Date    datetime64[ns]
#  2   Watt    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 499.8 MB
#          Unix                Date  Watt
# 0  1352500095 2012-11-09 22:28:15   599
# 1  1352500101 2012-11-09 22:28:21   582
# 2  1352500107 2012-11-09 22:28:27   600
# 3  1352500113 2012-11-09 22:28:33   586
# 4  1352500120 2012-11-09 22:28:40   596
# 5  1352500132 2012-11-09 22:28:52   581
# 6  1352500138 2012-11-09 22:28:58   597
# 7  1352500144 2012-11-09 22:29:04   592
# 8  1352500150 2012-11-09 22:29:10   587
# 9  1352500156 2012-11-09 22:29:16   574

# %%
ch1_dated[431369:431389]
# Out:
#               Unix                Date  Watt
# 431369  1356998407 2013-01-01 00:00:07   500
# 431370  1356998413 2013-01-01 00:00:13   515
# 431371  1356998419 2013-01-01 00:00:19   522
# 431372  1356998426 2013-01-01 00:00:26   508
# 431373  1356998432 2013-01-01 00:00:32   502
# 431374  1356998438 2013-01-01 00:00:38   507
# 431375  1356998444 2013-01-01 00:00:44   508
# 431376  1356998450 2013-01-01 00:00:50   500
# 431377  1356998456 2013-01-01 00:00:56   517
# 431378  1356998462 2013-01-01 00:01:02   505
# 431379  1356998468 2013-01-01 00:01:08   538
# 431380  1356998475 2013-01-01 00:01:15   551
# 431381  1356998481 2013-01-01 00:01:21   530
# 431382  1356998487 2013-01-01 00:01:27   558
# 431383  1356998493 2013-01-01 00:01:33   522
# 431384  1356998499 2013-01-01 00:01:39   514
# 431385  1356998505 2013-01-01 00:01:45   505
# 431386  1356998512 2013-01-01 00:01:52   511
# 431387  1356998518 2013-01-01 00:01:58   517
# 431388  1356998524 2013-01-01 00:02:04   519

# %% [markdown]
# ### 변수 및 구분 단계

# %% [markdown]
# ### csv 파일 저장을 위한 폴더 생성

# %%
import os
try:
    os.mkdir('./New_Electirc_Data_CSV')
except FileExistsError:
    print('해당 폴더가 이미 존재합니다.\n폴더를 확인해주세요.')
# Out:
# 해당 폴더가 이미 존재합니다.
# 폴더를 확인해주세요.

# %% [markdown]
# ### 데이터 변환 및 CSV 파일 저장 코드

# %% [markdown]
# ### 중간 정보 확인창 출력 없이 시작, 종료 메세지만 출력

# %%
import csv
import time
import sys
month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

"""
print("해당 전력 데이터는 2012년 11월 10일부터 2017년 4월 25일까지 온전한 데이터가 존재합니다.\n")
time.sleep(0.5)
print("데이터는 사용자가 선택한 기간 중 1년 단위로 처리됩니다.\n")
time.sleep(0.5)
global TARGET_YEAR_START 
TARGET_YEAR_START = int(input("목표로 하는 처리 기간의 시작 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)
global TARGET_YEAR_END
TARGET_YEAR_END = int(input("목표로 하는 처리 기간의 종료 연도를 4자리 숫자로 입력해주세요. : \n"))
time.sleep(0.5)

if(TARGET_YEAR_START<2012 or TARGET_YEAR_START>2017 or TARGET_YEAR_END>2017 or  TARGET_YEAR_END<2012):
    print("\---기간을 잘못 설정했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

if(TARGET_YEAR_START==2012 or TARGET_YEAR_END==2017):
    print("\n---해당 기간은 현재 서비스하지 않습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()

global HANDLE_MINUTE
HANDLE_MINUTE = int(input("데이터들은 기본적으로 1분 단위 최댓값으로 정리됩니다.\n추후 가공될 분 단위를 5분과 10분 중 골라 숫자만 입력해주세요. : \n"))
if(HANDLE_MINUTE!=5 and HANDLE_MINUTE!=10):
    print("\n---잘못된 시간 처리 단위를 선택했습니다!---")
    print("---프로그램을 종료합니다.---")
    sys.exit()
"""

TARGET_YEAR_START = 2013
TARGET_YEAR_END=2013

def value (data, num):
    list0 = data.loc[num].values.tolist()
    date = list0[1]
    YYYY = date.year
    MM = date.month
    DD = date.day
    hh = date.hour
    mm = date.minute
    watt = list0[2]
    return YYYY, MM, DD, hh, mm, watt, date

print(value(ch1_dated,431369)[0])

#i1=0
i1=431369
while(i1 < len(ch1_dated)):
    print("전체 과정 시작")
    YEAR0 = value(ch1_dated, i1)[0]
    #맨안쪽 1분의 안쪽 6초 단위에서 i1을 증가시켜줘야함.
    if(YEAR0>=TARGET_YEAR_START and YEAR0<=TARGET_YEAR_END):
        print("년 단위 시작")
        YEAR1 = value(ch1_dated, i1)[0]
        MONTH0 = value(ch1_dated, i1)[1]
        
        while(MONTH0<13):
            print("월 단위 시작")
            YEAR2 = value(ch1_dated, i1)[0]
            MONTH1 = value(ch1_dated, i1)[1]
            DAY0 = value(ch1_dated, i1)[2]
            
            while(DAY0<month[MONTH1]):
                print("하루 단위 시작")
                YEAR3 = value(ch1_dated, i1)[0]
                MONTH2 = value(ch1_dated, i1)[1]
                DAY1 = value(ch1_dated, i1)[2]
                HOUR0 = value(ch1_dated, i1)[3]
                
                while(HOUR0<24):
                    print("한시간 단위 시작")
                    YEAR4 = value(ch1_dated, i1)[0]
                    MONTH3 = value(ch1_dated, i1)[1]
                    DAY2 = value(ch1_dated, i1)[2]
                    HOUR1 = value(ch1_dated, i1)[3]
                    MINUTE0 = value(ch1_dated, i1)[4]
                    
                    MIN_LIST=[]
                    REAL_MINUTE = -1
                    while(REAL_MINUTE<59):#특정 시간대 안에서 분단위 데이터를 60개 처리
                        YEAR5 = value(ch1_dated, i1)[0]
                        MONTH4 = value(ch1_dated, i1)[1]
                        DAY3 = value(ch1_dated, i1)[2]
                        HOUR2 = value(ch1_dated, i1)[3]
                        MINUTE1 = value(ch1_dated, i1)[4]
                        REAL_MINUTE+=1
                        
                        print("{0}분 데이터 시작 {1}".format(MINUTE1, value(ch1_dated, i1)))
                        SEC_60_LIST=[]
                        
                        if MINUTE1==REAL_MINUTE:
                            while(True):#특정 분대 안에서 초단위 데이터를 처리
                                YEAR6 = value(ch1_dated, i1)[0]
                                MONTH5 = value(ch1_dated, i1)[1]
                                DAY4 = value(ch1_dated, i1)[2]
                                HOUR3 = value(ch1_dated, i1)[3]
                                MINUTE2 = value(ch1_dated, i1)[4]

                                SEC_60_LIST.append(value(ch1_dated, i1)[5])
                                i1+=1

                                if MINUTE1!=MINUTE2:
                                    if MINUTE2-MINUTE1==1 or MINUTE1-MINUTE2==59:
                                        print("*{0}분의 값들 >> {1}\n".format(MINUTE1, SEC_60_LIST))
                                        i1-=1
                                        break
                                    else:#진행되다가 분대가 다음 분으로 넘어가지 않고 결손칸으로 넘어가버린 경우. 
                                        print("*{0}분의 값들 >> {1}\n".format(MINUTE1, SEC_60_LIST))
                                        break
                            
                        if MINUTE1!=REAL_MINUTE:#아예 해당분대가 결손된 경우
                            print(MINUTE1, REAL_MINUTE)
                            sys.exit()
                            
                        MIN_LIST.append(max( SEC_60_LIST))
                        if HOUR2!=HOUR3:
                            print("*{0}시의 분별 최댓값 {1}개 >> {2}\n".format(HOUR2, len(MIN_LIST), MIN_LIST))
                            break
                            # 현재 중간 널값에 대한 처리가 없음!!
                            # 지난번 코드처럼 순번을 카운트하는게 필요함. 절대적인 횟수 순번
        
    
    

        
    else:
        i1+=1
        pass
# Out:
# 2013
# 전체 과정 시작
# 년 단위 시작
# 월 단위 시작
# 하루 단위 시작
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 0, 0, 500, Timestamp('2013-01-01 00:00:07'))
# *0분의 값들 >> [500, 515, 522, 508, 502, 507, 508, 500, 517, 505]
#
# 1분 데이터 시작 (2013, 1, 1, 0, 1, 505, Timestamp('2013-01-01 00:01:02'))
# *1분의 값들 >> [505, 538, 551, 530, 558, 522, 514, 505, 511, 517, 519]
#
# 2분 데이터 시작 (2013, 1, 1, 0, 2, 519, Timestamp('2013-01-01 00:02:04'))
# *2분의 값들 >> [519, 529, 512, 530, 513, 537, 513, 512, 508, 522, 525]
#
# 3분 데이터 시작 (2013, 1, 1, 0, 3, 525, Timestamp('2013-01-01 00:03:05'))
# *3분의 값들 >> [525, 513, 514, 510, 500, 511, 513, 503, 525, 505]
#
# 4분 데이터 시작 (2013, 1, 1, 0, 4, 505, Timestamp('2013-01-01 00:04:01'))
# *4분의 값들 >> [505, 510, 501, 521, 509, 511, 500, 517, 510, 539, 517]
#
# 5분 데이터 시작 (2013, 1, 1, 0, 5, 517, Timestamp('2013-01-01 00:05:02'))
# *5분의 값들 >> [517, 516, 509, 551, 515, 518, 528, 547, 499, 542]
#
# 6분 데이터 시작 (2013, 1, 1, 0, 6, 542, Timestamp('2013-01-01 00:06:04'))
# *6분의 값들 >> [542, 513, 518, 536, 502, 501, 510, 508, 506, 508]
#
# 7분 데이터 시작 (2013, 1, 1, 0, 7, 508, Timestamp('2013-01-01 00:07:05'))
# *7분의 값들 >> [508, 516, 506, 516, 507, 516, 522, 508, 510, 512]
#
# 8분 데이터 시작 (2013, 1, 1, 0, 8, 512, Timestamp('2013-01-01 00:08:00'))
# *8분의 값들 >> [512, 513, 521, 516, 507, 509, 510, 507, 500, 504, 513]
#
# 9분 데이터 시작 (2013, 1, 1, 0, 9, 513, Timestamp('2013-01-01 00:09:02'))
# *9분의 값들 >> [513, 511, 519, 533, 519, 516, 518, 530, 530, 516, 540]
#
# 10분 데이터 시작 (2013, 1, 1, 0, 10, 540, Timestamp('2013-01-01 00:10:03'))
# *10분의 값들 >> [540, 510, 523, 504, 510, 511, 537, 525, 551, 548, 531]
#
# 11분 데이터 시작 (2013, 1, 1, 0, 11, 531, Timestamp('2013-01-01 00:11:05'))
# *11분의 값들 >> [531, 547, 556, 537, 511, 507, 510, 509, 501, 509]
#
# 12분 데이터 시작 (2013, 1, 1, 0, 12, 509, Timestamp('2013-01-01 00:12:00'))
# *12분의 값들 >> [509, 502, 507, 508, 508, 503, 506, 503, 497, 509, 500]
#
# 13분 데이터 시작 (2013, 1, 1, 0, 13, 500, Timestamp('2013-01-01 00:13:02'))
# *13분의 값들 >> [500, 507, 507, 497, 503, 503, 507, 499, 497, 502, 501]
#
# 14분 데이터 시작 (2013, 1, 1, 0, 14, 501, Timestamp('2013-01-01 00:14:03'))
# *14분의 값들 >> [501, 500, 432, 428, 434, 467, 458, 436, 461, 443, 431]
#
# 15분 데이터 시작 (2013, 1, 1, 0, 15, 431, Timestamp('2013-01-01 00:15:05'))
# *15분의 값들 >> [431, 436, 437, 442, 444, 429, 434, 437, 425, 436]
#
# 16분 데이터 시작 (2013, 1, 1, 0, 16, 436, Timestamp('2013-01-01 00:16:06'))
# *16분의 값들 >> [436, 430, 428, 431, 438]
#
# 17분 데이터 시작 (2013, 1, 1, 0, 17, 438, Timestamp('2013-01-01 00:17:07'))
# *17분의 값들 >> [438, 435, 439, 437, 435, 429, 430]
#
# 18분 데이터 시작 (2013, 1, 1, 0, 18, 430, Timestamp('2013-01-01 00:18:33'))
# *18분의 값들 >> [430, 428, 434, 436, 439, 440]
#
# 19분 데이터 시작 (2013, 1, 1, 0, 19, 440, Timestamp('2013-01-01 00:19:04'))
# *19분의 값들 >> [440, 438, 437, 438, 435, 433, 438, 434]
#
# 20분 데이터 시작 (2013, 1, 1, 0, 20, 434, Timestamp('2013-01-01 00:20:00'))
# *20분의 값들 >> [434, 432, 428, 434, 434, 449, 449, 449, 449, 443, 455]
#
# 21분 데이터 시작 (2013, 1, 1, 0, 21, 455, Timestamp('2013-01-01 00:21:01'))
# *21분의 값들 >> [455, 456, 457, 450, 449, 456, 447, 454, 448, 459, 451]
#
# 22분 데이터 시작 (2013, 1, 1, 0, 22, 451, Timestamp('2013-01-01 00:22:02'))
# *22분의 값들 >> [451, 457, 461, 448, 456, 446, 451, 450, 456, 453, 456]
#
# 23분 데이터 시작 (2013, 1, 1, 0, 23, 456, Timestamp('2013-01-01 00:23:04'))
# *23분의 값들 >> [456, 449, 446, 458, 449, 450, 448, 447, 451, 458, 448]
#
# 24분 데이터 시작 (2013, 1, 1, 0, 24, 448, Timestamp('2013-01-01 00:24:05'))
# *24분의 값들 >> [448, 486, 477, 473, 482, 476, 479, 482, 487, 477]
#
# 25분 데이터 시작 (2013, 1, 1, 0, 25, 477, Timestamp('2013-01-01 00:25:00'))
# *25분의 값들 >> [477, 480, 478, 486, 483, 486, 492, 484, 486, 480, 678]
#
# 26분 데이터 시작 (2013, 1, 1, 0, 26, 678, Timestamp('2013-01-01 00:26:02'))
# *26분의 값들 >> [678, 688, 688, 683, 586, 441, 448, 431, 446, 450, 441]
#
# 27분 데이터 시작 (2013, 1, 1, 0, 27, 441, Timestamp('2013-01-01 00:27:03'))
# *27분의 값들 >> [441, 439, 449, 443, 437, 453, 442, 446, 447, 1136]
#
# 28분 데이터 시작 (2013, 1, 1, 0, 28, 1136, Timestamp('2013-01-01 00:28:11'))
# *28분의 값들 >> [1136, 613, 607, 624, 630, 615, 618]
#
# 29분 데이터 시작 (2013, 1, 1, 0, 29, 618, Timestamp('2013-01-01 00:29:00'))
# *29분의 값들 >> [618, 610, 645, 643, 649, 647, 657, 647, 632, 621, 614]
#
# 30분 데이터 시작 (2013, 1, 1, 0, 30, 614, Timestamp('2013-01-01 00:30:01'))
# *30분의 값들 >> [614, 613, 624, 610, 615, 622, 623, 607, 609, 615, 613]
#
# 31분 데이터 시작 (2013, 1, 1, 0, 31, 613, Timestamp('2013-01-01 00:31:03'))
# *31분의 값들 >> [613, 601, 609, 609, 604, 609, 614, 608, 612, 603, 609]
#
# 32분 데이터 시작 (2013, 1, 1, 0, 32, 609, Timestamp('2013-01-01 00:32:04'))
# *32분의 값들 >> [609, 623, 609, 604, 630, 627, 615, 609, 616, 610]
#
# 33분 데이터 시작 (2013, 1, 1, 0, 33, 610, Timestamp('2013-01-01 00:33:00'))
# *33분의 값들 >> [610, 609, 621, 628, 614, 619, 610, 460, 439, 431, 418]
#
# 34분 데이터 시작 (2013, 1, 1, 0, 34, 418, Timestamp('2013-01-01 00:34:01'))
# *34분의 값들 >> [418, 403, 366, 429, 457, 408, 405, 413, 404, 399, 390]
#
# 35분 데이터 시작 (2013, 1, 1, 0, 35, 390, Timestamp('2013-01-01 00:35:02'))
# *35분의 값들 >> [390, 409, 410, 198, 197, 400, 399, 402, 393, 398, 399]
#
# 36분 데이터 시작 (2013, 1, 1, 0, 36, 399, Timestamp('2013-01-01 00:36:04'))
# *36분의 값들 >> [399, 400, 405, 420, 463, 451, 464, 460, 450, 424, 428]
#
# 37분 데이터 시작 (2013, 1, 1, 0, 37, 428, Timestamp('2013-01-01 00:37:05'))
# *37분의 값들 >> [428, 410, 434, 423, 406, 416, 414, 412, 514, 509]
#
# 38분 데이터 시작 (2013, 1, 1, 0, 38, 509, Timestamp('2013-01-01 00:38:01'))
# *38분의 값들 >> [509, 512, 510, 522, 509, 508, 518, 499, 503, 507]
#
# 39분 데이터 시작 (2013, 1, 1, 0, 39, 507, Timestamp('2013-01-01 00:39:02'))
# *39분의 값들 >> [507, 510, 508, 500, 514, 503, 511, 508, 510, 506, 510]
#
# 40분 데이터 시작 (2013, 1, 1, 0, 40, 510, Timestamp('2013-01-01 00:40:04'))
# *40분의 값들 >> [510, 517, 506, 504, 506, 507, 525, 515, 513, 501, 505]
#
# 41분 데이터 시작 (2013, 1, 1, 0, 41, 505, Timestamp('2013-01-01 00:41:05'))
# *41분의 값들 >> [505, 509, 510, 499, 507, 519, 509, 515, 514, 509]
#
# 42분 데이터 시작 (2013, 1, 1, 0, 42, 509, Timestamp('2013-01-01 00:42:01'))
# *42분의 값들 >> [509, 509, 515, 507, 512, 516, 521, 513, 509, 517, 506]
#
# 43분 데이터 시작 (2013, 1, 1, 0, 43, 506, Timestamp('2013-01-01 00:43:02'))
# *43분의 값들 >> [506, 516, 516, 514, 509, 518, 507, 523, 516, 525, 511]
#
# 44분 데이터 시작 (2013, 1, 1, 0, 44, 511, Timestamp('2013-01-01 00:44:04'))
# *44분의 값들 >> [511, 296, 297, 297, 301, 296, 298, 295, 295, 299]
#
# 45분 데이터 시작 (2013, 1, 1, 0, 45, 299, Timestamp('2013-01-01 00:45:05'))
# *45분의 값들 >> [299, 295, 300, 297, 295, 302, 295, 296, 293, 300]
#
# 46분 데이터 시작 (2013, 1, 1, 0, 46, 300, Timestamp('2013-01-01 00:46:00'))
# *46분의 값들 >> [300, 295, 295, 295, 295, 295, 300, 301, 297, 298, 301]
#
# 47분 데이터 시작 (2013, 1, 1, 0, 47, 301, Timestamp('2013-01-01 00:47:02'))
# *47분의 값들 >> [301, 296, 297, 303, 301, 301, 299, 295, 301, 323, 320]
#
# 48분 데이터 시작 (2013, 1, 1, 0, 48, 320, Timestamp('2013-01-01 00:48:03'))
# *48분의 값들 >> [320, 322, 314, 322, 315, 318, 322, 322, 315, 323, 318]
#
# 49분 데이터 시작 (2013, 1, 1, 0, 49, 318, Timestamp('2013-01-01 00:49:04'))
# *49분의 값들 >> [318, 319, 322, 322, 322, 316, 318, 315, 316, 321]
#
# 50분 데이터 시작 (2013, 1, 1, 0, 50, 321, Timestamp('2013-01-01 00:50:00'))
# *50분의 값들 >> [321, 322, 325, 319, 323, 315, 321, 323, 323, 323, 323]
#
# 51분 데이터 시작 (2013, 1, 1, 0, 51, 323, Timestamp('2013-01-01 00:51:01'))
# *51분의 값들 >> [323, 316, 316, 321, 323, 323, 321, 314, 315, 320, 316]
#
# 52분 데이터 시작 (2013, 1, 1, 0, 52, 316, Timestamp('2013-01-01 00:52:02'))
# *52분의 값들 >> [316, 318, 321, 318, 321, 318, 322, 318, 315, 321, 335]
#
# 53분 데이터 시작 (2013, 1, 1, 0, 53, 335, Timestamp('2013-01-01 00:53:04'))
# *53분의 값들 >> [335, 329, 229, 228, 228, 229, 244, 238, 237, 240, 229]
#
# 54분 데이터 시작 (2013, 1, 1, 0, 54, 229, Timestamp('2013-01-01 00:54:05'))
# *54분의 값들 >> [229, 232, 227, 232, 226, 234, 235, 231, 238, 292]
#
# 55분 데이터 시작 (2013, 1, 1, 0, 55, 292, Timestamp('2013-01-01 00:55:13'))
# *55분의 값들 >> [292, 293, 291, 289, 282, 2429, 2483]
#
# 56분 데이터 시작 (2013, 1, 1, 0, 56, 2483, Timestamp('2013-01-01 00:56:02'))
# *56분의 값들 >> [2483, 2479, 2492, 2476, 2477, 2480, 2492, 2479, 2485, 2475]
#
# 57분 데이터 시작 (2013, 1, 1, 0, 57, 2475, Timestamp('2013-01-01 00:57:01'))
# *57분의 값들 >> [2475, 2481, 2478, 2488, 2481, 2478, 2483, 2476, 2474, 2478]
#
# 58분 데이터 시작 (2013, 1, 1, 0, 58, 2478, Timestamp('2013-01-01 00:58:00'))
# *58분의 값들 >> [2478, 2472, 2474, 2475, 2480, 2473, 2478, 2475, 2478, 2480, 2478, 2495]
#
# 59분 데이터 시작 (2013, 1, 1, 0, 59, 2495, Timestamp('2013-01-01 00:59:05'))
# *59분의 값들 >> [2495, 2481, 2470, 2480, 2476, 2473, 2479, 2473, 2480, 2477, 2475]
#
# *0시의 분별 최댓값 60개 >> [522, 558, 537, 525, 539, 551, 542, 522, 521, 540, 551, 556, 509, 507, 501, 444, 438, 439, 440, 440, 455, 459, 461, 458, 487, 678, 688, 1136, 1136, 657, 624, 614, 630, 628, 457, 410, 464, 514, 522, 514, 525, 519, 521, 525, 511, 302, 301, 323, 323, 322, 325, 323, 335, 335, 292, 2483, 2492, 2488, 2495, 2495]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 1, 0, 2475, Timestamp('2013-01-01 01:00:05'))
# *0분의 값들 >> [2475, 2481, 2477, 2476, 2477, 2473, 2480, 2475, 2476, 2475, 2473]
#
# 1분 데이터 시작 (2013, 1, 1, 1, 1, 2473, Timestamp('2013-01-01 01:01:10'))
# *1분의 값들 >> [2473, 2479, 2474, 2474, 2474, 2468, 2472, 2475, 2476, 2473]
#
# 2분 데이터 시작 (2013, 1, 1, 1, 2, 2473, Timestamp('2013-01-01 01:02:03'))
# *2분의 값들 >> [2473, 2477, 2474, 2476, 2466, 2474, 2477, 2471, 2473, 2473]
#
# 3분 데이터 시작 (2013, 1, 1, 1, 3, 2473, Timestamp('2013-01-01 01:03:02'))
# *3분의 값들 >> [2473, 2469, 2475, 2475, 2482, 2471, 2476, 2478, 2479, 2476, 2474]
#
# 4분 데이터 시작 (2013, 1, 1, 1, 4, 2474, Timestamp('2013-01-01 01:04:02'))
# *4분의 값들 >> [2474, 2480, 2477, 2470, 2476, 2477, 2469, 2473, 2475, 2475, 2474]
#
# 5분 데이터 시작 (2013, 1, 1, 1, 5, 2474, Timestamp('2013-01-01 01:05:07'))
# *5분의 값들 >> [2474, 2468, 2470, 2478, 2469, 2471, 2477, 2475, 2472]
#
# 6분 데이터 시작 (2013, 1, 1, 1, 6, 2472, Timestamp('2013-01-01 01:06:00'))
# *6분의 값들 >> [2472, 2477, 2428, 2416, 2420, 2427, 2421, 2426, 2423, 285, 285]
#
# 7분 데이터 시작 (2013, 1, 1, 1, 7, 285, Timestamp('2013-01-01 01:07:00'))
# *7분의 값들 >> [285, 281, 285, 283, 283, 283, 298, 282, 288, 278, 283]
#
# 8분 데이터 시작 (2013, 1, 1, 1, 8, 283, Timestamp('2013-01-01 01:08:02'))
# *8분의 값들 >> [283, 284, 279, 279, 286, 278, 281, 280, 283, 290]
#
# 9분 데이터 시작 (2013, 1, 1, 1, 9, 290, Timestamp('2013-01-01 01:09:03'))
# *9분의 값들 >> [290, 280, 279, 285, 279, 287, 279, 283, 282, 279, 282]
#
# 10분 데이터 시작 (2013, 1, 1, 1, 10, 282, Timestamp('2013-01-01 01:10:05'))
# *10분의 값들 >> [282, 282, 282, 286, 284, 281, 280, 281, 281, 284]
#
# 11분 데이터 시작 (2013, 1, 1, 1, 11, 284, Timestamp('2013-01-01 01:11:00'))
# *11분의 값들 >> [284, 282, 277, 282, 280, 281, 285, 279, 283, 278, 285]
#
# 12분 데이터 시작 (2013, 1, 1, 1, 12, 285, Timestamp('2013-01-01 01:12:01'))
# *12분의 값들 >> [285, 280, 278, 283, 278, 277, 278, 282, 276, 277, 283]
#
# 13분 데이터 시작 (2013, 1, 1, 1, 13, 283, Timestamp('2013-01-01 01:13:03'))
# *13분의 값들 >> [283, 279, 281, 280, 281, 280, 284, 280, 284, 280, 285]
#
# 14분 데이터 시작 (2013, 1, 1, 1, 14, 285, Timestamp('2013-01-01 01:14:04'))
# *14분의 값들 >> [285, 279, 284, 284, 283, 280, 286, 279, 280, 277]
#
# 15분 데이터 시작 (2013, 1, 1, 1, 15, 277, Timestamp('2013-01-01 01:15:05'))
# *15분의 값들 >> [277, 282, 282, 285, 278, 284, 285, 281, 283, 279]
#
# 16분 데이터 시작 (2013, 1, 1, 1, 16, 279, Timestamp('2013-01-01 01:16:01'))
# *16분의 값들 >> [279, 282, 279, 280, 282, 283, 283, 278, 283, 283, 278]
#
# 17분 데이터 시작 (2013, 1, 1, 1, 17, 278, Timestamp('2013-01-01 01:17:02'))
# *17분의 값들 >> [278, 283, 282, 279, 281, 281, 285, 279, 279, 279, 282]
#
# 18분 데이터 시작 (2013, 1, 1, 1, 18, 282, Timestamp('2013-01-01 01:18:04'))
# *18분의 값들 >> [282, 283, 278, 278, 282, 280, 283, 280, 281, 281, 278]
#
# 19분 데이터 시작 (2013, 1, 1, 1, 19, 278, Timestamp('2013-01-01 01:19:05'))
# *19분의 값들 >> [278, 277, 284, 283, 283, 278, 278, 282, 279, 279]
#
# 20분 데이터 시작 (2013, 1, 1, 1, 20, 279, Timestamp('2013-01-01 01:20:00'))
# *20분의 값들 >> [279, 283, 283, 285, 279, 283, 282, 280, 280, 284, 280]
#
# 21분 데이터 시작 (2013, 1, 1, 1, 21, 280, Timestamp('2013-01-01 01:21:02'))
# *21분의 값들 >> [280, 283, 280, 278, 281, 282, 284, 282, 282, 278, 282]
#
# 22분 데이터 시작 (2013, 1, 1, 1, 22, 282, Timestamp('2013-01-01 01:22:03'))
# *22분의 값들 >> [282, 279, 282, 280, 277, 278, 280, 282, 282, 279, 279]
#
# 23분 데이터 시작 (2013, 1, 1, 1, 23, 279, Timestamp('2013-01-01 01:23:05'))
# *23분의 값들 >> [279, 278, 279, 283, 282, 279, 282, 279, 278, 281]
#
# 24분 데이터 시작 (2013, 1, 1, 1, 24, 281, Timestamp('2013-01-01 01:24:00'))
# *24분의 값들 >> [281, 282, 277, 282, 284, 283, 280, 283, 283, 367, 358]
#
# 25분 데이터 시작 (2013, 1, 1, 1, 25, 358, Timestamp('2013-01-01 01:25:01'))
# *25분의 값들 >> [358, 361, 361, 357, 353, 357, 354, 359, 356, 359, 359]
#
# 26분 데이터 시작 (2013, 1, 1, 1, 26, 359, Timestamp('2013-01-01 01:26:03'))
# *26분의 값들 >> [359, 357, 358, 356, 348, 354, 349, 347, 347, 347, 350]
#
# 27분 데이터 시작 (2013, 1, 1, 1, 27, 350, Timestamp('2013-01-01 01:27:04'))
# *27분의 값들 >> [350, 357, 355, 353, 357, 350, 355, 351, 350, 358]
#
# 28분 데이터 시작 (2013, 1, 1, 1, 28, 358, Timestamp('2013-01-01 01:28:00'))
# *28분의 값들 >> [358, 354, 360, 355, 358, 355, 359, 357, 358, 354]
#
# 29분 데이터 시작 (2013, 1, 1, 1, 29, 354, Timestamp('2013-01-01 01:29:01'))
# *29분의 값들 >> [354, 358, 358, 360, 351, 359, 361, 355, 354, 359, 360]
#
# 30분 데이터 시작 (2013, 1, 1, 1, 30, 360, Timestamp('2013-01-01 01:30:02'))
# *30분의 값들 >> [360, 355, 358, 352, 354, 355, 359, 354, 360, 360, 353]
#
# 31분 데이터 시작 (2013, 1, 1, 1, 31, 353, Timestamp('2013-01-01 01:31:04'))
# *31분의 값들 >> [353, 360, 352, 359, 355, 354, 352, 361, 356, 353]
#
# 32분 데이터 시작 (2013, 1, 1, 1, 32, 353, Timestamp('2013-01-01 01:32:00'))
# *32분의 값들 >> [353, 360, 355, 358, 359, 355, 355, 353, 358, 355, 357]
#
# 33분 데이터 시작 (2013, 1, 1, 1, 33, 357, Timestamp('2013-01-01 01:33:01'))
# *33분의 값들 >> [357, 357, 352, 353, 352, 356, 357, 357, 352, 352, 354]
#
# 34분 데이터 시작 (2013, 1, 1, 1, 34, 354, Timestamp('2013-01-01 01:34:02'))
# *34분의 값들 >> [354, 352, 354, 353, 350, 358, 355, 352, 350, 353, 349]
#
# 35분 데이터 시작 (2013, 1, 1, 1, 35, 349, Timestamp('2013-01-01 01:35:04'))
# *35분의 값들 >> [349, 358, 350, 357, 351, 355, 359, 354, 357, 352]
#
# 36분 데이터 시작 (2013, 1, 1, 1, 36, 352, Timestamp('2013-01-01 01:36:05'))
# *36분의 값들 >> [352, 349, 351, 355, 358, 348, 351, 354, 351, 355]
#
# 37분 데이터 시작 (2013, 1, 1, 1, 37, 355, Timestamp('2013-01-01 01:37:01'))
# *37분의 값들 >> [355, 355, 350, 356, 350, 355, 351, 347, 351, 356, 358]
# 38분 데이터 시작 (2013, 1, 1, 1, 38, 358, Timestamp('2013-01-01 01:38:02'))
# *38분의 값들 >> [358, 350, 353, 353, 356, 351, 355, 358, 350, 351, 354]
#
# 39분 데이터 시작 (2013, 1, 1, 1, 39, 354, Timestamp('2013-01-01 01:39:04'))
# *39분의 값들 >> [354, 354, 357, 348, 351, 350, 355, 356, 352, 352, 352]
#
# 40분 데이터 시작 (2013, 1, 1, 1, 40, 352, Timestamp('2013-01-01 01:40:05'))
# *40분의 값들 >> [352, 349, 350, 348, 354, 351, 357, 355, 352, 351]
#
# 41분 데이터 시작 (2013, 1, 1, 1, 41, 351, Timestamp('2013-01-01 01:41:00'))
# *41분의 값들 >> [351, 349, 355, 357, 356]
#
# 42분 데이터 시작 (2013, 1, 1, 1, 42, 356, Timestamp('2013-01-01 01:42:20'))
# *42분의 값들 >> [356, 352, 352, 355, 357, 359, 352, 355]
#
# 43분 데이터 시작 (2013, 1, 1, 1, 43, 355, Timestamp('2013-01-01 01:43:03'))
# *43분의 값들 >> [355, 355, 357, 350, 351, 350, 356, 351, 350, 355, 353]
#
# 44분 데이터 시작 (2013, 1, 1, 1, 44, 353, Timestamp('2013-01-01 01:44:04'))
# *44분의 값들 >> [353, 357, 354, 358, 351, 350, 354, 356, 350]
#
# 45분 데이터 시작 (2013, 1, 1, 1, 45, 350, Timestamp('2013-01-01 01:45:12'))
# *45분의 값들 >> [350, 358, 357, 349, 357, 355, 349, 352, 352]
#
# 46분 데이터 시작 (2013, 1, 1, 1, 46, 352, Timestamp('2013-01-01 01:46:01'))
# *46분의 값들 >> [352, 355, 355, 351, 356, 351, 354, 357, 369, 271, 263]
#
# 47분 데이터 시작 (2013, 1, 1, 1, 47, 263, Timestamp('2013-01-01 01:47:02'))
# *47분의 값들 >> [263, 260, 261, 260, 250, 254, 252, 252, 252, 250, 249]
#
# 48분 데이터 시작 (2013, 1, 1, 1, 48, 249, Timestamp('2013-01-01 01:48:04'))
# *48분의 값들 >> [249, 254, 253, 350, 355, 356, 351, 355, 353, 355, 356]
#
# 49분 데이터 시작 (2013, 1, 1, 1, 49, 356, Timestamp('2013-01-01 01:49:06'))
# *49분의 값들 >> [356, 352, 357, 353, 356, 351, 350, 353, 349, 354]
#
# 50분 데이터 시작 (2013, 1, 1, 1, 50, 354, Timestamp('2013-01-01 01:50:01'))
# *50분의 값들 >> [354, 358, 356, 356, 357, 351, 350, 352, 356, 349, 352]
#
# 51분 데이터 시작 (2013, 1, 1, 1, 51, 352, Timestamp('2013-01-01 01:51:02'))
# *51분의 값들 >> [352, 351, 349, 356, 352, 349, 358, 357, 354, 353, 351]
#
# 52분 데이터 시작 (2013, 1, 1, 1, 52, 351, Timestamp('2013-01-01 01:52:04'))
# *52분의 값들 >> [351, 356, 353, 356, 354, 349, 353, 278, 277, 281, 281]
#
# 53분 데이터 시작 (2013, 1, 1, 1, 53, 281, Timestamp('2013-01-01 01:53:11'))
# *53분의 값들 >> [281, 277, 281, 276, 277, 277, 279, 276, 275]
#
# 54분 데이터 시작 (2013, 1, 1, 1, 54, 275, Timestamp('2013-01-01 01:54:00'))
# *54분의 값들 >> [275, 276, 282, 277, 281, 281, 277, 279, 276, 280, 281]
#
# 55분 데이터 시작 (2013, 1, 1, 1, 55, 281, Timestamp('2013-01-01 01:55:02'))
# *55분의 값들 >> [281, 276, 276, 275, 280, 277, 275, 275, 280, 275, 283]
#
# 56분 데이터 시작 (2013, 1, 1, 1, 56, 283, Timestamp('2013-01-01 01:56:03'))
# *56분의 값들 >> [283, 277, 278, 275, 276, 275, 277, 276, 280, 274, 277]
#
# 57분 데이터 시작 (2013, 1, 1, 1, 57, 277, Timestamp('2013-01-01 01:57:05'))
# *57분의 값들 >> [277, 280, 275, 280, 276, 276, 280, 276, 283, 281]
#
# 58분 데이터 시작 (2013, 1, 1, 1, 58, 281, Timestamp('2013-01-01 01:58:00'))
# *58분의 값들 >> [281, 285, 275, 307, 298, 202, 204, 203, 196, 198, 193]
#
# 59분 데이터 시작 (2013, 1, 1, 1, 59, 193, Timestamp('2013-01-01 01:59:02'))
# *59분의 값들 >> [193, 186, 192, 188, 191, 195, 188, 274, 2439]
#
# *1시의 분별 최댓값 60개 >> [2481, 2479, 2477, 2482, 2480, 2478, 2477, 298, 290, 290, 286, 285, 285, 285, 286, 285, 283, 285, 283, 284, 285, 284, 282, 283, 367, 361, 359, 358, 360, 361, 360, 361, 360, 357, 358, 359, 358, 358, 358, 357, 357, 357, 359, 357, 358, 358, 369, 263, 356, 357, 358, 358, 356, 281, 282, 283, 283, 283, 307, 2439]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 2, 0, 2439, Timestamp('2013-01-01 02:00:04'))
# *0분의 값들 >> [2439, 2429, 2435, 2429, 2428, 2433, 2427, 2424, 2426, 2419]
#
# 1분 데이터 시작 (2013, 1, 1, 2, 1, 2419, Timestamp('2013-01-01 02:01:03'))
# *1분의 값들 >> [2419, 2423, 2426, 2424, 2419, 2423, 2417, 2419, 2421, 2423]
#
# 2분 데이터 시작 (2013, 1, 1, 2, 2, 2423, Timestamp('2013-01-01 02:02:02'))
# *2분의 값들 >> [2423, 2425, 2422, 2427, 2430, 2421, 2425, 2425, 2420, 2422, 2423]
#
# 3분 데이터 시작 (2013, 1, 1, 2, 3, 2423, Timestamp('2013-01-01 02:03:01'))
# *3분의 값들 >> [2423, 2427, 2428, 2423, 2419, 2421, 2422, 2422, 2421, 2416, 2416]
#
# 4분 데이터 시작 (2013, 1, 1, 2, 4, 2416, Timestamp('2013-01-01 02:04:01'))
# *4분의 값들 >> [2416, 2422, 2422, 2419, 2426, 2422, 2428, 2421, 2426, 2420, 2424]
#
# 5분 데이터 시작 (2013, 1, 1, 2, 5, 2424, Timestamp('2013-01-01 02:05:00'))
# *5분의 값들 >> [2424, 2422, 2416, 2421, 2427, 2429, 2426, 2423, 2427, 2417, 2424]
#
# 6분 데이터 시작 (2013, 1, 1, 2, 6, 2424, Timestamp('2013-01-01 02:06:05'))
# *6분의 값들 >> [2424, 2428, 2426, 2420, 2423, 2430, 2421, 2430, 2427, 2427, 2427]
#
# 7분 데이터 시작 (2013, 1, 1, 2, 7, 2427, Timestamp('2013-01-01 02:07:04'))
# *7분의 값들 >> [2427, 2425, 2421, 2423, 2434, 2431, 2432, 2427, 2425, 2425, 2425]
#
# 8분 데이터 시작 (2013, 1, 1, 2, 8, 2425, Timestamp('2013-01-01 02:08:03'))
# *8분의 값들 >> [2425, 2425, 2424, 2424, 2424, 2423, 2438, 2426, 2428, 2441, 2426]
#
# 9분 데이터 시작 (2013, 1, 1, 2, 9, 2426, Timestamp('2013-01-01 02:09:02'))
# *9분의 값들 >> [2426, 2420, 2427, 2422, 2422, 2426, 2418, 2426, 2426, 2433, 2430]
#
# 10분 데이터 시작 (2013, 1, 1, 2, 10, 2430, Timestamp('2013-01-01 02:10:02'))
# *10분의 값들 >> [2430, 2433, 2440, 2428, 2425, 2427, 2423, 2419, 2427, 2424]
#
# 11분 데이터 시작 (2013, 1, 1, 2, 11, 2424, Timestamp('2013-01-01 02:11:01'))
# *11분의 값들 >> [2424, 2421, 2423, 2426, 2427, 2420, 2423, 2418, 2428, 2419]
#
# 12분 데이터 시작 (2013, 1, 1, 2, 12, 2419, Timestamp('2013-01-01 02:12:00'))
# *12분의 값들 >> [2419, 2430, 2422, 2427, 2428, 2425, 2417, 2421, 2419, 2422, 2426, 2423]
#
# 13분 데이터 시작 (2013, 1, 1, 2, 13, 2423, Timestamp('2013-01-01 02:13:05'))
# *13분의 값들 >> [2423, 2429, 2424, 2414, 2423, 2423, 2425, 2418, 2423, 2422, 2420]
#
# 14분 데이터 시작 (2013, 1, 1, 2, 14, 2420, Timestamp('2013-01-01 02:14:05'))
# *14분의 값들 >> [2420, 2422, 2426, 2425, 2421, 2416, 2419, 2420, 2420, 2411]
#
# 15분 데이터 시작 (2013, 1, 1, 2, 15, 2411, Timestamp('2013-01-01 02:15:04'))
# *15분의 값들 >> [2411, 2418, 2420, 2415, 2412, 2417, 2422, 2414, 2421, 2417]
#
# 16분 데이터 시작 (2013, 1, 1, 2, 16, 2417, Timestamp('2013-01-01 02:16:03'))
# *16분의 값들 >> [2417, 2421, 2420, 2422, 2422, 2419, 205]
#
# 17분 데이터 시작 (2013, 1, 1, 2, 17, 205, Timestamp('2013-01-01 02:17:16'))
# *17분의 값들 >> [205, 208, 207, 204, 204, 211, 207, 189, 187]
#
# 18분 데이터 시작 (2013, 1, 1, 2, 18, 187, Timestamp('2013-01-01 02:18:05'))
# *18분의 값들 >> [187, 188, 189, 191, 191, 188, 189, 191, 192]
#
# 19분 데이터 시작 (2013, 1, 1, 2, 19, 192, Timestamp('2013-01-01 02:19:01'))
# *19분의 값들 >> [192, 188, 192, 191, 183, 198, 201, 198, 199, 200, 182]
#
# 20분 데이터 시작 (2013, 1, 1, 2, 20, 182, Timestamp('2013-01-01 02:20:02'))
# *20분의 값들 >> [182, 186, 186, 183, 182, 185, 182, 186, 181, 183, 188]
#
# 21분 데이터 시작 (2013, 1, 1, 2, 21, 188, Timestamp('2013-01-01 02:21:03'))
# *21분의 값들 >> [188, 183, 184, 186, 186, 184, 183, 182, 184, 186, 181]
#
# 22분 데이터 시작 (2013, 1, 1, 2, 22, 181, Timestamp('2013-01-01 02:22:05'))
# *22분의 값들 >> [181, 184, 183, 186, 183, 183, 184, 183, 186, 186]
#
# 23분 데이터 시작 (2013, 1, 1, 2, 23, 186, Timestamp('2013-01-01 02:23:01'))
# *23분의 값들 >> [186, 187, 186, 184, 185, 183, 185, 185, 187, 185, 183]
#
# 24분 데이터 시작 (2013, 1, 1, 2, 24, 183, Timestamp('2013-01-01 02:24:02'))
# *24분의 값들 >> [183, 182, 181, 186, 186, 184, 184, 187, 183, 185, 191]
#
# 25분 데이터 시작 (2013, 1, 1, 2, 25, 191, Timestamp('2013-01-01 02:25:03'))
# *25분의 값들 >> [191, 186, 185, 249, 248, 244, 244, 243]
#
# 26분 데이터 시작 (2013, 1, 1, 2, 26, 243, Timestamp('2013-01-01 02:26:05'))
# *26분의 값들 >> [243, 242, 240, 240, 239, 244, 240, 243, 240, 244]
#
# 27분 데이터 시작 (2013, 1, 1, 2, 27, 244, Timestamp('2013-01-01 02:27:00'))
# *27분의 값들 >> [244, 243, 242, 241, 238, 248, 240, 242, 242, 242, 240]
#
# 28분 데이터 시작 (2013, 1, 1, 2, 28, 240, Timestamp('2013-01-01 02:28:02'))
# *28분의 값들 >> [240, 238, 243, 241, 240, 246, 240, 244, 239, 243, 244]
#
# 29분 데이터 시작 (2013, 1, 1, 2, 29, 244, Timestamp('2013-01-01 02:29:03'))
# *29분의 값들 >> [244, 242, 239, 240, 240, 241, 240, 243, 250, 246, 244]
#
# 30분 데이터 시작 (2013, 1, 1, 2, 30, 244, Timestamp('2013-01-01 02:30:05'))
# *30분의 값들 >> [244, 238, 246, 240, 241, 236, 236, 240, 240, 240]
#
# 31분 데이터 시작 (2013, 1, 1, 2, 31, 240, Timestamp('2013-01-01 02:31:00'))
# *31분의 값들 >> [240, 240, 239, 240, 237, 240, 237, 238, 241]
#
# 32분 데이터 시작 (2013, 1, 1, 2, 32, 241, Timestamp('2013-01-01 02:32:01'))
# *32분의 값들 >> [241, 239, 240, 240, 238, 240, 236, 240, 238, 239, 235]
#
# 33분 데이터 시작 (2013, 1, 1, 2, 33, 235, Timestamp('2013-01-01 02:33:03'))
# *33분의 값들 >> [235, 236, 238, 236, 236, 237, 239, 239, 239, 234, 237]
#
# 34분 데이터 시작 (2013, 1, 1, 2, 34, 237, Timestamp('2013-01-01 02:34:04'))
# *34분의 값들 >> [237, 234, 236, 232, 237, 237, 238, 234, 238, 236, 238]
#
# 35분 데이터 시작 (2013, 1, 1, 2, 35, 238, Timestamp('2013-01-01 02:35:05'))
# *35분의 값들 >> [238, 235, 234, 234, 237, 236, 234, 235, 186, 183]
#
# 36분 데이터 시작 (2013, 1, 1, 2, 36, 183, Timestamp('2013-01-01 02:36:01'))
# *36분의 값들 >> [183, 182, 184, 183, 183, 184, 185, 185, 180, 182, 182]
#
# 37분 데이터 시작 (2013, 1, 1, 2, 37, 182, Timestamp('2013-01-01 02:37:02'))
# *37분의 값들 >> [182, 181, 182, 183, 185, 182, 185, 185, 180, 182, 188]
#
# 38분 데이터 시작 (2013, 1, 1, 2, 38, 188, Timestamp('2013-01-01 02:38:04'))
# *38분의 값들 >> [188, 182, 182, 183, 186, 186, 179, 185, 183, 186, 184]
#
# 39분 데이터 시작 (2013, 1, 1, 2, 39, 184, Timestamp('2013-01-01 02:39:11'))
# *39분의 값들 >> [184, 184, 183, 185, 187, 182, 183, 184, 181]
#
# 40분 데이터 시작 (2013, 1, 1, 2, 40, 181, Timestamp('2013-01-01 02:40:00'))
# *40분의 값들 >> [181, 181, 182, 184, 182, 178, 182, 184, 181, 182, 185]
#
# 41분 데이터 시작 (2013, 1, 1, 2, 41, 185, Timestamp('2013-01-01 02:41:02'))
# *41분의 값들 >> [185, 181, 180, 183, 182, 178, 182, 184, 182, 182, 187]
#
# 42분 데이터 시작 (2013, 1, 1, 2, 42, 187, Timestamp('2013-01-01 02:42:03'))
# *42분의 값들 >> [187, 183, 181, 186, 186, 180, 186, 184, 186, 184, 186]
#
# 43분 데이터 시작 (2013, 1, 1, 2, 43, 186, Timestamp('2013-01-01 02:43:05'))
# *43분의 값들 >> [186, 183, 182, 182, 184, 182, 184, 180, 183, 183]
#
# 44분 데이터 시작 (2013, 1, 1, 2, 44, 183, Timestamp('2013-01-01 02:44:00'))
# *44분의 값들 >> [183, 185, 185, 183, 183, 185, 185, 183]
#
# 45분 데이터 시작 (2013, 1, 1, 2, 45, 183, Timestamp('2013-01-01 02:45:02'))
# *45분의 값들 >> [183, 182, 181, 185, 182, 181, 181, 182, 182, 181, 183]
#
# 46분 데이터 시작 (2013, 1, 1, 2, 46, 183, Timestamp('2013-01-01 02:46:03'))
# *46분의 값들 >> [183, 184, 181, 180, 183, 184, 180, 182, 181, 182, 179]
#
# 47분 데이터 시작 (2013, 1, 1, 2, 47, 179, Timestamp('2013-01-01 02:47:04'))
# *47분의 값들 >> [179, 184, 185, 182, 181, 180, 179, 183, 181, 181]
#
# 48분 데이터 시작 (2013, 1, 1, 2, 48, 181, Timestamp('2013-01-01 02:48:00'))
# *48분의 값들 >> [181, 183, 179, 180, 183, 182, 182, 182, 182, 182, 182]
# 49분 데이터 시작 (2013, 1, 1, 2, 49, 182, Timestamp('2013-01-01 02:49:02'))
# *49분의 값들 >> [182, 182, 183, 183, 184, 183, 183, 180, 186, 183, 187]
#
# 50분 데이터 시작 (2013, 1, 1, 2, 50, 187, Timestamp('2013-01-01 02:50:03'))
# *50분의 값들 >> [187, 182, 180, 183, 180, 182, 183, 181, 181, 182, 181]
#
# 51분 데이터 시작 (2013, 1, 1, 2, 51, 181, Timestamp('2013-01-01 02:51:29'))
# *51분의 값들 >> [181, 183, 182, 184, 183, 182]
#
# 52분 데이터 시작 (2013, 1, 1, 2, 52, 182, Timestamp('2013-01-01 02:52:00'))
# *52분의 값들 >> [182, 184, 185, 183, 181, 182, 186, 181, 182, 184, 186]
#
# 53분 데이터 시작 (2013, 1, 1, 2, 53, 186, Timestamp('2013-01-01 02:53:01'))
# *53분의 값들 >> [186, 181, 184, 184, 186, 183, 186, 184, 188, 185, 185]
#
# 54분 데이터 시작 (2013, 1, 1, 2, 54, 185, Timestamp('2013-01-01 02:54:03'))
# *54분의 값들 >> [185, 182, 181, 184, 183, 181, 182, 184, 183, 180, 182]
#
# 55분 데이터 시작 (2013, 1, 1, 2, 55, 182, Timestamp('2013-01-01 02:55:04'))
# *55분의 값들 >> [182, 186, 183, 185, 183, 185, 186, 183, 186, 186]
#
# 56분 데이터 시작 (2013, 1, 1, 2, 56, 186, Timestamp('2013-01-01 02:56:00'))
# *56분의 값들 >> [186, 184, 186, 183, 185, 186, 186, 185, 183, 183]
#
# 57분 데이터 시작 (2013, 1, 1, 2, 57, 183, Timestamp('2013-01-01 02:57:01'))
# *57분의 값들 >> [183, 186, 182, 185, 183, 183, 182, 185, 182, 182, 185]
#
# 58분 데이터 시작 (2013, 1, 1, 2, 58, 185, Timestamp('2013-01-01 02:58:02'))
# *58분의 값들 >> [185, 186, 181, 181, 186, 184, 180, 184, 184, 177, 183]
#
# 59분 데이터 시작 (2013, 1, 1, 2, 59, 183, Timestamp('2013-01-01 02:59:04'))
# *59분의 값들 >> [183, 185, 184, 182, 186, 182, 184, 181, 181, 183, 181]
#
# *2시의 분별 최댓값 60개 >> [2439, 2426, 2430, 2428, 2428, 2429, 2430, 2434, 2441, 2433, 2440, 2428, 2430, 2429, 2426, 2422, 2422, 211, 192, 201, 188, 188, 186, 187, 191, 249, 244, 248, 246, 250, 246, 241, 241, 239, 238, 238, 185, 188, 188, 187, 185, 187, 187, 186, 185, 185, 184, 185, 183, 187, 187, 184, 186, 188, 185, 186, 186, 186, 186, 186]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 3, 0, 181, Timestamp('2013-01-01 03:00:05'))
# *0분의 값들 >> [181, 184, 182, 184, 180, 180, 183, 247, 234, 244]
#
# 1분 데이터 시작 (2013, 1, 1, 3, 1, 244, Timestamp('2013-01-01 03:01:00'))
# *1분의 값들 >> [244, 243, 243, 247, 247, 249, 248, 237, 247, 245, 246]
#
# 2분 데이터 시작 (2013, 1, 1, 3, 2, 246, Timestamp('2013-01-01 03:02:02'))
# *2분의 값들 >> [246, 250, 245, 245, 245, 247, 244, 245, 181, 181, 187]
#
# 3분 데이터 시작 (2013, 1, 1, 3, 3, 187, Timestamp('2013-01-01 03:03:03'))
# *3분의 값들 >> [187, 180, 183, 183, 183, 182, 182, 178, 180, 180, 183]
#
# 4분 데이터 시작 (2013, 1, 1, 3, 4, 183, Timestamp('2013-01-01 03:04:11'))
# *4분의 값들 >> [183, 183, 181, 183, 182, 184, 182, 181, 183]
#
# 5분 데이터 시작 (2013, 1, 1, 3, 5, 183, Timestamp('2013-01-01 03:05:00'))
# *5분의 값들 >> [183, 181, 181, 181, 183, 180, 180, 184, 183, 184, 181]
#
# 6분 데이터 시작 (2013, 1, 1, 3, 6, 181, Timestamp('2013-01-01 03:06:02'))
# *6분의 값들 >> [181, 182, 180, 181, 183, 182, 183, 183, 180, 180, 187]
#
# 7분 데이터 시작 (2013, 1, 1, 3, 7, 187, Timestamp('2013-01-01 03:07:03'))
# *7분의 값들 >> [187, 185, 180, 180, 181, 180, 183, 183, 181, 183, 180]
#
# 8분 데이터 시작 (2013, 1, 1, 3, 8, 180, Timestamp('2013-01-01 03:08:05'))
# *8분의 값들 >> [180, 183, 182, 183, 180, 179, 180, 181, 179, 181]
#
# 9분 데이터 시작 (2013, 1, 1, 3, 9, 181, Timestamp('2013-01-01 03:09:00'))
# *9분의 값들 >> [181, 182, 183, 180, 180, 181, 181, 181, 180, 183, 180]
#
# 10분 데이터 시작 (2013, 1, 1, 3, 10, 180, Timestamp('2013-01-01 03:10:02'))
# *10분의 값들 >> [180, 183, 182, 180, 181, 182, 181, 183, 184, 182, 189]
#
# 11분 데이터 시작 (2013, 1, 1, 3, 11, 189, Timestamp('2013-01-01 03:11:03'))
# *11분의 값들 >> [189, 181, 185, 184, 184, 186, 181, 182]
#
# 12분 데이터 시작 (2013, 1, 1, 3, 12, 182, Timestamp('2013-01-01 03:12:04'))
# *12분의 값들 >> [182, 181, 182, 181, 181, 181, 182, 178, 182, 180]
#
# 13분 데이터 시작 (2013, 1, 1, 3, 13, 180, Timestamp('2013-01-01 03:13:00'))
# *13분의 값들 >> [180, 182, 181, 180, 181, 186, 186, 179, 180, 183, 183]
#
# 14분 데이터 시작 (2013, 1, 1, 3, 14, 183, Timestamp('2013-01-01 03:14:01'))
# *14분의 값들 >> [183, 181, 183, 179, 179, 181, 185, 182, 182, 183]
#
# 15분 데이터 시작 (2013, 1, 1, 3, 15, 183, Timestamp('2013-01-01 03:15:03'))
# *15분의 값들 >> [183, 179, 182, 179, 179, 179, 180, 181, 185, 180, 182]
#
# 16분 데이터 시작 (2013, 1, 1, 3, 16, 182, Timestamp('2013-01-01 03:16:05'))
# *16분의 값들 >> [182, 182, 179, 182, 183, 182, 179, 179, 181, 180]
#
# 17분 데이터 시작 (2013, 1, 1, 3, 17, 180, Timestamp('2013-01-01 03:17:00'))
# *17분의 값들 >> [180, 179, 182, 179, 182, 182, 180, 182, 183, 180, 182]
#
# 18분 데이터 시작 (2013, 1, 1, 3, 18, 182, Timestamp('2013-01-01 03:18:01'))
# *18분의 값들 >> [182, 179, 181, 179, 265, 247, 247, 245, 248, 245, 247]
#
# 19분 데이터 시작 (2013, 1, 1, 3, 19, 247, Timestamp('2013-01-01 03:19:04'))
# *19분의 값들 >> [247, 245, 241, 248, 252, 239, 239, 236, 240, 238, 239]
#
# 20분 데이터 시작 (2013, 1, 1, 3, 20, 239, Timestamp('2013-01-01 03:20:05'))
# *20분의 값들 >> [239, 234, 238, 236, 240, 236, 239, 240, 240]
#
# 21분 데이터 시작 (2013, 1, 1, 3, 21, 240, Timestamp('2013-01-01 03:21:01'))
# *21분의 값들 >> [240, 241, 239, 238, 240, 243, 240, 241, 241, 242, 243]
#
# 22분 데이터 시작 (2013, 1, 1, 3, 22, 243, Timestamp('2013-01-01 03:22:02'))
# *22분의 값들 >> [243, 240, 243, 241, 242, 240, 244, 240, 244, 245, 243]
#
# 23분 데이터 시작 (2013, 1, 1, 3, 23, 243, Timestamp('2013-01-01 03:23:04'))
# *23분의 값들 >> [243, 242, 240, 243, 241, 244, 241, 243, 243, 240, 241]
#
# 24분 데이터 시작 (2013, 1, 1, 3, 24, 241, Timestamp('2013-01-01 03:24:05'))
# *24분의 값들 >> [241, 244, 240, 242, 240, 240, 241, 243, 244, 241]
#
# 25분 데이터 시작 (2013, 1, 1, 3, 25, 241, Timestamp('2013-01-01 03:25:00'))
# *25분의 값들 >> [241, 245, 240, 242, 240, 243, 241, 240, 241, 241, 242]
#
# 26분 데이터 시작 (2013, 1, 1, 3, 26, 242, Timestamp('2013-01-01 03:26:02'))
# *26분의 값들 >> [242, 241, 240, 241, 241, 239, 240, 240, 246]
#
# 27분 데이터 시작 (2013, 1, 1, 3, 27, 246, Timestamp('2013-01-01 03:27:03'))
# *27분의 값들 >> [246, 240, 242, 240, 240, 241, 238, 244, 241, 243, 242]
#
# 28분 데이터 시작 (2013, 1, 1, 3, 28, 242, Timestamp('2013-01-01 03:28:05'))
# *28분의 값들 >> [242, 240, 240, 238, 244, 238, 244, 238, 242, 239]
#
# 29분 데이터 시작 (2013, 1, 1, 3, 29, 239, Timestamp('2013-01-01 03:29:00'))
# *29분의 값들 >> [239, 241, 243, 240, 240, 240, 241, 242, 243, 239, 240]
#
# 30분 데이터 시작 (2013, 1, 1, 3, 30, 240, Timestamp('2013-01-01 03:30:01'))
# *30분의 값들 >> [240, 243, 244, 244, 240, 241, 242, 240, 241, 242, 240]
#
# 31분 데이터 시작 (2013, 1, 1, 3, 31, 240, Timestamp('2013-01-01 03:31:03'))
# *31분의 값들 >> [240, 244, 239, 241, 238, 240, 238, 240, 239, 244, 241]
#
# 32분 데이터 시작 (2013, 1, 1, 3, 32, 241, Timestamp('2013-01-01 03:32:04'))
# *32분의 값들 >> [241, 243, 241, 243, 242, 242, 242, 240]
#
# 33분 데이터 시작 (2013, 1, 1, 3, 33, 240, Timestamp('2013-01-01 03:33:00'))
# *33분의 값들 >> [240, 241, 241, 242, 240, 241, 238, 242, 244, 240]
#
# 34분 데이터 시작 (2013, 1, 1, 3, 34, 240, Timestamp('2013-01-01 03:34:01'))
# *34분의 값들 >> [240, 240, 240, 244, 242, 242, 240, 243, 241, 240, 241]
#
# 35분 데이터 시작 (2013, 1, 1, 3, 35, 241, Timestamp('2013-01-01 03:35:03'))
# *35분의 값들 >> [241, 242, 240, 240, 240, 240, 240, 239, 239, 239, 237]
#
# 36분 데이터 시작 (2013, 1, 1, 3, 36, 237, Timestamp('2013-01-01 03:36:04'))
# *36분의 값들 >> [237, 243, 240, 238, 237, 242, 239, 242, 242, 239]
#
# 37분 데이터 시작 (2013, 1, 1, 3, 37, 239, Timestamp('2013-01-01 03:37:00'))
# *37분의 값들 >> [239, 239, 241, 239, 239, 240, 239, 240, 239]
#
# 38분 데이터 시작 (2013, 1, 1, 3, 38, 239, Timestamp('2013-01-01 03:38:01'))
# *38분의 값들 >> [239, 238, 241, 241, 242, 239, 239, 241, 239, 242, 242]
#
# 39분 데이터 시작 (2013, 1, 1, 3, 39, 242, Timestamp('2013-01-01 03:39:02'))
# *39분의 값들 >> [242, 243, 240, 241, 244, 238, 241, 240, 242, 243, 243]
#
# 40분 데이터 시작 (2013, 1, 1, 3, 40, 243, Timestamp('2013-01-01 03:40:04'))
# *40분의 값들 >> [243, 243, 239, 241, 243, 244, 242, 238, 243, 239, 241]
#
# 41분 데이터 시작 (2013, 1, 1, 3, 41, 241, Timestamp('2013-01-01 03:41:06'))
# *41분의 값들 >> [241, 242, 242, 240, 240, 242, 242, 244, 240, 240]
#
# 42분 데이터 시작 (2013, 1, 1, 3, 42, 240, Timestamp('2013-01-01 03:42:01'))
# *42분의 값들 >> [240, 239, 242, 240, 243, 242, 239, 241, 243, 240]
#
# 43분 데이터 시작 (2013, 1, 1, 3, 43, 240, Timestamp('2013-01-01 03:43:03'))
# *43분의 값들 >> [240, 243, 240, 242, 240, 239, 241, 242, 240, 242, 240]
#
# 44분 데이터 시작 (2013, 1, 1, 3, 44, 240, Timestamp('2013-01-01 03:44:04'))
# *44분의 값들 >> [240, 241, 248, 240, 241, 239, 241, 240, 243, 242, 244]
#
# 45분 데이터 시작 (2013, 1, 1, 3, 45, 244, Timestamp('2013-01-01 03:45:06'))
# *45분의 값들 >> [244, 244, 240, 241, 244, 240, 240, 243, 243, 242]
#
# 46분 데이터 시작 (2013, 1, 1, 3, 46, 242, Timestamp('2013-01-01 03:46:01'))
# *46분의 값들 >> [242, 241, 242, 240, 240, 237, 240, 238, 242, 239, 240]
#
# 47분 데이터 시작 (2013, 1, 1, 3, 47, 240, Timestamp('2013-01-01 03:47:02'))
# *47분의 값들 >> [240, 240, 237, 240, 238, 238, 240, 239, 239, 237, 237]
#
# 48분 데이터 시작 (2013, 1, 1, 3, 48, 237, Timestamp('2013-01-01 03:48:10'))
# *48분의 값들 >> [237, 240, 237, 238, 239, 235, 240, 236, 234, 235]
#
# 49분 데이터 시작 (2013, 1, 1, 3, 49, 235, Timestamp('2013-01-01 03:49:06'))
# *49분의 값들 >> [235, 240, 234, 236, 236, 239, 234, 236, 239, 224]
#
# 50분 데이터 시작 (2013, 1, 1, 3, 50, 224, Timestamp('2013-01-01 03:50:01'))
# *50분의 값들 >> [224, 182, 181, 182, 179, 182]
#
# 51분 데이터 시작 (2013, 1, 1, 3, 51, 182, Timestamp('2013-01-01 03:51:02'))
# *51분의 값들 >> [182, 181, 183, 179, 182, 181, 183, 183, 181, 180, 183]
#
# 52분 데이터 시작 (2013, 1, 1, 3, 52, 183, Timestamp('2013-01-01 03:52:04'))
# *52분의 값들 >> [183, 180, 179, 183, 179, 183, 183, 179, 183, 180, 180]
#
# 53분 데이터 시작 (2013, 1, 1, 3, 53, 180, Timestamp('2013-01-01 03:53:05'))
# *53분의 값들 >> [180, 180, 181, 179, 182, 181, 182, 178, 181, 179]
#
# 54분 데이터 시작 (2013, 1, 1, 3, 54, 179, Timestamp('2013-01-01 03:54:00'))
# *54분의 값들 >> [179, 183, 180, 182, 181, 183, 182, 179, 179, 183, 184]
#
# 55분 데이터 시작 (2013, 1, 1, 3, 55, 184, Timestamp('2013-01-01 03:55:02'))
# *55분의 값들 >> [184, 181, 182, 178, 181, 183, 182, 182, 180, 179, 184]
#
# 56분 데이터 시작 (2013, 1, 1, 3, 56, 184, Timestamp('2013-01-01 03:56:03'))
# *56분의 값들 >> [184, 181, 182, 181, 182, 180, 179, 182, 181, 182, 179]
#
# 57분 데이터 시작 (2013, 1, 1, 3, 57, 179, Timestamp('2013-01-01 03:57:05'))
# *57분의 값들 >> [179, 180, 181, 181, 179, 182, 181, 178, 182, 181]
#
# 58분 데이터 시작 (2013, 1, 1, 3, 58, 181, Timestamp('2013-01-01 03:58:00'))
# *58분의 값들 >> [181, 182, 182, 180, 182, 181, 180, 182, 183, 180, 182]
#
# 59분 데이터 시작 (2013, 1, 1, 3, 59, 182, Timestamp('2013-01-01 03:59:02'))
# *59분의 값들 >> [182, 179, 179, 180, 182, 180, 179, 183, 179, 184, 186]
#
# *3시의 분별 최댓값 60개 >> [247, 249, 250, 187, 184, 184, 187, 187, 183, 183, 189, 189, 182, 186, 185, 185, 183, 183, 265, 252, 240, 243, 245, 244, 244, 245, 246, 246, 244, 243, 244, 244, 243, 244, 244, 242, 243, 241, 242, 244, 244, 244, 243, 243, 248, 244, 242, 240, 240, 240, 224, 183, 183, 182, 184, 184, 184, 182, 183, 186]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 4, 0, 186, Timestamp('2013-01-01 04:00:03'))
# *0분의 값들 >> [186, 184, 180, 180, 182, 181, 180, 182, 181, 181, 182]
#
# 1분 데이터 시작 (2013, 1, 1, 4, 1, 182, Timestamp('2013-01-01 04:01:05'))
# *1분의 값들 >> [182, 184, 182, 180, 181, 178, 177, 180]
#
# 2분 데이터 시작 (2013, 1, 1, 4, 2, 180, Timestamp('2013-01-01 04:02:00'))
# *2분의 값들 >> [180, 183, 180, 181, 183, 179, 183, 177, 180, 180, 183]
#
# 3분 데이터 시작 (2013, 1, 1, 4, 3, 183, Timestamp('2013-01-01 04:03:02'))
# *3분의 값들 >> [183, 183, 177, 180, 179, 181, 180, 180, 180, 180, 181]
#
# 4분 데이터 시작 (2013, 1, 1, 4, 4, 181, Timestamp('2013-01-01 04:04:03'))
# *4분의 값들 >> [181, 177, 179, 183, 179, 179, 177, 180, 179, 179, 180]
#
# 5분 데이터 시작 (2013, 1, 1, 4, 5, 180, Timestamp('2013-01-01 04:05:04'))
# *5분의 값들 >> [180, 178, 179, 179, 181, 179, 182, 181, 181, 179]
#
# 6분 데이터 시작 (2013, 1, 1, 4, 6, 179, Timestamp('2013-01-01 04:06:00'))
# *6분의 값들 >> [179, 180, 179, 179, 178, 179]
#
# 7분 데이터 시작 (2013, 1, 1, 4, 7, 179, Timestamp('2013-01-01 04:07:02'))
# *7분의 값들 >> [179, 178, 182, 182, 182, 195, 191, 197, 194, 197, 182]
# 8분 데이터 시작 (2013, 1, 1, 4, 8, 182, Timestamp('2013-01-01 04:08:03'))
# *8분의 값들 >> [182, 178, 181, 182, 178, 180, 178, 178, 180, 178, 181]
#
# 9분 데이터 시작 (2013, 1, 1, 4, 9, 181, Timestamp('2013-01-01 04:09:05'))
# *9분의 값들 >> [181, 178, 182, 178, 178, 179, 179, 182, 178, 178]
#
# 10분 데이터 시작 (2013, 1, 1, 4, 10, 178, Timestamp('2013-01-01 04:10:00'))
# *10분의 값들 >> [178, 183, 179, 178, 179, 179, 181, 181, 180, 181, 180]
#
# 11분 데이터 시작 (2013, 1, 1, 4, 11, 180, Timestamp('2013-01-01 04:11:01'))
# *11분의 값들 >> [180, 179, 181, 181, 181, 180, 178, 178, 181, 184]
#
# 12분 데이터 시작 (2013, 1, 1, 4, 12, 184, Timestamp('2013-01-01 04:12:03'))
# *12분의 값들 >> [184, 178, 179, 182, 179, 181, 179, 178, 180, 179, 179]
#
# 13분 데이터 시작 (2013, 1, 1, 4, 13, 179, Timestamp('2013-01-01 04:13:04'))
# *13분의 값들 >> [179, 180, 180, 178, 179, 179, 180, 181, 178, 182]
#
# 14분 데이터 시작 (2013, 1, 1, 4, 14, 182, Timestamp('2013-01-01 04:14:00'))
# *14분의 값들 >> [182, 180, 180, 180, 178, 180, 180, 177, 178, 180, 180]
#
# 15분 데이터 시작 (2013, 1, 1, 4, 15, 180, Timestamp('2013-01-01 04:15:02'))
# *15분의 값들 >> [180, 179, 178, 179, 178, 179, 179, 181, 181, 182, 182]
#
# 16분 데이터 시작 (2013, 1, 1, 4, 16, 182, Timestamp('2013-01-01 04:16:03'))
# *16분의 값들 >> [182, 180, 178, 178, 179, 182, 181, 180, 182, 180, 181]
#
# 17분 데이터 시작 (2013, 1, 1, 4, 17, 181, Timestamp('2013-01-01 04:17:04'))
# *17분의 값들 >> [181, 178, 178, 177, 180, 180, 180, 178, 178]
#
# 18분 데이터 시작 (2013, 1, 1, 4, 18, 178, Timestamp('2013-01-01 04:18:00'))
# *18분의 값들 >> [178, 178, 179, 181, 181, 180, 178, 179, 178, 180, 179]
#
# 19분 데이터 시작 (2013, 1, 1, 4, 19, 179, Timestamp('2013-01-01 04:19:01'))
# *19분의 값들 >> [179, 183, 179, 181, 179, 182, 179, 178, 181, 180, 179]
#
# 20분 데이터 시작 (2013, 1, 1, 4, 20, 179, Timestamp('2013-01-01 04:20:02'))
# *20분의 값들 >> [179, 185, 184, 181, 179, 180, 179, 180, 182]
#
# 21분 데이터 시작 (2013, 1, 1, 4, 21, 182, Timestamp('2013-01-01 04:21:04'))
# *21분의 값들 >> [182, 179, 178, 183, 182, 182, 186, 183, 181, 182, 180]
#
# 22분 데이터 시작 (2013, 1, 1, 4, 22, 180, Timestamp('2013-01-01 04:22:05'))
# *22분의 값들 >> [180, 178, 180, 179, 179, 179, 182, 180]
#
# 23분 데이터 시작 (2013, 1, 1, 4, 23, 180, Timestamp('2013-01-01 04:23:01'))
# *23분의 값들 >> [180, 179, 179, 183, 181, 179, 182, 181, 182, 181, 182]
#
# 24분 데이터 시작 (2013, 1, 1, 4, 24, 182, Timestamp('2013-01-01 04:24:02'))
# *24분의 값들 >> [182, 182, 181, 179, 181, 179, 180, 180, 179, 179, 180]
#
# 25분 데이터 시작 (2013, 1, 1, 4, 25, 180, Timestamp('2013-01-01 04:25:04'))
# *25분의 값들 >> [180, 180, 183, 181, 185, 181, 180, 181, 182, 179]
#
# 26분 데이터 시작 (2013, 1, 1, 4, 26, 179, Timestamp('2013-01-01 04:26:05'))
# *26분의 값들 >> [179, 179, 182, 180, 179, 181, 183, 181, 182, 182]
#
# 27분 데이터 시작 (2013, 1, 1, 4, 27, 182, Timestamp('2013-01-01 04:27:01'))
# *27분의 값들 >> [182, 180, 182, 179, 182, 182, 179, 179, 182, 179, 181]
#
# 28분 데이터 시작 (2013, 1, 1, 4, 28, 181, Timestamp('2013-01-01 04:28:02'))
# *28분의 값들 >> [181, 180, 178, 179, 182, 180, 180, 180, 181, 181, 183]
#
# 29분 데이터 시작 (2013, 1, 1, 4, 29, 183, Timestamp('2013-01-01 04:29:04'))
# *29분의 값들 >> [183, 182, 179, 178, 180, 178, 179, 181, 181, 181, 179]
#
# 30분 데이터 시작 (2013, 1, 1, 4, 30, 179, Timestamp('2013-01-01 04:30:05'))
# *30분의 값들 >> [179, 182, 179, 181, 179, 178, 180, 182, 182, 181]
#
# 31분 데이터 시작 (2013, 1, 1, 4, 31, 181, Timestamp('2013-01-01 04:31:01'))
# *31분의 값들 >> [181, 183, 180, 182, 179, 180, 181, 182, 181, 181, 182]
#
# 32분 데이터 시작 (2013, 1, 1, 4, 32, 182, Timestamp('2013-01-01 04:32:02'))
# *32분의 값들 >> [182, 180, 179, 182, 181, 180, 180, 184, 181, 179]
#
# 33분 데이터 시작 (2013, 1, 1, 4, 33, 179, Timestamp('2013-01-01 04:33:04'))
# *33분의 값들 >> [179, 182, 182, 180, 179, 182, 181, 180, 183, 182, 179]
#
# 34분 데이터 시작 (2013, 1, 1, 4, 34, 179, Timestamp('2013-01-01 04:34:06'))
# *34분의 값들 >> [179, 180, 179, 182, 182, 260, 250, 244, 246, 244]
#
# 35분 데이터 시작 (2013, 1, 1, 4, 35, 244, Timestamp('2013-01-01 04:35:01'))
# *35분의 값들 >> [244, 241, 240, 240, 240, 237, 236, 240, 240, 240]
#
# 36분 데이터 시작 (2013, 1, 1, 4, 36, 240, Timestamp('2013-01-01 04:36:02'))
# *36분의 값들 >> [240, 240, 240, 236, 238, 240, 240, 236, 240, 235]
#
# 37분 데이터 시작 (2013, 1, 1, 4, 37, 235, Timestamp('2013-01-01 04:37:04'))
# *37분의 값들 >> [235, 237, 240, 239, 242, 240, 235, 238, 233, 236]
#
# 38분 데이터 시작 (2013, 1, 1, 4, 38, 236, Timestamp('2013-01-01 04:38:06'))
# *38분의 값들 >> [236, 240, 238, 235, 236, 234, 234, 236, 239, 237]
#
# 39분 데이터 시작 (2013, 1, 1, 4, 39, 237, Timestamp('2013-01-01 04:39:01'))
# *39분의 값들 >> [237, 239, 234, 234, 239, 235, 237, 238, 233, 237, 238]
#
# 40분 데이터 시작 (2013, 1, 1, 4, 40, 238, Timestamp('2013-01-01 04:40:03'))
# *40분의 값들 >> [238, 237, 238, 238, 235, 235, 237, 239, 238, 232, 236]
#
# 41분 데이터 시작 (2013, 1, 1, 4, 41, 236, Timestamp('2013-01-01 04:41:04'))
# *41분의 값들 >> [236, 235, 234, 235, 235, 234, 236, 236, 236, 235, 236]
#
# 42분 데이터 시작 (2013, 1, 1, 4, 42, 236, Timestamp('2013-01-01 04:42:05'))
# *42분의 값들 >> [236, 234, 232, 235, 236, 234, 235, 237, 234]
#
# 43분 데이터 시작 (2013, 1, 1, 4, 43, 234, Timestamp('2013-01-01 04:43:01'))
# *43분의 값들 >> [234, 238, 236, 237, 238, 233, 234, 234, 237, 238, 232]
#
# 44분 데이터 시작 (2013, 1, 1, 4, 44, 232, Timestamp('2013-01-01 04:44:02'))
# *44분의 값들 >> [232, 237, 234, 233, 235, 235, 194, 178, 177, 181, 186]
#
# 45분 데이터 시작 (2013, 1, 1, 4, 45, 186, Timestamp('2013-01-01 04:45:03'))
# *45분의 값들 >> [186, 182, 182, 180, 183, 182, 177, 176, 180, 178, 181]
#
# 46분 데이터 시작 (2013, 1, 1, 4, 46, 181, Timestamp('2013-01-01 04:46:05'))
# *46분의 값들 >> [181, 182, 180, 179, 179, 179, 178, 183, 180, 182]
#
# 47분 데이터 시작 (2013, 1, 1, 4, 47, 182, Timestamp('2013-01-01 04:47:00'))
# *47분의 값들 >> [182, 182, 179, 180, 182, 182, 178, 180, 177, 179, 179]
#
# 48분 데이터 시작 (2013, 1, 1, 4, 48, 179, Timestamp('2013-01-01 04:48:02'))
# *48분의 값들 >> [179, 182, 179, 183, 183, 177, 178, 184]
#
# 49분 데이터 시작 (2013, 1, 1, 4, 49, 184, Timestamp('2013-01-01 04:49:03'))
# *49분의 값들 >> [184, 178, 180, 182, 177, 180, 182, 182, 179, 178, 178]
#
# 50분 데이터 시작 (2013, 1, 1, 4, 50, 178, Timestamp('2013-01-01 04:50:05'))
# *50분의 값들 >> [178, 179, 180, 179, 179, 178, 178, 178, 180, 181]
#
# 51분 데이터 시작 (2013, 1, 1, 4, 51, 181, Timestamp('2013-01-01 04:51:00'))
# *51분의 값들 >> [181, 182, 178, 179, 182, 180, 181, 182, 178, 179, 183]
#
# 52분 데이터 시작 (2013, 1, 1, 4, 52, 183, Timestamp('2013-01-01 04:52:02'))
# *52분의 값들 >> [183, 178, 181, 181, 179, 183, 178, 180, 179, 179, 186]
#
# 53분 데이터 시작 (2013, 1, 1, 4, 53, 186, Timestamp('2013-01-01 04:53:03'))
# *53분의 값들 >> [186, 179, 178, 179, 179, 179, 181, 178, 181]
#
# 54분 데이터 시작 (2013, 1, 1, 4, 54, 181, Timestamp('2013-01-01 04:54:05'))
# *54분의 값들 >> [181, 178, 179, 182, 179, 181, 178, 181, 181, 181]
#
# 55분 데이터 시작 (2013, 1, 1, 4, 55, 181, Timestamp('2013-01-01 04:55:00'))
# *55분의 값들 >> [181, 178, 182, 181, 181, 181, 178, 181, 179, 181, 179]
#
# 56분 데이터 시작 (2013, 1, 1, 4, 56, 179, Timestamp('2013-01-01 04:56:02'))
# *56분의 값들 >> [179, 181, 178, 180, 180, 181, 177, 178, 180, 181, 186]
#
# 57분 데이터 시작 (2013, 1, 1, 4, 57, 186, Timestamp('2013-01-01 04:57:03'))
# *57분의 값들 >> [186, 179, 180, 178, 179, 180, 179, 181, 181, 179, 181]
#
# 58분 데이터 시작 (2013, 1, 1, 4, 58, 181, Timestamp('2013-01-01 04:58:05'))
# *58분의 값들 >> [181, 182, 179, 178, 182, 179, 181, 179, 179]
#
# 59분 데이터 시작 (2013, 1, 1, 4, 59, 179, Timestamp('2013-01-01 04:59:00'))
# *59분의 값들 >> [179, 180, 181, 181, 178, 178, 180, 182, 181, 182, 182]
#
# *4시의 분별 최댓값 60개 >> [186, 184, 183, 183, 183, 182, 180, 197, 182, 182, 183, 184, 184, 182, 182, 182, 182, 181, 181, 183, 185, 186, 182, 183, 182, 185, 183, 182, 183, 183, 182, 183, 184, 183, 260, 244, 240, 242, 240, 239, 239, 236, 237, 238, 237, 186, 183, 182, 184, 184, 181, 183, 186, 186, 182, 182, 186, 186, 182, 182]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 5, 0, 182, Timestamp('2013-01-01 05:00:02'))
# *0분의 값들 >> [182, 180, 183, 179, 180, 180, 179, 180, 183, 181, 180]
#
# 1분 데이터 시작 (2013, 1, 1, 5, 1, 180, Timestamp('2013-01-01 05:01:04'))
# *1분의 값들 >> [180, 181, 183, 179, 180, 180, 181, 181, 183, 181, 179]
#
# 2분 데이터 시작 (2013, 1, 1, 5, 2, 179, Timestamp('2013-01-01 05:02:05'))
# *2분의 값들 >> [179, 179, 182, 179, 180, 178, 182, 181, 184, 189]
#
# 3분 데이터 시작 (2013, 1, 1, 5, 3, 189, Timestamp('2013-01-01 05:03:00'))
# *3분의 값들 >> [189, 178, 182, 181, 182, 182, 182]
#
# 4분 데이터 시작 (2013, 1, 1, 5, 4, 182, Timestamp('2013-01-01 05:04:02'))
# *4분의 값들 >> [182, 179, 181, 180, 180, 181, 178, 181, 179, 179, 182]
#
# 5분 데이터 시작 (2013, 1, 1, 5, 5, 182, Timestamp('2013-01-01 05:05:03'))
# *5분의 값들 >> [182, 181, 179, 179, 179, 179, 181, 182, 181, 180, 178]
#
# 6분 데이터 시작 (2013, 1, 1, 5, 6, 178, Timestamp('2013-01-01 05:06:05'))
# *6분의 값들 >> [178, 181, 178, 182, 180, 178, 181, 181, 179, 179]
#
# 7분 데이터 시작 (2013, 1, 1, 5, 7, 179, Timestamp('2013-01-01 05:07:01'))
# *7분의 값들 >> [179, 181, 178, 181, 183, 180, 179, 179, 178, 182, 179]
#
# 8분 데이터 시작 (2013, 1, 1, 5, 8, 179, Timestamp('2013-01-01 05:08:02'))
# *8분의 값들 >> [179, 181, 178, 181, 178, 181, 181, 178, 182, 179, 186]
#
# 9분 데이터 시작 (2013, 1, 1, 5, 9, 186, Timestamp('2013-01-01 05:09:03'))
# *9분의 값들 >> [186, 182, 180, 182, 181, 183, 181, 181, 178, 179, 182]
#
# 10분 데이터 시작 (2013, 1, 1, 5, 10, 182, Timestamp('2013-01-01 05:10:05'))
# *10분의 값들 >> [182, 178, 178, 182, 179, 181, 180, 181, 182, 179]
#
# 11분 데이터 시작 (2013, 1, 1, 5, 11, 179, Timestamp('2013-01-01 05:11:00'))
# *11분의 값들 >> [179, 179, 180, 178, 182, 181, 179, 180, 179, 181, 179]
#
# 12분 데이터 시작 (2013, 1, 1, 5, 12, 179, Timestamp('2013-01-01 05:12:01'))
# *12분의 값들 >> [179, 182, 181, 180, 181, 182, 181, 180, 181, 181, 187]
#
# 13분 데이터 시작 (2013, 1, 1, 5, 13, 187, Timestamp('2013-01-01 05:13:03'))
# *13분의 값들 >> [187, 180, 180, 180, 181, 182, 179, 179, 181, 180]
#
# 14분 데이터 시작 (2013, 1, 1, 5, 14, 180, Timestamp('2013-01-01 05:14:05'))
# *14분의 값들 >> [180, 182, 180, 181, 179, 180, 179, 179, 179, 180]
#
# 15분 데이터 시작 (2013, 1, 1, 5, 15, 180, Timestamp('2013-01-01 05:15:00'))
# *15분의 값들 >> [180, 179, 179, 179, 179, 178, 182, 178, 179, 179]
#
# 16분 데이터 시작 (2013, 1, 1, 5, 16, 179, Timestamp('2013-01-01 05:16:01'))
# *16분의 값들 >> [179, 182, 182, 180, 179, 182, 181, 179, 181, 182, 186]
#
# 17분 데이터 시작 (2013, 1, 1, 5, 17, 186, Timestamp('2013-01-01 05:17:03'))
# *17분의 값들 >> [186, 180, 179, 181, 182, 182, 182, 183, 178, 181, 181]
#
# 18분 데이터 시작 (2013, 1, 1, 5, 18, 181, Timestamp('2013-01-01 05:18:05'))
# *18분의 값들 >> [181, 181, 179, 181, 181, 179, 182, 179, 180, 179]
#
# 19분 데이터 시작 (2013, 1, 1, 5, 19, 179, Timestamp('2013-01-01 05:19:00'))
# *19분의 값들 >> [179, 178, 179, 179, 178, 179, 181, 179, 181, 181, 179]
#
# 20분 데이터 시작 (2013, 1, 1, 5, 20, 179, Timestamp('2013-01-01 05:20:02'))
# *20분의 값들 >> [179, 179, 180, 182, 183, 179, 179, 178, 181, 180, 183]
#
# 21분 데이터 시작 (2013, 1, 1, 5, 21, 183, Timestamp('2013-01-01 05:21:03'))
# *21분의 값들 >> [183, 179, 181, 179, 181, 179, 182, 179, 181, 260]
#
# 22분 데이터 시작 (2013, 1, 1, 5, 22, 260, Timestamp('2013-01-01 05:22:00'))
# *22분의 값들 >> [260, 246, 245, 242, 242, 245, 243, 243, 240, 240]
#
# 23분 데이터 시작 (2013, 1, 1, 5, 23, 240, Timestamp('2013-01-01 05:23:01'))
# *23분의 값들 >> [240, 238, 236, 234, 239, 239, 236, 236, 236, 234, 238]
# 24분 데이터 시작 (2013, 1, 1, 5, 24, 238, Timestamp('2013-01-01 05:24:03'))
# *24분의 값들 >> [238, 234, 234, 239, 236, 238, 238, 236, 237, 239, 240]
#
# 25분 데이터 시작 (2013, 1, 1, 5, 25, 240, Timestamp('2013-01-01 05:25:04'))
# *25분의 값들 >> [240, 235, 239, 239, 238, 237, 240, 240, 238, 240]
#
# 26분 데이터 시작 (2013, 1, 1, 5, 26, 240, Timestamp('2013-01-01 05:26:00'))
# *26분의 값들 >> [240, 241, 238, 239, 241, 240, 241, 240, 238, 239]
#
# 27분 데이터 시작 (2013, 1, 1, 5, 27, 239, Timestamp('2013-01-01 05:27:02'))
# *27분의 값들 >> [239, 241, 238, 240, 240, 240, 241, 241, 242, 239, 245]
#
# 28분 데이터 시작 (2013, 1, 1, 5, 28, 245, Timestamp('2013-01-01 05:28:03'))
# *28분의 값들 >> [245, 240, 242, 240, 238, 239, 237, 242, 238, 240, 240]
#
# 29분 데이터 시작 (2013, 1, 1, 5, 29, 240, Timestamp('2013-01-01 05:29:04'))
# *29분의 값들 >> [240, 240, 241, 240, 241, 243, 240, 241, 238, 240]
#
# 30분 데이터 시작 (2013, 1, 1, 5, 30, 240, Timestamp('2013-01-01 05:30:00'))
# *30분의 값들 >> [240, 240, 240, 240, 238, 239, 239, 236, 241, 239, 239]
#
# 31분 데이터 시작 (2013, 1, 1, 5, 31, 239, Timestamp('2013-01-01 05:31:01'))
# *31분의 값들 >> [239, 239, 240, 236, 236, 238, 239, 240, 242]
#
# 32분 데이터 시작 (2013, 1, 1, 5, 32, 242, Timestamp('2013-01-01 05:32:03'))
# *32분의 값들 >> [242, 238, 236, 241, 236, 240, 237, 236, 236]
#
# 33분 데이터 시작 (2013, 1, 1, 5, 33, 236, Timestamp('2013-01-01 05:33:11'))
# *33분의 값들 >> [236, 239, 240, 240, 240, 239]
#
# 34분 데이터 시작 (2013, 1, 1, 5, 34, 239, Timestamp('2013-01-01 05:34:06'))
# *34분의 값들 >> [239, 240, 239, 240, 238, 240, 239, 238, 239, 238]
#
# 35분 데이터 시작 (2013, 1, 1, 5, 35, 238, Timestamp('2013-01-01 05:35:01'))
# *35분의 값들 >> [238, 239, 239, 237, 237, 240, 237, 239, 240, 236, 241]
#
# 36분 데이터 시작 (2013, 1, 1, 5, 36, 241, Timestamp('2013-01-01 05:36:03'))
# *36분의 값들 >> [241, 239, 236, 239, 240, 238, 240, 237, 240, 237]
#
# 37분 데이터 시작 (2013, 1, 1, 5, 37, 237, Timestamp('2013-01-01 05:37:04'))
# *37분의 값들 >> [237, 238, 239, 240, 237, 240, 240, 239, 239, 240]
#
# 38분 데이터 시작 (2013, 1, 1, 5, 38, 240, Timestamp('2013-01-01 05:38:00'))
# *38분의 값들 >> [240, 239, 238, 238, 240, 241, 240, 240, 241, 238, 239]
#
# 39분 데이터 시작 (2013, 1, 1, 5, 39, 239, Timestamp('2013-01-01 05:39:01'))
# ...
# *32분의 값들 >> [212, 208, 208, 209, 211, 212, 210, 208, 212, 206, 215]
#
# 33분 데이터 시작 (2013, 1, 1, 15, 33, 215, Timestamp('2013-01-01 15:33:03'))
# *33분의 값들 >> [215, 213, 208, 209, 208, 207, 208, 209, 211, 206, 213]
#
# 34분 데이터 시작 (2013, 1, 1, 15, 34, 213, Timestamp('2013-01-01 15:34:05'))
# *34분의 값들 >> [213, 212, 209, 206, 205, 209, 211, 210, 208, 208]
#
# 35분 데이터 시작 (2013, 1, 1, 15, 35, 208, Timestamp('2013-01-01 15:35:00'))
# *35분의 값들 >> [208, 208, 212, 210, 210, 209, 209, 208, 211, 210, 208]
#
# 36분 데이터 시작 (2013, 1, 1, 15, 36, 208, Timestamp('2013-01-01 15:36:01'))
# *36분의 값들 >> [208, 207, 209, 208, 207, 208, 208, 208, 211, 208]
#
# 37분 데이터 시작 (2013, 1, 1, 15, 37, 208, Timestamp('2013-01-01 15:37:03'))
# *37분의 값들 >> [208, 210, 208, 210, 208, 209, 207, 207, 208, 208, 207]
#
# 38분 데이터 시작 (2013, 1, 1, 15, 38, 207, Timestamp('2013-01-01 15:38:04'))
# *38분의 값들 >> [207, 210, 208, 208, 211, 210, 210, 208, 208, 210, 209]
# 39분 데이터 시작 (2013, 1, 1, 15, 39, 209, Timestamp('2013-01-01 15:39:06'))
# *39분의 값들 >> [209, 208, 211, 211, 208, 210, 210, 208, 208, 209]
#
# 40분 데이터 시작 (2013, 1, 1, 15, 40, 209, Timestamp('2013-01-01 15:40:01'))
# *40분의 값들 >> [209, 208, 208, 208, 207, 208, 208, 211, 210, 208, 208]
#
# 41분 데이터 시작 (2013, 1, 1, 15, 41, 208, Timestamp('2013-01-01 15:41:02'))
# *41분의 값들 >> [208, 210, 208, 208, 209, 208, 210, 208, 208]
#
# 42분 데이터 시작 (2013, 1, 1, 15, 42, 208, Timestamp('2013-01-01 15:42:04'))
# *42분의 값들 >> [208, 212, 207, 209, 209, 209, 207, 211, 208, 209, 210]
#
# 43분 데이터 시작 (2013, 1, 1, 15, 43, 210, Timestamp('2013-01-01 15:43:05'))
# *43분의 값들 >> [210, 208, 208, 208, 210, 208, 211, 208, 208, 209]
#
# 44분 데이터 시작 (2013, 1, 1, 15, 44, 209, Timestamp('2013-01-01 15:44:01'))
# *44분의 값들 >> [209, 209, 207, 213, 208, 214, 210, 213, 208, 208, 207]
#
# 45분 데이터 시작 (2013, 1, 1, 15, 45, 207, Timestamp('2013-01-01 15:45:02'))
# *45분의 값들 >> [207, 208, 210, 207, 210, 208, 208, 210, 208, 208]
#
# 46분 데이터 시작 (2013, 1, 1, 15, 46, 208, Timestamp('2013-01-01 15:46:04'))
# *46분의 값들 >> [208, 210, 209, 209, 209, 209, 211, 206, 206, 211, 210]
#
# 47분 데이터 시작 (2013, 1, 1, 15, 47, 210, Timestamp('2013-01-01 15:47:05'))
# *47분의 값들 >> [210, 211, 211, 206, 208, 210, 208, 209, 213]
#
# 48분 데이터 시작 (2013, 1, 1, 15, 48, 213, Timestamp('2013-01-01 15:48:01'))
# *48분의 값들 >> [213, 208, 213, 210, 209, 212, 208, 209, 211, 209, 213]
#
# 49분 데이터 시작 (2013, 1, 1, 15, 49, 213, Timestamp('2013-01-01 15:49:02'))
# *49분의 값들 >> [213, 210, 211, 211, 217]
#
# 50분 데이터 시작 (2013, 1, 1, 15, 50, 217, Timestamp('2013-01-01 15:50:03'))
# *50분의 값들 >> [217, 208, 208, 208, 208, 208, 208, 208, 207, 210]
#
# 51분 데이터 시작 (2013, 1, 1, 15, 51, 210, Timestamp('2013-01-01 15:51:17'))
# *51분의 값들 >> [210, 212, 210, 210]
#
# 52분 데이터 시작 (2013, 1, 1, 15, 52, 210, Timestamp('2013-01-01 15:52:38'))
# *52분의 값들 >> [210, 210, 208, 212, 205]
#
# 53분 데이터 시작 (2013, 1, 1, 15, 53, 205, Timestamp('2013-01-01 15:53:02'))
# *53분의 값들 >> [205, 208, 211, 211, 213]
#
# 54분 데이터 시작 (2013, 1, 1, 15, 54, 213, Timestamp('2013-01-01 15:54:22'))
# *54분의 값들 >> [213, 208, 285, 276, 284, 280, 278, 276]
#
# 55분 데이터 시작 (2013, 1, 1, 15, 55, 276, Timestamp('2013-01-01 15:55:05'))
# *55분의 값들 >> [276, 278, 272, 271, 267, 272, 273, 271, 274, 266]
#
# 56분 데이터 시작 (2013, 1, 1, 15, 56, 266, Timestamp('2013-01-01 15:56:00'))
# *56분의 값들 >> [266, 271, 268, 268, 268, 270, 268, 269, 272, 270, 274]
#
# 57분 데이터 시작 (2013, 1, 1, 15, 57, 274, Timestamp('2013-01-01 15:57:02'))
# *57분의 값들 >> [274, 269, 272, 269, 267, 271, 277, 272, 268, 269, 273]
#
# 58분 데이터 시작 (2013, 1, 1, 15, 58, 273, Timestamp('2013-01-01 15:58:03'))
# *58분의 값들 >> [273, 270, 271, 270, 274, 273, 269, 268, 271, 270, 268]
#
# 59분 데이터 시작 (2013, 1, 1, 15, 59, 268, Timestamp('2013-01-01 15:59:05'))
# *59분의 값들 >> [268, 265, 269, 268, 268, 266, 266, 267, 265, 273]
#
# *15시의 분별 최댓값 60개 >> [2869, 610, 621, 608, 616, 605, 342, 342, 334, 278, 272, 273, 216, 212, 213, 512, 578, 581, 216, 213, 214, 213, 212, 215, 211, 212, 213, 213, 213, 211, 213, 213, 215, 215, 213, 212, 211, 210, 211, 211, 211, 210, 212, 211, 214, 210, 211, 213, 213, 217, 217, 212, 212, 213, 285, 278, 274, 277, 274, 273]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 16, 0, 273, Timestamp('2013-01-01 16:00:00'))
# *0분의 값들 >> [273, 269, 273, 269, 264, 269, 263, 272, 268, 263, 267]
#
# 1분 데이터 시작 (2013, 1, 1, 16, 1, 267, Timestamp('2013-01-01 16:01:02'))
# *1분의 값들 >> [267, 267, 265, 268, 264, 271, 267, 267, 269, 266, 268]
#
# 2분 데이터 시작 (2013, 1, 1, 16, 2, 268, Timestamp('2013-01-01 16:02:03'))
# *2분의 값들 >> [268, 269, 262, 266, 267, 267, 264, 266, 266, 265, 265]
#
# 3분 데이터 시작 (2013, 1, 1, 16, 3, 265, Timestamp('2013-01-01 16:03:05'))
# *3분의 값들 >> [265, 265, 266, 264, 266, 268, 265, 267, 269, 264]
#
# 4분 데이터 시작 (2013, 1, 1, 16, 4, 264, Timestamp('2013-01-01 16:04:00'))
# *4분의 값들 >> [264, 263, 263, 270, 266, 269, 208, 207, 209, 209, 208]
#
# 5분 데이터 시작 (2013, 1, 1, 16, 5, 208, Timestamp('2013-01-01 16:05:01'))
# *5분의 값들 >> [208, 211, 208, 209, 208, 211, 208, 210, 208, 206, 214]
#
# 6분 데이터 시작 (2013, 1, 1, 16, 6, 214, Timestamp('2013-01-01 16:06:03'))
# *6분의 값들 >> [214, 212, 210, 211, 209, 209, 213, 214, 212, 209, 210]
#
# 7분 데이터 시작 (2013, 1, 1, 16, 7, 210, Timestamp('2013-01-01 16:07:04'))
# *7분의 값들 >> [210, 210, 218, 218, 210, 209, 213, 215, 210, 212, 209]
#
# 8분 데이터 시작 (2013, 1, 1, 16, 8, 209, Timestamp('2013-01-01 16:08:06'))
# *8분의 값들 >> [209, 211, 210, 212, 209, 213, 215, 223, 235, 229]
#
# 9분 데이터 시작 (2013, 1, 1, 16, 9, 229, Timestamp('2013-01-01 16:09:01'))
# *9분의 값들 >> [229, 229, 230, 229, 227, 229, 231, 230, 230, 229]
#
# 10분 데이터 시작 (2013, 1, 1, 16, 10, 229, Timestamp('2013-01-01 16:10:03'))
# *10분의 값들 >> [229, 230, 229, 227, 228, 226, 225, 226, 228, 229, 228]
#
# 11분 데이터 시작 (2013, 1, 1, 16, 11, 228, Timestamp('2013-01-01 16:11:04'))
# *11분의 값들 >> [228, 227, 228, 227, 221, 226, 227, 228, 222, 224, 222]
#
# 12분 데이터 시작 (2013, 1, 1, 16, 12, 222, Timestamp('2013-01-01 16:12:06'))
# *12분의 값들 >> [222, 224, 226, 225, 226, 226, 223, 219, 225, 223]
#
# 13분 데이터 시작 (2013, 1, 1, 16, 13, 223, Timestamp('2013-01-01 16:13:01'))
# *13분의 값들 >> [223, 223, 225, 221, 224, 221, 218, 221, 223, 224]
#
# 14분 데이터 시작 (2013, 1, 1, 16, 14, 224, Timestamp('2013-01-01 16:14:02'))
# *14분의 값들 >> [224, 220, 221, 220, 224, 223, 220, 220, 219, 220, 219]
#
# 15분 데이터 시작 (2013, 1, 1, 16, 15, 219, Timestamp('2013-01-01 16:15:04'))
# *15분의 값들 >> [219, 219, 220, 225, 219, 218, 221, 218, 222, 222, 218]
#
# 16분 데이터 시작 (2013, 1, 1, 16, 16, 218, Timestamp('2013-01-01 16:16:05'))
# *16분의 값들 >> [218, 220, 218, 219, 219, 219, 224, 220, 222, 218]
#
# 17분 데이터 시작 (2013, 1, 1, 16, 17, 218, Timestamp('2013-01-01 16:17:01'))
# *17분의 값들 >> [218, 218, 221, 217, 223, 218, 221, 218, 223, 219, 218]
#
# 18분 데이터 시작 (2013, 1, 1, 16, 18, 218, Timestamp('2013-01-01 16:18:02'))
# *18분의 값들 >> [218, 219, 218, 218, 221, 218, 219, 223, 218, 219]
#
# 19분 데이터 시작 (2013, 1, 1, 16, 19, 219, Timestamp('2013-01-01 16:19:04'))
# *19분의 값들 >> [219, 216, 219, 216, 220, 217, 219, 216, 217, 217]
#
# 20분 데이터 시작 (2013, 1, 1, 16, 20, 217, Timestamp('2013-01-01 16:20:00'))
# *20분의 값들 >> [217, 217, 220, 218, 215, 217, 219, 218, 218, 218, 217]
#
# 21분 데이터 시작 (2013, 1, 1, 16, 21, 217, Timestamp('2013-01-01 16:21:01'))
# *21분의 값들 >> [217, 218, 218, 218, 218, 217, 215, 218, 218, 218, 216]
#
# 22분 데이터 시작 (2013, 1, 1, 16, 22, 216, Timestamp('2013-01-01 16:22:02'))
# *22분의 값들 >> [216, 216, 218, 217, 219, 216, 218, 215, 218, 216, 215]
#
# 23분 데이터 시작 (2013, 1, 1, 16, 23, 215, Timestamp('2013-01-01 16:23:04'))
# *23분의 값들 >> [215, 215, 216, 215, 217, 218, 216, 218, 216, 215]
#
# 24분 데이터 시작 (2013, 1, 1, 16, 24, 215, Timestamp('2013-01-01 16:24:05'))
# *24분의 값들 >> [215, 216, 216, 218, 217, 217, 215, 218, 218, 214]
#
# 25분 데이터 시작 (2013, 1, 1, 16, 25, 214, Timestamp('2013-01-01 16:25:01'))
# *25분의 값들 >> [214, 218, 210, 217, 217, 216, 216, 217, 216, 214, 218]
#
# 26분 데이터 시작 (2013, 1, 1, 16, 26, 218, Timestamp('2013-01-01 16:26:03'))
# *26분의 값들 >> [218, 216, 220, 219, 218, 219, 215, 218, 220, 215, 215]
#
# 27분 데이터 시작 (2013, 1, 1, 16, 27, 215, Timestamp('2013-01-01 16:27:04'))
# *27분의 값들 >> [215, 215, 216, 218, 218, 216, 215, 218, 218, 217, 217]
#
# 28분 데이터 시작 (2013, 1, 1, 16, 28, 217, Timestamp('2013-01-01 16:28:11'))
# *28분의 값들 >> [217, 215, 216, 218, 215, 215, 216, 213, 216]
#
# 29분 데이터 시작 (2013, 1, 1, 16, 29, 216, Timestamp('2013-01-01 16:29:01'))
# *29분의 값들 >> [216, 211, 217, 215, 217, 213, 217, 214, 215, 214, 216]
#
# 30분 데이터 시작 (2013, 1, 1, 16, 30, 216, Timestamp('2013-01-01 16:30:02'))
# *30분의 값들 >> [216, 218, 214, 218, 217, 218, 211, 211]
#
# 31분 데이터 시작 (2013, 1, 1, 16, 31, 211, Timestamp('2013-01-01 16:31:16'))
# *31분의 값들 >> [211, 218, 214, 211, 218, 214]
#
# 32분 데이터 시작 (2013, 1, 1, 16, 32, 214, Timestamp('2013-01-01 16:32:05'))
# *32분의 값들 >> [214, 213, 215, 218, 214, 212, 212, 217, 217, 218]
#
# 33분 데이터 시작 (2013, 1, 1, 16, 33, 218, Timestamp('2013-01-01 16:33:00'))
# *33분의 값들 >> [218, 294, 284, 272, 271, 274, 269, 271, 276, 270]
#
# 34분 데이터 시작 (2013, 1, 1, 16, 34, 270, Timestamp('2013-01-01 16:34:02'))
# *34분의 값들 >> [270, 270, 273, 270, 270, 271, 273, 272, 272, 274, 273]
#
# 35분 데이터 시작 (2013, 1, 1, 16, 35, 273, Timestamp('2013-01-01 16:35:03'))
# *35분의 값들 >> [273, 277, 272, 272, 274, 272, 278, 279, 281, 277, 275]
#
# 36분 데이터 시작 (2013, 1, 1, 16, 36, 275, Timestamp('2013-01-01 16:36:05'))
# *36분의 값들 >> [275, 277, 273, 276, 269, 268, 272, 267, 270, 272]
#
# 37분 데이터 시작 (2013, 1, 1, 16, 37, 272, Timestamp('2013-01-01 16:37:01'))
# *37분의 값들 >> [272, 271, 269, 265, 265, 265, 269, 270, 267, 264]
#
# 38분 데이터 시작 (2013, 1, 1, 16, 38, 264, Timestamp('2013-01-01 16:38:02'))
# *38분의 값들 >> [264, 267, 264, 267, 263, 263, 258, 260, 262, 252, 259]
#
# 39분 데이터 시작 (2013, 1, 1, 16, 39, 259, Timestamp('2013-01-01 16:39:03'))
# *39분의 값들 >> [259, 253, 254, 250, 250, 249, 250, 250, 249, 252, 249]
#
# 40분 데이터 시작 (2013, 1, 1, 16, 40, 249, Timestamp('2013-01-01 16:40:05'))
# *40분의 값들 >> [249, 249, 252, 253, 249, 249, 252, 255, 251, 249]
#
# 41분 데이터 시작 (2013, 1, 1, 16, 41, 249, Timestamp('2013-01-01 16:41:00'))
# *41분의 값들 >> [249, 253, 251, 250, 283, 278, 277, 269, 271, 269, 268]
#
# 42분 데이터 시작 (2013, 1, 1, 16, 42, 268, Timestamp('2013-01-01 16:42:02'))
# *42분의 값들 >> [268, 266, 263, 270, 263, 270, 265, 268, 262, 266]
#
# 43분 데이터 시작 (2013, 1, 1, 16, 43, 266, Timestamp('2013-01-01 16:43:03'))
# *43분의 값들 >> [266, 268, 258, 257, 254, 262, 257, 250, 248, 251, 249]
#
# 44분 데이터 시작 (2013, 1, 1, 16, 44, 249, Timestamp('2013-01-01 16:44:05'))
# *44분의 값들 >> [249, 249, 253, 285, 276, 354, 351, 343, 343, 340]
#
# 45분 데이터 시작 (2013, 1, 1, 16, 45, 340, Timestamp('2013-01-01 16:45:01'))
# *45분의 값들 >> [340, 341, 347, 340, 330, 330, 332, 332, 319, 325, 316]
#
# 46분 데이터 시작 (2013, 1, 1, 16, 46, 316, Timestamp('2013-01-01 16:46:02'))
# *46분의 값들 >> [316, 316, 323, 324, 315, 314, 321, 346, 344, 337, 334]
#
# 47분 데이터 시작 (2013, 1, 1, 16, 47, 334, Timestamp('2013-01-01 16:47:16'))
# *47분의 값들 >> [334, 337, 339, 336, 327, 326, 329, 323, 322]
#
# 48분 데이터 시작 (2013, 1, 1, 16, 48, 322, Timestamp('2013-01-01 16:48:05'))
# *48분의 값들 >> [322, 327, 324, 321, 319, 327, 322, 326, 321, 326]
#
# 49분 데이터 시작 (2013, 1, 1, 16, 49, 326, Timestamp('2013-01-01 16:49:01'))
# *49분의 값들 >> [326, 324, 326, 321, 321, 327, 328, 323, 320, 321, 323]
#
# 50분 데이터 시작 (2013, 1, 1, 16, 50, 323, Timestamp('2013-01-01 16:50:02'))
# *50분의 값들 >> [323, 324, 324, 321, 326, 321, 352, 345, 340, 340]
#
# 51분 데이터 시작 (2013, 1, 1, 16, 51, 340, Timestamp('2013-01-01 16:51:04'))
# *51분의 값들 >> [340, 341, 341, 344, 341, 341, 342, 328, 329, 335, 328]
#
# 52분 데이터 시작 (2013, 1, 1, 16, 52, 328, Timestamp('2013-01-01 16:52:05'))
# *52분의 값들 >> [328, 326, 325, 325, 321, 319, 322, 327, 322, 323]
#
# 53분 데이터 시작 (2013, 1, 1, 16, 53, 323, Timestamp('2013-01-01 16:53:01'))
# *53분의 값들 >> [323, 318, 322, 343, 345, 338, 346, 340, 342, 336, 342]
#
# 54분 데이터 시작 (2013, 1, 1, 16, 54, 342, Timestamp('2013-01-01 16:54:02'))
# *54분의 값들 >> [342, 333, 326, 333, 334, 331, 321, 320, 327, 321, 328]
#
# 55분 데이터 시작 (2013, 1, 1, 16, 55, 328, Timestamp('2013-01-01 16:55:03'))
# *55분의 값들 >> [328, 321, 326, 325, 327, 323, 319, 320, 320, 320, 345]
#
# 56분 데이터 시작 (2013, 1, 1, 16, 56, 345, Timestamp('2013-01-01 16:56:05'))
# *56분의 값들 >> [345, 349, 341, 339, 341, 333, 336, 341, 328, 328]
#
# 57분 데이터 시작 (2013, 1, 1, 16, 57, 328, Timestamp('2013-01-01 16:57:00'))
# *57분의 값들 >> [328, 337, 333, 324, 320, 320, 319, 319, 324, 319]
#
# 58분 데이터 시작 (2013, 1, 1, 16, 58, 319, Timestamp('2013-01-01 16:58:02'))
# *58분의 값들 >> [319, 320, 316, 320, 320, 325, 324, 319, 320, 324, 325]
#
# 59분 데이터 시작 (2013, 1, 1, 16, 59, 325, Timestamp('2013-01-01 16:59:03'))
# *59분의 값들 >> [325, 323, 346, 343, 348, 345, 339, 333, 337, 339, 329]
#
# *16시의 분별 최댓값 60개 >> [273, 271, 269, 269, 270, 214, 214, 218, 235, 231, 230, 228, 226, 225, 224, 225, 224, 223, 223, 220, 220, 218, 219, 218, 218, 218, 220, 218, 218, 217, 218, 218, 218, 294, 274, 281, 277, 272, 267, 259, 255, 283, 270, 268, 354, 347, 346, 339, 327, 328, 352, 344, 328, 346, 342, 345, 349, 337, 325, 348]
#
# 한시간 단위 시작
# 0분 데이터 시작 (2013, 1, 1, 17, 0, 329, Timestamp('2013-01-01 17:00:05'))
# *0분의 값들 >> [329, 327, 329, 328, 322, 323, 322, 322, 328, 321]
#
# 1분 데이터 시작 (2013, 1, 1, 17, 1, 321, Timestamp('2013-01-01 17:01:00'))
# *1분의 값들 >> [321, 322, 321, 321, 319, 321, 319, 322, 322, 320]
#
# 2분 데이터 시작 (2013, 1, 1, 17, 2, 320, Timestamp('2013-01-01 17:02:02'))
# *2분의 값들 >> [320, 315, 324, 320, 321, 322, 341, 345, 341, 315, 320]
# 3분 데이터 시작 (2013, 1, 1, 17, 3, 320, Timestamp('2013-01-01 17:03:04'))
# *3분의 값들 >> [320, 321, 318, 313, 307, 308, 312, 312, 309, 311, 313]
#
# 4분 데이터 시작 (2013, 1, 1, 17, 4, 313, Timestamp('2013-01-01 17:04:05'))
# *4분의 값들 >> [313, 308, 312, 313, 311, 311, 305, 314, 310, 307]
#
# 5분 데이터 시작 (2013, 1, 1, 17, 5, 307, Timestamp('2013-01-01 17:05:00'))
# *5분의 값들 >> [307, 308, 311, 313, 309, 307, 309, 306, 312, 269, 275]
#
# 6분 데이터 시작 (2013, 1, 1, 17, 6, 275, Timestamp('2013-01-01 17:06:02'))
# *6분의 값들 >> [275, 270, 271, 269, 273, 273, 270, 272, 269, 272]
#
# 7분 데이터 시작 (2013, 1, 1, 17, 7, 272, Timestamp('2013-01-01 17:07:04'))
# *7분의 값들 >> [272, 269, 272, 272, 270, 273, 266, 269, 268, 272, 268]
#
# 8분 데이터 시작 (2013, 1, 1, 17, 8, 268, Timestamp('2013-01-01 17:08:05'))
# *8분의 값들 >> [268, 276, 272, 276, 273, 272, 273, 275, 269, 275]
#
# 9분 데이터 시작 (2013, 1, 1, 17, 9, 275, Timestamp('2013-01-01 17:09:00'))
# *9분의 값들 >> [275, 269, 273, 269, 273, 272, 268, 275, 271, 270, 271]
#
# 10분 데이터 시작 (2013, 1, 1, 17, 10, 271, Timestamp('2013-01-01 17:10:02'))
# *10분의 값들 >> [271, 273, 272, 272, 276, 273, 276, 274, 277, 270]
#
# 11분 데이터 시작 (2013, 1, 1, 17, 11, 270, Timestamp('2013-01-01 17:11:04'))
# *11분의 값들 >> [270, 270, 271, 279, 276, 271, 277, 275, 273, 269, 275]
#
# 12분 데이터 시작 (2013, 1, 1, 17, 12, 275, Timestamp('2013-01-01 17:12:05'))
# *12분의 값들 >> [275, 275, 277, 285, 288, 287, 285, 287, 285, 293]
#
# 13분 데이터 시작 (2013, 1, 1, 17, 13, 293, Timestamp('2013-01-01 17:13:01'))
# *13분의 값들 >> [293, 686, 705, 708, 699, 708, 699, 703, 695, 686, 681]
#
# 14분 데이터 시작 (2013, 1, 1, 17, 14, 681, Timestamp('2013-01-01 17:14:02'))
# *14분의 값들 >> [681, 699, 692, 669, 692, 687, 1209, 2297, 2117, 2293, 2106]
#
# 15분 데이터 시작 (2013, 1, 1, 17, 15, 2106, Timestamp('2013-01-01 17:15:04'))
# *15분의 값들 >> [2106, 2105, 2103, 2258, 2287, 2108, 2102, 2155, 2143, 2141]
#
# 16분 데이터 시작 (2013, 1, 1, 17, 16, 2141, Timestamp('2013-01-01 17:16:03'))
# *16분의 값들 >> [2141, 2154, 2074, 2122, 2097, 2104, 2078, 2101, 2116, 2145, 2145]
#
# 17분 데이터 시작 (2013, 1, 1, 17, 17, 2145, Timestamp('2013-01-01 17:17:02'))
# *17분의 값들 >> [2145, 2130, 2129, 2144, 2148, 2123, 2090, 2119, 2126, 2136, 2142]
#
# 18분 데이터 시작 (2013, 1, 1, 17, 18, 2142, Timestamp('2013-01-01 17:18:02'))
# *18분의 값들 >> [2142, 2120, 2070, 2159, 2143, 2081, 2134, 1271, 2081, 2201, 2109]
#
# 19분 데이터 시작 (2013, 1, 1, 17, 19, 2109, Timestamp('2013-01-01 17:19:01'))
# *19분의 값들 >> [2109, 2093, 2096, 2172, 2093, 2143, 2182, 2057, 2092, 2056, 2070]
#
# 20분 데이터 시작 (2013, 1, 1, 17, 20, 2070, Timestamp('2013-01-01 17:20:00'))
# *20분의 값들 >> [2070, 2092, 2070, 736, 705, 709, 718, 717, 717]
#
# 21분 데이터 시작 (2013, 1, 1, 17, 21, 717, Timestamp('2013-01-01 17:21:01'))
# *21분의 값들 >> [717, 726, 709, 722, 2054, 2057, 2054, 2063, 2057, 2061, 2057]
#
# 22분 데이터 시작 (2013, 1, 1, 17, 22, 2057, Timestamp('2013-01-01 17:22:02'))
# *22분의 값들 >> [2057, 2068, 2058, 2060, 2061, 2048, 2057, 2031, 749]
#
# 23분 데이터 시작 (2013, 1, 1, 17, 23, 749, Timestamp('2013-01-01 17:23:14'))
# *23분의 값들 >> [749, 756, 730]
#
# 25분 데이터 시작 (2013, 1, 1, 17, 25, 737, Timestamp('2013-01-01 17:25:23'))
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ### 아래가 원본

# %%
import csv
import time

month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}

# 1. 
i = 431369#431369가 맞음
print('Running!', '\n'*4)


# 2. 
while(i < 20284837):
    try:
        list1 = ch1_date.loc[i].values.tolist()
        date = list1[1]
        y1 = date.year
        M1 = date.month
        d1 = date.day
        H1 = date.hour 
        n = 0 

        # 3. 
        while(H1 < 24):
            H0 = 0 

            # 3'. 
            while(H0 < 24):
                watt_list=[]
                h = date.hour

                # 3.1. 
                if(H1 == H0):

                    # 3.1'. 
                    while(h < h+1):
                        n=n+1
                        list2 = ch1_date.loc[i].values.tolist()
                        date = list2[1]
                        watt = list2[2]
                        y = date.year
                        M = date.month
                        d = date.day
                        h = date.hour
                        m = date.minute
                        s = date.second

                        j=h-H1

                        # 3.1'.1. 
                        if(j==0):
                            watt_list.append(watt)
                            i = i+1
                            """
                            여기서 1시간 내의 과정이 이뤄지니 그안에서 5분이든 10분이든 처리를 해줘야 함.
                            """

                        # 3.1'.2.
                        elif (j==1):
                            max_watt = max(watt_list)

                            hourly_date2 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                            hourly_date5 = '{0} {1} {2}'.format(y, M, d) 
                            hourly_list = []
                            hourly_list.append(hourly_date2)
                            """
                            밑에 있는 hourly_list는 1시간 단위로 max_watt의 값을 가져오는 것이니 여기서도 주기에 맞게 처리를 해줘야함
                            
                            밑에 있는 max_watt 등장 부분 모두 마찬가지.
                            """
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            H1 = H1+1 
                            H0 = H0+1
                            break

                        # 3.1'.3. 
                        elif(d1+1==d and h ==0 and H1 ==23):
                            d=d-1
                            h=h+24

                            max_watt = max(watt_list)

                            hourly_date3 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H1)
                            hourly_list = []
                            hourly_list.append(hourly_date3)
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            H1 = H1+1 
                            H0 = H0+1                   
                            break

                        # 3.1'.4.
                        elif (n>600):
                            list(hourly_date5)
                            listed = hourly_date5.split()
                            y4 = listed[0]
                            M4 = listed[1]
                            d4 = listed[2]

                            max_watt = max(watt_list)

                            hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, H1)
                            hourly_list = []
                            hourly_list.append(hourly_date)
                            hourly_list.append(max_watt)

                            with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                writer = csv.writer(file)
                                writer.writerow(hourly_list)       

                            # 3.1'.4.1. 
                            if(d1==d):
                                jc=j

                                while(jc>1):
                                    h=h+1
                                    hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, h-j)
                                    hourly_list = []
                                    hourly_list.append(hourly_date)
                                    hourly_list.append('Null')

                                    with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                        writer = csv.writer(file)
                                        writer.writerow(hourly_list)  

                                    jc=jc-1
                                    H1 = H1+1
                                    H0 = H0+1

                                H1 = H1+1
                                H0 = H0+1

                            # 3.1'.4.2.
                            if(d1!=d):

                                while(H1<23):
                                    hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, d4, H1+1)
                                    hourly_list = []
                                    hourly_list.append(hourly_date)
                                    hourly_list.append('Null')

                                    with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                        writer = csv.writer(file)
                                        writer.writerow(hourly_list)  

                                    H1 = H1+1
                                    H0 = H0+1

                                H1 = H1+1
                                H0 = H0+1

                                # 3.1'.4.2.1. 
                                if(int(d4)+1 != d):
                                    D = int(d4)+1 

                                    # 3.1'.4.2.1.1. 
                                    if(int(M) == int(M4)):
                                        while(D<d):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, D, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D=D+1

                                    # 3.1'.4.2.1.2.
                                    if(int(M) != int(M4)):
                                        while(D<=month[int(M4)]):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M4, D, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M4)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D=D+1

                                        D2 = 1
                                        while(D2 < d):
                                            for x in range (0,24):
                                                hourly_date = '{0}년 {1}월 {2}일 - {3}시'.format(y4, M, D2, x)
                                                hourly_list = []
                                                hourly_list.append(hourly_date)
                                                hourly_list.append('Null')

                                                with open("./Electirc_Data_CSV/"+str(y4)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                                                    writer = csv.writer(file)
                                                    writer.writerow(hourly_list)  

                                            D2 = D2+1

                            break


                # 3.2. 
                if(H1 != H0):
                    list3 = ch1_date.loc[i].values.tolist()
                    date = list3[1]
                    watt = list3[2]
                    y = date.year
                    M = date.month
                    d = date.day
                    h = date.hour
                    m = date.minute
                    s = date.second

                    j=h-H1           

                    hourly_date3121 = '{0}년 {1}월 {2}일 - {3}시'.format(y, M, d, H0)
                    hourly_list3121 = []
                    hourly_list3121.append(hourly_date3121)
                    hourly_list3121.append('Null')

                    with open("./Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch1_Electric_Data.csv", 'a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow(hourly_list3121)       

                    h = h+1
                    H0 = H0+1

                    if (H0 ==23 and h!=24 and H1!=23):
                                break

                    if(h==24 and H0==23 and H1==23):
                        hourly_date3121 = '{0}년 {1}월 {2}일 - 23시'.format(y, M, d)
                        hourly_list3121 = []
                        hourly_list3121.append(hourly_date3121)
                        hourly_list3121.append('Null')

                        with open("./Ch"+str(Total_num)+"_Electirc_Data_CSV/"+str(y)+'_'+str(M)+'_'+"House1_Ch"+str(Total_num)+"_Electric_Data.csv", 'a', newline='') as file:
                            writer = csv.writer(file)
                            writer.writerow(hourly_list3121)

            break
    except:
        pass
    
print('Job Done!!')
time.sleep(5)
